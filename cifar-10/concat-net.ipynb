# %% [markdown]
# # Concat-net

# %%
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse

from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass

# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}
# Out:
# E: Package 'python-software-properties' has no installation candidate
# Selecting previously unselected package libfuse2:amd64.
# (Reading database ... 22280 files and directories currently installed.)
# Preparing to unpack .../libfuse2_2.9.7-1ubuntu1_amd64.deb ...
# Unpacking libfuse2:amd64 (2.9.7-1ubuntu1) ...
# Selecting previously unselected package fuse.
# Preparing to unpack .../fuse_2.9.7-1ubuntu1_amd64.deb ...
# Unpacking fuse (2.9.7-1ubuntu1) ...
# Selecting previously unselected package google-drive-ocamlfuse.
# Preparing to unpack .../google-drive-ocamlfuse_0.7.0-0ubuntu1~ubuntu18.04.1_amd64.deb ...
# Unpacking google-drive-ocamlfuse (0.7.0-0ubuntu1~ubuntu18.04.1) ...
# Setting up libfuse2:amd64 (2.9.7-1ubuntu1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...
# Setting up fuse (2.9.7-1ubuntu1) ...
# Setting up google-drive-ocamlfuse (0.7.0-0ubuntu1~ubuntu18.04.1) ...
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# ··········
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# Please enter the verification code: Access token retrieved correctly.

# %%
# !mkdir -p drive
# !google-drive-ocamlfuse drive

# %% [markdown]
# ## Loading the data

# %%
from time import time
import os
import gzip
import numpy as np
from keras.utils import np_utils
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

from keras.datasets import cifar10
# Out:
# Using TensorFlow backend.

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, 
                                                  test_size=0.2, 
                                                  random_state=1974)

# %%
train_features = X_train.reshape(X_train.shape[0], 32, 32, 3)/255
vali_features = X_val.reshape(X_val.shape[0], 32, 32, 3)/255
test_features = X_test.reshape(X_test.shape[0], 32, 32, 3)/255

y_train_cat = np_utils.to_categorical(y_train)
y_val_cat = np_utils.to_categorical(y_val)
y_test_cat = np_utils.to_categorical(y_test)

# %% [markdown]
# ## Defining coarse labels

# %%
dict_coarse1 = {0: 0,
              1: 0,
              2: 1,
              3: 1,
              4: 1,
              5: 1,
              6: 1,
              7: 1,
              8: 0,
              9: 0}

dict_coarse2 = {0: 0,
              1: 1,
              2: 3,
              3: 4,
              4: 6,
              5: 4,
              6: 5,
              7: 6,
              8: 2,
              9: 1}

y_train_coarse1 = np.vectorize(dict_coarse1.get)(y_train)
y_val_coarse1 = np.vectorize(dict_coarse1.get)(y_val)
y_test_coarse1 = np.vectorize(dict_coarse1.get)(y_test)

y_train_coarse2 = np.vectorize(dict_coarse2.get)(y_train)
y_val_coarse2 = np.vectorize(dict_coarse2.get)(y_val)
y_test_coarse2 = np.vectorize(dict_coarse2.get)(y_test)

y_train_c_cat1 = np_utils.to_categorical(y_train_coarse1)
y_val_c_cat1 = np_utils.to_categorical(y_val_coarse1)
y_test_c_cat1 = np_utils.to_categorical(y_test_coarse1)

y_train_c_cat2 = np_utils.to_categorical(y_train_coarse2)
y_val_c_cat2 = np_utils.to_categorical(y_val_coarse2)
y_test_c_cat2 = np_utils.to_categorical(y_test_coarse2)

# %% [markdown]
# ## Training the model

# %%
import keras
from keras.models import Model
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D, Input
from keras import optimizers
from keras.callbacks import TensorBoard, ReduceLROnPlateau, CSVLogger
from keras.layers.normalization import BatchNormalization
from keras import backend as K

# %%
class TimingCallback(keras.callbacks.Callback):
  """Callback that saves the time elapsed of each epoch to the log.
  """  
  def on_epoch_begin(self, epoch, logs={}):
    self.starttime=time()
  def on_epoch_end(self, epoch, logs={}):
    logs['time_elapsed'] = (time()-self.starttime)

# %%
class LossWeightsModifier3Vars(keras.callbacks.Callback):
  """Callback that modifies the loss weights on certain epochs.
    # Arguments
        alpha: coeficient for the coarser class.
        beta: coeficient for the second level coarse class.
        gamma: coeficient for the fine class.
  """  
  def __init__(self, alpha, beta, gamma):
    self.alpha = alpha
    self.beta = beta
    self.gamma = gamma
    
  def on_epoch_end(self, epoch, logs={}):

    if epoch == 4:
      K.set_value(self.alpha, 0)
      K.set_value(self.beta, 0.8)
      K.set_value(self.gamma, 0.2)
      print('Changing loss weights to: coarse1 = {}, coarse2 = {}, fine = {}'.format(K.eval(self.alpha), K.eval(self.beta), K.eval(self.gamma)))
    
    if epoch == 14:
      K.set_value(self.alpha, 0)
      K.set_value(self.beta, 0.4)
      K.set_value(self.gamma, 0.6)  
      print('Changing loss weights to: coarse1 = {}, coarse2 = {}, fine = {}'.format(K.eval(self.alpha), K.eval(self.beta), K.eval(self.gamma)))
  
    if epoch == 21:
      K.set_value(self.alpha, 0)
      K.set_value(self.beta, 0)
      K.set_value(self.gamma, 1)  
      print('Changing loss weights to: coarse1 = {}, coarse2 = {}, fine = {}'.format(K.eval(self.alpha), K.eval(self.beta), K.eval(self.gamma)))
  
    logs['alpha'] = K.eval(self.alpha)
    logs['beta'] = K.eval(self.beta) 
    logs['gamma'] = K.eval(self.gamma)

# %%
img_rows, img_cols = 32, 32
input_shape = (img_rows, img_cols, 3)

num_classes_coarse1 = 2
num_classes_coarse2 = 7
num_classes_fine = 10

img_input = Input(shape=input_shape, name='input')


x = Conv2D(128, (3, 3), activation='relu', name='block1_conv1', padding='same')(img_input)

x = Conv2D(128, (3, 3), activation='relu', name='block1_conv2', padding='same')(x)
x = MaxPooling2D((2, 2), name='block2_pool')(x)

#---- coarse branch 1 ----
coarse1 = Flatten(name='c1_flatten')(x)
coarse1 = Dense(64, name='c1_fc_1')(coarse1)
coarse1 = BatchNormalization()(coarse1)
coarse1 = Activation('relu')(coarse1)
coarse1 = Dropout(0.5)(coarse1)

coarse1 = Dense(64, name='c1_fc_2')(coarse1)
coarse1 = BatchNormalization()(coarse1)
coarse1 = Activation('relu')(coarse1)
coarse1 = Dropout(0.5)(coarse1)

coarse_pred1 = Dense(num_classes_coarse1, activation='softmax', name='predictions_coarse1')(coarse1)

x = Conv2D(128, (3, 3), activation='relu', name='block1_conv3', padding='same')(x)
x = MaxPooling2D((2, 2), name='block3_pool')(x)

#---- coarse branch 2 ----
coarse2 = Flatten(name='c2_flatten')(x)
coarse2 = Dense(512, name='c2_fc_1')(coarse2)
coarse2 = BatchNormalization()(coarse2)
coarse2 = Activation('relu')(coarse2)
coarse2 = Dropout(0.5)(coarse2)

coarse2 = Dense(512, name='c2_fc_2')(coarse2)
coarse2 = BatchNormalization()(coarse2)
coarse2 = Activation('relu')(coarse2)
coarse2 = Dropout(0.5)(coarse2)

coarse2 = keras.layers.concatenate([coarse2, coarse1])

coarse_pred2 = Dense(num_classes_coarse2, activation='softmax', name='predictions_coarse2')(coarse2)


x = Flatten(name='flatten')(x)
x = Dense(512, name='fc_1')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = Dropout(0.5)(x)

x = Dense(512, name='fc_2')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = Dropout(0.5)(x)

x = keras.layers.concatenate([x, coarse2])

fine_pred = Dense(num_classes_fine, activation='softmax', name='predictions_fine')(x)

# %%
model = Model(inputs=img_input, outputs= [coarse_pred1, coarse_pred2, fine_pred], name='concat_net')

model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 32, 32, 128)  3584        input[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 32, 32, 128)  147584      block1_conv1[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 16, 16, 128)  0           block1_conv2[0][0]
# __________________________________________________________________________________________________
# block1_conv3 (Conv2D)           (None, 16, 16, 128)  147584      block2_pool[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 8, 8, 128)    0           block1_conv3[0][0]
# __________________________________________________________________________________________________
# c1_flatten (Flatten)            (None, 32768)        0           block2_pool[0][0]
# __________________________________________________________________________________________________
# c2_flatten (Flatten)            (None, 8192)         0           block3_pool[0][0]
# __________________________________________________________________________________________________
# c1_fc_1 (Dense)                 (None, 64)           2097216     c1_flatten[0][0]
# __________________________________________________________________________________________________
# c2_fc_1 (Dense)                 (None, 512)          4194816     c2_flatten[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 8192)         0           block3_pool[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 64)           256         c1_fc_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 512)          2048        c2_fc_1[0][0]
# __________________________________________________________________________________________________
# fc_1 (Dense)                    (None, 512)          4194816     flatten[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 64)           0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 512)          0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 512)          2048        fc_1[0][0]
# __________________________________________________________________________________________________
# dropout_19 (Dropout)            (None, 64)           0           activation_19[0][0]
# __________________________________________________________________________________________________
# dropout_21 (Dropout)            (None, 512)          0           activation_21[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 512)          0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# c1_fc_2 (Dense)                 (None, 64)           4160        dropout_19[0][0]
# __________________________________________________________________________________________________
# c2_fc_2 (Dense)                 (None, 512)          262656      dropout_21[0][0]
# __________________________________________________________________________________________________
# dropout_23 (Dropout)            (None, 512)          0           activation_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 64)           256         c1_fc_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 512)          2048        c2_fc_2[0][0]
# __________________________________________________________________________________________________
# fc_2 (Dense)                    (None, 512)          262656      dropout_23[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 64)           0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 512)          0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 512)          2048        fc_2[0][0]
# __________________________________________________________________________________________________
# dropout_20 (Dropout)            (None, 64)           0           activation_20[0][0]
# __________________________________________________________________________________________________
# dropout_22 (Dropout)            (None, 512)          0           activation_22[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 512)          0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 576)          0           dropout_22[0][0]
#                                                                  dropout_20[0][0]
# __________________________________________________________________________________________________
# dropout_24 (Dropout)            (None, 512)          0           activation_24[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 1088)         0           dropout_24[0][0]
#                                                                  concatenate_7[0][0]
# __________________________________________________________________________________________________
# predictions_coarse1 (Dense)     (None, 2)            130         dropout_20[0][0]
# __________________________________________________________________________________________________
# predictions_coarse2 (Dense)     (None, 7)            4039        concatenate_7[0][0]
# __________________________________________________________________________________________________
# predictions_fine (Dense)        (None, 10)           10890       concatenate_8[0][0]
# ==================================================================================================
# Total params: 11,338,835
# Trainable params: 11,334,483
# Non-trainable params: 4,352
# __________________________________________________________________________________________________

# %%
alpha = K.variable(value=0.9, dtype="float32", name="alpha") 
beta = K.variable(value=0.1, dtype="float32", name="beta") 
gamma = K.variable(value=0, dtype="float32", name="gamma") 

adam = optimizers.Adam(lr=0.00025)

model.compile(loss='categorical_crossentropy', 
              optimizer=adam,
              loss_weights=[alpha, beta, gamma],
              metrics=['accuracy'])

# %%
clr_cb = ReduceLROnPlateau(monitor='val_predictions_fine_loss', factor=0.5, patience=10, verbose=1)
time_cb = TimingCallback()
change_lw = LossWeightsModifier3Vars(alpha, beta, gamma)
csv_cb = CSVLogger('drive/TCC-ITAU/cifar-10/training-data/concat-net/concat-net.csv', separator=',', append=False)


cbks = [clr_cb, time_cb, change_lw, csv_cb]

# %%
epochs = 50
start_time = time()
training = model.fit(train_features, [y_train_c_cat1, y_train_c_cat2, y_train_cat],
                     validation_data=(vali_features, [y_val_c_cat1, y_val_c_cat2, y_val_cat]),
                     epochs=epochs,
                     batch_size=256, 
                     callbacks=cbks,
                     verbose=1)
training_time = time() - start_time
# Out:
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/50
# 40000/40000 [==============================] - 32s 794us/step - loss: 0.4939 - predictions_coarse1_loss: 0.3884 - predictions_coarse2_loss: 1.4440 - predictions_fine_loss: 3.0852 - predictions_coarse1_acc: 0.8359 - predictions_coarse2_acc: 0.4878 - predictions_fine_acc: 0.0951 - val_loss: 0.3620 - val_predictions_coarse1_loss: 0.2929 - val_predictions_coarse2_loss: 0.9837 - val_predictions_fine_loss: 2.6150 - val_predictions_coarse1_acc: 0.8783 - val_predictions_coarse2_acc: 0.6312 - val_predictions_fine_acc: 0.0835
# Epoch 2/50
# 40000/40000 [==============================] - 27s 682us/step - loss: 0
50
# 40000/40000 [==============================] - 27s 681us/step - loss: 0.0074 - predictions_coarse1_loss: 0.1055 - predictions_coarse2_loss: 0.0126 - predictions_fine_loss: 0.0074 - predictions_coarse1_acc: 0.9613 - predictions_coarse2_acc: 0.9971 - predictions_fine_acc: 0.9981 - val_loss: 1.0791 - val_predictions_coarse1_loss: 0.1664 - val_predictions_coarse2_loss: 0.6892 - val_predictions_fine_loss: 1.0791 - val_predictions_coarse1_acc: 0.9397 - val_predictions_coarse2_acc: 0.8355 - val_predictions_fine_acc: 0.7838
# Epoch 31/50
# 40000/40000 [==============================] - 27s 681us/step - loss: 0.0066 - predictions_coarse1_loss: 0.1055 - predictions_coarse2_loss: 0.0110 - predictions_fine_loss: 0.0066 - predictions_coarse1_acc: 0.9616 - predictions_coarse2_acc: 0.9979 - predictions_fine_acc: 0.9984 - val_loss: 1.1021 - val_predictions_coarse1_loss: 0.1645 - val_predictions_coarse2_loss: 0.7083 - val_predictions_fine_loss: 1.1021 - val_predictions_coarse1_acc: 0.9397 - val_predictions_coarse2_acc: 0.8326 - val_predictions_fine_acc: 0.7816
# Epoch 32/50
# 40000/40000 [==============================] - 27s 681us/step - loss: 0.0062 - predictions_coarse1_loss: 0.1006 - predictions_coarse2_loss: 0.0115 - predictions_fine_loss: 0.0062 - predictions_coarse1_acc: 0.9637 - predictions_coarse2_acc: 0.9973 - predictions_fine_acc: 0.9985 - val_loss: 1.1058 - val_predictions_coarse1_loss: 0.1626 - val_predictions_coarse2_loss: 0.7083 - val_predictions_fine_loss: 1.1058 - val_predictions_coarse1_acc: 0.9395 - val_predictions_coarse2_acc: 0.8368 - val_predictions_fine_acc: 0.7836
# Epoch 33/50
# 40000/40000 [==============================] - 27s 681us/step - loss: 0.0055 - predictions_coarse1_loss: 0.1034 - predictions_coarse2_loss: 0.0107 - predictions_fine_loss: 0.0055 - predictions_coarse1_acc: 0.9624 - predictions_coarse2_acc: 0.9976 - predictions_fine_acc: 0.9987 - val_loss: 1.1120 - val_predictions_coarse1_loss: 0.1634 - val_predictions_coarse2_loss: 0.7002 - val_predictions_fine_loss: 1.1120 - val_predictions_coarse1_acc: 0.9392 - val_predictions_coarse2_acc: 0.8345 - val_predictions_fine_acc: 0.7839
# Epoch 34/50
# 40000/40000 [==============================] - 27s 680us/step - loss: 0.0056 - predictions_coarse1_loss: 0.1048 - predictions_coarse2_loss: 0.0117 - predictions_fine_loss: 0.0056 - predictions_coarse1_acc: 0.9605 - predictions_coarse2_acc: 0.9974 - predictions_fine_acc: 0.9987 - val_loss: 1.1038 - val_predictions_coarse1_loss: 0.1653 - val_predictions_coarse2_loss: 0.6961 - val_predictions_fine_loss: 1.1038 - val_predictions_coarse1_acc: 0.9391 - val_predictions_coarse2_acc: 0.8405 - val_predictions_fine_acc: 0.7851
# Epoch 35/50
# 40000/40000 [==============================] - 27s 678us/step - loss: 0.0045 - predictions_coarse1_loss: 0.1016 - predictions_coarse2_loss: 0.0102 - predictions_fine_loss: 0.0045 - predictions_coarse1_acc: 0.9630 - predictions_coarse2_acc: 0.9979 - predictions_fine_acc: 0.9991 - val_loss: 1.1098 - val_predictions_coarse1_loss: 0.1640 - val_predictions_coarse2_loss: 0.6999 - val_predictions_fine_loss: 1.1098 - val_predictions_coarse1_acc: 0.9387 - val_predictions_coarse2_acc: 0.8389 - val_predictions_fine_acc: 0.7841
# Epoch 36/50
# 40000/40000 [==============================] - 27s 682us/step - loss: 0.0048 - predictions_coarse1_loss: 0.1026 - predictions_coarse2_loss: 0.0103 - predictions_fine_loss: 0.0048 - predictions_coarse1_acc: 0.9618 - predictions_coarse2_acc: 0.9979 - predictions_fine_acc: 0.9990 - val_loss: 1.1010 - val_predictions_coarse1_loss: 0.1650 - val_predictions_coarse2_loss: 0.6967 - val_predictions_fine_loss: 1.1010 - val_predictions_coarse1_acc: 0.9386 - val_predictions_coarse2_acc: 0.8369 - val_predictions_fine_acc: 0.7869
# Epoch 37/50
# 40000/40000 [==============================] - 27s 680us/step - loss: 0.0050 - predictions_coarse1_loss: 0.1012 - predictions_coarse2_loss: 0.0111 - predictions_fine_loss: 0.0050 - predictions_coarse1_acc: 0.9641 - predictions_coarse2_acc: 0.9975 - predictions_fine_acc: 0.9987 - val_loss: 1.1358 - val_predictions_coarse1_loss: 0.1742 - val_predictions_coarse2_loss: 0.7096 - val_predictions_fine_loss: 1.1358 - val_predictions_coarse1_acc: 0.9368 - val_predictions_coarse2_acc: 0.8350 - val_predictions_fine_acc: 0.7839
# Epoch 38/50
# 40000/40000 [==============================] - 27s 682us/step - loss: 0.0048 - predictions_coarse1_loss: 0.1044 - predictions_coarse2_loss: 0.0105 - predictions_fine_loss: 0.0048 - predictions_coarse1_acc: 0.9616 - predictions_coarse2_acc: 0.9974 - predictions_fine_acc: 0.9990 - val_loss: 1.1468 - val_predictions_coarse1_loss: 0.1639 - val_predictions_coarse2_loss: 0.7218 - val_predictions_fine_loss: 1.1468 - val_predictions_coarse1_acc: 0.9385 - val_predictions_coarse2_acc: 0.8349 - val_predictions_fine_acc: 0.7837
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 39/50
# 40000/40000 [==============================] - 27s 680us/step - loss: 0.0031 - predictions_coarse1_loss: 0.1021 - predictions_coarse2_loss: 0.0083 - predictions_fine_loss: 0.0031 - predictions_coarse1_acc: 0.9618 - predictions_coarse2_acc: 0.9985 - predictions_fine_acc: 0.9995 - val_loss: 1.1301 - val_predictions_coarse1_loss: 0.1625 - val_predictions_coarse2_loss: 0.7072 - val_predictions_fine_loss: 1.1301 - val_predictions_coarse1_acc: 0.9408 - val_predictions_coarse2_acc: 0.8397 - val_predictions_fine_acc: 0.7862
# Epoch 40/50
# 40000/40000 [==============================] - 27s 680us/step - loss: 0.0031 - predictions_coarse1_loss: 0.1003 - predictions_coarse2_loss: 0.0081 - predictions_fine_loss: 0.0031 - predictions_coarse1_acc: 0.9634 - predictions_coarse2_acc: 0.9985 - predictions_fine_acc: 0.9994 - val_loss: 1.1323 - val_predictions_coarse1_loss: 0.1632 - val_predictions_coarse2_loss: 0.7015 - val_predictions_fine_loss: 1.1323 - val_predictions_coarse1_acc: 0.9387 - val_predictions_coarse2_acc: 0.8390 - val_predictions_fine_acc: 0.7877
# Epoch 41/50
# 40000/40000 [==============================] - 27s 681us/step - loss: 0.0034 - predictions_coarse1_loss: 0.1029 - predictions_coarse2_loss: 0.0086 - predictions_fine_loss: 0.0034 - predictions_coarse1_acc: 0.9631 - predictions_coarse2_acc: 0.9981 - predictions_fine_acc: 0.9993 - val_loss: 1.1181 - val_predictions_coarse1_loss: 0.1721 - val_predictions_coarse2_loss: 0.6933 - val_predictions_fine_loss: 1.1181 - val_predictions_coarse1_acc: 0.9353 - val_predictions_coarse2_acc: 0.8383 - val_predictions_fine_acc: 0.7878
# Epoch 42/50
# 40000/40000 [==============================] - 27s 679us/step - loss: 0.0031 - predictions_coarse1_loss: 0.1031 - predictions_coarse2_loss: 0.0090 - predictions_fine_loss: 0.0031 - predictions_coarse1_acc: 0.9628 - predictions_coarse2_acc: 0.9980 - predictions_fine_acc: 0.9994 - val_loss: 1.1377 - val_predictions_coarse1_loss: 0.1668 - val_predictions_coarse2_loss: 0.7014 - val_predictions_fine_loss: 1.1377 - val_predictions_coarse1_acc: 0.9382 - val_predictions_coarse2_acc: 0.8387 - val_predictions_fine_acc: 0.7868
# Epoch 43/50
# 40000/40000 [==============================] - 27s 680us/step - loss: 0.0033 - predictions_coarse1_loss: 0.1006 - predictions_coarse2_loss: 0.0087 - predictions_fine_loss: 0.0033 - predictions_coarse1_acc: 0.9639 - predictions_coarse2_acc: 0.9981 - predictions_fine_acc: 0.9993 - val_loss: 1.1262 - val_predictions_coarse1_loss: 0.1654 - val_predictions_coarse2_loss: 0.6963 - val_predictions_fine_loss: 1.1262 - val_predictions_coarse1_acc: 0.9390 - val_predictions_coarse2_acc: 0.8398 - val_predictions_fine_acc: 0.7895
# Epoch 44/50
# 40000/40000 [==============================] - 27s 680us/step - loss: 0.0029 - predictions_coarse1_loss: 0.1028 - predictions_coarse2_loss: 0.0084 - predictions_fine_loss: 0.0029 - predictions_coarse1_acc: 0.9617 - predictions_coarse2_acc: 0.9982 - predictions_fine_acc: 0.9994 - val_loss: 1.1432 - val_predictions_coarse1_loss: 0.1654 - val_predictions_coarse2_loss: 0.6976 - val_predictions_fine_loss: 1.1432 - val_predictions_coarse1_acc: 0.9392 - val_predictions_coarse2_acc: 0.8366 - val_predictions_fine_acc: 0.7864
# Epoch 45/50
# 40000/40000 [==============================] - 27s 681us/step - loss: 0.0025 - predictions_coarse1_loss: 0.0999 - predictions_coarse2_loss: 0.0075 - predictions_fine_loss: 0.0025 - predictions_coarse1_acc: 0.9640 - predictions_coarse2_acc: 0.9986 - predictions_fine_acc: 0.9996 - val_loss: 1.1451 - val_predictions_coarse1_loss: 0.1695 - val_predictions_coarse2_loss: 0.7060 - val_predictions_fine_loss: 1.1451 - val_predictions_coarse1_acc: 0.9363 - val_predictions_coarse2_acc: 0.8356 - val_predictions_fine_acc: 0.7854
# Epoch 46/50
# 40000/40000 [==============================] - 27s 680us/step - loss: 0.0031 - predictions_coarse1_loss: 0.0997 - predictions_coarse2_loss: 0.0084 - predictions_fine_loss: 0.0031 - predictions_coarse1_acc: 0.9634 - predictions_coarse2_acc: 0.9981 - predictions_fine_acc: 0.9993 - val_loss: 1.1392 - val_predictions_coarse1_loss: 0.1621 - val_predictions_coarse2_loss: 0.7017 - val_predictions_fine_loss: 1.1392 - val_predictions_coarse1_acc: 0.9397 - val_predictions_coarse2_acc: 0.8376 - val_predictions_fine_acc: 0.7867
# Epoch 47/50
# 40000/40000 [==============================] - 27s 680us/step - loss: 0.0026 - predictions_coarse1_loss: 0.1003 - predictions_coarse2_loss: 0.0078 - predictions_fine_loss: 0.0026 - predictions_coarse1_acc: 0.9633 - predictions_coarse2_acc: 0.9986 - predictions_fine_acc: 0.9995 - val_loss: 1.1505 - val_predictions_coarse1_loss: 0.1624 - val_predictions_coarse2_loss: 0.7035 - val_predictions_fine_loss: 1.1505 - val_predictions_coarse1_acc: 0.9390 - val_predictions_coarse2_acc: 0.8372 - val_predictions_fine_acc: 0.7863
# Epoch 48/50
# 40000/40000 [==============================] - 27s 680us/step - loss: 0.0022 - predictions_coarse1_loss: 0.1010 - predictions_coarse2_loss: 0.0071 - predictions_fine_loss: 0.0022 - predictions_coarse1_acc: 0.9628 - predictions_coarse2_acc: 0.9988 - predictions_fine_acc: 0.9997 - val_loss: 1.1732 - val_predictions_coarse1_loss: 0.1632 - val_predictions_coarse2_loss: 0.7187 - val_predictions_fine_loss: 1.1732 - val_predictions_coarse1_acc: 0.9397 - val_predictions_coarse2_acc: 0.8366 - val_predictions_fine_acc: 0.7881
#
# Epoch 00048: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 49/50
# 40000/40000 [==============================] - 27s 682us/step - loss: 0.0022 - predictions_coarse1_loss: 0.0970 - predictions_coarse2_loss: 0.0075 - predictions_fine_loss: 0.0022 - predictions_coarse1_acc: 0.9645 - predictions_coarse2_acc: 0.9983 - predictions_fine_acc: 0.9996 - val_loss: 1.1455 - val_predictions_coarse1_loss: 0.1618 - val_predictions_coarse2_loss: 0.6991 - val_predictions_fine_loss: 1.1455 - val_predictions_coarse1_acc: 0.9402 - val_predictions_coarse2_acc: 0.8397 - val_predictions_fine_acc: 0.7893
# Epoch 50/50
# 40000/40000 [==============================] - 27s 681us/step - loss: 0.0020 - predictions_coarse1_loss: 0.0975 - predictions_coarse2_loss: 0.0064 - predictions_fine_loss: 0.0020 - predictions_coarse1_acc: 0.9652 - predictions_coarse2_acc: 0.9989 - predictions_fine_acc: 0.9997 - val_loss: 1.1407 - val_predictions_coarse1_loss: 0.1647 - val_predictions_coarse2_loss: 0.6968 - val_predictions_fine_loss: 1.1407 - val_predictions_coarse1_acc: 0.9391 - val_predictions_coarse2_acc: 0.8400 - val_predictions_fine_acc: 0.7893

# %%
model.evaluate(test_features, [y_test_c_cat1,y_test_c_cat2, y_test_cat])
# Out:
# 10000/10000 [==============================] - 4s 438us/step
# [1.2163036173343658,
#  0.18053871150016784,
#  0.755285927939415,
#  1.2163036173343658,
#  0.9318,
#  0.824,
#  0.7779]

# %%
print('Total training time: {}'.format(training_time))
# Out:
# Total training time: 1414.8967072963715

# %%
model.save('drive/TCC-ITAU/cifar-10/models/concat-net.h5')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-3e3a8c61b6ea> in <module>()
# ----> 1 model.save('drive/TCC-ITAU/cifar-10/models/concat-net.h5')
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/network.py in save(self, filepath, overwrite, include_optimizer)
#    1088             raise NotImplementedError
#    1089         from ..models import save_model
# -> 1090         save_model(self, filepath, overwrite, include_optimizer)
#    1091
#    1092     def save_weights(self, filepath, overwrite=True):
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py in save_model(model, filepath, overwrite, include_optimizer)
#     380
#     381     try:
# --> 382         _serialize_model(model, f, include_optimizer)
#     383     finally:
#     384         if opened_new_file:
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py in _serialize_model(model, f, include_optimizer)
#     136                 'sample_weight_mode': model.sample_weight_mode,
#     137                 'loss_weights': model.loss_weights,
# --> 138             }, default=get_json_type).encode('utf8')
#     139             symbolic_weights = getattr(model.optimizer, 'weights')
#     140             if symbolic_weights:
#
# /usr/lib/python3.6/json/__init__.py in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     236         check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     237         separators=separators, default=default, sort_keys=sort_keys,
# --> 238         **kw).encode(obj)
#     239
#     240
#
# /usr/lib/python3.6/json/encoder.py in encode(self, o)
#     197         # exceptions aren't as detailed.  The list call should be roughly
#     198         # equivalent to the PySequence_Fast that ''.join() would do.
# --> 199         chunks = self.iterencode(o, _one_shot=True)
#     200         if not isinstance(chunks, (list, tuple)):
#     201             chunks = list(chunks)
#
# /usr/lib/python3.6/json/encoder.py in iterencode(self, o, _one_shot)
#     255                 self.key_separator, self.item_separator, self.sort_keys,
#     256                 self.skipkeys, _one_shot)
# --> 257         return _iterencode(o, 0)
#     258
#     259 def _make_iterencode(markers, _default, _encoder, _indent, _floatstr,
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py in get_json_type(obj)
#      72             return obj.__name__
#      73
# ---> 74         raise TypeError('Not JSON Serializable: %s' % (obj,))
#      75
#      76     from .. import __version__ as keras_version
#
# TypeError: Not JSON Serializable: <tf.Variable 'alpha_3:0' shape=() dtype=float32_ref>
