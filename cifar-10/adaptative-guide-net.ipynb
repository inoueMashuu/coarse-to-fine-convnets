# %% [markdown]
# # Adaptative-Guide-net

# %%
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse

from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass

# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}
# Out:
# E: Package 'python-software-properties' has no installation candidate
# Selecting previously unselected package libfuse2:amd64.
# (Reading database ... 22280 files and directories currently installed.)
# Preparing to unpack .../libfuse2_2.9.7-1ubuntu1_amd64.deb ...
# Unpacking libfuse2:amd64 (2.9.7-1ubuntu1) ...
# Selecting previously unselected package fuse.
# Preparing to unpack .../fuse_2.9.7-1ubuntu1_amd64.deb ...
# Unpacking fuse (2.9.7-1ubuntu1) ...
# Selecting previously unselected package google-drive-ocamlfuse.
# Preparing to unpack .../google-drive-ocamlfuse_0.7.0-0ubuntu1~ubuntu18.04.1_amd64.deb ...
# Unpacking google-drive-ocamlfuse (0.7.0-0ubuntu1~ubuntu18.04.1) ...
# Setting up libfuse2:amd64 (2.9.7-1ubuntu1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...
# Setting up fuse (2.9.7-1ubuntu1) ...
# Setting up google-drive-ocamlfuse (0.7.0-0ubuntu1~ubuntu18.04.1) ...
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# ··········
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# Please enter the verification code: Access token retrieved correctly.

# %%
# !mkdir -p drive
# !google-drive-ocamlfuse drive

# %% [markdown]
# ## Loading the data

# %%
from time import time
import os
import gzip
import numpy as np
from keras.utils import np_utils
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

from keras.datasets import cifar10
# Out:
# Using TensorFlow backend.

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, 
                                                  test_size=0.2, 
                                                  random_state=1974)

# %%
train_features = X_train.reshape(X_train.shape[0], 32, 32, 3)/255
vali_features = X_val.reshape(X_val.shape[0], 32, 32, 3)/255
test_features = X_test.reshape(X_test.shape[0], 32, 32, 3)/255

y_train_cat = np_utils.to_categorical(y_train)
y_val_cat = np_utils.to_categorical(y_val)
y_test_cat = np_utils.to_categorical(y_test)

# %% [markdown]
# ## Defining coarse labels

# %%
dict_coarse1 = {0: 0,
              1: 0,
              2: 1,
              3: 1,
              4: 1,
              5: 1,
              6: 1,
              7: 1,
              8: 0,
              9: 0}

dict_coarse2 = {0: 0,
              1: 1,
              2: 3,
              3: 4,
              4: 6,
              5: 4,
              6: 5,
              7: 6,
              8: 2,
              9: 1}

y_train_coarse1 = np.vectorize(dict_coarse1.get)(y_train)
y_val_coarse1 = np.vectorize(dict_coarse1.get)(y_val)
y_test_coarse1 = np.vectorize(dict_coarse1.get)(y_test)

y_train_coarse2 = np.vectorize(dict_coarse2.get)(y_train)
y_val_coarse2 = np.vectorize(dict_coarse2.get)(y_val)
y_test_coarse2 = np.vectorize(dict_coarse2.get)(y_test)

y_train_c_cat1 = np_utils.to_categorical(y_train_coarse1)
y_val_c_cat1 = np_utils.to_categorical(y_val_coarse1)
y_test_c_cat1 = np_utils.to_categorical(y_test_coarse1)

y_train_c_cat2 = np_utils.to_categorical(y_train_coarse2)
y_val_c_cat2 = np_utils.to_categorical(y_val_coarse2)
y_test_c_cat2 = np_utils.to_categorical(y_test_coarse2)

# %% [markdown]
# ## Training the model

# %%
import keras
from keras.models import Model
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D, Input
from keras import optimizers
from keras.callbacks import TensorBoard, ReduceLROnPlateau, CSVLogger
from keras.layers.normalization import BatchNormalization
from keras import backend as K

# %%
class TimingCallback(keras.callbacks.Callback):
  """Callback that saves the time elapsed of each epoch to the log.
  """  
  def on_epoch_begin(self, epoch, logs={}):
    self.starttime=time()
  def on_epoch_end(self, epoch, logs={}):
    logs['time_elapsed'] = (time()-self.starttime)

# %%
class AdaptativeLossWeightsModifier3Vars(keras.callbacks.Callback):
  def __init__(self, alpha, beta, gamma, decay_rate=0.5):
    self.alpha = alpha
    self.beta = beta
    self.gamma = gamma
    self.decay_rate = decay_rate
    self.offset_epoch = 0
    self.par_reduce = [0, 1]
  
  def calculate_exponential(self, ratio, decay_rate, epoch):
    return np.exp(-ratio*decay_rate*epoch)

  def on_epoch_end(self, epoch, logs={}):
    list_vars = [K.eval(self.alpha), K.eval(self.beta), K.eval(self.gamma)]
    if epoch < 1:
      pass
    
    else:
      loss_coarse1 = self.model.history.history['predictions_coarse1_loss'][-1]
      loss_coarse2 = self.model.history.history['predictions_coarse2_loss'][-1]
      loss_fine = self.model.history.history['predictions_fine_loss'][-1]
      
      losses_classes = [loss_coarse1, loss_coarse2, loss_fine]
      ratio = losses_classes[self.par_reduce[0]] / losses_classes[self.par_reduce[1]] *(epoch + 1 - self.offset_epoch) 
      
      decaying = self.calculate_exponential(ratio, self.decay_rate/(max(self.par_reduce)**2), epoch)
      increasing = 1 - decaying
    
    
      if (1 - increasing) < 0.3 and (self.par_reduce[1] < len(list_vars) - 1):
        list_vars[self.par_reduce[0]] = 0
        list_vars[self.par_reduce[1]] = 1
        self.par_reduce = [i + 1 for i in self.par_reduce]
        self.offset_epoch = self.offset_epoch + epoch

      else:
       list_vars[self.par_reduce[0]] = decaying
       list_vars[self.par_reduce[1]] = increasing

        
      K.set_value(self.alpha, list_vars[0])
      K.set_value(self.beta, list_vars[1])
      K.set_value(self.gamma, list_vars[2])
        
      print('Changing loss weights to: coarse1 = {}, coarse2 = {}, fine = {}'.format(K.eval(self.alpha), K.eval(self.beta), K.eval(self.gamma)))
    
    logs['alpha'] = K.eval(self.alpha)
    logs['beta'] = K.eval(self.beta) 
    logs['gamma'] = K.eval(self.gamma)

# %%
img_rows, img_cols = 32, 32
input_shape = (img_rows, img_cols, 3)

num_classes_coarse1 = 2
num_classes_coarse2 = 7
num_classes_fine = 10

img_input = Input(shape=input_shape, name='input')

# coarse1 network
coarse1 = Conv2D(128, (3, 3), activation='relu', name='c1_block1_conv1', padding='same')(img_input)

coarse1 = Conv2D(128, (3, 3), activation='relu', name='c1_block1_conv2', padding='same')(coarse1)
coarse1 = MaxPooling2D((2, 2), name='c1_block2_pool')(coarse1)

coarse1 = Conv2D(128, (3, 3), activation='relu', name='c1_block1_conv3', padding='same')(coarse1)
coarse1 = MaxPooling2D((2, 2), name='c1_block3_pool')(coarse1)

coarse1 = Flatten(name='c1_flatten')(coarse1)
coarse1 = Dense(512, name='c1_fc_1')(coarse1)
coarse1 = BatchNormalization()(coarse1)
coarse1 = Activation('relu')(coarse1)
coarse1 = Dropout(0.5)(coarse1)

coarse1 = Dense(512, name='c1_fc_2')(coarse1)
coarse1 = BatchNormalization()(coarse1)
coarse1 = Activation('relu')(coarse1)
coarse1 = Dropout(0.5)(coarse1)


# coarse2 network
coarse2 = Conv2D(128, (3, 3), activation='relu', name='c2_block1_conv1', padding='same')(img_input)

coarse2 = Conv2D(128, (3, 3), activation='relu', name='c2_block1_conv2', padding='same')(coarse2)
coarse2 = MaxPooling2D((2, 2), name='c2_block2_pool')(coarse2)

coarse2 = Conv2D(128, (3, 3), activation='relu', name='c2_block1_conv3', padding='same')(coarse2)
coarse2 = MaxPooling2D((2, 2), name='c2_block3_pool')(coarse2)

coarse2 = Flatten(name='c2_flatten')(coarse2)
coarse2 = Dense(512, name='c2_fc_1')(coarse2)
coarse2 = BatchNormalization()(coarse2)
coarse2 = Activation('relu')(coarse2)
coarse2 = Dropout(0.5)(coarse2)

coarse2 = Dense(512, name='c2_fc_2')(coarse2)
coarse2 = BatchNormalization()(coarse2)
coarse2 = Activation('relu')(coarse2)
coarse2 = Dropout(0.5)(coarse2)

coarse2 = keras.layers.concatenate([coarse2, coarse1])

# fine network
fine = Conv2D(128, (3, 3), activation='relu', name='block1_conv1', padding='same')(img_input)

fine = Conv2D(128, (3, 3), activation='relu', name='block1_conv2', padding='same')(fine)
fine = MaxPooling2D((2, 2), name='block2_pool')(fine)

fine = Conv2D(128, (3, 3), activation='relu', name='block1_conv3', padding='same')(fine)
fine = MaxPooling2D((2, 2), name='block3_pool')(fine)

fine = Flatten(name='flatten')(fine)
fine = Dense(512, name='fc_1')(fine)
fine = BatchNormalization()(fine)
fine = Activation('relu')(fine)
fine = Dropout(0.5)(fine)

fine = Dense(512, name='fc_2')(fine)
fine = BatchNormalization()(fine)
fine = Activation('relu')(fine)
fine = Dropout(0.5)(fine)

fine = keras.layers.concatenate([fine, coarse2])

coarse_pred1 = Dense(num_classes_coarse1, activation='softmax', name='predictions_coarse1')(coarse1)
coarse_pred2 = Dense(num_classes_coarse2, activation='softmax', name='predictions_coarse2')(coarse2)
fine_pred = Dense(num_classes_fine, activation='softmax', name='predictions_fine')(fine)

# %%
model = Model(inputs=img_input, outputs= [coarse_pred1, coarse_pred2, fine_pred], name='adaptative_guide_net')

model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# c1_block1_conv1 (Conv2D)        (None, 32, 32, 128)  3584        input[0][0]
# __________________________________________________________________________________________________
# c2_block1_conv1 (Conv2D)        (None, 32, 32, 128)  3584        input[0][0]
# __________________________________________________________________________________________________
# c1_block1_conv2 (Conv2D)        (None, 32, 32, 128)  147584      c1_block1_conv1[0][0]
# __________________________________________________________________________________________________
# c2_block1_conv2 (Conv2D)        (None, 32, 32, 128)  147584      c2_block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 32, 32, 128)  3584        input[0][0]
# __________________________________________________________________________________________________
# c1_block2_pool (MaxPooling2D)   (None, 16, 16, 128)  0           c1_block1_conv2[0][0]
# __________________________________________________________________________________________________
# c2_block2_pool (MaxPooling2D)   (None, 16, 16, 128)  0           c2_block1_conv2[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 32, 32, 128)  147584      block1_conv1[0][0]
# __________________________________________________________________________________________________
# c1_block1_conv3 (Conv2D)        (None, 16, 16, 128)  147584      c1_block2_pool[0][0]
# __________________________________________________________________________________________________
# c2_block1_conv3 (Conv2D)        (None, 16, 16, 128)  147584      c2_block2_pool[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 16, 16, 128)  0           block1_conv2[0][0]
# __________________________________________________________________________________________________
# c1_block3_pool (MaxPooling2D)   (None, 8, 8, 128)    0           c1_block1_conv3[0][0]
# __________________________________________________________________________________________________
# c2_block3_pool (MaxPooling2D)   (None, 8, 8, 128)    0           c2_block1_conv3[0][0]
# __________________________________________________________________________________________________
# block1_conv3 (Conv2D)           (None, 16, 16, 128)  147584      block2_pool[0][0]
# __________________________________________________________________________________________________
# c1_flatten (Flatten)            (None, 8192)         0           c1_block3_pool[0][0]
# __________________________________________________________________________________________________
# c2_flatten (Flatten)            (None, 8192)         0           c2_block3_pool[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 8, 8, 128)    0           block1_conv3[0][0]
# __________________________________________________________________________________________________
# c1_fc_1 (Dense)                 (None, 512)          4194816     c1_flatten[0][0]
# __________________________________________________________________________________________________
# c2_fc_1 (Dense)                 (None, 512)          4194816     c2_flatten[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 8192)         0           block3_pool[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 512)          2048        c1_fc_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 512)          2048        c2_fc_1[0][0]
# __________________________________________________________________________________________________
# fc_1 (Dense)                    (None, 512)          4194816     flatten[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 512)          0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 512)          0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 512)          2048        fc_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 512)          0           activation_1[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 512)          0           activation_3[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 512)          0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# c1_fc_2 (Dense)                 (None, 512)          262656      dropout_1[0][0]
# __________________________________________________________________________________________________
# c2_fc_2 (Dense)                 (None, 512)          262656      dropout_3[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 512)          0           activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 512)          2048        c1_fc_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 512)          2048        c2_fc_2[0][0]
# __________________________________________________________________________________________________
# fc_2 (Dense)                    (None, 512)          262656      dropout_5[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 512)          0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 512)          0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 512)          2048        fc_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 512)          0           activation_2[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 512)          0           activation_4[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 512)          0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 1024)         0           dropout_4[0][0]
#                                                                  dropout_2[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 512)          0           activation_6[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 1536)         0           dropout_6[0][0]
#                                                                  concatenate_1[0][0]
# __________________________________________________________________________________________________
# predictions_coarse1 (Dense)     (None, 2)            1026        dropout_2[0][0]
# __________________________________________________________________________________________________
# predictions_coarse2 (Dense)     (None, 7)            7175        concatenate_1[0][0]
# __________________________________________________________________________________________________
# predictions_fine (Dense)        (None, 10)           15370       concatenate_2[0][0]
# ==================================================================================================
# Total params: 14,304,531
# Trainable params: 14,298,387
# Non-trainable params: 6,144
# __________________________________________________________________________________________________

# %%
alpha = K.variable(value=0.9, dtype="float32", name="alpha") 
beta = K.variable(value=0.1, dtype="float32", name="beta") 
gamma = K.variable(value=0, dtype="float32", name="gamma") 

adam = optimizers.Adam(lr=0.00025)

model.compile(loss='categorical_crossentropy', 
              optimizer=adam,
              loss_weights=[alpha, beta, gamma],
              metrics=['accuracy'])

# %%
clr_cb = ReduceLROnPlateau(monitor='val_predictions_fine_loss', factor=0.5, patience=10, verbose=1)
time_cb = TimingCallback()
change_lw = AdaptativeLossWeightsModifier3Vars(alpha, beta, gamma, decay_rate=0.5)
csv_cb = CSVLogger('drive/TCC-ITAU/cifar-10/training-data/guide-net/adaptative-guide-net.csv', separator=',', append=False)


cbks = [clr_cb, time_cb, change_lw, csv_cb]

# %%
epochs = 50
start_time = time()
training = model.fit(train_features, [y_train_c_cat1, y_train_c_cat2, y_train_cat],
                     validation_data=(vali_features, [y_val_c_cat1, y_val_c_cat2, y_val_cat]),
                     epochs=epochs,
                     batch_size=256, 
                     callbacks=cbks,
                     verbose=1)
training_time = time() - start_time
# Out:
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/50
# 40000/40000 [==============================] - 70s 2ms/step - loss: 0.4867 - predictions_coarse1_loss: 0.3778 - predictions_coarse2_loss: 1.4675 - predictions_fine_loss: 3.0956 - predictions_coarse1_acc: 0.8539 - predictions_coarse2_acc: 0.4818 - predictions_fine_acc: 0.0980 - val_loss: 1.0222 - val_predictions_coarse1_loss: 0.9815 - val_predictions_coarse2_loss: 1.3884 - val_predictions_fine_loss: 2.4811 - val_predictions_coarse1_acc: 0.6396 - val_predictions_coarse2_acc: 0.5119 - val_predictions_fine_acc: 0.1375
# Epoch 2/50
# 40000/40000 [==============================] - 63s 2ms/step - loss: 0.3174 - predictions_coarse1_loss: 0.2398 - predictions_coarse2_loss: 1.0165 - predictions_fine_loss: 3.0966 - predictions_coarse1_acc: 0.9073 - predictions_coarse2_acc: 0.6330 - predictions_fine_acc: 0.0997 - val_loss: 0.2932 - val_predictions_coarse1_loss: 0.2346 - val_predictions_coarse2_loss: 0.8204 - val_predictions_fine_loss: 2.4442 - val_predictions_coarse1_acc: 0.9033 - val_predictions_coarse2_acc: 0.6984 - val_predictions_fine_acc: 0.1255
# Changing loss weights to: coarse1 = 0.7730376124382019, coarse2 = 0.22696241736412048, fine = 0.0
# Epoch 3/50
# 40000/40000 [==============================] - 63s 2ms/step - loss: 0.3379 - predictions_coarse1_loss: 0.1974 - predictions_coarse2_loss: 0.8165 - predictions_fine_loss: 3.1203 - predictions_coarse1_acc: 0.9230 - predictions_coarse2_acc: 0.7087 - predictions_fine_acc: 0.0949 - val_loss: 0.2955 - val_predictions_coarse1_loss: 0.1766 - val_predictions_coarse2_loss: 0.7003 - val_predictions_fine_loss: 2.5940 - val_predictions_coarse1_acc: 0.9337 - val_predictions_coarse2_acc: 0.7473 - val_predictions_fine_acc: 0.0723
# Changing loss weights to: coarse1 = 0.49279338121414185, coarse2 = 0.5072066187858582, fine = 0.0
# Epoch 4/50
# 40000/40000 [==============================] - 63s 2ms/step - loss: 0.4279 - predictions_coarse1_loss: 0.1670 - predictions_coarse2_loss: 0.6815 - predictions_fine_loss: 3.1216 - predictions_coarse1_acc: 0.9347 - predictions_coarse2_acc: 0.7546 - predictions_fine_acc: 0.0942 - val_loss: 0.5490 - val_predictions_coarse1_loss: 0.1825 - val_predictions_coarse2_loss: 0.9052 - val_predictions_fine_loss: 2.5532 - val_predictions_coarse1_acc: 0.9335 - val_predictions_coarse2_acc: 0.6887 - val_predictions_fine_acc: 0.1217
# Changing loss weights to: coarse1 = 0.0, coarse2 = 1.0, fine = 0.0
# Epoch 5/50
# 40000/40000 [==============================] - 63s 2ms/step - loss: 0.5779 - predictions_coarse1_loss: 0.1587 - predictions_coarse2_loss: 0.5779 - predictions_fine_loss: 3.0769 - predictions_coarse1_acc: 0.9374 - predictions_coarse2_acc: 0.7931 - predictions_fine_acc: 0.0978 - val_loss: 0.7712 - val_predictions_coarse1_loss: 0.2744 - val_predictions_coarse2_loss: 0.7712 - val_predictions_fine_loss: 2.5349 - val_predictions_coarse1_acc: 0.8873 - val_predictions_coarse2_acc: 0.7208 - val_predictions_fine_acc: 0.0930
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.8038809299468994, fine = 0.1961190551519394
# Epoch 6/50
# 40000/40000 [==============================] - 64s 2ms/step - loss: 0.5478 - predictions_coarse1_loss: 0.1529 - predictions_coarse2_loss: 0.4322 - predictions_fine_loss: 1.0214 - predictions_coarse1_acc: 0.9388 - predictions_coarse2_acc: 0.8475 - predictions_fine_acc: 0.6286 - val_loss: 0.7446 - val_predictions_coarse1_loss: 0.1770 - val_predictions_coarse2_loss: 0.6900 - val_predictions_fine_loss: 0.9684 - val_predictions_coarse1_acc: 0.9302 - val_predictions_coarse2_acc: 0.7623 - val_predictions_fine_acc: 0.6626
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.703164279460907, fine = 0.296835720539093
# Epoch 7/50
# 40000/40000 [==============================] - 64s 2ms/step - loss: 0.4461 - predictions_coarse1_loss: 0.1435 - predictions_coarse2_loss: 0.3453 - predictions_fine_loss: 0.6849 - predictions_coarse1_acc: 0.9427 - predictions_coarse2_acc: 0.8775 - predictions_fine_acc: 0.7441 - val_loss: 0.6837 - val_predictions_coarse1_loss: 0.1458 - val_predictions_coarse2_loss: 0.6159 - val_predictions_fine_loss: 0.8443 - val_predictions_coarse1_acc: 0.9440 - val_predictions_coarse2_acc: 0.7882 - val_predictions_fine_acc: 0.7064
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.2810085117816925, fine = 0.7189915180206299
# Epoch 8/50
# 40000/40000 [==============================] - 64s 2ms/step - loss: 0.4702 - predictions_coarse1_loss: 0.1440 - predictions_coarse2_loss: 0.2780 - predictions_fine_loss: 0.5453 - predictions_coarse1_acc: 0.9428 - predictions_coarse2_acc: 0.9024 - predictions_fine_acc: 0.7946 - val_loss: 0.7360 - val_predictions_coarse1_loss: 0.1622 - val_predictions_coarse2_loss: 0.5807 - val_predictions_fine_loss: 0.7968 - val_predictions_coarse1_acc: 0.9374 - val_predictions_coarse2_acc: 0.8017 - val_predictions_fine_acc: 0.7318
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.11016806215047836, fine = 0.8898319602012634
# Epoch 9/50
# 40000/40000 [==============================] - 63s 2ms/step - loss: 0.3988 - predictions_coarse1_loss: 0.1388 - predictions_coarse2_loss: 0.2246 - predictions_fine_loss: 0.4204 - predictions_coarse1_acc: 0.9451 - predictions_coarse2_acc: 0.9245 - predictions_fine_acc: 0.8442 - val_loss: 0.7769 - val_predictions_coarse1_loss: 0.2628 - val_predictions_coarse2_loss: 0.5614 - val_predictions_fine_loss: 0.8036 - val_predictions_coarse1_acc: 0.8909 - val_predictions_coarse2_acc: 0.8159 - val_predictions_fine_acc: 0.7417
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.04694315791130066, fine = 0.953056812286377
# Epoch 10/50
# 40000/40000 [==============================] - 64s 2ms/step - loss: 0.3293 - predictions_coarse1_loss: 0.1456 - predictions_coarse2_loss: 0.1906 - predictions_fine_loss: 0.3362 - predictions_coarse1_acc: 0.9420 - predictions_coarse2_acc: 0.9375 - predictions_fine_acc: 0.8762 - val_loss: 0.7866 - val_predictions_coarse1_loss: 0.1953 - val_predictions_coarse2_loss: 0.5365 - val_predictions_fine_loss: 0.7990 - val_predictions_coarse1_acc: 0.9232 - val_predictions_coarse2_acc: 0.8201 - val_predictions_fine_acc: 0.7493
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.014902038499712944, fine = 0.9850979447364807
# Epoch 11/50
# 40000/40000 [==============================] - 64s 2ms/step - loss: 0.2677 - predictions_coarse1_loss: 0.1405 - predictions_coarse2_loss: 0.1646 - predictions_fine_loss: 0.2693 - predictions_coarse1_acc: 0.9445 - predictions_coarse2_acc: 0.9479 - predictions_fine_acc: 0.8999 - val_loss: 0.9092 - val_predictions_coarse1_loss: 0.2184 - val_predictions_coarse2_loss: 0.5623 - val_predictions_fine_loss: 0.9144 - val_predictions_coarse1_acc: 0.9099 - val_predictions_coarse2_acc: 0.8198 - val_predictions_fine_acc: 0.7365
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.003453477518633008, fine = 0.9965465068817139
# Epoch 12/50
# 40000/40000 [==============================] - 63s 2ms/step - loss: 0.2059 - predictions_coarse1_loss: 0.1357 - predictions_coarse2_loss: 0.1377 - predictions_fine_loss: 0.2062 - predictions_coarse1_acc: 0.9460 - predictions_coarse2_acc: 0.9585 - predictions_fine_acc: 0.9267 - val_loss: 0.9290 - val_predictions_coarse1_loss: 0.1732 - val_predictions_coarse2_loss: 0.6204 - val_predictions_fine_loss: 0.9301 - val_predictions_coarse1_acc: 0.9343 - val_predictions_coarse2_acc: 0.8019 - val_predictions_fine_acc: 0.7455
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.0005192873650230467, fine = 0.9994807243347168
# Epoch 13/50
# 40000/40000 [==============================] - 64s 2ms/step - loss: 0.1691 - predictions_coarse1_loss: 0.1392 - predictions_coarse2_loss: 0.1236 - predictions_fine_loss: 0.1691 - predictions_coarse1_acc: 0.9455 - predictions_coarse2_acc: 0.9640 - predictions_fine_acc: 0.9408 - val_loss: 0.9008 - val_predictions_coarse1_loss: 0.1705 - val_predictions_coarse2_loss: 0.6025 - val_predictions_fine_loss: 0.9009 - val_predictions_coarse1_acc: 0.9330 - val_predictions_coarse2_acc: 0.8029 - val_predictions_fine_acc: 0.7530
# Changing loss weights to: coarse1 = 0.0, coarse2 = 4.4633325160248205e-05, fine = 0.9999553561210632
# Epoch 14/50
# 40000/40000 [==============================] - 63s 2ms/step - loss: 0.1309 - predictions_coarse1_loss: 0.1335 - predictions_coarse2_loss: 0.1094 - predictions_fine_loss: 0.1309 - predictions_coarse1_acc: 0.9480 - predictions_coarse2_acc: 0.9696 - predictions_fine_acc: 0.9543 - val_loss: 0.8414 - val_predictions_coarse1_loss: 0.1674 - val_predictions_coarse2_loss: 0.5376 - val_predictions_fine_loss: 0.8415 - val_predictions_coarse1_acc: 0.9357 - val_predictions_coarse2_acc: 0.8228 - val_predictions_fine_acc: 0.7693
# Changing loss weights to: coarse1 = 0.0, coarse2 = 2.1271805508149555e-06, fine = 0.9999978542327881
# Epoch 15/50
# 40000/40000 [==============================] - 63s 2ms/step - loss: 0.1082 - predictions_coarse1_loss: 0.1276 - predictions_coarse2_loss: 0.1017 - predictions_fine_loss: 0.1082 - predictions_coarse1_acc: 0.9505 - predictions_coarse2_acc: 0.9742 - predictions_fine_acc: 0.9632 - val_loss: 0.8966 - val_predictions_coarse1_loss: 0.1691 - val_predictions_coarse2_loss: 0.5316 - val_predictions_fine_loss: 0.8966 - val_predictions_coarse1_acc: 0.9354 - val_predictions_coarse2_acc: 0.8275 - val_predictions_fine_acc: 0.7709
# Changing loss weights to: coarse1 = 0.0, coarse2 = 2.3881577604356607e-08, fine = 1.0
# Epoch 16/50
# 40000/40000 [==============================] - 63s 2ms/step - loss: 0.0895 - predictions_coarse1_loss: 0.1322 - predictions_coarse2_loss: 0.0945 - predictions_fine_loss: 0.0895 - predictions_coarse1_acc: 0.9492 - predictions_coarse2_acc: 0.9762 - predictions_fine_acc: 0.9708 - val_loss: 0.9417 - val_predictions_coarse1_loss: 0.1680 - val_predictions_coarse2_loss: 0.5303 - val_predictions_fine_loss: 0.9417 - val_predictions_coarse1_acc: 0.9338 - val_predictions_coarse2_acc: 0.8264 - val_predictions_fine_acc: 0.7590
# Changing loss weights to: coarse1 = 0.0, coarse2 = 1.1317477510708329e-10, fine = 1.0
# Epoch 17/50
# 40000/40000 [==============================] - 64s 2ms/step - loss: 0.0798 - predictions_coarse1_loss: 0.1309 - predictions_coarse2_loss: 0.0911 - predictions_fine_loss: 0.0798 - predictions_coarse1_acc: 0.9502 - predictions_coarse2_acc: 0.9775 - predictions_fine_acc: 0.9734 - val_loss: 0.9167 - val_predictions_coarse1_loss: 0.1636 - val_predictions_coarse2_loss: 0.5459 - val_predictions_fine_loss: 0.9167 - val_predictions_coarse1_acc: 0.9358 - val_predictions_coarse2_acc: 0.8221 - val_predictions_fine_acc: 0.7769
# Changing loss weights to: coarse1 = 0.0, coarse2 = 1.4778156725691466e-13, fine = 1.0
# Epoch 18/50
# 40000/40000 [==============================] - 64s 2ms/step - loss: 0.0655 - predictions_coarse1_loss: 0.1305 - predictions_coarse2_loss: 0.0849 - predictions_fine_loss: 0.0655 - predictions_coarse1_acc: 0.9503 - predictions_coarse2_acc: 0.9792 - predictions_fine_acc: 0.9779 - val_loss: 1.0034 - val_predictions_coarse1_loss: 0.1792 - val_predictions_coarse2_loss: 0.5925 - val_predictions_fine_loss: 1.0034 - val_predictions_coarse1_acc: 0.9303 - val_predictions_coarse2_acc: 0.8076 - val_predictions_fine_acc: 0.7577
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Changing loss weights to: coarse1 = 0.0, coarse2 = 1.6081754301680345e-16, fine = 1.0
# Epoch 19/50
# 40000/40000 [==============================] - 64s 2ms/step - loss: 0.0436 - predictions_coarse1_loss: 0.1183 - predictions_coarse2_loss: 0.0689 - predictions_fine_loss: 0.0436 - predictions_coarse1_acc: 0.9564 - predictions_coarse2_acc: 0.9853 - predictions_fine_acc: 0.9866 - val_loss: 0.8764 - val_predictions_coarse1_loss: 0.1514 - val_predictions_coarse2_loss: 0.5036 - val_predictions_fine_loss: 0.8764 - val_predictions_coarse1_acc: 0.9405 - val_predictions_coarse2_acc: 0.8334 - val_predictions_fine_acc: 0.7867
# Changing loss weights to: coarse1 = 0.0, coarse2 = 5.514036450376417e-21, fine = 1.0
# Epoch 20/50
# 40000/40000 [==============================] - 64s 2ms/step - loss: 0.0310 - predictions_coarse1_loss: 0.1186 - predictions_coarse2_loss: 0.0590 - predictions_fine_loss: 0.0310 - predictions_coarse1_acc: 0.9550 - predictions_coarse2_acc: 0.9880 - predictions_fine_acc: 0.9912 - val_loss: 0.9124 - val_predictions_coarse1_loss: 0.1551 - val_predictions_coarse2_loss: 0.5129 - val_predictions_fine_loss: 0.9124 - val_predictions_coarse1_acc: 0.9408 - val_predictions_coarse2_acc: 0.8323 - val_predictions_fine_acc: 0.7831
# Changing loss weights to: coarse1 = 0.0, coarse2 = 1.8014912773380017e-28, fine = 1.0
# Epoch 21/50
# 40000/40000 [==============================] - 64s 2ms/step - loss: 0.0256 - predictions_coarse1_loss: 0.1149 - predictions_coarse2_loss: 0.0545 - predictions_fine_loss: 0.0256 - predictions_coarse1_acc: 0.9576 - predictions_coarse2_acc: 0.9894 - predictions_fine_acc: 0.9931 - val_loss: 0.9252 - val_predictions_coarse1_loss: 0.1574 - val_predictions_coarse2_loss: 0.5114 - val_predictions_fine_loss: 0.9252 - val_predictions_coarse1_acc: 0.9381 - val_predictions_coarse2_acc: 0.8353 - val_predictions_fine_acc: 0.7830
# Changing loss weights to: coarse1 = 0.0, coarse2 = 6.43649399256208e-38, fine = 1.0
# Epoch 22/50
# 40000/40000 [==============================] - 64s 2ms/step - loss: 0.0227 - predictions_coarse1_loss: 0.1111 - predictions_coarse2_loss: 0.0521 - predictions_fine_loss: 0.0227 - predictions_coarse1_acc: 0.9593 - predictions_coarse2_acc: 0.9908 - predictions_fine_acc: 0.9938 - val_loss: 0.9337 - val_predictions_coarse1_loss: 0.1550 - val_predictions_coarse2_loss: 0.5107 - val_predictions_fine_loss: 0.9337 - val_predictions_coarse1_acc: 0.9402 - val_predictions_coarse2_acc: 0.8364 - val_predictions_fine_acc: 0.7853
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.0, fine = 1.0
# Epoch 23/50
# 40000/40000 [==============================] - 64s 2ms/step - loss: 0.0195 - predictions_coarse1_loss: 0.1115 - predictions_coarse2_loss: 0.0489 - predictions_fine_loss: 0.0195 - predictions_coarse1_acc: 0.9589 - predictions_coarse2_acc: 0.9915 - predictions_fine_acc: 0.9949 - val_loss: 0.9684 - val_predictions_coarse1_loss: 0.1504 - val_predictions_coarse2_loss: 0.5139 - val_predictions_fine_loss: 0.9684 - val_predictions_coarse1_acc: 0.9440 - val_predictions_coarse2_acc: 0.8396 - val_predictions_fine_acc: 0.7858
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.0, fine = 1.0
# Epoch 24/50
# 40000/40000 [==============================] - 63s 2ms/step - loss: 0.0197 - predictions_coarse1_loss: 0.1086 - predictions_coarse2_loss: 0.0505 - predictions_fine_loss: 0.0197 - predictions_coarse1_acc: 0.9589 - predictions_coarse2_acc: 0.9909 - predictions_fine_acc: 0.9948 - val_loss: 0.9381 - val_predictions_coarse1_loss: 0.1564 - val_predictions_coarse2_loss: 0.5040 - val_predictions_fine_loss: 0.9381 - val_predictions_coarse1_acc: 0.9394 - val_predictions_coarse2_acc: 0.8379 - val_predictions_fine_acc: 0.7872
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.0, fine = 1.0
# Epoch 25/50
# 40000/40000 [==============================] - 63s 2ms/step - loss: 0.0171 - predictions_coarse1_loss: 0.1107 - predictions_coarse2_loss: 0.0470 - predictions_fine_loss: 0.0171 - predictions_coarse1_acc: 0.9593 - predictions_coarse2_acc: 0.9921 - predictions_fine_acc: 0.9958 - val_loss: 0.9887 - val_predictions_coarse1_loss: 0.1575 - val_predictions_coarse2_loss: 0.5256 - val_predictions_fine_loss: 0.9887 - val_predictions_coarse1_acc: 0.9390 - val_predictions_coarse2_acc: 0.8291 - val_predictions_fine_acc: 0.7834
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.0, fine = 1.0
# Epoch 26/50
# 40000/40000 [==============================] - 63s 2ms/step - loss: 0.0169 - predictions_coarse1_loss: 0.1113 - predictions_coarse2_loss: 0.0471 - predictions_fine_loss: 0.0169 - predictions_coarse1_acc: 0.9591 - predictions_coarse2_acc: 0.9918 - predictions_fine_acc: 0.9953 - val_loss: 0.9841 - val_predictions_coarse1_loss: 0.1493 - val_predictions_coarse2_loss: 0.5186 - val_predictions_fine_loss: 0.9841 - val_predictions_coarse1_acc: 0.9413 - val_predictions_coarse2_acc: 0.8313 - val_predictions_fine_acc: 0.7819
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.0, fine = 1.0
# Epoch 27/50
# 40000/40000 [==============================] - 63s 2ms/step - loss: 0.0163 - predictions_coarse1_loss: 0.1076 - predictions_coarse2_loss: 0.0446 - predictions_fine_loss: 0.0163 - predictions_coarse1_acc: 0.9607 - predictions_coarse2_acc: 0.9928 - predictions_fine_acc: 0.9959 - val_loss: 1.0241 - val_predictions_coarse1_loss: 0.1580 - val_predictions_coarse2_loss: 0.5329 - val_predictions_fine_loss: 1.0241 - val_predictions_coarse1_acc: 0.9384 - val_predictions_coarse2_acc: 0.8320 - val_predictions_fine_acc: 0.7813
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.0, fine = 1.0
# Epoch 28/50
# 40000/40000 [==============================] - 63s 2ms/step - loss: 0.0169 - predictions_coarse1_loss: 0.1083 - predictions_coarse2_loss: 0.0465 - predictions_fine_loss: 0.0169 - predictions_coarse1_acc: 0.9599 - predictions_coarse2_acc: 0.9922 - predictions_fine_acc: 0.9952 - val_loss: 1.0215 - val_predictions_coarse1_loss: 0.1764 - val_predictions_coarse2_loss: 0.5588 - val_predictions_fine_loss: 1.0215 - val_predictions_coarse1_acc: 0.9308 - val_predictions_coarse2_acc: 0.8180 - val_predictions_fine_acc: 0.7778
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.0, fine = 1.0
# Epoch 29/50
# 40000/40000 [==============================] - 63s 2ms/step - loss: 0.0128 - predictions_coarse1_loss: 0.1034 - predictions_coarse2_loss: 0.0425 - predictions_fine_loss: 0.0128 - predictions_coarse1_acc: 0.9629 - predictions_coarse2_acc: 0.9928 - predictions_fine_acc: 0.9965 - val_loss: 0.9723 - val_predictions_coarse1_loss: 0.1493 - val_predictions_coarse2_loss: 0.5157 - val_predictions_fine_loss: 0.9723 - val_predictions_coarse1_acc: 0.9390 - val_predictions_coarse2_acc: 0.8329 - val_predictions_fine_acc: 0.7860
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.0, fine = 1.0
# Epoch 30/50
# 40000/40000 [==============================] - 64s 2ms/step - loss: 0.0105 - predictions_coarse1_loss: 0.1023 - predictions_coarse2_loss: 0.0392 - predictions_fine_loss: 0.0105 - predictions_coarse1_acc: 0.9635 - predictions_coarse2_acc: 0.9940 - predictions_fine_acc: 0.9977 - val_loss: 0.9954 - val_predictions_coarse1_loss: 0.1633 - val_predictions_coarse2_loss: 0.5179 - val_predictions_fine_loss: 0.9954 - val_predictions_coarse1_acc: 0.9352 - val_predictions_coarse2_acc: 0.8335 - val_predictions_fine_acc: 0.7864
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.0, fine = 1.0
# Epoch 31/50
# 40000/40000 [==============================] - 63s 2ms/step - loss: 0.0087 - predictions_coarse1_loss: 0.1081 - predictions_coarse2_loss: 0.0379 - predictions_fine_loss: 0.0087 - predictions_coarse1_acc: 0.9611 - predictions_coarse2_acc: 0.9950 - predictions_fine_acc: 0.9982 - val_loss: 0.9935 - val_predictions_coarse1_loss: 0.1576 - val_predictions_coarse2_loss: 0.5146 - val_predictions_fine_loss: 0.9935 - val_predictions_coarse1_acc: 0.9384 - val_predictions_coarse2_acc: 0.8353 - val_predictions_fine_acc: 0.7869
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.0, fine = 1.0
# Epoch 32/50
# 40000/40000 [==============================] - 63s 2ms/step - loss: 0.0084 - predictions_coarse1_loss: 0.1035 - predictions_coarse2_loss: 0.0370 - predictions_fine_loss: 0.0084 - predictions_coarse1_acc: 0.9625 - predictions_coarse2_acc: 0.9944 - predictions_fine_acc: 0.9982 - val_loss: 0.9959 - val_predictions_coarse1_loss: 0.1549 - val_predictions_coarse2_loss: 0.5124 - val_predictions_fine_loss: 0.9959 - val_predictions_coarse1_acc: 0.9385 - val_predictions_coarse2_acc: 0.8367 - val_predictions_fine_acc: 0.7883
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.0, fine = 1.0
# Epoch 33/50
# 40000/40000 [==============================] - 63s 2ms/step - loss: 0.0087 - predictions_coarse1_loss: 0.1010 - predictions_coarse2_loss: 0.0367 - predictions_fine_loss: 0.0087 - predictions_coarse1_acc: 0.9633 - predictions_coarse2_acc: 0.9946 - predictions_fine_acc: 0.9979 - val_loss: 0.9975 - val_predictions_coarse1_loss: 0.1568 - val_predictions_coarse2_loss: 0.5107 - val_predictions_fine_loss: 0.9975 - val_predictions_coarse1_acc: 0.9379 - val_predictions_coarse2_acc: 0.8366 - val_predictions_fine_acc: 0.7885
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.0, fine = 1.0
# Epoch 34/50
# 40000/40000 [==============================] - 63s 2ms/step - loss: 0.0074 - predictions_coarse1_loss: 0.0994 - predictions_coarse2_loss: 0.0354 - predictions_fine_loss: 0.0074 - predictions_coarse1_acc: 0.9644 - predictions_coarse2_acc: 0.9952 - predictions_fine_acc: 0.9985 - val_loss: 1.0100 - val_predictions_coarse1_loss: 0.1519 - val_predictions_coarse2_loss: 0.5100 - val_predictions_fine_loss: 1.0100 - val_predictions_coarse1_acc: 0.9406 - val_predictions_coarse2_acc: 0.8389 - val_predictions_fine_acc: 0.7892
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.0, fine = 1.0
# Epoch 35/50
# 40000/40000 [==============================] - 63s 2ms/step - loss: 0.0069 - predictions_coarse1_loss: 0.1014 - predictions_coarse2_loss: 0.0347 - predictions_fine_loss: 0.0069 - predictions_coarse1_acc: 0.9633 - predictions_coarse2_acc: 0.9950 - predictions_fine_acc: 0.9987 - val_loss: 1.0120 - val_predictions_coarse1_loss: 0.1561 - val_predictions_coarse2_loss: 0.5101 - val_predictions_fine_loss: 1.0120 - val_predictions_coarse1_acc: 0.9394 - val_predictions_coarse2_acc: 0.8384 - val_predictions_fine_acc: 0.7895
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.0, fine = 1.0
# Epoch 36/50
# 40000/40000 [==============================] - 63s 2ms/step - loss: 0.0072 - predictions_coarse1_loss: 0.1017 - predictions_coarse2_loss: 0.0347 - predictions_fine_loss: 0.0072 - predictions_coarse1_acc: 0.9628 - predictions_coarse2_acc: 0.9955 - predictions_fine_acc: 0.9984 - val_loss: 1.0316 - val_predictions_coarse1_loss: 0.1508 - val_predictions_coarse2_loss: 0.5166 - val_predictions_fine_loss: 1.0316 - val_predictions_coarse1_acc: 0.9405 - val_predictions_coarse2_acc: 0.8379 - val_predictions_fine_acc: 0.7880
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.0, fine = 1.0
# Epoch 37/50
# 40000/40000 [==============================] - 63s 2ms/step - loss: 0.0067 - predictions_coarse1_loss: 0.1023 - predictions_coarse2_loss: 0.0342 - predictions_fine_loss: 0.0067 - predictions_coarse1_acc: 0.9633 - predictions_coarse2_acc: 0.9953 - predictions_fine_acc: 0.9986 - val_loss: 1.0418 - val_predictions_coarse1_loss: 0.1509 - val_predictions_coarse2_loss: 0.5138 - val_predictions_fine_loss: 1.0418 - val_predictions_coarse1_acc: 0.9418 - val_predictions_coarse2_acc: 0.8401 - val_predictions_fine_acc: 0.7887
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.0, fine = 1.0
# Epoch 38/50
# 40000/40000 [==============================] - 63s 2ms/step - loss: 0.0065 - predictions_coarse1_loss: 0.0968 - predictions_coarse2_loss: 0.0330 - predictions_fine_loss: 0.0065 - predictions_coarse1_acc: 0.9643 - predictions_coarse2_acc: 0.9957 - predictions_fine_acc: 0.9987 - val_loss: 1.0335 - val_predictions_coarse1_loss: 0.1541 - val_predictions_coarse2_loss: 0.5206 - val_predictions_fine_loss: 1.0335 - val_predictions_coarse1_acc: 0.9416 - val_predictions_coarse2_acc: 0.8340 - val_predictions_fine_acc: 0.7851
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.0, fine = 1.0
# Epoch 39/50
# 40000/40000 [==============================] - 63s 2ms/step - loss: 0.0059 - predictions_coarse1_loss: 0.1015 - predictions_coarse2_loss: 0.0330 - predictions_fine_loss: 0.0059 - predictions_coarse1_acc: 0.9637 - predictions_coarse2_acc: 0.9955 - predictions_fine_acc: 0.9988 - val_loss: 1.0372 - val_predictions_coarse1_loss: 0.1517 - val_predictions_coarse2_loss: 0.5169 - val_predictions_fine_loss: 1.0372 - val_predictions_coarse1_acc: 0.9425 - val_predictions_coarse2_acc: 0.8374 - val_predictions_fine_acc: 0.7888
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.0, fine = 1.0
# Epoch 40/50
# 40000/40000 [==============================] - 63s 2ms/step - loss: 0.0051 - predictions_coarse1_loss: 0.0995 - predictions_coarse2_loss: 0.0312 - predictions_fine_loss: 0.0051 - predictions_coarse1_acc: 0.9648 - predictions_coarse2_acc: 0.9958 - predictions_fine_acc: 0.9989 - val_loss: 1.0356 - val_predictions_coarse1_loss: 0.1504 - val_predictions_coarse2_loss: 0.5169 - val_predictions_fine_loss: 1.0356 - val_predictions_coarse1_acc: 0.9404 - val_predictions_coarse2_acc: 0.8374 - val_predictions_fine_acc: 0.7872
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.0, fine = 1.0
# Epoch 41/50
# 40000/40000 [==============================] - 63s 2ms/step - loss: 0.0051 - predictions_coarse1_loss: 0.0970 - predictions_coarse2_loss: 0.0307 - predictions_fine_loss: 0.0051 - predictions_coarse1_acc: 0.9657 - predictions_coarse2_acc: 0.9962 - predictions_fine_acc: 0.9990 - val_loss: 1.0330 - val_predictions_coarse1_loss: 0.1507 - val_predictions_coarse2_loss: 0.5139 - val_predictions_fine_loss: 1.0330 - val_predictions_coarse1_acc: 0.9422 - val_predictions_coarse2_acc: 0.8379 - val_predictions_fine_acc: 0.7899
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.0, fine = 1.0
# Epoch 42/50
# 40000/40000 [==============================] - 63s 2ms/step - loss: 0.0047 - predictions_coarse1_loss: 0.0980 - predictions_coarse2_loss: 0.0307 - predictions_fine_loss: 0.0047 - predictions_coarse1_acc: 0.9648 - predictions_coarse2_acc: 0.9958 - predictions_fine_acc: 0.9990 - val_loss: 1.0432 - val_predictions_coarse1_loss: 0.1478 - val_predictions_coarse2_loss: 0.5150 - val_predictions_fine_loss: 1.0432 - val_predictions_coarse1_acc: 0.9433 - val_predictions_coarse2_acc: 0.8390 - val_predictions_fine_acc: 0.7899
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.0, fine = 1.0
# Epoch 43/50
# 40000/40000 [==============================] - 63s 2ms/step - loss: 0.0040 - predictions_coarse1_loss: 0.0992 - predictions_coarse2_loss: 0.0292 - predictions_fine_loss: 0.0040 - predictions_coarse1_acc: 0.9647 - predictions_coarse2_acc: 0.9966 - predictions_fine_acc: 0.9994 - val_loss: 1.0499 - val_predictions_coarse1_loss: 0.1488 - val_predictions_coarse2_loss: 0.5222 - val_predictions_fine_loss: 1.0499 - val_predictions_coarse1_acc: 0.9436 - val_predictions_coarse2_acc: 0.8357 - val_predictions_fine_acc: 0.7854
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.0, fine = 1.0
# Epoch 44/50
# 40000/40000 [==============================] - 63s 2ms/step - loss: 0.0045 - predictions_coarse1_loss: 0.0965 - predictions_coarse2_loss: 0.0294 - predictions_fine_loss: 0.0045 - predictions_coarse1_acc: 0.9662 - predictions_coarse2_acc: 0.9967 - predictions_fine_acc: 0.9991 - val_loss: 1.0475 - val_predictions_coarse1_loss: 0.1494 - val_predictions_coarse2_loss: 0.5215 - val_predictions_fine_loss: 1.0475 - val_predictions_coarse1_acc: 0.9432 - val_predictions_coarse2_acc: 0.8353 - val_predictions_fine_acc: 0.7893
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.0, fine = 1.0
# Epoch 45/50
# 40000/40000 [==============================] - 63s 2ms/step - loss: 0.0043 - predictions_coarse1_loss: 0.0976 - predictions_coarse2_loss: 0.0300 - predictions_fine_loss: 0.0043 - predictions_coarse1_acc: 0.9652 - predictions_coarse2_acc: 0.9966 - predictions_fine_acc: 0.9990 - val_loss: 1.0413 - val_predictions_coarse1_loss: 0.1576 - val_predictions_coarse2_loss: 0.5148 - val_predictions_fine_loss: 1.0413 - val_predictions_coarse1_acc: 0.9381 - val_predictions_coarse2_acc: 0.8371 - val_predictions_fine_acc: 0.7898
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.0, fine = 1.0
# Epoch 46/50
# 40000/40000 [==============================] - 63s 2ms/step - loss: 0.0044 - predictions_coarse1_loss: 0.0983 - predictions_coarse2_loss: 0.0291 - predictions_fine_loss: 0.0044 - predictions_coarse1_acc: 0.9656 - predictions_coarse2_acc: 0.9963 - predictions_fine_acc: 0.9990 - val_loss: 1.0527 - val_predictions_coarse1_loss: 0.1488 - val_predictions_coarse2_loss: 0.5101 - val_predictions_fine_loss: 1.0527 - val_predictions_coarse1_acc: 0.9435 - val_predictions_coarse2_acc: 0.8407 - val_predictions_fine_acc: 0.7897
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.0, fine = 1.0
# Epoch 47/50
# 40000/40000 [==============================] - 63s 2ms/step - loss: 0.0041 - predictions_coarse1_loss: 0.0956 - predictions_coarse2_loss: 0.0295 - predictions_fine_loss: 0.0041 - predictions_coarse1_acc: 0.9663 - predictions_coarse2_acc: 0.9962 - predictions_fine_acc: 0.9991 - val_loss: 1.0609 - val_predictions_coarse1_loss: 0.1509 - val_predictions_coarse2_loss: 0.5225 - val_predictions_fine_loss: 1.0609 - val_predictions_coarse1_acc: 0.9432 - val_predictions_coarse2_acc: 0.8356 - val_predictions_fine_acc: 0.7871
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.0, fine = 1.0
# Epoch 48/50
# 40000/40000 [==============================] - 63s 2ms/step - loss: 0.0039 - predictions_coarse1_loss: 0.0970 - predictions_coarse2_loss: 0.0290 - predictions_fine_loss: 0.0039 - predictions_coarse1_acc: 0.9662 - predictions_coarse2_acc: 0.9965 - predictions_fine_acc: 0.9992 - val_loss: 1.0492 - val_predictions_coarse1_loss: 0.1503 - val_predictions_coarse2_loss: 0.5118 - val_predictions_fine_loss: 1.0492 - val_predictions_coarse1_acc: 0.9425 - val_predictions_coarse2_acc: 0.8402 - val_predictions_fine_acc: 0.7917
#
# Epoch 00048: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.0, fine = 1.0
# Epoch 49/50
# 40000/40000 [==============================] - 63s 2ms/step - loss: 0.0040 - predictions_coarse1_loss: 0.0975 - predictions_coarse2_loss: 0.0280 - predictions_fine_loss: 0.0040 - predictions_coarse1_acc: 0.9657 - predictions_coarse2_acc: 0.9967 - predictions_fine_acc: 0.9991 - val_loss: 1.0499 - val_predictions_coarse1_loss: 0.1518 - val_predictions_coarse2_loss: 0.5128 - val_predictions_fine_loss: 1.0499 - val_predictions_coarse1_acc: 0.9409 - val_predictions_coarse2_acc: 0.8392 - val_predictions_fine_acc: 0.7923
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.0, fine = 1.0
# Epoch 50/50
# 40000/40000 [==============================] - 63s 2ms/step - loss: 0.0036 - predictions_coarse1_loss: 0.0976 - predictions_coarse2_loss: 0.0272 - predictions_fine_loss: 0.0036 - predictions_coarse1_acc: 0.9653 - predictions_coarse2_acc: 0.9971 - predictions_fine_acc: 0.9992 - val_loss: 1.0630 - val_predictions_coarse1_loss: 0.1523 - val_predictions_coarse2_loss: 0.5123 - val_predictions_fine_loss: 1.0630 - val_predictions_coarse1_acc: 0.9414 - val_predictions_coarse2_acc: 0.8401 - val_predictions_fine_acc: 0.7928
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.0, fine = 1.0

# %%
model.evaluate(test_features, [y_test_c_cat1,y_test_c_cat2, y_test_cat])
# Out:
# 10000/10000 [==============================] - 7s 731us/step
# [1.1079905588626862,
#  0.16439523479640483,
#  0.5621586464881897,
#  1.1079905588626862,
#  0.935,
#  0.8285,
#  0.7839]

# %%
print('Total training time: {}'.format(training_time))
# Out:
# Total training time: 3245.3184847831726

# %%
model.save('drive/TCC-ITAU/cifar-10/models/adaptative-guide-net.h5')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-9977a92d8940> in <module>()
# ----> 1 model.save('drive/TCC-ITAU/cifar-10/models/adaptative-guide-net.h5')
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/network.py in save(self, filepath, overwrite, include_optimizer)
#    1088             raise NotImplementedError
#    1089         from ..models import save_model
# -> 1090         save_model(self, filepath, overwrite, include_optimizer)
#    1091
#    1092     def save_weights(self, filepath, overwrite=True):
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py in save_model(model, filepath, overwrite, include_optimizer)
#     380
#     381     try:
# --> 382         _serialize_model(model, f, include_optimizer)
#     383     finally:
#     384         if opened_new_file:
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py in _serialize_model(model, f, include_optimizer)
#     136                 'sample_weight_mode': model.sample_weight_mode,
#     137                 'loss_weights': model.loss_weights,
# --> 138             }, default=get_json_type).encode('utf8')
#     139             symbolic_weights = getattr(model.optimizer, 'weights')
#     140             if symbolic_weights:
#
# /usr/lib/python3.6/json/__init__.py in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     236         check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     237         separators=separators, default=default, sort_keys=sort_keys,
# --> 238         **kw).encode(obj)
#     239
#     240
#
# /usr/lib/python3.6/json/encoder.py in encode(self, o)
#     197         # exceptions aren't as detailed.  The list call should be roughly
#     198         # equivalent to the PySequence_Fast that ''.join() would do.
# --> 199         chunks = self.iterencode(o, _one_shot=True)
#     200         if not isinstance(chunks, (list, tuple)):
#     201             chunks = list(chunks)
#
# /usr/lib/python3.6/json/encoder.py in iterencode(self, o, _one_shot)
#     255                 self.key_separator, self.item_separator, self.sort_keys,
#     256                 self.skipkeys, _one_shot)
# --> 257         return _iterencode(o, 0)
#     258
#     259 def _make_iterencode(markers, _default, _encoder, _indent, _floatstr,
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py in get_json_type(obj)
#      72             return obj.__name__
#      73
# ---> 74         raise TypeError('Not JSON Serializable: %s' % (obj,))
#      75
#      76     from .. import __version__ as keras_version
#
# TypeError: Not JSON Serializable: <tf.Variable 'alpha:0' shape=() dtype=float32_ref>
