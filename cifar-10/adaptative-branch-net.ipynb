# %% [markdown]
# # Adaptative Branch-net

# %%
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse

from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass

# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}
# Out:
# E: Package 'python-software-properties' has no installation candidate
# Selecting previously unselected package libfuse2:amd64.
# (Reading database ... 22280 files and directories currently installed.)
# Preparing to unpack .../libfuse2_2.9.7-1ubuntu1_amd64.deb ...
# Unpacking libfuse2:amd64 (2.9.7-1ubuntu1) ...
# Selecting previously unselected package fuse.
# Preparing to unpack .../fuse_2.9.7-1ubuntu1_amd64.deb ...
# Unpacking fuse (2.9.7-1ubuntu1) ...
# Selecting previously unselected package google-drive-ocamlfuse.
# Preparing to unpack .../google-drive-ocamlfuse_0.7.0-0ubuntu1~ubuntu18.04.1_amd64.deb ...
# Unpacking google-drive-ocamlfuse (0.7.0-0ubuntu1~ubuntu18.04.1) ...
# Setting up libfuse2:amd64 (2.9.7-1ubuntu1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...
# Setting up fuse (2.9.7-1ubuntu1) ...
# Setting up google-drive-ocamlfuse (0.7.0-0ubuntu1~ubuntu18.04.1) ...
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# ··········
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# Please enter the verification code: Access token retrieved correctly.

# %%
# !mkdir -p drive
# !google-drive-ocamlfuse drive

# %% [markdown]
# ## Loading the data

# %%
from time import time
import os
import gzip
import numpy as np
from keras.utils import np_utils
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

from keras.datasets import cifar10
# Out:
# Using TensorFlow backend.

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, 
                                                  test_size=0.2, 
                                                  random_state=1974)

# %%
train_features = X_train.reshape(X_train.shape[0], 32, 32, 3)/255
vali_features = X_val.reshape(X_val.shape[0], 32, 32, 3)/255
test_features = X_test.reshape(X_test.shape[0], 32, 32, 3)/255

y_train_cat = np_utils.to_categorical(y_train)
y_val_cat = np_utils.to_categorical(y_val)
y_test_cat = np_utils.to_categorical(y_test)

# %% [markdown]
# ## Defining coarse labels

# %%
dict_coarse1 = {0: 0,
              1: 0,
              2: 1,
              3: 1,
              4: 1,
              5: 1,
              6: 1,
              7: 1,
              8: 0,
              9: 0}

dict_coarse2 = {0: 0,
              1: 1,
              2: 3,
              3: 4,
              4: 6,
              5: 4,
              6: 5,
              7: 6,
              8: 2,
              9: 1}

y_train_coarse1 = np.vectorize(dict_coarse1.get)(y_train)
y_val_coarse1 = np.vectorize(dict_coarse1.get)(y_val)
y_test_coarse1 = np.vectorize(dict_coarse1.get)(y_test)

y_train_coarse2 = np.vectorize(dict_coarse2.get)(y_train)
y_val_coarse2 = np.vectorize(dict_coarse2.get)(y_val)
y_test_coarse2 = np.vectorize(dict_coarse2.get)(y_test)

y_train_c_cat1 = np_utils.to_categorical(y_train_coarse1)
y_val_c_cat1 = np_utils.to_categorical(y_val_coarse1)
y_test_c_cat1 = np_utils.to_categorical(y_test_coarse1)

y_train_c_cat2 = np_utils.to_categorical(y_train_coarse2)
y_val_c_cat2 = np_utils.to_categorical(y_val_coarse2)
y_test_c_cat2 = np_utils.to_categorical(y_test_coarse2)

# %% [markdown]
# ## Training the model

# %%
import keras
from keras.models import Model
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D, Input
from keras import optimizers
from keras.callbacks import TensorBoard, ReduceLROnPlateau, CSVLogger
from keras.layers.normalization import BatchNormalization
from keras import backend as K

# %%
class TimingCallback(keras.callbacks.Callback):
  """Callback that saves the time elapsed of each epoch to the log.
  """  
  def on_epoch_begin(self, epoch, logs={}):
    self.starttime=time()
  def on_epoch_end(self, epoch, logs={}):
    logs['time_elapsed'] = (time()-self.starttime)

# %%
class AdaptativeLossWeightsModifier3Vars(keras.callbacks.Callback):
  def __init__(self, alpha, beta, gamma, decay_rate=0.5):
    self.alpha = alpha
    self.beta = beta
    self.gamma = gamma
    self.decay_rate = decay_rate
    self.offset_epoch = 0
    self.par_reduce = [0, 1]
  
  def calculate_exponential(self, ratio, decay_rate, epoch):
    return np.exp(-ratio*decay_rate*epoch)

  def on_epoch_end(self, epoch, logs={}):
    list_vars = [K.eval(self.alpha), K.eval(self.beta), K.eval(self.gamma)]
    if epoch < 1:
      pass
    
    else:
      loss_coarse1 = self.model.history.history['predictions_coarse1_loss'][-1]
      loss_coarse2 = self.model.history.history['predictions_coarse2_loss'][-1]
      loss_fine = self.model.history.history['predictions_fine_loss'][-1]
      
      losses_classes = [loss_coarse1, loss_coarse2, loss_fine]
      ratio = losses_classes[self.par_reduce[0]] / losses_classes[self.par_reduce[1]] *(epoch + 1 - self.offset_epoch) 
      
      decaying = self.calculate_exponential(ratio, self.decay_rate/(max(self.par_reduce)**2), epoch)
      increasing = 1 - decaying
    
    
      if (1 - increasing) < 0.3 and (self.par_reduce[1] < len(list_vars) - 1):
        list_vars[self.par_reduce[0]] = 0
        list_vars[self.par_reduce[1]] = 1
        self.par_reduce = [i + 1 for i in self.par_reduce]
        self.offset_epoch = self.offset_epoch + epoch

      else:
       list_vars[self.par_reduce[0]] = decaying
       list_vars[self.par_reduce[1]] = increasing

        
      K.set_value(self.alpha, list_vars[0])
      K.set_value(self.beta, list_vars[1])
      K.set_value(self.gamma, list_vars[2])
        
      print('Changing loss weights to: coarse1 = {}, coarse2 = {}, fine = {}'.format(K.eval(self.alpha), K.eval(self.beta), K.eval(self.gamma)))
    
    logs['alpha'] = K.eval(self.alpha)
    logs['beta'] = K.eval(self.beta) 
    logs['gamma'] = K.eval(self.gamma)

# %%
img_rows, img_cols = 32, 32
input_shape = (img_rows, img_cols, 3)

num_classes_coarse1 = 2
num_classes_coarse2 = 7
num_classes_fine = 10

img_input = Input(shape=input_shape, name='input')


x = Conv2D(128, (3, 3), activation='relu', name='block1_conv1', padding='same')(img_input)

x = Conv2D(128, (3, 3), activation='relu', name='block1_conv2', padding='same')(x)
x = MaxPooling2D((2, 2), name='block2_pool')(x)

#---- coarse branch 1 ----
coarse1 = Flatten(name='c1_flatten')(x)
coarse1 = Dense(64, name='c1_fc_1')(coarse1)
coarse1 = BatchNormalization()(coarse1)
coarse1 = Activation('relu')(coarse1)
coarse1 = Dropout(0.5)(coarse1)

coarse1 = Dense(64, name='c1_fc_2')(coarse1)
coarse1 = BatchNormalization()(coarse1)
coarse1 = Activation('relu')(coarse1)
coarse1 = Dropout(0.5)(coarse1)

coarse_pred1 = Dense(num_classes_coarse1, activation='softmax', name='predictions_coarse1')(coarse1)

x = Conv2D(128, (3, 3), activation='relu', name='block1_conv3', padding='same')(x)
x = MaxPooling2D((2, 2), name='block3_pool')(x)

#---- coarse branch 2 ----
coarse2 = Flatten(name='c2_flatten')(x)
coarse2 = Dense(512, name='c2_fc_1')(coarse2)
coarse2 = BatchNormalization()(coarse2)
coarse2 = Activation('relu')(coarse2)
coarse2 = Dropout(0.5)(coarse2)

coarse2 = Dense(512, name='c2_fc_2')(coarse2)
coarse2 = BatchNormalization()(coarse2)
coarse2 = Activation('relu')(coarse2)
coarse2 = Dropout(0.5)(coarse2)

coarse_pred2 = Dense(num_classes_coarse2, activation='softmax', name='predictions_coarse2')(coarse2)


x = Flatten(name='flatten')(x)
x = Dense(512, name='fc_1')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = Dropout(0.5)(x)

x = Dense(512, name='fc_2')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = Dropout(0.5)(x)

fine_pred = Dense(num_classes_fine, activation='softmax', name='predictions_fine')(x)

# %%
model = Model(inputs=img_input, outputs= [coarse_pred1, coarse_pred2, fine_pred], name='adaptative_branch_net')

model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 32, 32, 128)  3584        input[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 32, 32, 128)  147584      block1_conv1[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 16, 16, 128)  0           block1_conv2[0][0]
# __________________________________________________________________________________________________
# block1_conv3 (Conv2D)           (None, 16, 16, 128)  147584      block2_pool[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 8, 8, 128)    0           block1_conv3[0][0]
# __________________________________________________________________________________________________
# c1_flatten (Flatten)            (None, 32768)        0           block2_pool[0][0]
# __________________________________________________________________________________________________
# c2_flatten (Flatten)            (None, 8192)         0           block3_pool[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 8192)         0           block3_pool[0][0]
# __________________________________________________________________________________________________
# c1_fc_1 (Dense)                 (None, 64)           2097216     c1_flatten[0][0]
# __________________________________________________________________________________________________
# c2_fc_1 (Dense)                 (None, 512)          4194816     c2_flatten[0][0]
# __________________________________________________________________________________________________
# fc_1 (Dense)                    (None, 512)          4194816     flatten[0][0]
# __________________________________________________________________________________________________
# batch_normalization_73 (BatchNo (None, 64)           256         c1_fc_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_75 (BatchNo (None, 512)          2048        c2_fc_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, 512)          2048        fc_1[0][0]
# __________________________________________________________________________________________________
# activation_73 (Activation)      (None, 64)           0           batch_normalization_73[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, 512)          0           batch_normalization_75[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 512)          0           batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# dropout_73 (Dropout)            (None, 64)           0           activation_73[0][0]
# __________________________________________________________________________________________________
# dropout_75 (Dropout)            (None, 512)          0           activation_75[0][0]
# __________________________________________________________________________________________________
# dropout_77 (Dropout)            (None, 512)          0           activation_77[0][0]
# __________________________________________________________________________________________________
# c1_fc_2 (Dense)                 (None, 64)           4160        dropout_73[0][0]
# __________________________________________________________________________________________________
# c2_fc_2 (Dense)                 (None, 512)          262656      dropout_75[0][0]
# __________________________________________________________________________________________________
# fc_2 (Dense)                    (None, 512)          262656      dropout_77[0][0]
# __________________________________________________________________________________________________
# batch_normalization_74 (BatchNo (None, 64)           256         c1_fc_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_76 (BatchNo (None, 512)          2048        c2_fc_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_78 (BatchNo (None, 512)          2048        fc_2[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 64)           0           batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, 512)          0           batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, 512)          0           batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# dropout_74 (Dropout)            (None, 64)           0           activation_74[0][0]
# __________________________________________________________________________________________________
# dropout_76 (Dropout)            (None, 512)          0           activation_76[0][0]
# __________________________________________________________________________________________________
# dropout_78 (Dropout)            (None, 512)          0           activation_78[0][0]
# __________________________________________________________________________________________________
# predictions_coarse1 (Dense)     (None, 2)            130         dropout_74[0][0]
# __________________________________________________________________________________________________
# predictions_coarse2 (Dense)     (None, 7)            3591        dropout_76[0][0]
# __________________________________________________________________________________________________
# predictions_fine (Dense)        (None, 10)           5130        dropout_78[0][0]
# ==================================================================================================
# Total params: 11,332,627
# Trainable params: 11,328,275
# Non-trainable params: 4,352
# __________________________________________________________________________________________________

# %%
alpha = K.variable(value=0.9, dtype="float32", name="alpha") 
beta = K.variable(value=0.1, dtype="float32", name="beta") 
gamma = K.variable(value=0, dtype="float32", name="gamma") 

adam = optimizers.Adam(lr=0.00025)

model.compile(loss='categorical_crossentropy', 
              optimizer=adam,
              loss_weights=[alpha, beta, gamma],
              metrics=['accuracy'])

# %%
clr_cb = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, verbose=1)
time_cb = TimingCallback()
change_lw = AdaptativeLossWeightsModifier3Vars(alpha, beta, gamma, decay_rate=0.5)
csv_cb = CSVLogger('drive/TCC-ITAU/cifar-10/training-data/branch-net/adaptative-branch-net.csv', separator=',', append=False)


cbks = [clr_cb, time_cb, change_lw, csv_cb]

# %%
epochs = 50
start_time = time()
training = model.fit(train_features, [y_train_c_cat1, y_train_c_cat2, y_train_cat],
                     validation_data=(vali_features, [y_val_c_cat1, y_val_c_cat2, y_val_cat]),
                     epochs=epochs,
                     batch_size=256, 
                     callbacks=cbks,
                     verbose=1)
training_time = time() - start_time
# Out:
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/50
# 40000/40000 [==============================] - 36s 905us/step - loss: 0.4810 - predictions_coarse1_loss: 0.3720 - predictions_coarse2_loss: 1.4615 - predictions_fine_loss: 3.1711 - predictions_coarse1_acc: 0.8426 - predictions_coarse2_acc: 0.4842 - predictions_fine_acc: 0.0950 - val_loss: 0.3925 - val_predictions_coarse1_loss: 0.2896 - val_predictions_coarse2_loss: 1.3189 - val_predictions_fine_loss: 2.6867 - val_predictions_coarse1_acc: 0.8742 - val_predictions_coarse2_acc: 0.4952 - val_predictions_fine_acc: 0.0914
# Epoch 2/50
# 40000/40000 [==============================] - 28s 689us/step - loss: 0.3212 - predictions_coarse1_loss: 0.2435 - predictions_coarse2_loss: 1.0205 - predictions_fine_loss: 3.1791 - predictions_coarse1_acc: 0.9060 - predictions_coarse2_acc: 0.6298 - predictions_fine_acc: 0.0936 - val_loss: 0.2504 - val_predictions_coarse1_loss: 0.1832 - val_predictions_coarse2_loss: 0.8557 - val_predictions_fine_loss: 2.5645 - val_predictions_coarse1_acc: 0.9303 - val_predictions_coarse2_acc: 0.6844 - val_predictions_fine_acc: 0.0887
# Changing loss weights to: coarse1 = 0.7752560973167419, coarse2 = 0.22474391758441925, fine = 0.0
# Epoch 3/50
# 40000/40000 [==============================] - 28s 689us/step - loss: 0.3389 - predictions_coarse1_loss: 0.1977 - predictions_coarse2_loss: 0.8257 - predictions_fine_loss: 3.1577 - predictions_coarse1_acc: 0.9252 - predictions_coarse2_acc: 0.7036 - predictions_fine_acc: 0.0957 - val_loss: 0.3546 - val_predictions_coarse1_loss: 0.2147 - val_predictions_coarse2_loss: 0.8372 - val_predictions_fine_loss: 2.5803 - val_predictions_coarse1_acc: 0.9144 - val_predictions_coarse2_acc: 0.6939 - val_predictions_fine_acc: 0.0994
# Changing loss weights to: coarse1 = 0.48884543776512146, coarse2 = 0.5111545324325562, fine = 0.0
# Epoch 4/50
# 40000/40000 [==============================] - 27s 686us/step - loss: 0.4404 - predictions_coarse1_loss: 0.1711 - predictions_coarse2_loss: 0.6979 - predictions_fine_loss: 3.1412 - predictions_coarse1_acc: 0.9361 - predictions_coarse2_acc: 0.7519 - predictions_fine_acc: 0.0968 - val_loss: 0.4725 - val_predictions_coarse1_loss: 0.1715 - val_predictions_coarse2_loss: 0.7603 - val_predictions_fine_loss: 2.5402 - val_predictions_coarse1_acc: 0.9381 - val_predictions_coarse2_acc: 0.7227 - val_predictions_fine_acc: 0.0859
# Changing loss weights to: coarse1 = 0.0, coarse2 = 1.0, fine = 0.0
# Epoch 5/50
# 40000/40000 [==============================] - 27s 686us/step - loss: 0.5839 - predictions_coarse1_loss: 0.1583 - predictions_coarse2_loss: 0.5839 - predictions_fine_loss: 3.1514 - predictions_coarse1_acc: 0.9411 - predictions_coarse2_acc: 0.7898 - predictions_fine_acc: 0.0947 - val_loss: 0.6390 - val_predictions_coarse1_loss: 0.1477 - val_predictions_coarse2_loss: 0.6390 - val_predictions_fine_loss: 2.5602 - val_predictions_coarse1_acc: 0.9439 - val_predictions_coarse2_acc: 0.7722 - val_predictions_fine_acc: 0.0937
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.8007704615592957, fine = 0.19922953844070435
# Epoch 6/50
# 40000/40000 [==============================] - 28s 688us/step - loss: 0.5877 - predictions_coarse1_loss: 0.1595 - predictions_coarse2_loss: 0.4561 - predictions_fine_loss: 1.1164 - predictions_coarse1_acc: 0.9403 - predictions_coarse2_acc: 0.8385 - predictions_fine_acc: 0.6129 - val_loss: 0.6389 - val_predictions_coarse1_loss: 0.1510 - val_predictions_coarse2_loss: 0.5690 - val_predictions_fine_loss: 0.9200 - val_predictions_coarse1_acc: 0.9410 - val_predictions_coarse2_acc: 0.7984 - val_predictions_fine_acc: 0.6830
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0
50
# 40000/40000 [==============================] - 27s 686us/step - loss: 0.2000 - predictions_coarse1_loss: 0.1685 - predictions_coarse2_loss: 0.1933 - predictions_fine_loss: 0.2000 - predictions_coarse1_acc: 0.9371 - predictions_coarse2_acc: 0.9371 - predictions_fine_acc: 0.9322 - val_loss: 0.8054 - val_predictions_coarse1_loss: 0.1779 - val_predictions_coarse2_loss: 0.5288 - val_predictions_fine_loss: 0.8060 - val_predictions_coarse1_acc: 0.9302 - val_predictions_coarse2_acc: 0.8230 - val_predictions_fine_acc: 0.7629
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Changing loss weights to: coarse1 = 0.0, coarse2 = 6.09929375059437e-05, fine = 0.9999390244483948
# Epoch 13/50
# 40000/40000 [==============================] - 27s 687us/step - loss: 0.1222 - predictions_coarse1_loss: 0.1634 - predictions_coarse2_loss: 0.1743 - predictions_fine_loss: 0.1222 - predictions_coarse1_acc: 0.9387 - predictions_coarse2_acc: 0.9443 - predictions_fine_acc: 0.9612 - val_loss: 0.7465 - val_predictions_coarse1_loss: 0.1600 - val_predictions_coarse2_loss: 0.4947 - val_predictions_fine_loss: 0.7465 - val_predictions_coarse1_acc: 0.9381 - val_predictions_coarse2_acc: 0.8328 - val_predictions_fine_acc: 0.7712
# Changing loss weights to: coarse1 = 0.0, coarse2 = 5.049437845627835e-07, fine = 0.9999995231628418
# Epoch 14/50
# 40000/40000 [==============================] - 27s 685us/step - loss: 0.0933 - predictions_coarse1_loss: 0.1640 - predictions_coarse2_loss: 0.1686 - predictions_fine_loss: 0.0933 - predictions_coarse1_acc: 0.9371 - predictions_coarse2_acc: 0.9470 - predictions_fine_acc: 0.9731 - val_loss: 0.7869 - val_predictions_coarse1_loss: 0.1612 - val_predictions_coarse2_loss: 0.5076 - val_predictions_fine_loss: 0.7869 - val_predictions_coarse1_acc: 0.9363 - val_predictions_coarse2_acc: 0.8275 - val_predictions_fine_acc: 0.7750
# Changing loss weights to: coarse1 = 0.0, coarse2 = 8.580086294229794e-12, fine = 1.0
# Epoch 15/50
# 40000/40000 [==============================] - 27s 685us/step - loss: 0.0783 - predictions_coarse1_loss: 0.1641 - predictions_coarse2_loss: 0.1667 - predictions_fine_loss: 0.0783 - predictions_coarse1_acc: 0.9390 - predictions_coarse2_acc: 0.9484 - predictions_fine_acc: 0.9775 - val_loss: 0.7933 - val_predictions_coarse1_loss: 0.1641 - val_predictions_coarse2_loss: 0.4925 - val_predictions_fine_loss: 0.7933 - val_predictions_coarse1_acc: 0.9352 - val_predictions_coarse2_acc: 0.8305 - val_predictions_fine_acc: 0.7775
# Changing loss weights to: coarse1 = 0.0, coarse2 = 3.347101976273346e-17, fine = 1.0
# Epoch 16/50
# 40000/40000 [==============================] - 27s 685us/step - loss: 0.0606 - predictions_coarse1_loss: 0.1650 - predictions_coarse2_loss: 0.1635 - predictions_fine_loss: 0.0606 - predictions_coarse1_acc: 0.9378 - predictions_coarse2_acc: 0.9496 - predictions_fine_acc: 0.9839 - val_loss: 0.8229 - val_predictions_coarse1_loss: 0.1601 - val_predictions_coarse2_loss: 0.4980 - val_predictions_fine_loss: 0.8229 - val_predictions_coarse1_acc: 0.9373 - val_predictions_coarse2_acc: 0.8341 - val_predictions_fine_acc: 0.7773
# Changing loss weights to: coarse1 = 0.0, coarse2 = 2.8470375033548064e-23, fine = 1.0
# Epoch 17/50
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.0, fine = 1.0
# Epoch 48/50
# 40000/40000 [==============================] - 27s 684us/step - loss: 0.0064 - predictions_coarse1_loss: 0.1628 - predictions_coarse2_loss: 0.1528 - predictions_fine_loss: 0.0064 - predictions_coarse1_acc: 0.9401 - predictions_coarse2_acc: 0.9536 - predictions_fine_acc: 0.9988 - val_loss: 1.0293 - val_predictions_coarse1_loss: 0.1597 - val_predictions_coarse2_loss: 0.4857 - val_predictions_fine_loss: 1.0293 - val_predictions_coarse1_acc: 0.9386 - val_predictions_coarse2_acc: 0.8358 - val_predictions_fine_acc: 0.7830
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.0, fine = 1.0
# Epoch 49/50
# 40000/40000 [==============================] - 27s 684us/step - loss: 0.0058 - predictions_coarse1_loss: 0.1621 - predictions_coarse2_loss: 0.1505 - predictions_fine_loss: 0.0058 - predictions_coarse1_acc: 0.9388 - predictions_coarse2_acc: 0.9562 - predictions_fine_acc: 0.9989 - val_loss: 1.0282 - val_predictions_coarse1_loss: 0.1618 - val_predictions_coarse2_loss: 0.4865 - val_predictions_fine_loss: 1.0282 - val_predictions_coarse1_acc: 0.9362 - val_predictions_coarse2_acc: 0.8356 - val_predictions_fine_acc: 0.7832
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.0, fine = 1.0
# Epoch 50/50
# 40000/40000 [==============================] - 27s 685us/step - loss: 0.0061 - predictions_coarse1_loss: 0.1641 - predictions_coarse2_loss: 0.1531 - predictions_fine_loss: 0.0061 - predictions_coarse1_acc: 0.9375 - predictions_coarse2_acc: 0.9548 - predictions_fine_acc: 0.9989 - val_loss: 1.0320 - val_predictions_coarse1_loss: 0.1611 - val_predictions_coarse2_loss: 0.4881 - val_predictions_fine_loss: 1.0320 - val_predictions_coarse1_acc: 0.9374 - val_predictions_coarse2_acc: 0.8341 - val_predictions_fine_acc: 0.7833
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.0, fine = 1.0

# %%
model.evaluate(test_features, [y_test_c_cat1,y_test_c_cat2, y_test_cat])
# Out:
# 10000/10000 [==============================] - 5s 475us/step
# [1.088071904182434,
#  0.1722930873274803,
#  0.5149368666648865,
#  1.088071904182434,
#  0.9309,
#  0.8286,
#  0.7753]

# %%
print('Total training time: {}'.format(training_time))
# Out:
# Total training time: 1420.0694496631622

# %%
model.save('drive/TCC-ITAU/cifar-10/models/adaptative-branch-net.h5')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-77-8d09956c7a24> in <module>()
# ----> 1 model.save('drive/TCC-ITAU/cifar-10/models/adaptative-branch-net.h5')
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/network.py in save(self, filepath, overwrite, include_optimizer)
#    1088             raise NotImplementedError
#    1089         from ..models import save_model
# -> 1090         save_model(self, filepath, overwrite, include_optimizer)
#    1091
#    1092     def save_weights(self, filepath, overwrite=True):
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py in save_model(model, filepath, overwrite, include_optimizer)
#     380
#     381     try:
# --> 382         _serialize_model(model, f, include_optimizer)
#     383     finally:
#     384         if opened_new_file:
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py in _serialize_model(model, f, include_optimizer)
#     136                 'sample_weight_mode': model.sample_weight_mode,
#     137                 'loss_weights': model.loss_weights,
# --> 138             }, default=get_json_type).encode('utf8')
#     139             symbolic_weights = getattr(model.optimizer, 'weights')
#     140             if symbolic_weights:
#
# /usr/lib/python3.6/json/__init__.py in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     236         check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     237         separators=separators, default=default, sort_keys=sort_keys,
# --> 238         **kw).encode(obj)
#     239
#     240
#
# /usr/lib/python3.6/json/encoder.py in encode(self, o)
#     197         # exceptions aren't as detailed.  The list call should be roughly
#     198         # equivalent to the PySequence_Fast that ''.join() would do.
# --> 199         chunks = self.iterencode(o, _one_shot=True)
#     200         if not isinstance(chunks, (list, tuple)):
#     201             chunks = list(chunks)
#
# /usr/lib/python3.6/json/encoder.py in iterencode(self, o, _one_shot)
#     255                 self.key_separator, self.item_separator, self.sort_keys,
#     256                 self.skipkeys, _one_shot)
# --> 257         return _iterencode(o, 0)
#     258
#     259 def _make_iterencode(markers, _default, _encoder, _indent, _floatstr,
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py in get_json_type(obj)
#      72             return obj.__name__
#      73
# ---> 74         raise TypeError('Not JSON Serializable: %s' % (obj,))
#      75
#      76     from .. import __version__ as keras_version
#
# TypeError: Not JSON Serializable: <tf.Variable 'alpha_12:0' shape=() dtype=float32_ref>
