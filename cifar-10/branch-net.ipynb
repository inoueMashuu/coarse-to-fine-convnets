# %% [markdown]
# # Branch-net

# %%
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse

from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass

# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}
# Out:
# E: Package 'python-software-properties' has no installation candidate
# Selecting previously unselected package libfuse2:amd64.
# (Reading database ... 22280 files and directories currently installed.)
# Preparing to unpack .../libfuse2_2.9.7-1ubuntu1_amd64.deb ...
# Unpacking libfuse2:amd64 (2.9.7-1ubuntu1) ...
# Selecting previously unselected package fuse.
# Preparing to unpack .../fuse_2.9.7-1ubuntu1_amd64.deb ...
# Unpacking fuse (2.9.7-1ubuntu1) ...
# Selecting previously unselected package google-drive-ocamlfuse.
# Preparing to unpack .../google-drive-ocamlfuse_0.7.0-0ubuntu1~ubuntu18.04.1_amd64.deb ...
# Unpacking google-drive-ocamlfuse (0.7.0-0ubuntu1~ubuntu18.04.1) ...
# Setting up libfuse2:amd64 (2.9.7-1ubuntu1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...
# Setting up fuse (2.9.7-1ubuntu1) ...
# Setting up google-drive-ocamlfuse (0.7.0-0ubuntu1~ubuntu18.04.1) ...
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# ··········
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# Please enter the verification code: Access token retrieved correctly.

# %%
# !mkdir -p drive
# !google-drive-ocamlfuse drive

# %% [markdown]
# ## Loading the data

# %%
from time import time
import os
import gzip
import numpy as np
from keras.utils import np_utils
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

from keras.datasets import cifar10
# Out:
# Using TensorFlow backend.

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, 
                                                  test_size=0.2, 
                                                  random_state=1974)

# %%
train_features = X_train.reshape(X_train.shape[0], 32, 32, 3)/255
vali_features = X_val.reshape(X_val.shape[0], 32, 32, 3)/255
test_features = X_test.reshape(X_test.shape[0], 32, 32, 3)/255

y_train_cat = np_utils.to_categorical(y_train)
y_val_cat = np_utils.to_categorical(y_val)
y_test_cat = np_utils.to_categorical(y_test)

# %% [markdown]
# ## Defining coarse labels

# %%
dict_coarse1 = {0: 0,
              1: 0,
              2: 1,
              3: 1,
              4: 1,
              5: 1,
              6: 1,
              7: 1,
              8: 0,
              9: 0}

dict_coarse2 = {0: 0,
              1: 1,
              2: 3,
              3: 4,
              4: 6,
              5: 4,
              6: 5,
              7: 6,
              8: 2,
              9: 1}

y_train_coarse1 = np.vectorize(dict_coarse1.get)(y_train)
y_val_coarse1 = np.vectorize(dict_coarse1.get)(y_val)
y_test_coarse1 = np.vectorize(dict_coarse1.get)(y_test)

y_train_coarse2 = np.vectorize(dict_coarse2.get)(y_train)
y_val_coarse2 = np.vectorize(dict_coarse2.get)(y_val)
y_test_coarse2 = np.vectorize(dict_coarse2.get)(y_test)

y_train_c_cat1 = np_utils.to_categorical(y_train_coarse1)
y_val_c_cat1 = np_utils.to_categorical(y_val_coarse1)
y_test_c_cat1 = np_utils.to_categorical(y_test_coarse1)

y_train_c_cat2 = np_utils.to_categorical(y_train_coarse2)
y_val_c_cat2 = np_utils.to_categorical(y_val_coarse2)
y_test_c_cat2 = np_utils.to_categorical(y_test_coarse2)

# %% [markdown]
# ## Training the model

# %%
import keras
from keras.models import Model
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D, Input
from keras import optimizers
from keras.callbacks import TensorBoard, ReduceLROnPlateau, CSVLogger
from keras.layers.normalization import BatchNormalization
from keras import backend as K

# %%
class TimingCallback(keras.callbacks.Callback):
  """Callback that saves the time elapsed of each epoch to the log.
  """  
  def on_epoch_begin(self, epoch, logs={}):
    self.starttime=time()
  def on_epoch_end(self, epoch, logs={}):
    logs['time_elapsed'] = (time()-self.starttime)

# %%
class LossWeightsModifier3Vars(keras.callbacks.Callback):
  """Callback that modifies the loss weights on certain epochs.
    # Arguments
        alpha: coeficient for the coarser class.
        beta: coeficient for the second level coarse class.
        gamma: coeficient for the fine class.
  """  
  def __init__(self, alpha, beta, gamma):
    self.alpha = alpha
    self.beta = beta
    self.gamma = gamma
    
  def on_epoch_end(self, epoch, logs={}):

    if epoch == 4:
      K.set_value(self.alpha, 0)
      K.set_value(self.beta, 0.8)
      K.set_value(self.gamma, 0.2)
      print('Changing loss weights to: coarse1 = {}, coarse2 = {}, fine = {}'.format(K.eval(self.alpha), K.eval(self.beta), K.eval(self.gamma)))
    
    if epoch == 14:
      K.set_value(self.alpha, 0)
      K.set_value(self.beta, 0.4)
      K.set_value(self.gamma, 0.6)  
      print('Changing loss weights to: coarse1 = {}, coarse2 = {}, fine = {}'.format(K.eval(self.alpha), K.eval(self.beta), K.eval(self.gamma)))
  
    if epoch == 21:
      K.set_value(self.alpha, 0)
      K.set_value(self.beta, 0)
      K.set_value(self.gamma, 1)  
      print('Changing loss weights to: coarse1 = {}, coarse2 = {}, fine = {}'.format(K.eval(self.alpha), K.eval(self.beta), K.eval(self.gamma)))
  
    logs['alpha'] = K.eval(self.alpha)
    logs['beta'] = K.eval(self.beta) 
    logs['gamma'] = K.eval(self.gamma)

# %%
img_rows, img_cols = 32, 32
input_shape = (img_rows, img_cols, 3)

num_classes_coarse1 = 2
num_classes_coarse2 = 7
num_classes_fine = 10

img_input = Input(shape=input_shape, name='input')


x = Conv2D(128, (3, 3), activation='relu', name='block1_conv1', padding='same')(img_input)

x = Conv2D(128, (3, 3), activation='relu', name='block1_conv2', padding='same')(x)
x = MaxPooling2D((2, 2), name='block2_pool')(x)

#---- coarse branch 1 ----
coarse1 = Flatten(name='c1_flatten')(x)
coarse1 = Dense(64, name='c1_fc_1')(coarse1)
coarse1 = BatchNormalization()(coarse1)
coarse1 = Activation('relu')(coarse1)
coarse1 = Dropout(0.5)(coarse1)

coarse1 = Dense(64, name='c1_fc_2')(coarse1)
coarse1 = BatchNormalization()(coarse1)
coarse1 = Activation('relu')(coarse1)
coarse1 = Dropout(0.5)(coarse1)

coarse_pred1 = Dense(num_classes_coarse1, activation='softmax', name='predictions_coarse1')(coarse1)

x = Conv2D(128, (3, 3), activation='relu', name='block1_conv3', padding='same')(x)
x = MaxPooling2D((2, 2), name='block3_pool')(x)

#---- coarse branch 2 ----
coarse2 = Flatten(name='c2_flatten')(x)
coarse2 = Dense(512, name='c2_fc_1')(coarse2)
coarse2 = BatchNormalization()(coarse2)
coarse2 = Activation('relu')(coarse2)
coarse2 = Dropout(0.5)(coarse2)

coarse2 = Dense(512, name='c2_fc_2')(coarse2)
coarse2 = BatchNormalization()(coarse2)
coarse2 = Activation('relu')(coarse2)
coarse2 = Dropout(0.5)(coarse2)

coarse_pred2 = Dense(num_classes_coarse2, activation='softmax', name='predictions_coarse2')(coarse2)


x = Flatten(name='flatten')(x)
x = Dense(512, name='fc_1')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = Dropout(0.5)(x)

x = Dense(512, name='fc_2')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = Dropout(0.5)(x)

fine_pred = Dense(num_classes_fine, activation='softmax', name='predictions_fine')(x)

# %%
model = Model(inputs=img_input, outputs= [coarse_pred1, coarse_pred2, fine_pred], name='branch_net')

model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 32, 32, 128)  3584        input[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 32, 32, 128)  147584      block1_conv1[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 16, 16, 128)  0           block1_conv2[0][0]
# __________________________________________________________________________________________________
# block1_conv3 (Conv2D)           (None, 16, 16, 128)  147584      block2_pool[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 8, 8, 128)    0           block1_conv3[0][0]
# __________________________________________________________________________________________________
# c1_flatten (Flatten)            (None, 32768)        0           block2_pool[0][0]
# __________________________________________________________________________________________________
# c2_flatten (Flatten)            (None, 8192)         0           block3_pool[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 8192)         0           block3_pool[0][0]
# __________________________________________________________________________________________________
# c1_fc_1 (Dense)                 (None, 64)           2097216     c1_flatten[0][0]
# __________________________________________________________________________________________________
# c2_fc_1 (Dense)                 (None, 512)          4194816     c2_flatten[0][0]
# __________________________________________________________________________________________________
# fc_1 (Dense)                    (None, 512)          4194816     flatten[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 64)           256         c1_fc_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 512)          2048        c2_fc_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 512)          2048        fc_1[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 64)           0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 512)          0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 512)          0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 64)           0           activation_13[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 512)          0           activation_15[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, 512)          0           activation_17[0][0]
# __________________________________________________________________________________________________
# c1_fc_2 (Dense)                 (None, 64)           4160        dropout_13[0][0]
# __________________________________________________________________________________________________
# c2_fc_2 (Dense)                 (None, 512)          262656      dropout_15[0][0]
# __________________________________________________________________________________________________
# fc_2 (Dense)                    (None, 512)          262656      dropout_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 64)           256         c1_fc_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 512)          2048        c2_fc_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 512)          2048        fc_2[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 64)           0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 512)          0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 512)          0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 64)           0           activation_14[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 512)          0           activation_16[0][0]
# __________________________________________________________________________________________________
# dropout_18 (Dropout)            (None, 512)          0           activation_18[0][0]
# __________________________________________________________________________________________________
# predictions_coarse1 (Dense)     (None, 2)            130         dropout_14[0][0]
# __________________________________________________________________________________________________
# predictions_coarse2 (Dense)     (None, 7)            3591        dropout_16[0][0]
# __________________________________________________________________________________________________
# predictions_fine (Dense)        (None, 10)           5130        dropout_18[0][0]
# ==================================================================================================
# Total params: 11,332,627
# Trainable params: 11,328,275
# Non-trainable params: 4,352
# __________________________________________________________________________________________________

# %%
alpha = K.variable(value=0.9, dtype="float32", name="alpha") 
beta = K.variable(value=0.1, dtype="float32", name="beta") 
gamma = K.variable(value=0, dtype="float32", name="gamma") 

adam = optimizers.Adam(lr=0.00025)

model.compile(loss='categorical_crossentropy', 
              optimizer=adam,
              loss_weights=[alpha, beta, gamma],
              metrics=['accuracy'])

# %%
clr_cb = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, verbose=1)
time_cb = TimingCallback()
change_lw = LossWeightsModifier3Vars(alpha, beta, gamma)
csv_cb = CSVLogger('drive/TCC-ITAU/cifar-10/training-data/branch-net/branch-net.csv', separator=',', append=False)


cbks = [clr_cb, time_cb, change_lw, csv_cb]

# %%
epochs = 50
start_time = time()
training = model.fit(train_features, [y_train_c_cat1, y_train_c_cat2, y_train_cat],
                     validation_data=(vali_features, [y_val_c_cat1, y_val_c_cat2, y_val_cat]),
                     epochs=epochs,
                     batch_size=256, 
                     callbacks=cbks,
                     verbose=1)
training_time = time() - start_time
# Out:
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/50
# 40000/40000 [==============================] - 31s 775us/step - loss: 0.4665 - predictions_coarse1_loss: 0.3600 - predictions_coarse2_loss: 1.4246 - predictions_fine_loss: 3.1328 - predictions_coarse1_acc: 0.8483 - predictions_coarse2_acc: 0.4930 - predictions_fine_acc: 0.1004 - val_loss: 0.4668 - val_predictions_coarse1_loss: 0.3616 - val_predictions_coarse2_loss: 1.4135 - val_predictions_fine_loss: 2.6242 - val_predictions_coarse1_acc: 0.8409 - val_predictions_coarse2_acc: 0.4868 - val_predictions_fine_acc: 0.0769
# 40000/40000 [==============================] - 27s 674us/step - loss: 0.0065 - predictions_coarse1_loss: 0.1418 - predictions_coarse2_loss: 0.0121 - predictions_fine_loss: 0.0065 - predictions_coarse1_acc: 0.9467 - predictions_coarse2_acc: 0.9975 - predictions_fine_acc: 0.9985 - val_loss: 1.0980 - val_predictions_coarse1_loss: 0.1599 - val_predictions_coarse2_loss: 0.6710 - val_predictions_fine_loss: 1.0980 - val_predictions_coarse1_acc: 0.9391 - val_predictions_coarse2_acc: 0.8367 - val_predictions_fine_acc: 0.7780
# Epoch 44/50
# 40000/40000 [==============================] - 27s 673us/step - loss: 0.0059 - predictions_coarse1_loss: 0.1395 - predictions_coarse2_loss: 0.0122 - predictions_fine_loss: 0.0059 - predictions_coarse1_acc: 0.9469 - predictions_coarse2_acc: 0.9975 - predictions_fine_acc: 0.9988 - val_loss: 1.0883 - val_predictions_coarse1_loss: 0.1572 - val_predictions_coarse2_loss: 0.6712 - val_predictions_fine_loss: 1.0883 - val_predictions_coarse1_acc: 0.9401 - val_predictions_coarse2_acc: 0.8382 - val_predictions_fine_acc: 0.7766
# Epoch 45/50
# 40000/40000 [==============================] - 27s 673us/step - loss: 0.0067 - predictions_coarse1_loss: 0.1423 - predictions_coarse2_loss: 0.0122 - predictions_fine_loss: 0.0067 - predictions_coarse1_acc: 0.9464 - predictions_coarse2_acc: 0.9975 - predictions_fine_acc: 0.9982 - val_loss: 1.1198 - val_predictions_coarse1_loss: 0.1590 - val_predictions_coarse2_loss: 0.6820 - val_predictions_fine_loss: 1.1198 - val_predictions_coarse1_acc: 0.9398 - val_predictions_coarse2_acc: 0.8366 - val_predictions_fine_acc: 0.7758
#
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 46/50
# 40000/40000 [==============================] - 27s 673us/step - loss: 0.0053 - predictions_coarse1_loss: 0.1443 - predictions_coarse2_loss: 0.0124 - predictions_fine_loss: 0.0053 - predictions_coarse1_acc: 0.9453 - predictions_coarse2_acc: 0.9975 - predictions_fine_acc: 0.9988 - val_loss: 1.0917 - val_predictions_coarse1_loss: 0.1568 - val_predictions_coarse2_loss: 0.6713 - val_predictions_fine_loss: 1.0917 - val_predictions_coarse1_acc: 0.9404 - val_predictions_coarse2_acc: 0.8375 - val_predictions_fine_acc: 0.7793
# Epoch 47/50
# 40000/40000 [==============================] - 27s 673us/step - loss: 0.0051 - predictions_coarse1_loss: 0.1409 - predictions_coarse2_loss: 0.0110 - predictions_fine_loss: 0.0051 - predictions_coarse1_acc: 0.9473 - predictions_coarse2_acc: 0.9981 - predictions_fine_acc: 0.9990 - val_loss: 1.0877 - val_predictions_coarse1_loss: 0.1567 - val_predictions_coarse2_loss: 0.6694 - val_predictions_fine_loss: 1.0877 - val_predictions_coarse1_acc: 0.9401 - val_predictions_coarse2_acc: 0.8392 - val_predictions_fine_acc: 0.7803
# Epoch 48/50
# 40000/40000 [==============================] - 27s 674us/step - loss: 0.0049 - predictions_coarse1_loss: 0.1402 - predictions_coarse2_loss: 0.0121 - predictions_fine_loss: 0.0049 - predictions_coarse1_acc: 0.9476 - predictions_coarse2_acc: 0.9978 - predictions_fine_acc: 0.9990 - val_loss: 1.0967 - val_predictions_coarse1_loss: 0.1572 - val_predictions_coarse2_loss: 0.6737 - val_predictions_fine_loss: 1.0967 - val_predictions_coarse1_acc: 0.9401 - val_predictions_coarse2_acc: 0.8374 - val_predictions_fine_acc: 0.7776
# Epoch 49/50
# 40000/40000 [==============================] - 27s 674us/step - loss: 0.0049 - predictions_coarse1_loss: 0.1417 - predictions_coarse2_loss: 0.0112 - predictions_fine_loss: 0.0049 - predictions_coarse1_acc: 0.9465 - predictions_coarse2_acc: 0.9977 - predictions_fine_acc: 0.9990 - val_loss: 1.0934 - val_predictions_coarse1_loss: 0.1567 - val_predictions_coarse2_loss: 0.6710 - val_predictions_fine_loss: 1.0934 - val_predictions_coarse1_acc: 0.9398 - val_predictions_coarse2_acc: 0.8394 - val_predictions_fine_acc: 0.7796
# Epoch 50/50
# 40000/40000 [==============================] - 27s 674us/step - loss: 0.0046 - predictions_coarse1_loss: 0.1398 - predictions_coarse2_loss: 0.0114 - predictions_fine_loss: 0.0046 - predictions_coarse1_acc: 0.9475 - predictions_coarse2_acc: 0.9979 - predictions_fine_acc: 0.9992 - val_loss: 1.0996 - val_predictions_coarse1_loss: 0.1561 - val_predictions_coarse2_loss: 0.6704 - val_predictions_fine_loss: 1.0996 - val_predictions_coarse1_acc: 0.9412 - val_predictions_coarse2_acc: 0.8373 - val_predictions_fine_acc: 0.7804

# %%
model.evaluate(test_features, [y_test_c_cat1,y_test_c_cat2, y_test_cat])
# Out:
# 10000/10000 [==============================] - 4s 447us/step
# [1.1178586259841918,
#  0.17172808547616006,
#  0.6901459753751755,
#  1.1178586259841918,
#  0.9311,
#  0.8342,
#  0.7768]

# %%
print('Total training time: {}'.format(training_time))
# Out:
# Total training time: 1381.6245164871216

# %%
model.save('drive/TCC-ITAU/cifar-10/models/branch-net.h5')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-136b0b3d288d> in <module>()
# ----> 1 model.save('drive/TCC-ITAU/cifar-10/models/branch-net.h5')
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/network.py in save(self, filepath, overwrite, include_optimizer)
#    1088             raise NotImplementedError
#    1089         from ..models import save_model
# -> 1090         save_model(self, filepath, overwrite, include_optimizer)
#    1091
#    1092     def save_weights(self, filepath, overwrite=True):
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py in save_model(model, filepath, overwrite, include_optimizer)
#     380
#     381     try:
# --> 382         _serialize_model(model, f, include_optimizer)
#     383     finally:
#     384         if opened_new_file:
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py in _serialize_model(model, f, include_optimizer)
#     136                 'sample_weight_mode': model.sample_weight_mode,
#     137                 'loss_weights': model.loss_weights,
# --> 138             }, default=get_json_type).encode('utf8')
#     139             symbolic_weights = getattr(model.optimizer, 'weights')
#     140             if symbolic_weights:
#
# /usr/lib/python3.6/json/__init__.py in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     236         check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     237         separators=separators, default=default, sort_keys=sort_keys,
# --> 238         **kw).encode(obj)
#     239
#     240
#
# /usr/lib/python3.6/json/encoder.py in encode(self, o)
#     197         # exceptions aren't as detailed.  The list call should be roughly
#     198         # equivalent to the PySequence_Fast that ''.join() would do.
# --> 199         chunks = self.iterencode(o, _one_shot=True)
#     200         if not isinstance(chunks, (list, tuple)):
#     201             chunks = list(chunks)
#
# /usr/lib/python3.6/json/encoder.py in iterencode(self, o, _one_shot)
#     255                 self.key_separator, self.item_separator, self.sort_keys,
#     256                 self.skipkeys, _one_shot)
# --> 257         return _iterencode(o, 0)
#     258
#     259 def _make_iterencode(markers, _default, _encoder, _indent, _floatstr,
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py in get_json_type(obj)
#      72             return obj.__name__
#      73
# ---> 74         raise TypeError('Not JSON Serializable: %s' % (obj,))
#      75
#      76     from .. import __version__ as keras_version
#
# TypeError: Not JSON Serializable: <tf.Variable 'alpha_2:0' shape=() dtype=float32_ref>
