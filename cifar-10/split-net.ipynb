# %% [markdown]
# # Split-net

# %%
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse

from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass

# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}
# Out:
# E: Package 'python-software-properties' has no installation candidate
# Selecting previously unselected package libfuse2:amd64.
# (Reading database ... 22280 files and directories currently installed.)
# Preparing to unpack .../libfuse2_2.9.7-1ubuntu1_amd64.deb ...
# Unpacking libfuse2:amd64 (2.9.7-1ubuntu1) ...
# Selecting previously unselected package fuse.
# Preparing to unpack .../fuse_2.9.7-1ubuntu1_amd64.deb ...
# Unpacking fuse (2.9.7-1ubuntu1) ...
# Selecting previously unselected package google-drive-ocamlfuse.
# Preparing to unpack .../google-drive-ocamlfuse_0.7.0-0ubuntu1~ubuntu18.04.1_amd64.deb ...
# Unpacking google-drive-ocamlfuse (0.7.0-0ubuntu1~ubuntu18.04.1) ...
# Setting up libfuse2:amd64 (2.9.7-1ubuntu1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...
# Setting up fuse (2.9.7-1ubuntu1) ...
# Setting up google-drive-ocamlfuse (0.7.0-0ubuntu1~ubuntu18.04.1) ...
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# ··········
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# Please enter the verification code: Access token retrieved correctly.

# %%
# !mkdir -p drive
# !google-drive-ocamlfuse drive
# Out:
# fuse: mountpoint is not empty
# fuse: if you are sure this is safe, use the 'nonempty' mount option

# %% [markdown]
# ## Loading the data

# %%
from time import time
import os
import gzip
import numpy as np
from keras.utils import np_utils
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

from keras.datasets import cifar10
# Out:
# Using TensorFlow backend.

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, 
                                                  test_size=0.2, 
                                                  random_state=1974)

# %%
train_features = X_train.reshape(X_train.shape[0], 32, 32, 3)/255
vali_features = X_val.reshape(X_val.shape[0], 32, 32, 3)/255
test_features = X_test.reshape(X_test.shape[0], 32, 32, 3)/255

y_train_cat = np_utils.to_categorical(y_train)
y_val_cat = np_utils.to_categorical(y_val)
y_test_cat = np_utils.to_categorical(y_test)

# %% [markdown]
# ## Defining coarse labels

# %%
dict_coarse1 = {0: 0,
              1: 0,
              2: 1,
              3: 1,
              4: 1,
              5: 1,
              6: 1,
              7: 1,
              8: 0,
              9: 0}

dict_coarse2 = {0: 0,
              1: 1,
              2: 3,
              3: 4,
              4: 6,
              5: 4,
              6: 5,
              7: 6,
              8: 2,
              9: 1}

y_train_coarse1 = np.vectorize(dict_coarse1.get)(y_train)
y_val_coarse1 = np.vectorize(dict_coarse1.get)(y_val)
y_test_coarse1 = np.vectorize(dict_coarse1.get)(y_test)

y_train_coarse2 = np.vectorize(dict_coarse2.get)(y_train)
y_val_coarse2 = np.vectorize(dict_coarse2.get)(y_val)
y_test_coarse2 = np.vectorize(dict_coarse2.get)(y_test)

y_train_c_cat1 = np_utils.to_categorical(y_train_coarse1)
y_val_c_cat1 = np_utils.to_categorical(y_val_coarse1)
y_test_c_cat1 = np_utils.to_categorical(y_test_coarse1)

y_train_c_cat2 = np_utils.to_categorical(y_train_coarse2)
y_val_c_cat2 = np_utils.to_categorical(y_val_coarse2)
y_test_c_cat2 = np_utils.to_categorical(y_test_coarse2)

# %% [markdown]
# ## Training the model

# %%
import keras
from keras.models import Model
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D, Input
from keras import optimizers
from keras.callbacks import TensorBoard, ReduceLROnPlateau, CSVLogger
from keras.layers.normalization import BatchNormalization
from keras import backend as K

# %%
class TimingCallback(keras.callbacks.Callback):
  """Callback that saves the time elapsed of each epoch to the log.
  """  
  def on_epoch_begin(self, epoch, logs={}):
    self.starttime=time()
  def on_epoch_end(self, epoch, logs={}):
    logs['time_elapsed'] = (time()-self.starttime)

# %%
class LossWeightsModifier3Vars(keras.callbacks.Callback):
  """Callback that modifies the loss weights on certain epochs.
    # Arguments
        alpha: coeficient for the coarser class.
        beta: coeficient for the second level coarse class.
        gamma: coeficient for the fine class.
  """  
  def __init__(self, alpha, beta, gamma):
    self.alpha = alpha
    self.beta = beta
    self.gamma = gamma
    
  def on_epoch_end(self, epoch, logs={}):

    if epoch == 4:
      K.set_value(self.alpha, 0)
      K.set_value(self.beta, 0.8)
      K.set_value(self.gamma, 0.2)
      print('Changing loss weights to: coarse1 = {}, coarse2 = {}, fine = {}'.format(K.eval(self.alpha), K.eval(self.beta), K.eval(self.gamma)))
    
    if epoch == 14:
      K.set_value(self.alpha, 0)
      K.set_value(self.beta, 0.4)
      K.set_value(self.gamma, 0.6)  
      print('Changing loss weights to: coarse1 = {}, coarse2 = {}, fine = {}'.format(K.eval(self.alpha), K.eval(self.beta), K.eval(self.gamma)))
  
    if epoch == 21:
      K.set_value(self.alpha, 0)
      K.set_value(self.beta, 0)
      K.set_value(self.gamma, 1)  
      print('Changing loss weights to: coarse1 = {}, coarse2 = {}, fine = {}'.format(K.eval(self.alpha), K.eval(self.beta), K.eval(self.gamma)))
  
    logs['alpha'] = K.eval(self.alpha)
    logs['beta'] = K.eval(self.beta) 
    logs['gamma'] = K.eval(self.gamma)

# %%
img_rows, img_cols = 32, 32
input_shape = (img_rows, img_cols, 3)

num_classes_coarse1 = 2
num_classes_coarse2 = 7
num_classes_fine = 10

img_input = Input(shape=input_shape, name='input')


x = Conv2D(128, (3, 3), activation='relu', name='block1_conv1', padding='same')(img_input)

x = Conv2D(128, (3, 3), activation='relu', name='block1_conv2', padding='same')(x)
x = MaxPooling2D((2, 2), name='block2_pool')(x)

x = Conv2D(128, (3, 3), activation='relu', name='block1_conv3', padding='same')(x)
x = MaxPooling2D((2, 2), name='block3_pool')(x)

x = Flatten(name='flatten')(x)
x = Dense(512, name='fc_1')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = Dropout(0.5)(x)

x = Dense(512, name='fc_2')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = Dropout(0.5)(x)

coarse_pred1 = Dense(num_classes_coarse1, activation='softmax', name='predictions_coarse1')(x)
coarse_pred2 = Dense(num_classes_coarse2, activation='softmax', name='predictions_coarse2')(x)
fine_pred = Dense(num_classes_fine, activation='softmax', name='predictions_fine')(x)

# %%
model = Model(inputs=img_input, outputs= [coarse_pred1, coarse_pred2, fine_pred], name='split_net')

model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 32, 32, 128)  3584        input[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 32, 32, 128)  147584      block1_conv1[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 16, 16, 128)  0           block1_conv2[0][0]
# __________________________________________________________________________________________________
# block1_conv3 (Conv2D)           (None, 16, 16, 128)  147584      block2_pool[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 8, 8, 128)    0           block1_conv3[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 8192)         0           block3_pool[0][0]
# __________________________________________________________________________________________________
# fc_1 (Dense)                    (None, 512)          4194816     flatten[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 512)          2048        fc_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 512)          0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 512)          0           activation_1[0][0]
# __________________________________________________________________________________________________
# fc_2 (Dense)                    (None, 512)          262656      dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 512)          2048        fc_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 512)          0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 512)          0           activation_2[0][0]
# __________________________________________________________________________________________________
# predictions_coarse1 (Dense)     (None, 2)            1026        dropout_2[0][0]
# __________________________________________________________________________________________________
# predictions_coarse2 (Dense)     (None, 7)            3591        dropout_2[0][0]
# __________________________________________________________________________________________________
# predictions_fine (Dense)        (None, 10)           5130        dropout_2[0][0]
# ==================================================================================================
# Total params: 4,770,067
# Trainable params: 4,768,019
# Non-trainable params: 2,048
# __________________________________________________________________________________________________

# %%
alpha = K.variable(value=0.9, dtype="float32", name="alpha") 
beta = K.variable(value=0.1, dtype="float32", name="beta") 
gamma = K.variable(value=0, dtype="float32", name="gamma") 

adam = optimizers.Adam(lr=0.00025)

model.compile(loss='categorical_crossentropy', 
              optimizer=adam,
              loss_weights=[alpha, beta, gamma],
              metrics=['accuracy'])

# %%
clr_cb = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, verbose=1)
time_cb = TimingCallback()
change_lw = LossWeightsModifier3Vars(alpha, beta, gamma)
csv_cb = CSVLogger('drive/TCC-ITAU/cifar-10/training-data/split-baseline-net/split-baseline-net-simple.csv', separator=',', append=False)


cbks = [clr_cb, time_cb, change_lw, csv_cb]

# %%
epochs = 50
start_time = time()
training = model.fit(train_features, [y_train_c_cat1, y_train_c_cat2, y_train_cat],
                     validation_data=(vali_features, [y_val_c_cat1, y_val_c_cat2, y_val_cat]),
                     epochs=epochs,
                     batch_size=256, 
                     callbacks=cbks,
                     verbose=1)
training_time = time() - start_time
# Out:
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/50
# 40000/40000 [==============================] - 27s 682us/step - loss: 0.4657 - predictions_coarse1_loss: 0.3347 - predictions_coarse2_loss: 1.6448 - predictions_fine_loss: 3.1107 - predictions_coarse1_acc: 0.8682 - predictions_coarse2_acc: 0.4053 - predictions_fine_acc: 0.1024 - val_loss: 0.3420 - val_predictions_coarse1_loss: 0.2489 - val_predictions_coarse2_loss: 1.1796 - val_predictions_fine_loss: 3.2142 - val_predictions_coarse1_acc: 0.9069 - val_predictions_coarse2_acc: 0.5495 - val_predictions_fine_acc: 0.0720
# Epoch 2/50
# 40000/40000 [==============================] - 23s 568us/step - loss: 0.3152 - predictions_coarse1_loss: 0.2140 - predictions_coarse2_loss: 1.2258 - predictions_fine_loss: 3.1620 - predictions_coarse1_acc: 0.9172 - predictions_coarse2_acc: 0.5402 - predictions_fine_acc: 0.1032 - val_loss: 0.3067 - val_predictions_coarse1_loss: 0.2177 - val_predictions_coarse2_loss: 1.1076 - val_predictions_fine_loss: 2.7437 - val_predictions_coarse1_acc: 0.9147 - val_predictions_coarse2_acc: 0.5739 - val_predictions_fine_acc: 0.1758
# Epoch 3/50
# 40000/40000 [==============================] - 23s 568us/step - loss: 0.2575 - predictions_coarse1_loss: 0.1697 - predictions_coarse2_loss: 1.0480 - predictions_fine_loss: 3.2149 - predictions_coarse1_acc: 0.9330 - predictions_coarse2_acc: 0.6093 - predictions_fine_acc: 0.1002 - val_loss: 0.8098 - val_predictions_coarse1_loss: 0.7298 - val_predictions_coarse2_loss: 1.5306 - val_predictions_fine_loss: 3.0546 - val_predictions_coarse1_acc: 0.8012 - val_predictions_coarse2_acc: 0.5379 - val_predictions_fine_acc: 0.0793
# Epoch 4/50
# 40000/40000 [==============================] - 23s 569us/step - loss: 0.2206 - predictions_coarse1_loss: 0.1433 - predictions_coarse2_loss: 0.9162 - predictions_fine_loss: 3.2350 - predictions_coarse1_acc: 0.9434 - predictions_coarse2_acc: 0.6613 - predictions_fine_acc: 0.0990 - val_loss: 0.3861 - val_predictions_coarse1_loss: 0.3170 - val_predictions_coarse2_loss: 1.0081 - val_predictions_fine_loss: 2.9243 - val_predictions_coarse1_acc: 0.8824 - val_predictions_coarse2_acc: 0.6340 - val_predictions_fine_acc: 0.1003
# Epoch 5/50
# Epoch 38/50
# 40000/40000 [==============================] - 23s 569us/step - loss: 0.0147 - predictions_coarse1_loss: 0.0471 - predictions_coarse2_loss: 0.0128 - predictions_fine_loss: 0.0147 - predictions_coarse1_acc: 0.9911 - predictions_coarse2_acc: 0.9981 - predictions_fine_acc: 0.9968 - val_loss: 1.0283 - val_predictions_coarse1_loss: 0.1097 - val_predictions_coarse2_loss: 0.6652 - val_predictions_fine_loss: 1.0283 - val_predictions_coarse1_acc: 0.9568 - val_predictions_coarse2_acc: 0.8280 - val_predictions_fine_acc: 0.7752
# Epoch 39/50
# 40000/40000 [==============================] - 23s 568us/step - loss: 0.0143 - predictions_coarse1_loss: 0.0474 - predictions_coarse2_loss: 0.0131 - predictions_fine_loss: 0.0143 - predictions_coarse1_acc: 0.9910 - predictions_coarse2_acc: 0.9977 - predictions_fine_acc: 0.9971 - val_loss: 1.0374 - val_predictions_coarse1_loss: 0.1089 - val_predictions_coarse2_loss: 0.6621 - val_predictions_fine_loss: 1.0374 - val_predictions_coarse1_acc: 0.9577 - val_predictions_coarse2_acc: 0.8290 - val_predictions_fine_acc: 0.7751
# Epoch 40/50
# 40000/40000 [==============================] - 23s 567us/step - loss: 0.0147 - predictions_coarse1_loss: 0.0465 - predictions_coarse2_loss: 0.0128 - predictions_fine_loss: 0.0147 - predictions_coarse1_acc: 0.9916 - predictions_coarse2_acc: 0.9980 - predictions_fine_acc: 0.9965 - val_loss: 1.0354 - val_predictions_coarse1_loss: 0.1126 - val_predictions_coarse2_loss: 0.6637 - val_predictions_fine_loss: 1.0354 - val_predictions_coarse1_acc: 0.9558 - val_predictions_coarse2_acc: 0.8262 - val_predictions_fine_acc: 0.7748
# Epoch 41/50
# 40000/40000 [==============================] - 23s 567us/step - loss: 0.0138 - predictions_coarse1_loss: 0.0467 - predictions_coarse2_loss: 0.0122 - predictions_fine_loss: 0.0138 - predictions_coarse1_acc: 0.9912 - predictions_coarse2_acc: 0.9983 - predictions_fine_acc: 0.9971 - val_loss: 1.0372 - val_predictions_coarse1_loss: 0.1082 - val_predictions_coarse2_loss: 0.6593 - val_predictions_fine_loss: 1.0372 - val_predictions_coarse1_acc: 0.9588 - val_predictions_coarse2_acc: 0.8297 - val_predictions_fine_acc: 0.7761
# Epoch 42/50
# 40000/40000 [==============================] - 23s 566us/step - loss: 0.0132 - predictions_coarse1_loss: 0.0458 - predictions_coarse2_loss: 0.0119 - predictions_fine_loss: 0.0132 - predictions_coarse1_acc: 0.9917 - predictions_coarse2_acc: 0.9982 - predictions_fine_acc: 0.9970 - val_loss: 1.0543 - val_predictions_coarse1_loss: 0.1095 - val_predictions_coarse2_loss: 0.6615 - val_predictions_fine_loss: 1.0543 - val_predictions_coarse1_acc: 0.9590 - val_predictions_coarse2_acc: 0.8314 - val_predictions_fine_acc: 0.7738
# Epoch 43/50
# 40000/40000 [==============================] - 23s 568us/step - loss: 0.0137 - predictions_coarse1_loss: 0.0458 - predictions_coarse2_loss: 0.0126 - predictions_fine_loss: 0.0137 - predictions_coarse1_acc: 0.9922 - predictions_coarse2_acc: 0.9981 - predictions_fine_acc: 0.9967 - val_loss: 1.0553 - val_predictions_coarse1_loss: 0.1094 - val_predictions_coarse2_loss: 0.6653 - val_predictions_fine_loss: 1.0553 - val_predictions_coarse1_acc: 0.9588 - val_predictions_coarse2_acc: 0.8310 - val_predictions_fine_acc: 0.7741
# Epoch 44/50
# 40000/40000 [==============================] - 23s 568us/step - loss: 0.0123 - predictions_coarse1_loss: 0.0461 - predictions_coarse2_loss: 0.0118 - predictions_fine_loss: 0.0123 - predictions_coarse1_acc: 0.9920 - predictions_coarse2_acc: 0.9983 - predictions_fine_acc: 0.9972 - val_loss: 1.0661 - val_predictions_coarse1_loss: 0.1081 - val_predictions_coarse2_loss: 0.6647 - val_predictions_fine_loss: 1.0661 - val_predictions_coarse1_acc: 0.9587 - val_predictions_coarse2_acc: 0.8336 - val_predictions_fine_acc: 0.7763
# Epoch 45/50
# 40000/40000 [==============================] - 23s 567us/step - loss: 0.0113 - predictions_coarse1_loss: 0.0447 - predictions_coarse2_loss: 0.0111 - predictions_fine_loss: 0.0113 - predictions_coarse1_acc: 0.9926 - predictions_coarse2_acc: 0.9985 - predictions_fine_acc: 0.9975 - val_loss: 1.0671 - val_predictions_coarse1_loss: 0.1079 - val_predictions_coarse2_loss: 0.6665 - val_predictions_fine_loss: 1.0671 - val_predictions_coarse1_acc: 0.9580 - val_predictions_coarse2_acc: 0.8292 - val_predictions_fine_acc: 0.7766
#
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 46/50
# 40000/40000 [==============================] - 23s 568us/step - loss: 0.0099 - predictions_coarse1_loss: 0.0453 - predictions_coarse2_loss: 0.0109 - predictions_fine_loss: 0.0099 - predictions_coarse1_acc: 0.9922 - predictions_coarse2_acc: 0.9986 - predictions_fine_acc: 0.9983 - val_loss: 1.0585 - val_predictions_coarse1_loss: 0.1091 - val_predictions_coarse2_loss: 0.6566 - val_predictions_fine_loss: 1.0585 - val_predictions_coarse1_acc: 0.9583 - val_predictions_coarse2_acc: 0.8320 - val_predictions_fine_acc: 0.7787
# Epoch 47/50
# 40000/40000 [==============================] - 23s 569us/step - loss: 0.0103 - predictions_coarse1_loss: 0.0453 - predictions_coarse2_loss: 0.0108 - predictions_fine_loss: 0.0103 - predictions_coarse1_acc: 0.9916 - predictions_coarse2_acc: 0.9985 - predictions_fine_acc: 0.9978 - val_loss: 1.0613 - val_predictions_coarse1_loss: 0.1090 - val_predictions_coarse2_loss: 0.6599 - val_predictions_fine_loss: 1.0613 - val_predictions_coarse1_acc: 0.9571 - val_predictions_coarse2_acc: 0.8313 - val_predictions_fine_acc: 0.7781
# Epoch 48/50
# 40000/40000 [==============================] - 23s 570us/step - loss: 0.0100 - predictions_coarse1_loss: 0.0450 - predictions_coarse2_loss: 0.0102 - predictions_fine_loss: 0.0100 - predictions_coarse1_acc: 0.9921 - predictions_coarse2_acc: 0.9986 - predictions_fine_acc: 0.9978 - val_loss: 1.0570 - val_predictions_coarse1_loss: 0.1087 - val_predictions_coarse2_loss: 0.6591 - val_predictions_fine_loss: 1.0570 - val_predictions_coarse1_acc: 0.9576 - val_predictions_coarse2_acc: 0.8313 - val_predictions_fine_acc: 0.7773
# Epoch 49/50
# 40000/40000 [==============================] - 23s 571us/step - loss: 0.0095 - predictions_coarse1_loss: 0.0446 - predictions_coarse2_loss: 0.0111 - predictions_fine_loss: 0.0095 - predictions_coarse1_acc: 0.9932 - predictions_coarse2_acc: 0.9981 - predictions_fine_acc: 0.9981 - val_loss: 1.0622 - val_predictions_coarse1_loss: 0.1089 - val_predictions_coarse2_loss: 0.6603 - val_predictions_fine_loss: 1.0622 - val_predictions_coarse1_acc: 0.9578 - val_predictions_coarse2_acc: 0.8286 - val_predictions_fine_acc: 0.7767
# Epoch 50/50
# 40000/40000 [==============================] - 23s 573us/step - loss: 0.0098 - predictions_coarse1_loss: 0.0443 - predictions_coarse2_loss: 0.0100 - predictions_fine_loss: 0.0098 - predictions_coarse1_acc: 0.9928 - predictions_coarse2_acc: 0.9987 - predictions_fine_acc: 0.9978 - val_loss: 1.0675 - val_predictions_coarse1_loss: 0.1097 - val_predictions_coarse2_loss: 0.6668 - val_predictions_fine_loss: 1.0675 - val_predictions_coarse1_acc: 0.9578 - val_predictions_coarse2_acc: 0.8293 - val_predictions_fine_acc: 0.7765

# %%
model.evaluate(test_features, [y_test_c_cat1,y_test_c_cat2, y_test_cat])
# Out:
# 10000/10000 [==============================] - 3s 335us/step
# [1.1365437711715698,
#  0.12059403451383113,
#  0.7119519683122635,
#  1.1365437711715698,
#  0.954,
#  0.8173,
#  0.7665]

# %%
print('Total training time: {}'.format(training_time))
# Out:
# Total training time: 1172.1725940704346

# %%
model.save('drive/TCC-ITAU/cifar-10/models/split-net.h5')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-b13e9845520c> in <module>()
# ----> 1 model.save('drive/TCC-ITAU/cifar-10/models/split-net.h5')
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/network.py in save(self, filepath, overwrite, include_optimizer)
#    1088             raise NotImplementedError
#    1089         from ..models import save_model
# -> 1090         save_model(self, filepath, overwrite, include_optimizer)
#    1091
#    1092     def save_weights(self, filepath, overwrite=True):
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py in save_model(model, filepath, overwrite, include_optimizer)
#     380
#     381     try:
# --> 382         _serialize_model(model, f, include_optimizer)
#     383     finally:
#     384         if opened_new_file:
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py in _serialize_model(model, f, include_optimizer)
#     136                 'sample_weight_mode': model.sample_weight_mode,
#     137                 'loss_weights': model.loss_weights,
# --> 138             }, default=get_json_type).encode('utf8')
#     139             symbolic_weights = getattr(model.optimizer, 'weights')
#     140             if symbolic_weights:
#
# /usr/lib/python3.6/json/__init__.py in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     236         check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     237         separators=separators, default=default, sort_keys=sort_keys,
# --> 238         **kw).encode(obj)
#     239
#     240
#
# /usr/lib/python3.6/json/encoder.py in encode(self, o)
#     197         # exceptions aren't as detailed.  The list call should be roughly
#     198         # equivalent to the PySequence_Fast that ''.join() would do.
# --> 199         chunks = self.iterencode(o, _one_shot=True)
#     200         if not isinstance(chunks, (list, tuple)):
#     201             chunks = list(chunks)
#
# /usr/lib/python3.6/json/encoder.py in iterencode(self, o, _one_shot)
#     255                 self.key_separator, self.item_separator, self.sort_keys,
#     256                 self.skipkeys, _one_shot)
# --> 257         return _iterencode(o, 0)
#     258
#     259 def _make_iterencode(markers, _default, _encoder, _indent, _floatstr,
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py in get_json_type(obj)
#      72             return obj.__name__
#      73
# ---> 74         raise TypeError('Not JSON Serializable: %s' % (obj,))
#      75
#      76     from .. import __version__ as keras_version
#
# TypeError: Not JSON Serializable: <tf.Variable 'alpha:0' shape=() dtype=float32_ref>
