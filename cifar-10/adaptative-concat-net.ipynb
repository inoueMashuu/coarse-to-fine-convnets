# %% [markdown]
# # Adaptative Concat-net

# %%
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse

from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass

# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}
# Out:
# E: Package 'python-software-properties' has no installation candidate
# Selecting previously unselected package libfuse2:amd64.
# (Reading database ... 22280 files and directories currently installed.)
# Preparing to unpack .../libfuse2_2.9.7-1ubuntu1_amd64.deb ...
# Unpacking libfuse2:amd64 (2.9.7-1ubuntu1) ...
# Selecting previously unselected package fuse.
# Preparing to unpack .../fuse_2.9.7-1ubuntu1_amd64.deb ...
# Unpacking fuse (2.9.7-1ubuntu1) ...
# Selecting previously unselected package google-drive-ocamlfuse.
# Preparing to unpack .../google-drive-ocamlfuse_0.7.0-0ubuntu1~ubuntu18.04.1_amd64.deb ...
# Unpacking google-drive-ocamlfuse (0.7.0-0ubuntu1~ubuntu18.04.1) ...
# Setting up libfuse2:amd64 (2.9.7-1ubuntu1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...
# Setting up fuse (2.9.7-1ubuntu1) ...
# Setting up google-drive-ocamlfuse (0.7.0-0ubuntu1~ubuntu18.04.1) ...
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# ··········
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# Please enter the verification code: Access token retrieved correctly.

# %%
# !mkdir -p drive
# !google-drive-ocamlfuse drive

# %% [markdown]
# ## Loading the data

# %%
from time import time
import os
import gzip
import numpy as np
from keras.utils import np_utils
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

from keras.datasets import cifar10
# Out:
# Using TensorFlow backend.

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, 
                                                  test_size=0.2, 
                                                  random_state=1974)

# %%
train_features = X_train.reshape(X_train.shape[0], 32, 32, 3)/255
vali_features = X_val.reshape(X_val.shape[0], 32, 32, 3)/255
test_features = X_test.reshape(X_test.shape[0], 32, 32, 3)/255

y_train_cat = np_utils.to_categorical(y_train)
y_val_cat = np_utils.to_categorical(y_val)
y_test_cat = np_utils.to_categorical(y_test)

# %% [markdown]
# ## Defining coarse labels

# %%
dict_coarse1 = {0: 0,
              1: 0,
              2: 1,
              3: 1,
              4: 1,
              5: 1,
              6: 1,
              7: 1,
              8: 0,
              9: 0}

dict_coarse2 = {0: 0,
              1: 1,
              2: 3,
              3: 4,
              4: 6,
              5: 4,
              6: 5,
              7: 6,
              8: 2,
              9: 1}

y_train_coarse1 = np.vectorize(dict_coarse1.get)(y_train)
y_val_coarse1 = np.vectorize(dict_coarse1.get)(y_val)
y_test_coarse1 = np.vectorize(dict_coarse1.get)(y_test)

y_train_coarse2 = np.vectorize(dict_coarse2.get)(y_train)
y_val_coarse2 = np.vectorize(dict_coarse2.get)(y_val)
y_test_coarse2 = np.vectorize(dict_coarse2.get)(y_test)

y_train_c_cat1 = np_utils.to_categorical(y_train_coarse1)
y_val_c_cat1 = np_utils.to_categorical(y_val_coarse1)
y_test_c_cat1 = np_utils.to_categorical(y_test_coarse1)

y_train_c_cat2 = np_utils.to_categorical(y_train_coarse2)
y_val_c_cat2 = np_utils.to_categorical(y_val_coarse2)
y_test_c_cat2 = np_utils.to_categorical(y_test_coarse2)

# %% [markdown]
# ## Training the model

# %%
import keras
from keras.models import Model
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D, Input
from keras import optimizers
from keras.callbacks import TensorBoard, ReduceLROnPlateau, CSVLogger
from keras.layers.normalization import BatchNormalization
from keras import backend as K

# %%
class TimingCallback(keras.callbacks.Callback):
  """Callback that saves the time elapsed of each epoch to the log.
  """  
  def on_epoch_begin(self, epoch, logs={}):
    self.starttime=time()
  def on_epoch_end(self, epoch, logs={}):
    logs['time_elapsed'] = (time()-self.starttime)

# %%
class AdaptativeLossWeightsModifier3Vars(keras.callbacks.Callback):
  def __init__(self, alpha, beta, gamma, decay_rate=0.5):
    self.alpha = alpha
    self.beta = beta
    self.gamma = gamma
    self.decay_rate = decay_rate
    self.offset_epoch = 0
    self.par_reduce = [0, 1]
  
  def calculate_exponential(self, ratio, decay_rate, epoch):
    return np.exp(-ratio*decay_rate*epoch)

  def on_epoch_end(self, epoch, logs={}):
    list_vars = [K.eval(self.alpha), K.eval(self.beta), K.eval(self.gamma)]
    if epoch < 1:
      pass
    
    else:
      loss_coarse1 = self.model.history.history['predictions_coarse1_loss'][-1]
      loss_coarse2 = self.model.history.history['predictions_coarse2_loss'][-1]
      loss_fine = self.model.history.history['predictions_fine_loss'][-1]
      
      losses_classes = [loss_coarse1, loss_coarse2, loss_fine]
      ratio = losses_classes[self.par_reduce[0]] / losses_classes[self.par_reduce[1]] *(epoch + 1 - self.offset_epoch) 
      
      decaying = self.calculate_exponential(ratio, self.decay_rate/(max(self.par_reduce)**2), epoch)
      increasing = 1 - decaying
    
    
      if (1 - increasing) < 0.3 and (self.par_reduce[1] < len(list_vars) - 1):
        list_vars[self.par_reduce[0]] = 0
        list_vars[self.par_reduce[1]] = 1
        self.par_reduce = [i + 1 for i in self.par_reduce]
        self.offset_epoch = self.offset_epoch + epoch

      else:
       list_vars[self.par_reduce[0]] = decaying
       list_vars[self.par_reduce[1]] = increasing

        
      K.set_value(self.alpha, list_vars[0])
      K.set_value(self.beta, list_vars[1])
      K.set_value(self.gamma, list_vars[2])
        
      print('Changing loss weights to: coarse1 = {}, coarse2 = {}, fine = {}'.format(K.eval(self.alpha), K.eval(self.beta), K.eval(self.gamma)))
    
    logs['alpha'] = K.eval(self.alpha)
    logs['beta'] = K.eval(self.beta) 
    logs['gamma'] = K.eval(self.gamma)

# %%
img_rows, img_cols = 32, 32
input_shape = (img_rows, img_cols, 3)

num_classes_coarse1 = 2
num_classes_coarse2 = 7
num_classes_fine = 10

img_input = Input(shape=input_shape, name='input')


x = Conv2D(128, (3, 3), activation='relu', name='block1_conv1', padding='same')(img_input)

x = Conv2D(128, (3, 3), activation='relu', name='block1_conv2', padding='same')(x)
x = MaxPooling2D((2, 2), name='block2_pool')(x)

#---- coarse branch 1 ----
coarse1 = Flatten(name='c1_flatten')(x)
coarse1 = Dense(64, name='c1_fc_1')(coarse1)
coarse1 = BatchNormalization()(coarse1)
coarse1 = Activation('relu')(coarse1)
coarse1 = Dropout(0.5)(coarse1)

coarse1 = Dense(64, name='c1_fc_2')(coarse1)
coarse1 = BatchNormalization()(coarse1)
coarse1 = Activation('relu')(coarse1)
coarse1 = Dropout(0.5)(coarse1)

coarse_pred1 = Dense(num_classes_coarse1, activation='softmax', name='predictions_coarse1')(coarse1)

x = Conv2D(128, (3, 3), activation='relu', name='block1_conv3', padding='same')(x)
x = MaxPooling2D((2, 2), name='block3_pool')(x)

#---- coarse branch 2 ----
coarse2 = Flatten(name='c2_flatten')(x)
coarse2 = Dense(512, name='c2_fc_1')(coarse2)
coarse2 = BatchNormalization()(coarse2)
coarse2 = Activation('relu')(coarse2)
coarse2 = Dropout(0.5)(coarse2)

coarse2 = Dense(512, name='c2_fc_2')(coarse2)
coarse2 = BatchNormalization()(coarse2)
coarse2 = Activation('relu')(coarse2)
coarse2 = Dropout(0.5)(coarse2)

coarse2 = keras.layers.concatenate([coarse2, coarse1])

coarse_pred2 = Dense(num_classes_coarse2, activation='softmax', name='predictions_coarse2')(coarse2)


x = Flatten(name='flatten')(x)
x = Dense(512, name='fc_1')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = Dropout(0.5)(x)

x = Dense(512, name='fc_2')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = Dropout(0.5)(x)

x = keras.layers.concatenate([x, coarse2])

fine_pred = Dense(num_classes_fine, activation='softmax', name='predictions_fine')(x)

# %%
model = Model(inputs=img_input, outputs= [coarse_pred1, coarse_pred2, fine_pred], name='adaptative_concat_net')

model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 32, 32, 128)  3584        input[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 32, 32, 128)  147584      block1_conv1[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 16, 16, 128)  0           block1_conv2[0][0]
# __________________________________________________________________________________________________
# block1_conv3 (Conv2D)           (None, 16, 16, 128)  147584      block2_pool[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 8, 8, 128)    0           block1_conv3[0][0]
# __________________________________________________________________________________________________
# c1_flatten (Flatten)            (None, 32768)        0           block2_pool[0][0]
# __________________________________________________________________________________________________
# c2_flatten (Flatten)            (None, 8192)         0           block3_pool[0][0]
# __________________________________________________________________________________________________
# c1_fc_1 (Dense)                 (None, 64)           2097216     c1_flatten[0][0]
# __________________________________________________________________________________________________
# c2_fc_1 (Dense)                 (None, 512)          4194816     c2_flatten[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 8192)         0           block3_pool[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 64)           256         c1_fc_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 512)          2048        c2_fc_1[0][0]
# __________________________________________________________________________________________________
# fc_1 (Dense)                    (None, 512)          4194816     flatten[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 64)           0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 512)          0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 512)          2048        fc_1[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 64)           0           activation_7[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 512)          0           activation_9[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 512)          0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# c1_fc_2 (Dense)                 (None, 64)           4160        dropout_7[0][0]
# __________________________________________________________________________________________________
# c2_fc_2 (Dense)                 (None, 512)          262656      dropout_9[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 512)          0           activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 64)           256         c1_fc_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 512)          2048        c2_fc_2[0][0]
# __________________________________________________________________________________________________
# fc_2 (Dense)                    (None, 512)          262656      dropout_11[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 64)           0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 512)          0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 512)          2048        fc_2[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 64)           0           activation_8[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 512)          0           activation_10[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 512)          0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 576)          0           dropout_10[0][0]
#                                                                  dropout_8[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 512)          0           activation_12[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 1088)         0           dropout_12[0][0]
#                                                                  concatenate_3[0][0]
# __________________________________________________________________________________________________
# predictions_coarse1 (Dense)     (None, 2)            130         dropout_8[0][0]
# __________________________________________________________________________________________________
# predictions_coarse2 (Dense)     (None, 7)            4039        concatenate_3[0][0]
# __________________________________________________________________________________________________
# predictions_fine (Dense)        (None, 10)           10890       concatenate_4[0][0]
# ==================================================================================================
# Total params: 11,338,835
# Trainable params: 11,334,483
# Non-trainable params: 4,352
# __________________________________________________________________________________________________

# %%
alpha = K.variable(value=0.9, dtype="float32", name="alpha") 
beta = K.variable(value=0.1, dtype="float32", name="beta") 
gamma = K.variable(value=0, dtype="float32", name="gamma") 

adam = optimizers.Adam(lr=0.00025)

model.compile(loss='categorical_crossentropy', 
              optimizer=adam,
              loss_weights=[alpha, beta, gamma],
              metrics=['accuracy'])

# %%
clr_cb = ReduceLROnPlateau(monitor='val_predictions_fine_loss', factor=0.5, patience=10, verbose=1)
time_cb = TimingCallback()
change_lw = AdaptativeLossWeightsModifier3Vars(alpha, beta, gamma, decay_rate=0.5)
csv_cb = CSVLogger('drive/TCC-ITAU/cifar-10/training-data/concat-net/adaptative-concat-net.csv', separator=',', append=False)


cbks = [clr_cb, time_cb, change_lw, csv_cb]

# %%
epochs = 50
start_time = time()
training = model.fit(train_features, [y_train_c_cat1, y_train_c_cat2, y_train_cat],
                     validation_data=(vali_features, [y_val_c_cat1, y_val_c_cat2, y_val_cat]),
                     epochs=epochs,
                     batch_size=256, 
                     callbacks=cbks,
                     verbose=1)
training_time = time() - start_time
# Out:
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/50
# 40000/40000 [==============================] - 31s 770us/step - loss: 0.4599 - predictions_coarse1_loss: 0.3537 - predictions_coarse2_loss: 1.4157 - predictions_fine_loss: 3.1219 - predictions_coarse1_acc: 0.8525 - predictions_coarse2_acc: 0.4953 - predictions_fine_acc: 0.0971 - val_loss: 0.4500 - val_predictions_coarse1_loss: 0.3745 - val_predictions_coarse2_loss: 1.1292 - val_predictions_fine_loss: 2.6470 - val_predictions_coarse1_acc: 0.8435 - val_predictions_coarse2_acc: 0.5902 - val_predictions_fine_acc: 0.1149
# Epoch 2/50
# 40000/40000 [==============================] - 27s 682us/step - loss: 0.3089 - predictions_coarse1_loss: 0.2328 - predictions_coarse2_loss: 0.9940 - predictions_fine_loss: 3.1412 - predictions_coarse1_acc: 0.9116 - predictions_coarse2_acc: 0.6424 - predictions_fine_acc: 0.0959 - val_loss: 0.2633 - val_predictions_coarse1_loss: 0.1995 - val_predictions_coarse2_loss: 0.8370 - val_predictions_fine_loss: 2.5954 - val_predictions_coarse1_acc: 0.9216 - val_predictions_coarse2_acc: 0.6853 - val_predictions_fine_acc: 0.0923
# Changing loss weights to: coarse1 = 0.778900146484375, coarse2 = 0.2210998684167862, fine = 0.0
# Epoch 3/50
# 40000/40000 [==============================] - 27s 684us/step - loss: 0.3265 - predictions_coarse1_loss: 0.1908 - predictions_coarse2_loss: 0.8046 - predictions_fine_loss: 3.1707 - predictions_coarse1_acc: 0.9280 - predictions_coarse2_acc: 0.7122 - predictions_fine_acc: 0.0940 - val_loss: 0.3352 - val_predictions_coarse1_loss: 0.1726 - val_predictions_coarse2_loss: 0.9077 - val_predictions_fine_loss: 2.7303 - val_predictions_coarse1_acc: 0.9328 - val_predictions_coarse2_acc: 0.6627 - val_predictions_fine_acc: 0.1059
# Changing loss weights to: coarse1 = 0.49533793330192566, coarse2 = 0.5046620965003967, fine = 0.0
# Epoch 4/50
# 40000/40000 [==============================] - 27s 683us/step - loss: 0.4229 - predictions_coarse1_loss: 0.1592 - predictions_coarse2_loss: 0.6818 - predictions_fine_loss: 3.1468 - predictions_coarse1_acc: 0.9401 - predictions_coarse2_acc: 0.7550 - predictions_fine_acc: 0.0915 - val_loss: 0.6944 - val_predictions_coarse1_loss: 0.3812 - val_predictions_coarse2_loss: 1.0018 - val_predictions_fine_loss: 2.7768 - val_predictions_coarse1_acc: 0.8693 - val_predictions_coarse2_acc: 0.6537 - val_predictions_fine_acc: 0.0876
# Changing loss weights to: coarse1 = 0.0, coarse2 = 1.0, fine = 0.0
# Epoch 5/50
# 40000/40000 [==============================] - 27s 683us/step - loss: 0.5764 - predictions_coarse1_loss: 0.1538 - predictions_coarse2_loss: 0.5764 - predictions_fine_loss: 3.1390 - predictions_coarse1_acc: 0.9422 - predictions_coarse2_acc: 0.7948 - predictions_fine_acc: 0.0901 - val_loss: 0.6658 - val_predictions_coarse1_loss: 0.1579 - val_predictions_coarse2_loss: 0.6658 - val_predictions_fine_loss: 2.7262 - val_predictions_coarse1_acc: 0.9385 - val_predictions_coarse2_acc: 0.7639 - val_predictions_fine_acc: 0.0734
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.8052109479904175, fine = 0.19478903710842133
# Epoch 6/50
# 40000/40000 [==============================] - 27s 683us/step - loss: 0.5440 - predictions_coarse1_loss: 0.1529 - predictions_coarse2_loss: 0.4440 - predictions_fine_loss: 0.9577 - predictions_coarse1_acc: 0.9424 - predictions_coarse2_acc: 0.8412 - predictions_fine_acc: 0.6621 - val_loss: 0.7551 - val_predictions_coarse1_loss: 0.1682 - val_predictions_coarse2_loss: 0.7118 - val_predictions_fine_loss: 0.9343 - val_predictions_coarse1_acc: 0.9338 - val_predictions_coarse2_acc: 0.7478 - val_predictions_fine_acc: 0.6908
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.7087228894233704, fine = 0.29127708077430725
# Epoch 7/50
# 40000/40000 [==============================] - 27s 680us/step - loss: 0.4251 - predictions_coarse1_loss: 0.1536 - predictions_coarse2_loss: 0.3495 - predictions_fine_loss: 0.6092 - predictions_coarse1_acc: 0.9410 - predictions_coarse2_acc: 0.8775 - predictions_fine_acc: 0.7805 - val_loss: 0.6322 - val_predictions_coarse1_loss: 0.1602 - val_predictions_coarse2_loss: 0.5616 - val_predictions_fine_loss: 0.8040 - val_predictions_coarse1_acc: 0.9373 - val_predictions_coarse2_acc: 0.8095 - val_predictions_fine_acc: 0.7251
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.24890536069869995, fine = 0.7510946393013
# Epoch 8/50
# 40000/40000 [==============================] - 27s 681us/step - loss: 0.4191 - predictions_coarse1_loss: 0.1506 - predictions_coarse2_loss: 0.2787 - predictions_fine_loss: 0.4657 - predictions_coarse1_acc: 0.9435 - predictions_coarse2_acc: 0.9028 - predictions_fine_acc: 0.8297 - val_loss: 1.0690 - val_predictions_coarse1_loss: 0.1799 - val_predictions_coarse2_loss: 0.8178 - val_predictions_fine_loss: 1.1523 - val_predictions_coarse1_acc: 0.9292 - val_predictions_coarse2_acc: 0.7329 - val_predictions_fine_acc: 0.6684
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.08125946670770645, fine = 0.9187405109405518
# Epoch 9/50
# 40000/40000 [==============================] - 27s 679us/step - loss: 0.3205 - predictions_coarse1_loss: 0.1481 - predictions_coarse2_loss: 0.2295 - predictions_fine_loss: 0.3286 - predictions_coarse1_acc: 0.9448 - predictions_coarse2_acc: 0.9212 - predictions_fine_acc: 0.8801 - val_loss: 0.8589 - val_predictions_coarse1_loss: 0.1634 - val_predictions_coarse2_loss: 0.6402 - val_predictions_fine_loss: 0.8783 - val_predictions_coarse1_acc: 0.9371 - val_predictions_coarse2_acc: 0.7864 - val_predictions_fine_acc: 0.7360
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.02759191207587719, fine = 0.9724081158638
# Epoch 10/50
# 40000/40000 [==============================] - 27s 680us/step - loss: 0.2302 - predictions_coarse1_loss: 0.1521 - predictions_coarse2_loss: 0.1919 - predictions_fine_loss: 0.2313 - predictions_coarse1_acc: 0.9431 - predictions_coarse2_acc: 0.9371 - predictions_fine_acc: 0.9193 - val_loss: 0.9090 - val_predictions_coarse1_loss: 0.1682 - val_predictions_coarse2_loss: 0.6104 - val_predictions_fine_loss: 0.9174 - val_predictions_coarse1_acc: 0.9346 - val_predictions_coarse2_acc: 0.8043 - val_predictions_fine_acc: 0.7431
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.004083580337464809, fine = 0.9959164261817932
# Epoch 11/50
# 40000/40000 [==============================] - 27s 681us/step - loss: 0.1674 - predictions_coarse1_loss: 0.1557 - predictions_coarse2_loss: 0.1622 - predictions_fine_loss: 0.1674 - predictions_coarse1_acc: 0.9416 - predictions_coarse2_acc: 0.9503 - predictions_fine_acc: 0.9433 - val_loss: 0.8690 - val_predictions_coarse1_loss: 0.1693 - val_predictions_coarse2_loss: 0.5903 - val_predictions_fine_loss: 0.8701 - val_predictions_coarse1_acc: 0.9340 - val_predictions_coarse2_acc: 0.8060 - val_predictions_fine_acc: 0.7525
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.00024927378399297595, fine = 0.9997507333755493
# Epoch 12/50
# 40000/40000 [==============================] - 27s 681us/step - loss: 0.1207 - predictions_coarse1_loss: 0.1559 - predictions_coarse2_loss: 0.1419 - predictions_fine_loss: 0.1207 - predictions_coarse1_acc: 0.9408 - predictions_coarse2_acc: 0.9569 - predictions_fine_acc: 0.9592 - val_loss: 0.9619 - val_predictions_coarse1_loss: 0.1802 - val_predictions_coarse2_loss: 0.6083 - val_predictions_fine_loss: 0.9620 - val_predictions_coarse1_acc: 0.9317 - val_predictions_coarse2_acc: 0.8038 - val_predictions_fine_acc: 0.7499
# Changing loss weights to: coarse1 = 0.0, coarse2 = 6.221864623512374e-06, fine = 0.9999938011169434
# Epoch 13/50
# 40000/40000 [==============================] - 27s 682us/step - loss: 0.0977 - predictions_coarse1_loss: 0.1599 - predictions_coarse2_loss: 0.1296 - predictions_fine_loss: 0.0977 - predictions_coarse1_acc: 0.9388 - predictions_coarse2_acc: 0.9627 - predictions_fine_acc: 0.9671 - val_loss: 0.9911 - val_predictions_coarse1_loss: 0.1709 - val_predictions_coarse2_loss: 0.6161 - val_predictions_fine_loss: 0.9911 - val_predictions_coarse1_acc: 0.9338 - val_predictions_coarse2_acc: 0.7981 - val_predictions_fine_acc: 0.7516
# Changing loss weights to: coarse1 = 0.0, coarse2 = 2.1948880046807062e-08, fine = 1.0
# Epoch 14/50
# 40000/40000 [==============================] - 27s 680us/step - loss: 0.0721 - predictions_coarse1_loss: 0.1554 - predictions_coarse2_loss: 0.1134 - predictions_fine_loss: 0.0721 - predictions_coarse1_acc: 0.9409 - predictions_coarse2_acc: 0.9688 - predictions_fine_acc: 0.9760 - val_loss: 1.0060 - val_predictions_coarse1_loss: 0.1778 - val_predictions_coarse2_loss: 0.5949 - val_predictions_fine_loss: 1.0060 - val_predictions_coarse1_acc: 0.9327 - val_predictions_coarse2_acc: 0.8091 - val_predictions_fine_acc: 0.7534
# Changing loss weights to: coarse1 = 0.0, coarse2 = 5.0298543108340255e-11, fine = 1.0
# Epoch 15/50
# 40000/40000 [==============================] - 27s 681us/step - loss: 0.0631 - predictions_coarse1_loss: 0.1619 - predictions_coarse2_loss: 0.1079 - predictions_fine_loss: 0.0631 - predictions_coarse1_acc: 0.9380 - predictions_coarse2_acc: 0.9714 - predictions_fine_acc: 0.9800 - val_loss: 1.0786 - val_predictions_coarse1_loss: 0.1944 - val_predictions_coarse2_loss: 0.6156 - val_predictions_fine_loss: 1.0786 - val_predictions_coarse1_acc: 0.9270 - val_predictions_coarse2_acc: 0.8015 - val_predictions_fine_acc: 0.7523
# Changing loss weights to: coarse1 = 0.0, coarse2 = 4.505757034568413e-15, fine = 1.0
# Epoch 16/50
# 40000/40000 [==============================] - 27s 678us/step - loss: 0.0545 - predictions_coarse1_loss: 0.1575 - predictions_coarse2_loss: 0.1034 - predictions_fine_loss: 0.0545 - predictions_coarse1_acc: 0.9391 - predictions_coarse2_acc: 0.9718 - predictions_fine_acc: 0.9831 - val_loss: 0.9959 - val_predictions_coarse1_loss: 0.1761 - val_predictions_coarse2_loss: 0.5570 - val_predictions_fine_loss: 0.9959 - val_predictions_coarse1_acc: 0.9322 - val_predictions_coarse2_acc: 0.8196 - val_predictions_fine_acc: 0.7643
# Changing loss weights to: coarse1 = 0.0, coarse2 = 7.896808447720307e-19, fine = 1.0
# Epoch 17/50
# 40000/40000 [==============================] - 27s 679us/step - loss: 0.0486 - predictions_coarse1_loss: 0.1584 - predictions_coarse2_loss: 0.0993 - predictions_fine_loss: 0.0486 - predictions_coarse1_acc: 0.9402 - predictions_coarse2_acc: 0.9736 - predictions_fine_acc: 0.9841 - val_loss: 1.2370 - val_predictions_coarse1_loss: 0.1704 - val_predictions_coarse2_loss: 0.6625 - val_predictions_fine_loss: 1.2370 - val_predictions_coarse1_acc: 0.9340 - val_predictions_coarse2_acc: 0.8023 - val_predictions_fine_acc: 0.7424
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Changing loss weights to: coarse1 = 0.0, coarse2 = 8.549728922187786e-24, fine = 1.0
# Epoch 18/50
# 40000/40000 [==============================] - 27s 683us/step - loss: 0.0304 - predictions_coarse1_loss: 0.1504 - predictions_coarse2_loss: 0.0803 - predictions_fine_loss: 0.0304 - predictions_coarse1_acc: 0.9441 - predictions_coarse2_acc: 0.9804 - predictions_fine_acc: 0.9908 - val_loss: 0.9754 - val_predictions_coarse1_loss: 0.1733 - val_predictions_coarse2_loss: 0.5489 - val_predictions_fine_loss: 0.9754 - val_predictions_coarse1_acc: 0.9327 - val_predictions_coarse2_acc: 0.8281 - val_predictions_fine_acc: 0.7779
# Changing loss weights to: coarse1 = 0.0, coarse2 = 5.357421317172059e-29, fine = 1.0
# Epoch 19/50
# 40000/40000 [==============================] - 27s 682us/step - loss: 0.0218 - predictions_coarse1_loss: 0.1434 - predictions_coarse2_loss: 0.0688 - predictions_fine_loss: 0.0218 - predictions_coarse1_acc: 0.9456 - predictions_coarse2_acc: 0.9849 - predictions_fine_acc: 0.9940 - val_loss: 0.9902 - val_predictions_coarse1_loss: 0.1635 - val_predictions_coarse2_loss: 0.5599 - val_predictions_fine_loss: 0.9902 - val_predictions_coarse1_acc: 0.9364 - val_predictions_coarse2_acc: 0.8206 - val_predictions_fine_acc: 0.7765
# Changing loss weights to: coarse1 = 0.0, coarse2 = 4.778427763347626e-42, fine = 1.0
# Epoch 20/50
# 40000/40000 [==============================] - 27s 685us/step - loss: 0.0191 - predictions_coarse1_loss: 0.1411 - predictions_coarse2_loss: 0.0652 - predictions_fine_loss: 0.0191 - predictions_coarse1_acc: 0.9466 - predictions_coarse2_acc: 0.9868 - predictions_fine_acc: 0.9948 - val_loss: 1.0267 - val_predictions_coarse1_loss: 0.1867 - val_predictions_coarse2_loss: 0.5684 - val_predictions_fine_loss: 1.0267 - val_predictions_coarse1_acc: 0.9268 - val_predictions_coarse2_acc: 0.8217 - val_predictions_fine_acc: 0.7764
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.0, fine = 1.0
# Epoch 21/50
# 40000/40000 [==============================] - 27s 682us/step - loss: 0.0171 - predictions_coarse1_loss: 0.1445 - predictions_coarse2_loss: 0.0647 - predictions_fine_loss: 0.0171 - predictions_coarse1_acc: 0.9465 - predictions_coarse2_acc: 0.9861 - predictions_fine_acc: 0.9958 - val_loss: 1.0499 - val_predictions_coarse1_loss: 0.1635 - val_predictions_coarse2_loss: 0.5722 - val_predictions_fine_loss: 1.0499 - val_predictions_coarse1_acc: 0.9361 - val_predictions_coarse2_acc: 0.8203 - val_predictions_fine_acc: 0.7759
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.0, fine = 1.0
# Epoch 22/50
# 40000/40000 [==============================] - 27s 682us/step - loss: 0.0149 - predictions_coarse1_loss: 0.1400 - predictions_coarse2_loss: 0.0580 - predictions_fine_loss: 0.0149 - predictions_coarse1_acc: 0.9474 - predictions_coarse2_acc: 0.9884 - predictions_fine_acc: 0.9960 - val_loss: 1.0378 - val_predictions_coarse1_loss: 0.1702 - val_predictions_coarse2_loss: 0.5544 - val_predictions_fine_loss: 1.0378 - val_predictions_coarse1_acc: 0.9353 - val_predictions_coarse2_acc: 0.8265 - val_predictions_fine_acc: 0.7793
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.0, fine = 1.0
# Epoch 23/50
# 40000/40000 [==============================] - 27s 684us/step - loss: 0.0140 - predictions_coarse1_loss: 0.1438 - predictions_coarse2_loss: 0.0582 - predictions_fine_loss: 0.0140 - predictions_coarse1_acc: 0.9456 - predictions_coarse2_acc: 0.9878 - predictions_fine_acc: 0.9965 - val_loss: 1.1305 - val_predictions_coarse1_loss: 0.1668 - val_predictions_coarse2_loss: 0.5976 - val_predictions_fine_loss: 1.1305 - val_predictions_coarse1_acc: 0.9367 - val_predictions_coarse2_acc: 0.8187 - val_predictions_fine_acc: 0.7671
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.0, fine = 1.0
# Epoch 24/50
# 40000/40000 [==============================] - 27s 681us/step - loss: 0.0124 - predictions_coarse1_loss: 0.1409 - predictions_coarse2_loss: 0.0570 - predictions_fine_loss: 0.0124 - predictions_coarse1_acc: 0.9470 - predictions_coarse2_acc: 0.9883 - predictions_fine_acc: 0.9968 - val_loss: 1.0746 - val_predictions_coarse1_loss: 0.1667 - val_predictions_coarse2_loss: 0.5869 - val_predictions_fine_loss: 1.0746 - val_predictions_coarse1_acc: 0.9347 - val_predictions_coarse2_acc: 0.8172 - val_predictions_fine_acc: 0.7740
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.0, fine = 1.0
# Epoch 25/50
# 40000/40000 [==============================] - 27s 682us/step - loss: 0.0105 - predictions_coarse1_loss: 0.1407 - predictions_coarse2_loss: 0.0534 - predictions_fine_loss: 0.0105 - predictions_coarse1_acc: 0.9477 - predictions_coarse2_acc: 0.9901 - predictions_fine_acc: 0.9974 - val_loss: 1.1054 - val_predictions_coarse1_loss: 0.1710 - val_predictions_coarse2_loss: 0.5643 - val_predictions_fine_loss: 1.1054 - val_predictions_coarse1_acc: 0.9349 - val_predictions_coarse2_acc: 0.8219 - val_predictions_fine_acc: 0.7694
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.0, fine = 1.0
# Epoch 26/50
# 40000/40000 [==============================] - 27s 682us/step - loss: 0.0109 - predictions_coarse1_loss: 0.1458 - predictions_coarse2_loss: 0.0545 - predictions_fine_loss: 0.0109 - predictions_coarse1_acc: 0.9455 - predictions_coarse2_acc: 0.9900 - predictions_fine_acc: 0.9973 - val_loss: 1.1063 - val_predictions_coarse1_loss: 0.1727 - val_predictions_coarse2_loss: 0.5863 - val_predictions_fine_loss: 1.1063 - val_predictions_coarse1_acc: 0.9347 - val_predictions_coarse2_acc: 0.8171 - val_predictions_fine_acc: 0.7775
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.0, fine = 1.0
# Epoch 27/50
# 40000/40000 [==============================] - 27s 683us/step - loss: 0.0140 - predictions_coarse1_loss: 0.1521 - predictions_coarse2_loss: 0.0600 - predictions_fine_loss: 0.0140 - predictions_coarse1_acc: 0.9427 - predictions_coarse2_acc: 0.9875 - predictions_fine_acc: 0.9963 - val_loss: 1.1435 - val_predictions_coarse1_loss: 0.1791 - val_predictions_coarse2_loss: 0.5797 - val_predictions_fine_loss: 1.1435 - val_predictions_coarse1_acc: 0.9306 - val_predictions_coarse2_acc: 0.8200 - val_predictions_fine_acc: 0.7740
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.0, fine = 1.0
# Epoch 28/50
# 40000/40000 [==============================] - 27s 684us/step - loss: 0.0090 - predictions_coarse1_loss: 0.1448 - predictions_coarse2_loss: 0.0504 - predictions_fine_loss: 0.0090 - predictions_coarse1_acc: 0.9460 - predictions_coarse2_acc: 0.9912 - predictions_fine_acc: 0.9978 - val_loss: 1.0871 - val_predictions_coarse1_loss: 0.1726 - val_predictions_coarse2_loss: 0.5664 - val_predictions_fine_loss: 1.0871 - val_predictions_coarse1_acc: 0.9331 - val_predictions_coarse2_acc: 0.8253 - val_predictions_fine_acc: 0.7805
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.0, fine = 1.0
# Epoch 29/50
# 40000/40000 [==============================] - 27s 682us/step - loss: 0.0067 - predictions_coarse1_loss: 0.1416 - predictions_coarse2_loss: 0.0479 - predictions_fine_loss: 0.0067 - predictions_coarse1_acc: 0.9467 - predictions_coarse2_acc: 0.9905 - predictions_fine_acc: 0.9987 - val_loss: 1.1048 - val_predictions_coarse1_loss: 0.1682 - val_predictions_coarse2_loss: 0.5642 - val_predictions_fine_loss: 1.1048 - val_predictions_coarse1_acc: 0.9358 - val_predictions_coarse2_acc: 0.8272 - val_predictions_fine_acc: 0.7827
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.0, fine = 1.0
# Epoch 30/50
# 40000/40000 [==============================] - 27s 681us/step - loss: 0.0070 - predictions_coarse1_loss: 0.1419 - predictions_coarse2_loss: 0.0457 - predictions_fine_loss: 0.0070 - predictions_coarse1_acc: 0.9459 - predictions_coarse2_acc: 0.9918 - predictions_fine_acc: 0.9983 - val_loss: 1.1159 - val_predictions_coarse1_loss: 0.1730 - val_predictions_coarse2_loss: 0.5676 - val_predictions_fine_loss: 1.1159 - val_predictions_coarse1_acc: 0.9334 - val_predictions_coarse2_acc: 0.8275 - val_predictions_fine_acc: 0.7817
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.0, fine = 1.0
# Epoch 31/50
# 40000/40000 [==============================] - 27s 683us/step - loss: 0.0063 - predictions_coarse1_loss: 0.1411 - predictions_coarse2_loss: 0.0433 - predictions_fine_loss: 0.0063 - predictions_coarse1_acc: 0.9464 - predictions_coarse2_acc: 0.9926 - predictions_fine_acc: 0.9987 - val_loss: 1.1151 - val_predictions_coarse1_loss: 0.1698 - val_predictions_coarse2_loss: 0.5715 - val_predictions_fine_loss: 1.1151 - val_predictions_coarse1_acc: 0.9346 - val_predictions_coarse2_acc: 0.8244 - val_predictions_fine_acc: 0.7809
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.0, fine = 1.0
# Epoch 32/50
# 40000/40000 [==============================] - 27s 683us/step - loss: 0.0054 - predictions_coarse1_loss: 0.1408 - predictions_coarse2_loss: 0.0423 - predictions_fine_loss: 0.0054 - predictions_coarse1_acc: 0.9482 - predictions_coarse2_acc: 0.9926 - predictions_fine_acc: 0.9988 - val_loss: 1.0980 - val_predictions_coarse1_loss: 0.1699 - val_predictions_coarse2_loss: 0.5687 - val_predictions_fine_loss: 1.0980 - val_predictions_coarse1_acc: 0.9348 - val_predictions_coarse2_acc: 0.8222 - val_predictions_fine_acc: 0.7800
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.0, fine = 1.0
# Epoch 33/50
# 40000/40000 [==============================] - 27s 681us/step - loss: 0.0053 - predictions_coarse1_loss: 0.1402 - predictions_coarse2_loss: 0.0411 - predictions_fine_loss: 0.0053 - predictions_coarse1_acc: 0.9468 - predictions_coarse2_acc: 0.9931 - predictions_fine_acc: 0.9988 - val_loss: 1.1131 - val_predictions_coarse1_loss: 0.1830 - val_predictions_coarse2_loss: 0.5677 - val_predictions_fine_loss: 1.1131 - val_predictions_coarse1_acc: 0.9311 - val_predictions_coarse2_acc: 0.8281 - val_predictions_fine_acc: 0.7820
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.0, fine = 1.0
# Epoch 34/50
# 40000/40000 [==============================] - 27s 683us/step - loss: 0.0049 - predictions_coarse1_loss: 0.1345 - predictions_coarse2_loss: 0.0406 - predictions_fine_loss: 0.0049 - predictions_coarse1_acc: 0.9513 - predictions_coarse2_acc: 0.9934 - predictions_fine_acc: 0.9990 - val_loss: 1.1181 - val_predictions_coarse1_loss: 0.1726 - val_predictions_coarse2_loss: 0.5773 - val_predictions_fine_loss: 1.1181 - val_predictions_coarse1_acc: 0.9355 - val_predictions_coarse2_acc: 0.8224 - val_predictions_fine_acc: 0.7820
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.0, fine = 1.0
# Epoch 35/50
# 40000/40000 [==============================] - 27s 681us/step - loss: 0.0052 - predictions_coarse1_loss: 0.1380 - predictions_coarse2_loss: 0.0429 - predictions_fine_loss: 0.0052 - predictions_coarse1_acc: 0.9477 - predictions_coarse2_acc: 0.9925 - predictions_fine_acc: 0.9987 - val_loss: 1.1203 - val_predictions_coarse1_loss: 0.1679 - val_predictions_coarse2_loss: 0.5632 - val_predictions_fine_loss: 1.1203 - val_predictions_coarse1_acc: 0.9358 - val_predictions_coarse2_acc: 0.8281 - val_predictions_fine_acc: 0.7821
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.0, fine = 1.0
# Epoch 36/50
# 40000/40000 [==============================] - 27s 680us/step - loss: 0.0048 - predictions_coarse1_loss: 0.1357 - predictions_coarse2_loss: 0.0415 - predictions_fine_loss: 0.0048 - predictions_coarse1_acc: 0.9489 - predictions_coarse2_acc: 0.9928 - predictions_fine_acc: 0.9990 - val_loss: 1.1228 - val_predictions_coarse1_loss: 0.1708 - val_predictions_coarse2_loss: 0.5619 - val_predictions_fine_loss: 1.1228 - val_predictions_coarse1_acc: 0.9363 - val_predictions_coarse2_acc: 0.8277 - val_predictions_fine_acc: 0.7862
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.0, fine = 1.0
# Epoch 37/50
# 40000/40000 [==============================] - 27s 683us/step - loss: 0.0041 - predictions_coarse1_loss: 0.1368 - predictions_coarse2_loss: 0.0407 - predictions_fine_loss: 0.0041 - predictions_coarse1_acc: 0.9502 - predictions_coarse2_acc: 0.9935 - predictions_fine_acc: 0.9993 - val_loss: 1.1333 - val_predictions_coarse1_loss: 0.1715 - val_predictions_coarse2_loss: 0.5660 - val_predictions_fine_loss: 1.1333 - val_predictions_coarse1_acc: 0.9354 - val_predictions_coarse2_acc: 0.8259 - val_predictions_fine_acc: 0.7868
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.0, fine = 1.0
# Epoch 38/50
# 40000/40000 [==============================] - 27s 681us/step - loss: 0.0040 - predictions_coarse1_loss: 0.1357 - predictions_coarse2_loss: 0.0377 - predictions_fine_loss: 0.0040 - predictions_coarse1_acc: 0.9493 - predictions_coarse2_acc: 0.9940 - predictions_fine_acc: 0.9992 - val_loss: 1.1207 - val_predictions_coarse1_loss: 0.1685 - val_predictions_coarse2_loss: 0.5600 - val_predictions_fine_loss: 1.1207 - val_predictions_coarse1_acc: 0.9370 - val_predictions_coarse2_acc: 0.8251 - val_predictions_fine_acc: 0.7835
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.0, fine = 1.0
# Epoch 39/50
# 40000/40000 [==============================] - 27s 682us/step - loss: 0.0037 - predictions_coarse1_loss: 0.1338 - predictions_coarse2_loss: 0.0381 - predictions_fine_loss: 0.0037 - predictions_coarse1_acc: 0.9508 - predictions_coarse2_acc: 0.9936 - predictions_fine_acc: 0.9995 - val_loss: 1.1143 - val_predictions_coarse1_loss: 0.1702 - val_predictions_coarse2_loss: 0.5630 - val_predictions_fine_loss: 1.1143 - val_predictions_coarse1_acc: 0.9355 - val_predictions_coarse2_acc: 0.8265 - val_predictions_fine_acc: 0.7859
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.0, fine = 1.0
# Epoch 40/50
# 40000/40000 [==============================] - 27s 681us/step - loss: 0.0032 - predictions_coarse1_loss: 0.1321 - predictions_coarse2_loss: 0.0364 - predictions_fine_loss: 0.0032 - predictions_coarse1_acc: 0.9510 - predictions_coarse2_acc: 0.9944 - predictions_fine_acc: 0.9994 - val_loss: 1.1273 - val_predictions_coarse1_loss: 0.1730 - val_predictions_coarse2_loss: 0.5630 - val_predictions_fine_loss: 1.1273 - val_predictions_coarse1_acc: 0.9338 - val_predictions_coarse2_acc: 0.8274 - val_predictions_fine_acc: 0.7846
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.0, fine = 1.0
# Epoch 41/50
# 40000/40000 [==============================] - 27s 682us/step - loss: 0.0034 - predictions_coarse1_loss: 0.1348 - predictions_coarse2_loss: 0.0362 - predictions_fine_loss: 0.0034 - predictions_coarse1_acc: 0.9499 - predictions_coarse2_acc: 0.9946 - predictions_fine_acc: 0.9995 - val_loss: 1.1386 - val_predictions_coarse1_loss: 0.1680 - val_predictions_coarse2_loss: 0.5651 - val_predictions_fine_loss: 1.1386 - val_predictions_coarse1_acc: 0.9375 - val_predictions_coarse2_acc: 0.8290 - val_predictions_fine_acc: 0.7856
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.0, fine = 1.0
# Epoch 42/50
# 40000/40000 [==============================] - 27s 682us/step - loss: 0.0031 - predictions_coarse1_loss: 0.1351 - predictions_coarse2_loss: 0.0350 - predictions_fine_loss: 0.0031 - predictions_coarse1_acc: 0.9507 - predictions_coarse2_acc: 0.9944 - predictions_fine_acc: 0.9996 - val_loss: 1.1277 - val_predictions_coarse1_loss: 0.1696 - val_predictions_coarse2_loss: 0.5617 - val_predictions_fine_loss: 1.1277 - val_predictions_coarse1_acc: 0.9363 - val_predictions_coarse2_acc: 0.8277 - val_predictions_fine_acc: 0.7848
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.0, fine = 1.0
# Epoch 43/50
# 40000/40000 [==============================] - 27s 680us/step - loss: 0.0029 - predictions_coarse1_loss: 0.1380 - predictions_coarse2_loss: 0.0352 - predictions_fine_loss: 0.0029 - predictions_coarse1_acc: 0.9476 - predictions_coarse2_acc: 0.9950 - predictions_fine_acc: 0.9996 - val_loss: 1.1264 - val_predictions_coarse1_loss: 0.1706 - val_predictions_coarse2_loss: 0.5668 - val_predictions_fine_loss: 1.1264 - val_predictions_coarse1_acc: 0.9360 - val_predictions_coarse2_acc: 0.8278 - val_predictions_fine_acc: 0.7832
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.0, fine = 1.0
# Epoch 44/50
# 40000/40000 [==============================] - 27s 681us/step - loss: 0.0033 - predictions_coarse1_loss: 0.1349 - predictions_coarse2_loss: 0.0363 - predictions_fine_loss: 0.0033 - predictions_coarse1_acc: 0.9495 - predictions_coarse2_acc: 0.9944 - predictions_fine_acc: 0.9993 - val_loss: 1.1566 - val_predictions_coarse1_loss: 0.1705 - val_predictions_coarse2_loss: 0.5717 - val_predictions_fine_loss: 1.1566 - val_predictions_coarse1_acc: 0.9350 - val_predictions_coarse2_acc: 0.8275 - val_predictions_fine_acc: 0.7831
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.0, fine = 1.0
# Epoch 45/50
# 40000/40000 [==============================] - 27s 682us/step - loss: 0.0031 - predictions_coarse1_loss: 0.1308 - predictions_coarse2_loss: 0.0348 - predictions_fine_loss: 0.0031 - predictions_coarse1_acc: 0.9517 - predictions_coarse2_acc: 0.9945 - predictions_fine_acc: 0.9994 - val_loss: 1.1525 - val_predictions_coarse1_loss: 0.1677 - val_predictions_coarse2_loss: 0.5725 - val_predictions_fine_loss: 1.1525 - val_predictions_coarse1_acc: 0.9374 - val_predictions_coarse2_acc: 0.8253 - val_predictions_fine_acc: 0.7814
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.0, fine = 1.0
# Epoch 46/50
# 40000/40000 [==============================] - 27s 681us/step - loss: 0.0028 - predictions_coarse1_loss: 0.1352 - predictions_coarse2_loss: 0.0360 - predictions_fine_loss: 0.0028 - predictions_coarse1_acc: 0.9496 - predictions_coarse2_acc: 0.9944 - predictions_fine_acc: 0.9995 - val_loss: 1.1450 - val_predictions_coarse1_loss: 0.1711 - val_predictions_coarse2_loss: 0.5639 - val_predictions_fine_loss: 1.1450 - val_predictions_coarse1_acc: 0.9351 - val_predictions_coarse2_acc: 0.8274 - val_predictions_fine_acc: 0.7809
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.0, fine = 1.0
# Epoch 47/50
# 40000/40000 [==============================] - 27s 680us/step - loss: 0.0024 - predictions_coarse1_loss: 0.1348 - predictions_coarse2_loss: 0.0336 - predictions_fine_loss: 0.0024 - predictions_coarse1_acc: 0.9491 - predictions_coarse2_acc: 0.9950 - predictions_fine_acc: 0.9997 - val_loss: 1.1621 - val_predictions_coarse1_loss: 0.1672 - val_predictions_coarse2_loss: 0.5661 - val_predictions_fine_loss: 1.1621 - val_predictions_coarse1_acc: 0.9379 - val_predictions_coarse2_acc: 0.8294 - val_predictions_fine_acc: 0.7814
#
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.0, fine = 1.0
# Epoch 48/50
# 40000/40000 [==============================] - 27s 681us/step - loss: 0.0027 - predictions_coarse1_loss: 0.1326 - predictions_coarse2_loss: 0.0335 - predictions_fine_loss: 0.0027 - predictions_coarse1_acc: 0.9505 - predictions_coarse2_acc: 0.9951 - predictions_fine_acc: 0.9995 - val_loss: 1.1491 - val_predictions_coarse1_loss: 0.1705 - val_predictions_coarse2_loss: 0.5622 - val_predictions_fine_loss: 1.1491 - val_predictions_coarse1_acc: 0.9351 - val_predictions_coarse2_acc: 0.8291 - val_predictions_fine_acc: 0.7857
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.0, fine = 1.0
# Epoch 49/50
# 40000/40000 [==============================] - 27s 680us/step - loss: 0.0026 - predictions_coarse1_loss: 0.1281 - predictions_coarse2_loss: 0.0332 - predictions_fine_loss: 0.0026 - predictions_coarse1_acc: 0.9528 - predictions_coarse2_acc: 0.9949 - predictions_fine_acc: 0.9994 - val_loss: 1.1420 - val_predictions_coarse1_loss: 0.1663 - val_predictions_coarse2_loss: 0.5616 - val_predictions_fine_loss: 1.1420 - val_predictions_coarse1_acc: 0.9366 - val_predictions_coarse2_acc: 0.8264 - val_predictions_fine_acc: 0.7866
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.0, fine = 1.0
# Epoch 50/50
# 40000/40000 [==============================] - 27s 681us/step - loss: 0.0022 - predictions_coarse1_loss: 0.1287 - predictions_coarse2_loss: 0.0323 - predictions_fine_loss: 0.0022 - predictions_coarse1_acc: 0.9523 - predictions_coarse2_acc: 0.9953 - predictions_fine_acc: 0.9996 - val_loss: 1.1420 - val_predictions_coarse1_loss: 0.1659 - val_predictions_coarse2_loss: 0.5595 - val_predictions_fine_loss: 1.1420 - val_predictions_coarse1_acc: 0.9373 - val_predictions_coarse2_acc: 0.8297 - val_predictions_fine_acc: 0.7870
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.0, fine = 1.0

# %%
model.evaluate(test_features, [y_test_c_cat1,y_test_c_cat2, y_test_cat])
# Out:
# 10000/10000 [==============================] - 4s 396us/step
# [1.1867699301719665,
#  0.1882263901412487,
#  0.588687863278389,
#  1.1867699301719665,
#  0.9254,
#  0.8255,
#  0.7843]

# %%
print('Total training time: {}'.format(training_time))
# Out:
# Total training time: 1392.8259329795837

# %%
model.save('drive/TCC-ITAU/cifar-10/models/adaptative-concat-net.h5')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-6c28b1fb20cd> in <module>()
# ----> 1 model.save('drive/TCC-ITAU/cifar-10/models/adaptative-concat-net.h5')
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/network.py in save(self, filepath, overwrite, include_optimizer)
#    1088             raise NotImplementedError
#    1089         from ..models import save_model
# -> 1090         save_model(self, filepath, overwrite, include_optimizer)
#    1091
#    1092     def save_weights(self, filepath, overwrite=True):
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py in save_model(model, filepath, overwrite, include_optimizer)
#     380
#     381     try:
# --> 382         _serialize_model(model, f, include_optimizer)
#     383     finally:
#     384         if opened_new_file:
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py in _serialize_model(model, f, include_optimizer)
#     136                 'sample_weight_mode': model.sample_weight_mode,
#     137                 'loss_weights': model.loss_weights,
# --> 138             }, default=get_json_type).encode('utf8')
#     139             symbolic_weights = getattr(model.optimizer, 'weights')
#     140             if symbolic_weights:
#
# /usr/lib/python3.6/json/__init__.py in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     236         check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     237         separators=separators, default=default, sort_keys=sort_keys,
# --> 238         **kw).encode(obj)
#     239
#     240
#
# /usr/lib/python3.6/json/encoder.py in encode(self, o)
#     197         # exceptions aren't as detailed.  The list call should be roughly
#     198         # equivalent to the PySequence_Fast that ''.join() would do.
# --> 199         chunks = self.iterencode(o, _one_shot=True)
#     200         if not isinstance(chunks, (list, tuple)):
#     201             chunks = list(chunks)
#
# /usr/lib/python3.6/json/encoder.py in iterencode(self, o, _one_shot)
#     255                 self.key_separator, self.item_separator, self.sort_keys,
#     256                 self.skipkeys, _one_shot)
# --> 257         return _iterencode(o, 0)
#     258
#     259 def _make_iterencode(markers, _default, _encoder, _indent, _floatstr,
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py in get_json_type(obj)
#      72             return obj.__name__
#      73
# ---> 74         raise TypeError('Not JSON Serializable: %s' % (obj,))
#      75
#      76     from .. import __version__ as keras_version
#
# TypeError: Not JSON Serializable: <tf.Variable 'alpha_1:0' shape=() dtype=float32_ref>
