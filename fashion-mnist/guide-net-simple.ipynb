# %% [markdown]
# # Guide-net simple

# %%
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse

from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass

# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}

# %%
# !mkdir -p drive
# !google-drive-ocamlfuse drive

# %%
from time import time
import os
import gzip
import numpy as np
from keras.utils import np_utils

import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
def load_mnist(path, kind='train'):
    import os
    import gzip
    import numpy as np

    """Load MNIST data from `path`"""
    labels_path = os.path.join(path,
                               '%s-labels-idx1-ubyte.gz'
                               % kind)
    images_path = os.path.join(path,
                               '%s-images-idx3-ubyte.gz'
                               % kind)

    with gzip.open(labels_path, 'rb') as lbpath:
        labels = np.frombuffer(lbpath.read(), dtype=np.uint8,
                               offset=8)

    with gzip.open(images_path, 'rb') as imgpath:
        images = np.frombuffer(imgpath.read(), dtype=np.uint8,
                               offset=16).reshape(len(labels), 784)

    return images, labels

# %%
X_train, y_train = load_mnist('drive/TCC-ITAU/fashion-mnist/data/fashion', kind='train')
X_test, y_test = load_mnist('drive/TCC-ITAU/fashion-mnist/data/fashion', kind='t10k')

# %%
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=1974)

# %%
train_features = X_train.reshape(X_train.shape[0], 28, 28, 1)/255
vali_features = X_val.reshape(X_val.shape[0], 28, 28, 1)/255
test_features = X_test.reshape(X_test.shape[0], 28, 28, 1)/255

y_train_cat = np_utils.to_categorical(y_train)
y_val_cat = np_utils.to_categorical(y_val)
y_test_cat = np_utils.to_categorical(y_test)

# %% [markdown]
# ## Coarse and Fine classe
#
# | Label | Fine | Coarse |
# | --- | --- | --- |
# | 0 | T-shirt/top | TOP |
# | 1 | Trouser | BOTTOM |
# | 2 | Pullover | TOP |
# | 3 | Dress |BODY |
# | 4 | Coat | TOP |
# | 5 | Sandal | FEET |
# | 6 | Shirt | TOP |
# | 7 | Sneaker | FEET |
# | 8 | Bag | ACCESSORY |
# | 9 | Ankle boot | FEET |

# %%
dict_coarse = {0: 0,
              1: 1,
              2: 0,
              3: 2,
              4: 0,
              5: 3,
              6: 0,
              7: 3,
              8: 4,
              9: 3}

y_train_coarse = np.vectorize(dict_coarse.get)(y_train)
y_val_coarse = np.vectorize(dict_coarse.get)(y_val)
y_test_coarse = np.vectorize(dict_coarse.get)(y_test)

y_train_c_cat = np_utils.to_categorical(y_train_coarse)
y_val_c_cat = np_utils.to_categorical(y_val_coarse)
y_test_c_cat= np_utils.to_categorical(y_test_coarse)

# %%
import keras
from keras.models import Model
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D, Input
from keras import optimizers
from keras.callbacks import TensorBoard, ReduceLROnPlateau, CSVLogger
from keras.layers.normalization import BatchNormalization
from keras.utils.data_utils import get_file
from keras import backend as K

# %%
class LossWeightsModifier(keras.callbacks.Callback):
  def __init__(self, alpha, beta):
    self.alpha = alpha
    self.beta = beta
    
  def on_epoch_end(self, epoch, logs={}):
    if epoch == 7:
      K.set_value(self.alpha, 0.6)
      K.set_value(self.beta, 0.4)
      print('Changing loss weights to: coarse = {}, fine = {}'.format(K.eval(self.alpha), K.eval(self.beta)))

    if epoch == 11:
      K.set_value(self.alpha, 0.2)
      K.set_value(self.beta, 0.8)
      print('Changing loss weights to: coarse = {}, fine = {}'.format(K.eval(self.alpha), K.eval(self.beta)))
      
    if epoch == 21:
      K.set_value(self.alpha, 0)
      K.set_value(self.beta, 1)
      print('Changing loss weights to: coarse = {}, fine = {}'.format(K.eval(self.alpha), K.eval(self.beta)))
      
    logs['alpha'] = K.eval(self.alpha)
    logs['beta'] = K.eval(self.beta)

# %%
img_rows, img_cols = 28, 28
if K.image_data_format() == 'channels_first':
    input_shape = (1, img_rows, img_cols)
else:
    input_shape = (img_rows, img_cols, 1)

# %%
num_classes_coarse = 5
num_classes_fine = 10




num_classes_fine = 10

img_input = Input(shape=input_shape, name='input')


# coarse network
coarse = Conv2D(32, (3, 3), activation='relu', name='coarse_block1_conv1')(img_input)
coarse = MaxPooling2D((2, 2), name='coarse_block1_pool')(coarse)

coarse = Conv2D(64, (3, 3), activation='relu', name='coarse_block1_conv2')(coarse)
coarse = MaxPooling2D((2, 2), name='coarse_block2_pool')(coarse)


coarse = Flatten(name='coarse_flatten')(coarse)
coarse = Dense(128, name='coarse_fc_1')(coarse)
coarse = BatchNormalization()(coarse)
coarse = Activation('relu')(coarse)
coarse = Dropout(0.5)(coarse)

# fine network
fine = Conv2D(32, (3, 3), activation='relu', name='block1_conv1')(img_input)
fine = MaxPooling2D((2, 2), name='block1_pool')(fine)

fine = Conv2D(64, (3, 3), activation='relu', name='block1_conv2')(fine)
fine = MaxPooling2D((2, 2), name='block2_pool')(fine)


fine = Flatten(name='flatten')(fine)
fine = Dense(128, name='fc_1')(fine)
fine = BatchNormalization()(fine)
fine = Activation('relu')(fine)
fine = Dropout(0.5)(fine)

fine = keras.layers.concatenate([fine, coarse])

coarse_pred = Dense(num_classes_coarse, activation='softmax', name='predictions_coarse')(coarse)
fine_pred = Dense(num_classes_fine, activation='softmax', name='predictions_fine')(fine)

# %%
model = Model(inputs=img_input, outputs=[coarse_pred, fine_pred], name='guide_net')

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              (None, 28, 28, 1)    0
# __________________________________________________________________________________________________
# coarse_block1_conv1 (Conv2D)    (None, 26, 26, 32)   320         input[0][0]
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 26, 26, 32)   320         input[0][0]
# __________________________________________________________________________________________________
# coarse_block1_pool (MaxPooling2 (None, 13, 13, 32)   0           coarse_block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_pool (MaxPooling2D)      (None, 13, 13, 32)   0           block1_conv1[0][0]
# __________________________________________________________________________________________________
# coarse_block1_conv2 (Conv2D)    (None, 11, 11, 64)   18496       coarse_block1_pool[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 11, 11, 64)   18496       block1_pool[0][0]
# __________________________________________________________________________________________________
# coarse_block2_pool (MaxPooling2 (None, 5, 5, 64)     0           coarse_block1_conv2[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 5, 5, 64)     0           block1_conv2[0][0]
# __________________________________________________________________________________________________
# coarse_flatten (Flatten)        (None, 1600)         0           coarse_block2_pool[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 1600)         0           block2_pool[0][0]
# __________________________________________________________________________________________________
# coarse_fc_1 (Dense)             (None, 128)          204928      coarse_flatten[0][0]
# __________________________________________________________________________________________________
# fc_1 (Dense)                    (None, 128)          204928      flatten[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 128)          512         coarse_fc_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 128)          512         fc_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 128)          0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 128)          0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 128)          0           activation_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 128)          0           activation_2[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 256)          0           dropout_2[0][0]
#                                                                  dropout_1[0][0]
# __________________________________________________________________________________________________
# predictions_coarse (Dense)      (None, 5)            645         dropout_1[0][0]
# __________________________________________________________________________________________________
# predictions_fine (Dense)        (None, 10)           2570        concatenate_1[0][0]
# ==================================================================================================
# Total params: 451,727
# Trainable params: 451,215
# Non-trainable params: 512
# __________________________________________________________________________________________________

# %%
alpha = K.variable(value=0.95, dtype="float32", name="alpha") # A1 in paper
beta = K.variable(value=0.05, dtype="float32", name="beta") # A2 in paper

model.compile(loss='categorical_crossentropy', 
              optimizer='adam', 
              loss_weights=[alpha, beta],
              metrics=['accuracy'])

# %%
class TimingCallback(keras.callbacks.Callback):
    
  def on_epoch_begin(self, epoch, logs={}):
    self.starttime=time()
  def on_epoch_end(self, epoch, logs={}):
    logs['time_elapsed'] = (time()-self.starttime)

# %%
tb_cb = TensorBoard(log_dir='drive/TCC-ITAU/fashion-mnist/tensorboard/guide-net-simple', histogram_freq=0)
clr_cb = ReduceLROnPlateau(monitor='val_predictions_fine_loss', factor=0.5, patience=10, verbose=1)
time_cb = TimingCallback()
csv_cb = CSVLogger('drive/TCC-ITAU/fashion-mnist/training-data/guide-net/guide-net-simple.csv', separator=',', append=False)
change_lw = LossWeightsModifier(alpha, beta)

cbks = [tb_cb, clr_cb, time_cb, change_lw, csv_cb]

# %%
epochs = 50
start_time = time()
training = model.fit(train_features, [y_train_c_cat, y_train_cat],
                     validation_data=(vali_features, [y_val_c_cat, y_val_cat]),
                     epochs=epochs,
                     batch_size=512, 
                     callbacks=cbks,
                     verbose=1)
training_time = time() - start_time
# Out:
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/50
# 48000/48000 [==============================] - 7s 139us/step - loss: 0.2318 - predictions_coarse_loss: 0.2063 - predictions_fine_loss: 0.7151 - predictions_coarse_acc: 0.9324 - predictions_fine_acc: 0.7479 - val_loss: 0.1256 - val_predictions_coarse_loss: 0.1100 - val_predictions_fine_loss: 0.4216 - val_predictions_coarse_acc: 0.9633 - val_predictions_fine_acc: 0.8554
# Epoch 2/50
# 48000/48000 [==============================] - 5s 101us/step - loss: 0.1154 - predictions_coarse_loss: 0.1008 - predictions_fine_loss: 0.3922 - predictions_coarse_acc: 0.9670 - predictions_fine_acc: 0.8600 - val_loss: 0.1162 - val_predictions_coarse_loss: 0.1028 - val_predictions_fine_loss: 0.3725 - val_predictions_coarse_acc: 0.9653 - val_predictions_fine_acc: 0.8561
# Epoch 3/50
# 48000/48000 [==============================] - 5s 101us/step - loss: 0.0960 - predictions_coarse_loss: 0.0838 - predictions_fine_loss: 0.3284 - predictions_coarse_acc: 0.9724 - predictions_fine_acc: 0.8827 - val_loss: 0.0857 - val_predictions_coarse_loss: 0.0726 - val_predictions_fine_loss: 0.3332 - val_predictions_coarse_acc: 0.9752 - val_predictions_fine_acc: 0.8724
# Epoch 4/50
# 48000/48000 [==============================] - 5s 101us/step - loss: 0.0822 - predictions_coarse_loss: 0.0712 - predictions_fine_loss: 0.2899 - predictions_coarse_acc: 0.9760 - predictions_fine_acc: 0.8939 - val_loss: 0.0812 - val_predictions_coarse_loss: 0.0701 - val_predictions_fine_loss: 0.2932 - val_predictions_coarse_acc: 0.9770 - val_predictions_fine_acc: 0.8920
# Epoch 5/50
# 48000/48000 [==============================] - 5s 101us/step - loss: 0.0736 - predictions_coarse_loss: 0.0634 - predictions_fine_loss: 0.2667 - predictions_coarse_acc: 0.9784 - predictions_fine_acc: 0.9021 - val_loss: 0.0810 - val_predictions_coarse_loss: 0.0696 - val_predictions_fine_loss: 0.2963 - val_predictions_coarse_acc: 0.9761 - val_predictions_fine_acc: 0.8907
# Epoch 6/50
# 48000/48000 [==============================] - 5s 100us/step - loss: 0.0642 - predictions_coarse_loss: 0.0548 - predictions_fine_loss: 0.2427 - predictions_coarse_acc: 0.9809 - predictions_fine_acc: 0.9113 - val_loss: 0.0730 - val_predictions_coarse_loss: 0.0628 - val_predictions_fine_loss: 0.2670 - val_predictions_coarse_acc: 0.9778 - val_predictions_fine_acc: 0.9019
# Epoch 7/50
# 48000/48000 [==============================] - 5s 100us/step - loss: 0.0586 - predictions_coarse_loss: 0.0498 - predictions_fine_loss: 0.2240 - predictions_coarse_acc: 0.9823 - predictions_fine_acc: 0.9182 - val_loss: 0.0774 - val_predictions_coarse_loss: 0.0678 - val_predictions_fine_loss: 0.2581 - val_predictions_coarse_acc: 0.9760 - val_predictions_fine_acc: 0.9029
# Epoch 8/50
# 48000/48000 [==============================] - 5s 100us/step - loss: 0.0528 - predictions_coarse_loss: 0.0449 - predictions_fine_loss: 0.2040 - predictions_coarse_acc: 0.9836 - predictions_fine_acc: 0.9251 - val_loss: 0.0733 - val_predictions_coarse_loss: 0.0634 - val_predictions_fine_loss: 0.2605 - val_predictions_coarse_acc: 0.9785 - val_predictions_fine_acc: 0.8999
# Changing loss weights to: coarse = 0.6000000238418579, fine = 0.4000000059604645
# Epoch 9/50
# 48000/48000 [==============================] - 5s 100us/step - loss: 0.1247 - predictions_coarse_loss: 0.0411 - predictions_fine_loss: 0.2501 - predictions_coarse_acc: 0.9857 - predictions_fine_acc: 0.9055 - val_loss: 0.1891 - val_predictions_coarse_loss: 0.0586 - val_predictions_fine_loss: 0.3849 - val_predictions_coarse_acc: 0.9787 - val_predictions_fine_acc: 0.8519
# Epoch 10/50
# 48000/48000 [==============================] - 5s 100us/step - loss: 0.1015 - predictions_coarse_loss: 0.0367 - predictions_fine_loss: 0.1988 - predictions_coarse_acc: 0.9870 - predictions_fine_acc: 0.9253 - val_loss: 0.1533 - val_predictions_coarse_loss: 0.0677 - val_predictions_fine_loss: 0.2818 - val_predictions_coarse_acc: 0.9779 - val_predictions_fine_acc: 0.9034
# Epoch 11/50
# 48000/48000 [==============================] - 5s 101us/step - loss: 0.0895 - predictions_coarse_loss: 0.0342 - predictions_fine_loss: 0.1723 - predictions_coarse_acc: 0.9876 - predictions_fine_acc: 0.9353 - val_loss: 0.1497 - val_predictions_coarse_loss: 0.0602 - val_predictions_fine_loss: 0.2841 - val_predictions_coarse_acc: 0.9792 - val_predictions_fine_acc: 0.8990
# Epoch 12/50
# 48000/48000 [==============================] - 5s 100us/step - loss: 0.0814 - predictions_coarse_loss: 0.0323 - predictions_fine_loss: 0.1550 - predictions_coarse_acc: 0.9887 - predictions_fine_acc: 0.9430 - val_loss: 0.1496 - val_predictions_coarse_loss: 0.0646 - val_predictions_fine_loss: 0.2771 - val_predictions_coarse_acc: 0.9777 - val_predictions_fine_acc: 0.9044
# Changing loss weights to: coarse = 0.20000000298023224, fine = 0.800000011920929
# Epoch 13/50
# 48000/48000 [==============================] - 5s 100us/step - loss: 0.1366 - predictions_coarse_loss: 0.0300 - predictions_fine_loss: 0.1632 - predictions_coarse_acc: 0.9899 - predictions_fine_acc: 0.9382 - val_loss: 0.2480 - val_predictions_coarse_loss: 0.0621 - val_predictions_fine_loss: 0.2945 - val_predictions_coarse_acc: 0.9797 - val_predictions_fine_acc: 0.8930
# Epoch 14/50
# 48000/48000 [==============================] - 5s 99us/step - loss: 0.1177 - predictions_coarse_loss: 0.0285 - predictions_fine_loss: 0.1399 - predictions_coarse_acc: 0.9903 - predictions_fine_acc: 0.9474 - val_loss: 0.2505 - val_predictions_coarse_loss: 0.0645 - val_predictions_fine_loss: 0.2971 - val_predictions_coarse_acc: 0.9782 - val_predictions_fine_acc: 0.9000
# Epoch 15/50
# 48000/48000 [==============================] - 5s 100us/step - loss: 0.1052 - predictions_coarse_loss: 0.0273 - predictions_fine_loss: 0.1246 - predictions_coarse_acc: 0.9909 - predictions_fine_acc: 0.9538 - val_loss: 0.2278 - val_predictions_coarse_loss: 0.0638 - val_predictions_fine_loss: 0.2689 - val_predictions_coarse_acc: 0.9787 - val_predictions_fine_acc: 0.9088
# Epoch 16/50
# 48000/48000 [==============================] - 5s 99us/step - loss: 0.0936 - predictions_coarse_loss: 0.0262 - predictions_fine_loss: 0.1105 - predictions_coarse_acc: 0.9911 - predictions_fine_acc: 0.9595 - val_loss: 0.2488 - val_predictions_coarse_loss: 0.0769 - val_predictions_fine_loss: 0.2917 - val_predictions_coarse_acc: 0.9761 - val_predictions_fine_acc: 0.9090
# Epoch 17/50
# 48000/48000 [==============================] - 5s 99us/step - loss: 0.0874 - predictions_coarse_loss: 0.0251 - predictions_fine_loss: 0.1030 - predictions_coarse_acc: 0.9917 - predictions_fine_acc: 0.9620 - val_loss: 0.2337 - val_predictions_coarse_loss: 0.0595 - val_predictions_fine_loss: 0.2772 - val_predictions_coarse_acc: 0.9792 - val_predictions_fine_acc: 0.9114
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 18/50
# 48000/48000 [==============================] - 5s 99us/step - loss: 0.0681 - predictions_coarse_loss: 0.0198 - predictions_fine_loss: 0.0802 - predictions_coarse_acc: 0.9935 - predictions_fine_acc: 0.9710 - val_loss: 0.2186 - val_predictions_coarse_loss: 0.0593 - val_predictions_fine_loss: 0.2584 - val_predictions_coarse_acc: 0.9793 - val_predictions_fine_acc: 0.9195
# Epoch 19/50
# 48000/48000 [==============================] - 5s 99us/step - loss: 0.0585 - predictions_coarse_loss: 0.0169 - predictions_fine_loss: 0.0689 - predictions_coarse_acc: 0.9949 - predictions_fine_acc: 0.9756 - val_loss: 0.2193 - val_predictions_coarse_loss: 0.0584 - val_predictions_fine_loss: 0.2595 - val_predictions_coarse_acc: 0.9799 - val_predictions_fine_acc: 0.9195
# Epoch 20/50
# 48000/48000 [==============================] - 5s 100us/step - loss: 0.0528 - predictions_coarse_loss: 0.0159 - predictions_fine_loss: 0.0620 - predictions_coarse_acc: 0.9954 - predictions_fine_acc: 0.9789 - val_loss: 0.2262 - val_predictions_coarse_loss: 0.0574 - val_predictions_fine_loss: 0.2684 - val_predictions_coarse_acc: 0.9816 - val_predictions_fine_acc: 0.9197
# Epoch 21/50
# 48000/48000 [==============================] - 5s 99us/step - loss: 0.0507 - predictions_coarse_loss: 0.0157 - predictions_fine_loss: 0.0594 - predictions_coarse_acc: 0.9951 - predictions_fine_acc: 0.9794 - val_loss: 0.2285 - val_predictions_coarse_loss: 0.0591 - val_predictions_fine_loss: 0.2709 - val_predictions_coarse_acc: 0.9812 - val_predictions_fine_acc: 0.9196
# Epoch 22/50
# 48000/48000 [==============================] - 5s 100us/step - loss: 0.0476 - predictions_coarse_loss: 0.0145 - predictions_fine_loss: 0.0558 - predictions_coarse_acc: 0.9956 - predictions_fine_acc: 0.9805 - val_loss: 0.2287 - val_predictions_coarse_loss: 0.0618 - val_predictions_fine_loss: 0.2704 - val_predictions_coarse_acc: 0.9803 - val_predictions_fine_acc: 0.9210
# Changing loss weights to: coarse = 0.0, fine = 1.0
# Epoch 23/50
# 48000/48000 [==============================] - 5s 99us/step - loss: 0.0528 - predictions_coarse_loss: 0.0144 - predictions_fine_loss: 0.0528 - predictions_coarse_acc: 0.9957 - predictions_fine_acc: 0.9814 - val_loss: 0.2749 - val_predictions_coarse_loss: 0.0665 - val_predictions_fine_loss: 0.2749 - val_predictions_coarse_acc: 0.9796 - val_predictions_fine_acc: 0.9208
# Epoch 24/50
# 48000/48000 [==============================] - 5s 100us/step - loss: 0.0485 - predictions_coarse_loss: 0.0147 - predictions_fine_loss: 0.0485 - predictions_coarse_acc: 0.9955 - predictions_fine_acc: 0.9832 - val_loss: 0.2959 - val_predictions_coarse_loss: 0.0642 - val_predictions_fine_loss: 0.2959 - val_predictions_coarse_acc: 0.9780 - val_predictions_fine_acc: 0.9154
# Epoch 25/50
# 48000/48000 [==============================] - 5s 99us/step - loss: 0.0456 - predictions_coarse_loss: 0.0157 - predictions_fine_loss: 0.0456 - predictions_coarse_acc: 0.9956 - predictions_fine_acc: 0.9845 - val_loss: 0.3073 - val_predictions_coarse_loss: 0.0641 - val_predictions_fine_loss: 0.3073 - val_predictions_coarse_acc: 0.9805 - val_predictions_fine_acc: 0.9158
# Epoch 26/50
# 48000/48000 [==============================] - 5s 100us/step - loss: 0.0430 - predictions_coarse_loss: 0.0167 - predictions_fine_loss: 0.0430 - predictions_coarse_acc: 0.9952 - predictions_fine_acc: 0.9854 - val_loss: 0.2995 - val_predictions_coarse_loss: 0.0669 - val_predictions_fine_loss: 0.2995 - val_predictions_coarse_acc: 0.9776 - val_predictions_fine_acc: 0.9208
# Epoch 27/50
# 48000/48000 [==============================] - 5s 100us/step - loss: 0.0393 - predictions_coarse_loss: 0.0163 - predictions_fine_loss: 0.0393 - predictions_coarse_acc: 0.9953 - predictions_fine_acc: 0.9874 - val_loss: 0.3112 - val_predictions_coarse_loss: 0.0719 - val_predictions_fine_loss: 0.3112 - val_predictions_coarse_acc: 0.9757 - val_predictions_fine_acc: 0.9190
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 28/50
# 48000/48000 [==============================] - 5s 99us/step - loss: 0.0331 - predictions_coarse_loss: 0.0143 - predictions_fine_loss: 0.0331 - predictions_coarse_acc: 0.9962 - predictions_fine_acc: 0.9896 - val_loss: 0.2985 - val_predictions_coarse_loss: 0.0625 - val_predictions_fine_loss: 0.2985 - val_predictions_coarse_acc: 0.9800 - val_predictions_fine_acc: 0.9214
# Epoch 29/50
# 48000/48000 [==============================] - 5s 98us/step - loss: 0.0298 - predictions_coarse_loss: 0.0138 - predictions_fine_loss: 0.0298 - predictions_coarse_acc: 0.9963 - predictions_fine_acc: 0.9909 - val_loss: 0.3066 - val_predictions_coarse_loss: 0.0630 - val_predictions_fine_loss: 0.3066 - val_predictions_coarse_acc: 0.9808 - val_predictions_fine_acc: 0.9217
# Epoch 30/50
# 48000/48000 [==============================] - 5s 99us/step - loss: 0.0271 - predictions_coarse_loss: 0.0139 - predictions_fine_loss: 0.0271 - predictions_coarse_acc: 0.9961 - predictions_fine_acc: 0.9920 - val_loss: 0.3100 - val_predictions_coarse_loss: 0.0633 - val_predictions_fine_loss: 0.3100 - val_predictions_coarse_acc: 0.9811 - val_predictions_fine_acc: 0.9192
# Epoch 31/50
# 48000/48000 [==============================] - 5s 98us/step - loss: 0.0261 - predictions_coarse_loss: 0.0138 - predictions_fine_loss: 0.0261 - predictions_coarse_acc: 0.9967 - predictions_fine_acc: 0.9920 - val_loss: 0.3153 - val_predictions_coarse_loss: 0.0641 - val_predictions_fine_loss: 0.3153 - val_predictions_coarse_acc: 0.9811 - val_predictions_fine_acc: 0.9215
# Epoch 32/50
# 48000/48000 [==============================] - 5s 99us/step - loss: 0.0262 - predictions_coarse_loss: 0.0135 - predictions_fine_loss: 0.0262 - predictions_coarse_acc: 0.9967 - predictions_fine_acc: 0.9925 - val_loss: 0.3272 - val_predictions_coarse_loss: 0.0658 - val_predictions_fine_loss: 0.3272 - val_predictions_coarse_acc: 0.9800 - val_predictions_fine_acc: 0.9205
# Epoch 33/50
# 48000/48000 [==============================] - 5s 100us/step - loss: 0.0242 - predictions_coarse_loss: 0.0145 - predictions_fine_loss: 0.0242 - predictions_coarse_acc: 0.9959 - predictions_fine_acc: 0.9925 - val_loss: 0.3207 - val_predictions_coarse_loss: 0.0643 - val_predictions_fine_loss: 0.3207 - val_predictions_coarse_acc: 0.9805 - val_predictions_fine_acc: 0.9216
# Epoch 34/50
# 48000/48000 [==============================] - 5s 99us/step - loss: 0.0224 - predictions_coarse_loss: 0.0132 - predictions_fine_loss: 0.0224 - predictions_coarse_acc: 0.9965 - predictions_fine_acc: 0.9939 - val_loss: 0.3257 - val_predictions_coarse_loss: 0.0666 - val_predictions_fine_loss: 0.3257 - val_predictions_coarse_acc: 0.9807 - val_predictions_fine_acc: 0.9209
# Epoch 35/50
# 48000/48000 [==============================] - 5s 99us/step - loss: 0.0217 - predictions_coarse_loss: 0.0140 - predictions_fine_loss: 0.0217 - predictions_coarse_acc: 0.9964 - predictions_fine_acc: 0.9935 - val_loss: 0.3363 - val_predictions_coarse_loss: 0.0630 - val_predictions_fine_loss: 0.3363 - val_predictions_coarse_acc: 0.9799 - val_predictions_fine_acc: 0.9211
# Epoch 36/50
# 48000/48000 [==============================] - 5s 100us/step - loss: 0.0209 - predictions_coarse_loss: 0.0134 - predictions_fine_loss: 0.0209 - predictions_coarse_acc: 0.9971 - predictions_fine_acc: 0.9943 - val_loss: 0.3302 - val_predictions_coarse_loss: 0.0716 - val_predictions_fine_loss: 0.3302 - val_predictions_coarse_acc: 0.9809 - val_predictions_fine_acc: 0.9209
# Epoch 37/50
# 48000/48000 [==============================] - 5s 98us/step - loss: 0.0215 - predictions_coarse_loss: 0.0139 - predictions_fine_loss: 0.0215 - predictions_coarse_acc: 0.9967 - predictions_fine_acc: 0.9941 - val_loss: 0.3343 - val_predictions_coarse_loss: 0.0665 - val_predictions_fine_loss: 0.3343 - val_predictions_coarse_acc: 0.9798 - val_predictions_fine_acc: 0.9204
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 38/50
# 48000/48000 [==============================] - 5s 99us/step - loss: 0.0179 - predictions_coarse_loss: 0.0124 - predictions_fine_loss: 0.0179 - predictions_coarse_acc: 0.9972 - predictions_fine_acc: 0.9954 - val_loss: 0.3296 - val_predictions_coarse_loss: 0.0661 - val_predictions_fine_loss: 0.3296 - val_predictions_coarse_acc: 0.9810 - val_predictions_fine_acc: 0.9218
# Epoch 39/50
# 48000/48000 [==============================] - 5s 99us/step - loss: 0.0180 - predictions_coarse_loss: 0.0130 - predictions_fine_loss: 0.0180 - predictions_coarse_acc: 0.9968 - predictions_fine_acc: 0.9953 - val_loss: 0.3327 - val_predictions_coarse_loss: 0.0642 - val_predictions_fine_loss: 0.3327 - val_predictions_coarse_acc: 0.9807 - val_predictions_fine_acc: 0.9221
# Epoch 40/50
# 48000/48000 [==============================] - 5s 98us/step - loss: 0.0166 - predictions_coarse_loss: 0.0121 - predictions_fine_loss: 0.0166 - predictions_coarse_acc: 0.9974 - predictions_fine_acc: 0.9961 - val_loss: 0.3366 - val_predictions_coarse_loss: 0.0655 - val_predictions_fine_loss: 0.3366 - val_predictions_coarse_acc: 0.9806 - val_predictions_fine_acc: 0.9223
# Epoch 41/50
# 48000/48000 [==============================] - 5s 99us/step - loss: 0.0159 - predictions_coarse_loss: 0.0120 - predictions_fine_loss: 0.0159 - predictions_coarse_acc: 0.9974 - predictions_fine_acc: 0.9961 - val_loss: 0.3349 - val_predictions_coarse_loss: 0.0636 - val_predictions_fine_loss: 0.3349 - val_predictions_coarse_acc: 0.9808 - val_predictions_fine_acc: 0.9222
# Epoch 42/50
# 48000/48000 [==============================] - 5s 100us/step - loss: 0.0160 - predictions_coarse_loss: 0.0124 - predictions_fine_loss: 0.0160 - predictions_coarse_acc: 0.9972 - predictions_fine_acc: 0.9959 - val_loss: 0.3388 - val_predictions_coarse_loss: 0.0659 - val_predictions_fine_loss: 0.3388 - val_predictions_coarse_acc: 0.9799 - val_predictions_fine_acc: 0.9217
# Epoch 43/50
# 48000/48000 [==============================] - 5s 99us/step - loss: 0.0153 - predictions_coarse_loss: 0.0126 - predictions_fine_loss: 0.0153 - predictions_coarse_acc: 0.9971 - predictions_fine_acc: 0.9962 - val_loss: 0.3417 - val_predictions_coarse_loss: 0.0650 - val_predictions_fine_loss: 0.3417 - val_predictions_coarse_acc: 0.9802 - val_predictions_fine_acc: 0.9215
# Epoch 44/50
# 48000/48000 [==============================] - 5s 99us/step - loss: 0.0157 - predictions_coarse_loss: 0.0125 - predictions_fine_loss: 0.0157 - predictions_coarse_acc: 0.9973 - predictions_fine_acc: 0.9961 - val_loss: 0.3418 - val_predictions_coarse_loss: 0.0657 - val_predictions_fine_loss: 0.3418 - val_predictions_coarse_acc: 0.9805 - val_predictions_fine_acc: 0.9218
# Epoch 45/50
# 48000/48000 [==============================] - 5s 100us/step - loss: 0.0144 - predictions_coarse_loss: 0.0126 - predictions_fine_loss: 0.0144 - predictions_coarse_acc: 0.9972 - predictions_fine_acc: 0.9965 - val_loss: 0.3488 - val_predictions_coarse_loss: 0.0658 - val_predictions_fine_loss: 0.3488 - val_predictions_coarse_acc: 0.9806 - val_predictions_fine_acc: 0.9224
# Epoch 46/50
# 48000/48000 [==============================] - 5s 99us/step - loss: 0.0148 - predictions_coarse_loss: 0.0119 - predictions_fine_loss: 0.0148 - predictions_coarse_acc: 0.9973 - predictions_fine_acc: 0.9959 - val_loss: 0.3490 - val_predictions_coarse_loss: 0.0683 - val_predictions_fine_loss: 0.3490 - val_predictions_coarse_acc: 0.9805 - val_predictions_fine_acc: 0.9227
# Epoch 47/50
# 48000/48000 [==============================] - 5s 99us/step - loss: 0.0142 - predictions_coarse_loss: 0.0130 - predictions_fine_loss: 0.0142 - predictions_coarse_acc: 0.9974 - predictions_fine_acc: 0.9966 - val_loss: 0.3468 - val_predictions_coarse_loss: 0.0661 - val_predictions_fine_loss: 0.3468 - val_predictions_coarse_acc: 0.9803 - val_predictions_fine_acc: 0.9221
#
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 48/50
# 48000/48000 [==============================] - 5s 99us/step - loss: 0.0138 - predictions_coarse_loss: 0.0115 - predictions_fine_loss: 0.0138 - predictions_coarse_acc: 0.9976 - predictions_fine_acc: 0.9966 - val_loss: 0.3434 - val_predictions_coarse_loss: 0.0660 - val_predictions_fine_loss: 0.3434 - val_predictions_coarse_acc: 0.9800 - val_predictions_fine_acc: 0.9230
# Epoch 49/50
# 48000/48000 [==============================] - 5s 99us/step - loss: 0.0132 - predictions_coarse_loss: 0.0119 - predictions_fine_loss: 0.0132 - predictions_coarse_acc: 0.9974 - predictions_fine_acc: 0.9971 - val_loss: 0.3492 - val_predictions_coarse_loss: 0.0673 - val_predictions_fine_loss: 0.3492 - val_predictions_coarse_acc: 0.9797 - val_predictions_fine_acc: 0.9223
# Epoch 50/50
# 48000/48000 [==============================] - 5s 99us/step - loss: 0.0128 - predictions_coarse_loss: 0.0125 - predictions_fine_loss: 0.0128 - predictions_coarse_acc: 0.9973 - predictions_fine_acc: 0.9972 - val_loss: 0.3512 - val_predictions_coarse_loss: 0.0661 - val_predictions_fine_loss: 0.3512 - val_predictions_coarse_acc: 0.9797 - val_predictions_fine_acc: 0.9212

# %%
model.evaluate(test_features, [y_test_c_cat, y_test_cat])
# Out:
# 10000/10000 [==============================] - 2s 167us/step
# [0.38645037794206294, 0.0817308042580029, 0.38645037794206294, 0.979, 0.9187]

# %%
model.save('drive/TCC-ITAU/fashion-mnist/models/guide-net-simple.h5')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-1b11a7e76696> in <module>()
# ----> 1 model.save('drive/TCC-ITAU/fashion-mnist/models/guide-net-simple.h5')
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/network.py in save(self, filepath, overwrite, include_optimizer)
#    1088             raise NotImplementedError
#    1089         from ..models import save_model
# -> 1090         save_model(self, filepath, overwrite, include_optimizer)
#    1091
#    1092     def save_weights(self, filepath, overwrite=True):
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py in save_model(model, filepath, overwrite, include_optimizer)
#     380
#     381     try:
# --> 382         _serialize_model(model, f, include_optimizer)
#     383     finally:
#     384         if opened_new_file:
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py in _serialize_model(model, f, include_optimizer)
#     136                 'sample_weight_mode': model.sample_weight_mode,
#     137                 'loss_weights': model.loss_weights,
# --> 138             }, default=get_json_type).encode('utf8')
#     139             symbolic_weights = getattr(model.optimizer, 'weights')
#     140             if symbolic_weights:
#
# /usr/lib/python3.6/json/__init__.py in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     236         check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     237         separators=separators, default=default, sort_keys=sort_keys,
# --> 238         **kw).encode(obj)
#     239
#     240
#
# /usr/lib/python3.6/json/encoder.py in encode(self, o)
#     197         # exceptions aren't as detailed.  The list call should be roughly
#     198         # equivalent to the PySequence_Fast that ''.join() would do.
# --> 199         chunks = self.iterencode(o, _one_shot=True)
#     200         if not isinstance(chunks, (list, tuple)):
#     201             chunks = list(chunks)
#
# /usr/lib/python3.6/json/encoder.py in iterencode(self, o, _one_shot)
#     255                 self.key_separator, self.item_separator, self.sort_keys,
#     256                 self.skipkeys, _one_shot)
# --> 257         return _iterencode(o, 0)
#     258
#     259 def _make_iterencode(markers, _default, _encoder, _indent, _floatstr,
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py in get_json_type(obj)
#      72             return obj.__name__
#      73
# ---> 74         raise TypeError('Not JSON Serializable: %s' % (obj,))
#      75
#      76     from .. import __version__ as keras_version
#
# TypeError: Not JSON Serializable: <tf.Variable 'alpha:0' shape=() dtype=float32_ref>

# %%
training_time
# Out:
# 252.0791630744934
