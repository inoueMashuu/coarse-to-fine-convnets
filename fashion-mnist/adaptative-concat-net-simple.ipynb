# %% [markdown]
# # Adaptative Concat-net simple

# %%
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse

from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass

# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}

# %%
# !mkdir -p drive
# !google-drive-ocamlfuse drive

# %%
from time import time
import os
import gzip
import numpy as np
from keras.utils import np_utils

import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
def load_mnist(path, kind='train'):
    import os
    import gzip
    import numpy as np

    """Load MNIST data from `path`"""
    labels_path = os.path.join(path,
                               '%s-labels-idx1-ubyte.gz'
                               % kind)
    images_path = os.path.join(path,
                               '%s-images-idx3-ubyte.gz'
                               % kind)

    with gzip.open(labels_path, 'rb') as lbpath:
        labels = np.frombuffer(lbpath.read(), dtype=np.uint8,
                               offset=8)

    with gzip.open(images_path, 'rb') as imgpath:
        images = np.frombuffer(imgpath.read(), dtype=np.uint8,
                               offset=16).reshape(len(labels), 784)

    return images, labels

# %%
X_train, y_train = load_mnist('drive/TCC-ITAU/fashion-mnist/data/fashion', kind='train')
X_test, y_test = load_mnist('drive/TCC-ITAU/fashion-mnist/data/fashion', kind='t10k')

# %%
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=1974)

# %%
train_features = X_train.reshape(X_train.shape[0], 28, 28, 1)/255
vali_features = X_val.reshape(X_val.shape[0], 28, 28, 1)/255
test_features = X_test.reshape(X_test.shape[0], 28, 28, 1)/255

y_train_cat = np_utils.to_categorical(y_train)
y_val_cat = np_utils.to_categorical(y_val)
y_test_cat = np_utils.to_categorical(y_test)

# %% [markdown]
# ## Coarse and Fine classe
#
# | Label | Fine | Coarse |
# | --- | --- | --- |
# | 0 | T-shirt/top | TOP |
# | 1 | Trouser | BOTTOM |
# | 2 | Pullover | TOP |
# | 3 | Dress |BODY |
# | 4 | Coat | TOP |
# | 5 | Sandal | FEET |
# | 6 | Shirt | TOP |
# | 7 | Sneaker | FEET |
# | 8 | Bag | ACCESSORY |
# | 9 | Ankle boot | FEET |

# %%
dict_coarse = {0: 0,
              1: 1,
              2: 0,
              3: 2,
              4: 0,
              5: 3,
              6: 0,
              7: 3,
              8: 4,
              9: 3}

y_train_coarse = np.vectorize(dict_coarse.get)(y_train)
y_val_coarse = np.vectorize(dict_coarse.get)(y_val)
y_test_coarse = np.vectorize(dict_coarse.get)(y_test)

y_train_c_cat = np_utils.to_categorical(y_train_coarse)
y_val_c_cat = np_utils.to_categorical(y_val_coarse)
y_test_c_cat= np_utils.to_categorical(y_test_coarse)

# %%
import keras
from keras.models import Model
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D, Input
from keras import optimizers
from keras.callbacks import TensorBoard, ReduceLROnPlateau, CSVLogger
from keras.layers.normalization import BatchNormalization
from keras.utils.data_utils import get_file
from keras import backend as K

# %%
class TimingCallback(keras.callbacks.Callback):
    
  def on_epoch_begin(self, epoch, logs={}):
    self.starttime=time()
  def on_epoch_end(self, epoch, logs={}):
    logs['time_elapsed'] = (time()-self.starttime)

# %%
class AdaptativeLossWeightsModifier2Vars(keras.callbacks.Callback):
  def __init__(self, alpha, beta, decay_rate=0.5):
    self.alpha = alpha
    self.beta = beta
    self.decay_rate = decay_rate
  
  def calculate_exponential(self, ratio, decay_rate, epoch):
    return np.exp(-ratio*decay_rate*epoch)

  def on_epoch_end(self, epoch, logs={}):
    if epoch < 1:
      pass
    
    else:
      loss_coarse = self.model.history.history['predictions_coarse_loss'][-1]
      loss_fine = self.model.history.history['predictions_fine_loss'][-1]
      ratio = (loss_coarse/loss_fine) 
      decaying = self.calculate_exponential(ratio, self.decay_rate, epoch)
        
      K.set_value(self.alpha, decaying)
      K.set_value(self.beta, 1 - decaying)
      print('Changing loss weights to: coarse = {}, fine = {}'.format(K.eval(self.alpha), K.eval(self.beta)))  
    
    logs['alpha'] = K.eval(self.alpha)
    logs['beta'] = K.eval(self.beta)

# %%
img_rows, img_cols = 28, 28
if K.image_data_format() == 'channels_first':
    input_shape = (1, img_rows, img_cols)
else:
    input_shape = (img_rows, img_cols, 1)

# %%
num_classes_coarse = 5
num_classes_fine = 10

img_input = Input(shape=input_shape, name='input')


x = Conv2D(32, (3, 3), activation='relu', name='block1_conv1')(img_input)
x = MaxPooling2D((2, 2), name='block1_pool')(x)

#---- coarse branch ----
coarse = Flatten(name='c1_flatten')(x)
coarse = Dense(64, name='c1_fc_1')(coarse)
coarse = BatchNormalization()(coarse)
coarse = Activation('relu')(coarse)
coarse = Dropout(0.5)(coarse)
coarse_pred = Dense(num_classes_coarse, activation='softmax', name='predictions_coarse')(coarse)

x = Conv2D(64, (3, 3), activation='relu', name='block1_conv2')(x)
x = MaxPooling2D((2, 2), name='block2_pool')(x)

x = Flatten(name='flatten')(x)
x = Dense(128, name='fc_1')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = Dropout(0.5)(x)
x = keras.layers.concatenate([x, coarse])
fine_pred = Dense(num_classes_fine, activation='softmax', name='predictions_fine')(x)

# %%
model = Model(inputs=img_input, outputs=[coarse_pred, fine_pred], name='concat_net')

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              (None, 28, 28, 1)    0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 26, 26, 32)   320         input[0][0]
# __________________________________________________________________________________________________
# block1_pool (MaxPooling2D)      (None, 13, 13, 32)   0           block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 11, 11, 64)   18496       block1_pool[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 5, 5, 64)     0           block1_conv2[0][0]
# __________________________________________________________________________________________________
# c1_flatten (Flatten)            (None, 5408)         0           block1_pool[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 1600)         0           block2_pool[0][0]
# __________________________________________________________________________________________________
# c1_fc_1 (Dense)                 (None, 64)           346176      c1_flatten[0][0]
# __________________________________________________________________________________________________
# fc_1 (Dense)                    (None, 128)          204928      flatten[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 64)           256         c1_fc_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 128)          512         fc_1[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 64)           0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 128)          0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 64)           0           activation_9[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 128)          0           activation_10[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 192)          0           dropout_10[0][0]
#                                                                  dropout_9[0][0]
# __________________________________________________________________________________________________
# predictions_coarse (Dense)      (None, 5)            325         dropout_9[0][0]
# __________________________________________________________________________________________________
# predictions_fine (Dense)        (None, 10)           1930        concatenate_5[0][0]
# ==================================================================================================
# Total params: 572,943
# Trainable params: 572,559
# Non-trainable params: 384
# __________________________________________________________________________________________________

# %%
alpha = K.variable(value=0.95, dtype="float32", name="alpha") # A1 in paper
beta = K.variable(value=0.05, dtype="float32", name="beta") # A2 in paper

model.compile(loss='categorical_crossentropy', 
              optimizer='adam', 
              loss_weights=[alpha, beta],
              metrics=['accuracy'])

# %%
tb_cb = TensorBoard(log_dir='drive/TCC-ITAU/fashion-mnist/tensorboard/adaptative-concat-net-simple', histogram_freq=0)
clr_cb = ReduceLROnPlateau(monitor='val_predictions_fine_loss', factor=0.5, patience=10, verbose=1)
time_cb = TimingCallback()
csv_cb = CSVLogger('drive/TCC-ITAU/fashion-mnist/training-data/concat-net/adaptative-concat-net-simple.csv', separator=',', append=False)
change_lw = AdaptativeLossWeightsModifier2Vars(alpha, beta, decay_rate=0.2)


cbks = [tb_cb, clr_cb, time_cb, change_lw, csv_cb]

# %%
epochs = 50
start_time = time()
training = model.fit(train_features, [y_train_c_cat, y_train_cat],
                     validation_data=(vali_features, [y_val_c_cat, y_val_cat]),
                     epochs=epochs,
                     batch_size=512, 
                     callbacks=cbks,
                     verbose=1)
training_time = time() - start_time
# Out:
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/50
# 48000/48000 [==============================] - 6s 119us/step - loss: 0.2600 - predictions_coarse_loss: 0.2388 - predictions_fine_loss: 0.6630 - predictions_coarse_acc: 0.9315 - predictions_fine_acc: 0.7661 - val_loss: 0.1260 - val_predictions_coarse_loss: 0.1103 - val_predictions_fine_loss: 0.4241 - val_predictions_coarse_acc: 0.9705 - val_predictions_fine_acc: 0.8473
# Epoch 2/50
# 48000/48000 [==============================] - 5s 94us/step - loss: 0.1225 - predictions_coarse_loss: 0.1091 - predictions_fine_loss: 0.3775 - predictions_coarse_acc: 0.9681 - predictions_fine_acc: 0.8661 - val_loss: 0.0992 - val_predictions_coarse_loss: 0.0867 - val_predictions_fine_loss: 0.3365 - val_predictions_coarse_acc: 0.9743 - val_predictions_fine_acc: 0.8792
# Changing loss weights to: coarse = 0.9304864406585693, fine = 0.06951353698968887
# Epoch 3/50
# 48000/48000 [==============================] - 4s 92us/step - loss: 0.1018 - predictions_coarse_loss: 0.0856 - predictions_fine_loss: 0.3176 - predictions_coarse_acc: 0.9740 - predictions_fine_acc: 0.8861 - val_loss: 0.0846 - val_predictions_coarse_loss: 0.0693 - val_predictions_fine_loss: 0.2899 - val_predictions_coarse_acc: 0.9772 - val_predictions_fine_acc: 0.8930
# Changing loss weights to: coarse = 0.8908694982528687, fine = 0.10913047939538956
# Epoch 4/50
# 48000/48000 [==============================] - 4s 90us/step - loss: 0.0954 - predictions_coarse_loss: 0.0731 - predictions_fine_loss: 0.2774 - predictions_coarse_acc: 0.9773 - predictions_fine_acc: 0.9001 - val_loss: 0.0897 - val_predictions_coarse_loss: 0.0649 - val_predictions_fine_loss: 0.2919 - val_predictions_coarse_acc: 0.9780 - val_predictions_fine_acc: 0.8929
# Changing loss weights to: coarse = 0.8506274223327637, fine = 0.14937257766723633
# Epoch 5/50
# 48000/48000 [==============================] - 4s 87us/step - loss: 0.0927 - predictions_coarse_loss: 0.0652 - predictions_fine_loss: 0.2493 - predictions_coarse_acc: 0.9794 - predictions_fine_acc: 0.9099 - val_loss: 0.0963 - val_predictions_coarse_loss: 0.0653 - val_predictions_fine_loss: 0.2727 - val_predictions_coarse_acc: 0.9772 - val_predictions_fine_acc: 0.9001
# Changing loss weights to: coarse = 0.8098763227462769, fine = 0.19012367725372314
# Epoch 6/50
# 48000/48000 [==============================] - 4s 89us/step - loss: 0.0890 - predictions_coarse_loss: 0.0570 - predictions_fine_loss: 0.2252 - predictions_coarse_acc: 0.9813 - predictions_fine_acc: 0.9166 - val_loss: 0.1114 - val_predictions_coarse_loss: 0.0625 - val_predictions_fine_loss: 0.3196 - val_predictions_coarse_acc: 0.9783 - val_predictions_fine_acc: 0.8815
# Changing loss weights to: coarse = 0.7698241472244263, fine = 0.23017582297325134
# Epoch 7/50
# 48000/48000 [==============================] - 4s 88us/step - loss: 0.0870 - predictions_coarse_loss: 0.0523 - predictions_fine_loss: 0.2033 - predictions_coarse_acc: 0.9830 - predictions_fine_acc: 0.9251 - val_loss: 0.1047 - val_predictions_coarse_loss: 0.0595 - val_predictions_fine_loss: 0.2560 - val_predictions_coarse_acc: 0.9796 - val_predictions_fine_acc: 0.9028
# Changing loss weights to: coarse = 0.7381384372711182, fine = 0.26186156272888184
# Epoch 8/50
# 48000/48000 [==============================] - 4s 87us/step - loss: 0.0823 - predictions_coarse_loss: 0.0473 - predictions_fine_loss: 0.1811 - predictions_coarse_acc: 0.9849 - predictions_fine_acc: 0.9337 - val_loss: 0.1066 - val_predictions_coarse_loss: 0.0584 - val_predictions_fine_loss: 0.2425 - val_predictions_coarse_acc: 0.9795 - val_predictions_fine_acc: 0.9117
# Changing loss weights to: coarse = 0.6977695226669312, fine = 0.30223047733306885
# Epoch 9/50
# 48000/48000 [==============================] - 4s 85us/step - loss: 0.0825 - predictions_coarse_loss: 0.0437 - predictions_fine_loss: 0.1721 - predictions_coarse_acc: 0.9854 - predictions_fine_acc: 0.9361 - val_loss: 0.1138 - val_predictions_coarse_loss: 0.0571 - val_predictions_fine_loss: 0.2448 - val_predictions_coarse_acc: 0.9801 - val_predictions_fine_acc: 0.9111
# Changing loss weights to: coarse = 0.6583580374717712, fine = 0.34164196252822876
# Epoch 10/50
# 48000/48000 [==============================] - 4s 84us/step - loss: 0.0805 - predictions_coarse_loss: 0.0408 - predictions_fine_loss: 0.1569 - predictions_coarse_acc: 0.9861 - predictions_fine_acc: 0.9420 - val_loss: 0.1381 - val_predictions_coarse_loss: 0.0694 - val_predictions_fine_loss: 0.2703 - val_predictions_coarse_acc: 0.9797 - val_predictions_fine_acc: 0.9045
# Changing loss weights to: coarse = 0.6330235600471497, fine = 0.36697643995285034
# Epoch 11/50
# 48000/48000 [==============================] - 4s 83us/step - loss: 0.0768 - predictions_coarse_loss: 0.0388 - predictions_fine_loss: 0.1423 - predictions_coarse_acc: 0.9873 - predictions_fine_acc: 0.9479 - val_loss: 0.1605 - val_predictions_coarse_loss: 0.0587 - val_predictions_fine_loss: 0.3360 - val_predictions_coarse_acc: 0.9803 - val_predictions_fine_acc: 0.8844
# Changing loss weights to: coarse = 0.594221830368042, fine = 0.405778169631958
# Epoch 12/50
# 48000/48000 [==============================] - 4s 83us/step - loss: 0.0743 - predictions_coarse_loss: 0.0360 - predictions_fine_loss: 0.1303 - predictions_coarse_acc: 0.9879 - predictions_fine_acc: 0.9511 - val_loss: 0.1540 - val_predictions_coarse_loss: 0.0604 - val_predictions_fine_loss: 0.2910 - val_predictions_coarse_acc: 0.9811 - val_predictions_fine_acc: 0.9017
# Changing loss weights to: coarse = 0.5489316582679749, fine = 0.45106834173202515
# Epoch 13/50
# 48000/48000 [==============================] - 4s 84us/step - loss: 0.0736 - predictions_coarse_loss: 0.0341 - predictions_fine_loss: 0.1217 - predictions_coarse_acc: 0.9883 - predictions_fine_acc: 0.9551 - val_loss: 0.1937 - val_predictions_coarse_loss: 0.0589 - val_predictions_fine_loss: 0.3578 - val_predictions_coarse_acc: 0.9806 - val_predictions_fine_acc: 0.8868
# Changing loss weights to: coarse = 0.5149304866790771, fine = 0.48506948351860046
# Epoch 14/50
# 48000/48000 [==============================] - 4s 84us/step - loss: 0.0698 - predictions_coarse_loss: 0.0312 - predictions_fine_loss: 0.1108 - predictions_coarse_acc: 0.9894 - predictions_fine_acc: 0.9595 - val_loss: 0.1787 - val_predictions_coarse_loss: 0.0603 - val_predictions_fine_loss: 0.3044 - val_predictions_coarse_acc: 0.9802 - val_predictions_fine_acc: 0.9037
# Changing loss weights to: coarse = 0.4824720025062561, fine = 0.5175279974937439
# Epoch 15/50
# 48000/48000 [==============================] - 4s 85us/step - loss: 0.0708 - predictions_coarse_loss: 0.0320 - predictions_fine_loss: 0.1070 - predictions_coarse_acc: 0.9890 - predictions_fine_acc: 0.9594 - val_loss: 0.1929 - val_predictions_coarse_loss: 0.0616 - val_predictions_fine_loss: 0.3152 - val_predictions_coarse_acc: 0.9792 - val_predictions_fine_acc: 0.9046
# Changing loss weights to: coarse = 0.45407819747924805, fine = 0.545921802520752
# Epoch 16/50
# 48000/48000 [==============================] - 5s 110us/step - loss: 0.0660 - predictions_coarse_loss: 0.0287 - predictions_fine_loss: 0.0970 - predictions_coarse_acc: 0.9910 - predictions_fine_acc: 0.9639 - val_loss: 0.1677 - val_predictions_coarse_loss: 0.0632 - val_predictions_fine_loss: 0.2545 - val_predictions_coarse_acc: 0.9796 - val_predictions_fine_acc: 0.9178
# Changing loss weights to: coarse = 0.40796154737472534, fine = 0.5920384526252747
# Epoch 17/50
# 48000/48000 [==============================] - 4s 84us/step - loss: 0.0644 - predictions_coarse_loss: 0.0281 - predictions_fine_loss: 0.0894 - predictions_coarse_acc: 0.9904 - predictions_fine_acc: 0.9670 - val_loss: 0.1911 - val_predictions_coarse_loss: 0.0668 - val_predictions_fine_loss: 0.2768 - val_predictions_coarse_acc: 0.9798 - val_predictions_fine_acc: 0.9151
# Changing loss weights to: coarse = 0.3881468176841736, fine = 0.6118531823158264
# Epoch 18/50
# 48000/48000 [==============================] - 4s 84us/step - loss: 0.0608 - predictions_coarse_loss: 0.0269 - predictions_fine_loss: 0.0823 - predictions_coarse_acc: 0.9908 - predictions_fine_acc: 0.9697 - val_loss: 0.1914 - val_predictions_coarse_loss: 0.0641 - val_predictions_fine_loss: 0.2721 - val_predictions_coarse_acc: 0.9788 - val_predictions_fine_acc: 0.9168
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Changing loss weights to: coarse = 0.34410762786865234, fine = 0.6558923721313477
# Epoch 19/50
# 48000/48000 [==============================] - 4s 82us/step - loss: 0.0494 - predictions_coarse_loss: 0.0242 - predictions_fine_loss: 0.0626 - predictions_coarse_acc: 0.9918 - predictions_fine_acc: 0.9794 - val_loss: 0.1885 - val_predictions_coarse_loss: 0.0641 - val_predictions_fine_loss: 0.2537 - val_predictions_coarse_acc: 0.9794 - val_predictions_fine_acc: 0.9235
# Changing loss weights to: coarse = 0.3081572651863098, fine = 0.6918427348136902
# Epoch 20/50
# 48000/48000 [==============================] - 4s 83us/step - loss: 0.0447 - predictions_coarse_loss: 0.0212 - predictions_fine_loss: 0.0553 - predictions_coarse_acc: 0.9937 - predictions_fine_acc: 0.9800 - val_loss: 0.2065 - val_predictions_coarse_loss: 0.0607 - val_predictions_fine_loss: 0.2714 - val_predictions_coarse_acc: 0.9811 - val_predictions_fine_acc: 0.9218
# Changing loss weights to: coarse = 0.2300814986228943, fine = 0.7699185013771057
# Epoch 21/50
# 48000/48000 [==============================] - 4s 83us/step - loss: 0.0421 - predictions_coarse_loss: 0.0207 - predictions_fine_loss: 0.0485 - predictions_coarse_acc: 0.9939 - predictions_fine_acc: 0.9835 - val_loss: 0.2233 - val_predictions_coarse_loss: 0.0621 - val_predictions_fine_loss: 0.2715 - val_predictions_coarse_acc: 0.9806 - val_predictions_fine_acc: 0.9174
# Changing loss weights to: coarse = 0.21611656248569489, fine = 0.7838834524154663
# Epoch 22/50
# 48000/48000 [==============================] - 4s 87us/step - loss: 0.0413 - predictions_coarse_loss: 0.0195 - predictions_fine_loss: 0.0473 - predictions_coarse_acc: 0.9939 - predictions_fine_acc: 0.9833 - val_loss: 0.2317 - val_predictions_coarse_loss: 0.0646 - val_predictions_fine_loss: 0.2777 - val_predictions_coarse_acc: 0.9804 - val_predictions_fine_acc: 0.9217
# Changing loss weights to: coarse = 0.16750690340995789, fine = 0.8324931263923645
# Epoch 23/50
# 48000/48000 [==============================] - 4s 88us/step - loss: 0.0379 - predictions_coarse_loss: 0.0198 - predictions_fine_loss: 0.0416 - predictions_coarse_acc: 0.9939 - predictions_fine_acc: 0.9864 - val_loss: 0.2480 - val_predictions_coarse_loss: 0.0678 - val_predictions_fine_loss: 0.2843 - val_predictions_coarse_acc: 0.9793 - val_predictions_fine_acc: 0.9202
# Changing loss weights to: coarse = 0.16254198551177979, fine = 0.8374580144882202
# Epoch 24/50
# 48000/48000 [==============================] - 4s 87us/step - loss: 0.0370 - predictions_coarse_loss: 0.0189 - predictions_fine_loss: 0.0406 - predictions_coarse_acc: 0.9946 - predictions_fine_acc: 0.9866 - val_loss: 0.2498 - val_predictions_coarse_loss: 0.0651 - val_predictions_fine_loss: 0.2856 - val_predictions_coarse_acc: 0.9798 - val_predictions_fine_acc: 0.9229
# Changing loss weights to: coarse = 0.11150923371315002, fine = 0.8884907364845276
# Epoch 25/50
# 48000/48000 [==============================] - 4s 87us/step - loss: 0.0360 - predictions_coarse_loss: 0.0193 - predictions_fine_loss: 0.0381 - predictions_coarse_acc: 0.9944 - predictions_fine_acc: 0.9872 - val_loss: 0.2777 - val_predictions_coarse_loss: 0.0718 - val_predictions_fine_loss: 0.3036 - val_predictions_coarse_acc: 0.9799 - val_predictions_fine_acc: 0.9163
# Changing loss weights to: coarse = 0.1064898744225502, fine = 0.893510103225708
# Epoch 26/50
# 48000/48000 [==============================] - 4s 88us/step - loss: 0.0338 - predictions_coarse_loss: 0.0194 - predictions_fine_loss: 0.0355 - predictions_coarse_acc: 0.9943 - predictions_fine_acc: 0.9883 - val_loss: 0.2929 - val_predictions_coarse_loss: 0.0713 - val_predictions_fine_loss: 0.3193 - val_predictions_coarse_acc: 0.9793 - val_predictions_fine_acc: 0.9205
# Changing loss weights to: coarse = 0.0798138976097107, fine = 0.9201861023902893
# Epoch 27/50
# 48000/48000 [==============================] - 4s 89us/step - loss: 0.0337 - predictions_coarse_loss: 0.0198 - predictions_fine_loss: 0.0349 - predictions_coarse_acc: 0.9936 - predictions_fine_acc: 0.9881 - val_loss: 0.2923 - val_predictions_coarse_loss: 0.0657 - val_predictions_fine_loss: 0.3120 - val_predictions_coarse_acc: 0.9797 - val_predictions_fine_acc: 0.9206
# Changing loss weights to: coarse = 0.05822909250855446, fine = 0.9417709112167358
# Epoch 28/50
# 48000/48000 [==============================] - 4s 89us/step - loss: 0.0313 - predictions_coarse_loss: 0.0200 - predictions_fine_loss: 0.0320 - predictions_coarse_acc: 0.9937 - predictions_fine_acc: 0.9893 - val_loss: 0.3152 - val_predictions_coarse_loss: 0.0695 - val_predictions_fine_loss: 0.3304 - val_predictions_coarse_acc: 0.9788 - val_predictions_fine_acc: 0.9183
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Changing loss weights to: coarse = 0.04693745821714401, fine = 0.9530625343322754
# Epoch 29/50
# 48000/48000 [==============================] - 4s 89us/step - loss: 0.0261 - predictions_coarse_loss: 0.0190 - predictions_fine_loss: 0.0265 - predictions_coarse_acc: 0.9942 - predictions_fine_acc: 0.9920 - val_loss: 0.2967 - val_predictions_coarse_loss: 0.0660 - val_predictions_fine_loss: 0.3081 - val_predictions_coarse_acc: 0.9796 - val_predictions_fine_acc: 0.9223
# Changing loss weights to: coarse = 0.030170155689120293, fine = 0.9698298573493958
# Epoch 30/50
# 48000/48000 [==============================] - 4s 90us/step - loss: 0.0240 - predictions_coarse_loss: 0.0176 - predictions_fine_loss: 0.0242 - predictions_coarse_acc: 0.9949 - predictions_fine_acc: 0.9925 - val_loss: 0.3053 - val_predictions_coarse_loss: 0.0714 - val_predictions_fine_loss: 0.3126 - val_predictions_coarse_acc: 0.9806 - val_predictions_fine_acc: 0.9232
# Changing loss weights to: coarse = 0.015629904344677925, fine = 0.9843701124191284
# Epoch 31/50
# 48000/48000 [==============================] - 4s 89us/step - loss: 0.0214 - predictions_coarse_loss: 0.0179 - predictions_fine_loss: 0.0214 - predictions_coarse_acc: 0.9952 - predictions_fine_acc: 0.9937 - val_loss: 0.2982 - val_predictions_coarse_loss: 0.0682 - val_predictions_fine_loss: 0.3019 - val_predictions_coarse_acc: 0.9793 - val_predictions_fine_acc: 0.9241
# Changing loss weights to: coarse = 0.012849966064095497, fine = 0.9871500134468079
# Epoch 32/50
# 48000/48000 [==============================] - 4s 88us/step - loss: 0.0211 - predictions_coarse_loss: 0.0183 - predictions_fine_loss: 0.0212 - predictions_coarse_acc: 0.9946 - predictions_fine_acc: 0.9938 - val_loss: 0.3163 - val_predictions_coarse_loss: 0.0673 - val_predictions_fine_loss: 0.3196 - val_predictions_coarse_acc: 0.9794 - val_predictions_fine_acc: 0.9230
# Changing loss weights to: coarse = 0.005727566312998533, fine = 0.9942724108695984
# Epoch 33/50
# 48000/48000 [==============================] - 4s 90us/step - loss: 0.0207 - predictions_coarse_loss: 0.0177 - predictions_fine_loss: 0.0207 - predictions_coarse_acc: 0.9952 - predictions_fine_acc: 0.9939 - val_loss: 0.3264 - val_predictions_coarse_loss: 0.0693 - val_predictions_fine_loss: 0.3279 - val_predictions_coarse_acc: 0.9790 - val_predictions_fine_acc: 0.9227
# Changing loss weights to: coarse = 0.003911178093403578, fine = 0.9960888028144836
# Epoch 34/50
# 48000/48000 [==============================] - 4s 88us/step - loss: 0.0195 - predictions_coarse_loss: 0.0180 - predictions_fine_loss: 0.0196 - predictions_coarse_acc: 0.9949 - predictions_fine_acc: 0.9944 - val_loss: 0.3140 - val_predictions_coarse_loss: 0.0699 - val_predictions_fine_loss: 0.3150 - val_predictions_coarse_acc: 0.9790 - val_predictions_fine_acc: 0.9226
# Changing loss weights to: coarse = 0.003575196722522378, fine = 0.9964247941970825
# Epoch 35/50
# 48000/48000 [==============================] - 4s 88us/step - loss: 0.0184 - predictions_coarse_loss: 0.0183 - predictions_fine_loss: 0.0184 - predictions_coarse_acc: 0.9946 - predictions_fine_acc: 0.9948 - val_loss: 0.3288 - val_predictions_coarse_loss: 0.0718 - val_predictions_fine_loss: 0.3297 - val_predictions_coarse_acc: 0.9791 - val_predictions_fine_acc: 0.9222
# Changing loss weights to: coarse = 0.001881217584013939, fine = 0.9981187582015991
# Epoch 36/50
# 48000/48000 [==============================] - 4s 91us/step - loss: 0.0175 - predictions_coarse_loss: 0.0180 - predictions_fine_loss: 0.0175 - predictions_coarse_acc: 0.9950 - predictions_fine_acc: 0.9955 - val_loss: 0.3257 - val_predictions_coarse_loss: 0.0691 - val_predictions_fine_loss: 0.3262 - val_predictions_coarse_acc: 0.9790 - val_predictions_fine_acc: 0.9207
# Changing loss weights to: coarse = 0.0009716913918964565, fine = 0.9990283250808716
# Epoch 37/50
# 48000/48000 [==============================] - 4s 91us/step - loss: 0.0167 - predictions_coarse_loss: 0.0190 - predictions_fine_loss: 0.0167 - predictions_coarse_acc: 0.9946 - predictions_fine_acc: 0.9951 - val_loss: 0.3245 - val_predictions_coarse_loss: 0.0713 - val_predictions_fine_loss: 0.3248 - val_predictions_coarse_acc: 0.9789 - val_predictions_fine_acc: 0.9226
# Changing loss weights to: coarse = 0.0006067686481401324, fine = 0.9993932247161865
# Epoch 38/50
# 48000/48000 [==============================] - 4s 92us/step - loss: 0.0156 - predictions_coarse_loss: 0.0186 - predictions_fine_loss: 0.0156 - predictions_coarse_acc: 0.9946 - predictions_fine_acc: 0.9957 - val_loss: 0.3262 - val_predictions_coarse_loss: 0.0718 - val_predictions_fine_loss: 0.3263 - val_predictions_coarse_acc: 0.9793 - val_predictions_fine_acc: 0.9243
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Changing loss weights to: coarse = 0.00022502739739138633, fine = 0.9997749924659729
# Epoch 39/50
# 48000/48000 [==============================] - 4s 90us/step - loss: 0.0148 - predictions_coarse_loss: 0.0176 - predictions_fine_loss: 0.0148 - predictions_coarse_acc: 0.9948 - predictions_fine_acc: 0.9961 - val_loss: 0.3274 - val_predictions_coarse_loss: 0.0729 - val_predictions_fine_loss: 0.3274 - val_predictions_coarse_acc: 0.9784 - val_predictions_fine_acc: 0.9236
# Changing loss weights to: coarse = 0.00011800968059105799, fine = 0.9998819828033447
# Epoch 40/50
# 48000/48000 [==============================] - 4s 91us/step - loss: 0.0135 - predictions_coarse_loss: 0.0175 - predictions_fine_loss: 0.0135 - predictions_coarse_acc: 0.9949 - predictions_fine_acc: 0.9966 - val_loss: 0.3312 - val_predictions_coarse_loss: 0.0730 - val_predictions_fine_loss: 0.3312 - val_predictions_coarse_acc: 0.9796 - val_predictions_fine_acc: 0.9252
# Changing loss weights to: coarse = 8.962403080658987e-05, fine = 0.9999103546142578
# Epoch 41/50
# 48000/48000 [==============================] - 4s 90us/step - loss: 0.0133 - predictions_coarse_loss: 0.0182 - predictions_fine_loss: 0.0133 - predictions_coarse_acc: 0.9948 - predictions_fine_acc: 0.9965 - val_loss: 0.3364 - val_predictions_coarse_loss: 0.0709 - val_predictions_fine_loss: 0.3364 - val_predictions_coarse_acc: 0.9799 - val_predictions_fine_acc: 0.9236
# Changing loss weights to: coarse = 2.947635221062228e-05, fine = 0.9999704957008362
# Epoch 42/50
# 48000/48000 [==============================] - 4s 91us/step - loss: 0.0127 - predictions_coarse_loss: 0.0174 - predictions_fine_loss: 0.0127 - predictions_coarse_acc: 0.9951 - predictions_fine_acc: 0.9971 - val_loss: 0.3353 - val_predictions_coarse_loss: 0.0721 - val_predictions_fine_loss: 0.3353 - val_predictions_coarse_acc: 0.9792 - val_predictions_fine_acc: 0.9235
# Changing loss weights to: coarse = 1.3479530025506392e-05, fine = 0.9999865293502808
# Epoch 43/50
# 48000/48000 [==============================] - 4s 90us/step - loss: 0.0130 - predictions_coarse_loss: 0.0173 - predictions_fine_loss: 0.0130 - predictions_coarse_acc: 0.9954 - predictions_fine_acc: 0.9968 - val_loss: 0.3449 - val_predictions_coarse_loss: 0.0732 - val_predictions_fine_loss: 0.3449 - val_predictions_coarse_acc: 0.9788 - val_predictions_fine_acc: 0.9247
# Changing loss weights to: coarse = 9.57021075009834e-06, fine = 0.9999904036521912
# Epoch 44/50
# 48000/48000 [==============================] - 4s 91us/step - loss: 0.0126 - predictions_coarse_loss: 0.0173 - predictions_fine_loss: 0.0126 - predictions_coarse_acc: 0.9951 - predictions_fine_acc: 0.9971 - val_loss: 0.3400 - val_predictions_coarse_loss: 0.0728 - val_predictions_fine_loss: 0.3400 - val_predictions_coarse_acc: 0.9788 - val_predictions_fine_acc: 0.9231
# Changing loss weights to: coarse = 1.0325912626285572e-05, fine = 0.9999896883964539
# Epoch 45/50
# 48000/48000 [==============================] - 4s 91us/step - loss: 0.0126 - predictions_coarse_loss: 0.0189 - predictions_fine_loss: 0.0126 - predictions_coarse_acc: 0.9945 - predictions_fine_acc: 0.9969 - val_loss: 0.3512 - val_predictions_coarse_loss: 0.0732 - val_predictions_fine_loss: 0.3512 - val_predictions_coarse_acc: 0.9790 - val_predictions_fine_acc: 0.9225
# Changing loss weights to: coarse = 5.931948180659674e-06, fine = 0.9999940395355225
# Epoch 46/50
# 48000/48000 [==============================] - 4s 90us/step - loss: 0.0120 - predictions_coarse_loss: 0.0184 - predictions_fine_loss: 0.0120 - predictions_coarse_acc: 0.9948 - predictions_fine_acc: 0.9969 - val_loss: 0.3407 - val_predictions_coarse_loss: 0.0714 - val_predictions_fine_loss: 0.3407 - val_predictions_coarse_acc: 0.9788 - val_predictions_fine_acc: 0.9242
# Changing loss weights to: coarse = 1.3496834299076e-06, fine = 0.9999986290931702
# Epoch 47/50
# 48000/48000 [==============================] - 4s 91us/step - loss: 0.0119 - predictions_coarse_loss: 0.0178 - predictions_fine_loss: 0.0119 - predictions_coarse_acc: 0.9948 - predictions_fine_acc: 0.9971 - val_loss: 0.3494 - val_predictions_coarse_loss: 0.0724 - val_predictions_fine_loss: 0.3494 - val_predictions_coarse_acc: 0.9787 - val_predictions_fine_acc: 0.9245
# Changing loss weights to: coarse = 7.194860813797277e-07, fine = 0.9999992847442627
# Epoch 48/50
# 48000/48000 [==============================] - 4s 87us/step - loss: 0.0122 - predictions_coarse_loss: 0.0179 - predictions_fine_loss: 0.0122 - predictions_coarse_acc: 0.9948 - predictions_fine_acc: 0.9970 - val_loss: 0.3449 - val_predictions_coarse_loss: 0.0726 - val_predictions_fine_loss: 0.3449 - val_predictions_coarse_acc: 0.9785 - val_predictions_fine_acc: 0.9227
#
# Epoch 00048: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Changing loss weights to: coarse = 7.859283073230472e-07, fine = 0.9999992251396179
# Epoch 49/50
# 48000/48000 [==============================] - 4s 88us/step - loss: 0.0105 - predictions_coarse_loss: 0.0182 - predictions_fine_loss: 0.0105 - predictions_coarse_acc: 0.9949 - predictions_fine_acc: 0.9977 - val_loss: 0.3465 - val_predictions_coarse_loss: 0.0736 - val_predictions_fine_loss: 0.3465 - val_predictions_coarse_acc: 0.9789 - val_predictions_fine_acc: 0.9240
# Changing loss weights to: coarse = 7.474106382687751e-07, fine = 0.9999992251396179
# Epoch 50/50
# 48000/48000 [==============================] - 4s 88us/step - loss: 0.0108 - predictions_coarse_loss: 0.0187 - predictions_fine_loss: 0.0108 - predictions_coarse_acc: 0.9946 - predictions_fine_acc: 0.9973 - val_loss: 0.3485 - val_predictions_coarse_loss: 0.0719 - val_predictions_fine_loss: 0.3485 - val_predictions_coarse_acc: 0.9785 - val_predictions_fine_acc: 0.9250
# Changing loss weights to: coarse = 4.168507317103831e-08, fine = 0.9999999403953552

# %%
model.evaluate(test_features, [y_test_c_cat, y_test_cat])
# Out:
# 10000/10000 [==============================] - 3s 350us/step
# [0.38398931596800684, 0.08377632160016801, 0.3839893489010632, 0.9795, 0.9216]

# %%
model.save('drive/TCC-ITAU/fashion-mnist/models/adaptative-concat-net-simple.h5')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-de02de6a5bd9> in <module>()
# ----> 1 model.save('drive/TCC-ITAU/fashion-mnist/models/adaptative-concat-net-simple.h5')
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/network.py in save(self, filepath, overwrite, include_optimizer)
#    1088             raise NotImplementedError
#    1089         from ..models import save_model
# -> 1090         save_model(self, filepath, overwrite, include_optimizer)
#    1091
#    1092     def save_weights(self, filepath, overwrite=True):
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py in save_model(model, filepath, overwrite, include_optimizer)
#     380
#     381     try:
# --> 382         _serialize_model(model, f, include_optimizer)
#     383     finally:
#     384         if opened_new_file:
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py in _serialize_model(model, f, include_optimizer)
#     136                 'sample_weight_mode': model.sample_weight_mode,
#     137                 'loss_weights': model.loss_weights,
# --> 138             }, default=get_json_type).encode('utf8')
#     139             symbolic_weights = getattr(model.optimizer, 'weights')
#     140             if symbolic_weights:
#
# /usr/lib/python3.6/json/__init__.py in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     236         check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     237         separators=separators, default=default, sort_keys=sort_keys,
# --> 238         **kw).encode(obj)
#     239
#     240
#
# /usr/lib/python3.6/json/encoder.py in encode(self, o)
#     197         # exceptions aren't as detailed.  The list call should be roughly
#     198         # equivalent to the PySequence_Fast that ''.join() would do.
# --> 199         chunks = self.iterencode(o, _one_shot=True)
#     200         if not isinstance(chunks, (list, tuple)):
#     201             chunks = list(chunks)
#
# /usr/lib/python3.6/json/encoder.py in iterencode(self, o, _one_shot)
#     255                 self.key_separator, self.item_separator, self.sort_keys,
#     256                 self.skipkeys, _one_shot)
# --> 257         return _iterencode(o, 0)
#     258
#     259 def _make_iterencode(markers, _default, _encoder, _indent, _floatstr,
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py in get_json_type(obj)
#      72             return obj.__name__
#      73
# ---> 74         raise TypeError('Not JSON Serializable: %s' % (obj,))
#      75
#      76     from .. import __version__ as keras_version
#
# TypeError: Not JSON Serializable: <tf.Variable 'alpha_4:0' shape=() dtype=float32_ref>

# %%
training_time
# Out:
# 226.6177282333374
