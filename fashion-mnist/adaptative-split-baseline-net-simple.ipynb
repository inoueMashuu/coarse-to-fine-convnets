# %% [markdown]
# # Adaptative Split-baseline-net simple

# %%
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse

from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass

# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}

# %%
# !mkdir -p drive
# !google-drive-ocamlfuse drive

# %%
from time import time
import os
import gzip
import numpy as np
from keras.utils import np_utils

import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
def load_mnist(path, kind='train'):
    import os
    import gzip
    import numpy as np

    """Load MNIST data from `path`"""
    labels_path = os.path.join(path,
                               '%s-labels-idx1-ubyte.gz'
                               % kind)
    images_path = os.path.join(path,
                               '%s-images-idx3-ubyte.gz'
                               % kind)

    with gzip.open(labels_path, 'rb') as lbpath:
        labels = np.frombuffer(lbpath.read(), dtype=np.uint8,
                               offset=8)

    with gzip.open(images_path, 'rb') as imgpath:
        images = np.frombuffer(imgpath.read(), dtype=np.uint8,
                               offset=16).reshape(len(labels), 784)

    return images, labels

# %%
X_train, y_train = load_mnist('drive/TCC-ITAU/fashion-mnist/data/fashion', kind='train')
X_test, y_test = load_mnist('drive/TCC-ITAU/fashion-mnist/data/fashion', kind='t10k')

# %%
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=1974)

# %%
train_features = X_train.reshape(X_train.shape[0], 28, 28, 1)/255
vali_features = X_val.reshape(X_val.shape[0], 28, 28, 1)/255
test_features = X_test.reshape(X_test.shape[0], 28, 28, 1)/255

y_train_cat = np_utils.to_categorical(y_train)
y_val_cat = np_utils.to_categorical(y_val)
y_test_cat = np_utils.to_categorical(y_test)

# %% [markdown]
# ## Coarse and Fine classe
#
# | Label | Fine | Coarse |
# | --- | --- | --- |
# | 0 | T-shirt/top | TOP |
# | 1 | Trouser | BOTTOM |
# | 2 | Pullover | TOP |
# | 3 | Dress |BODY |
# | 4 | Coat | TOP |
# | 5 | Sandal | FEET |
# | 6 | Shirt | TOP |
# | 7 | Sneaker | FEET |
# | 8 | Bag | ACCESSORY |
# | 9 | Ankle boot | FEET |

# %%
dict_coarse = {0: 0,
              1: 1,
              2: 0,
              3: 2,
              4: 0,
              5: 3,
              6: 0,
              7: 3,
              8: 4,
              9: 3}

y_train_coarse = np.vectorize(dict_coarse.get)(y_train)
y_val_coarse = np.vectorize(dict_coarse.get)(y_val)
y_test_coarse = np.vectorize(dict_coarse.get)(y_test)

y_train_c_cat = np_utils.to_categorical(y_train_coarse)
y_val_c_cat = np_utils.to_categorical(y_val_coarse)
y_test_c_cat= np_utils.to_categorical(y_test_coarse)

# %%
import keras
from keras.models import Model
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D, Input
from keras import optimizers
from keras.callbacks import TensorBoard, ReduceLROnPlateau, CSVLogger
from keras.layers.normalization import BatchNormalization
from keras.utils.data_utils import get_file
from keras import backend as K

# %%
class TimingCallback(keras.callbacks.Callback):
    
  def on_epoch_begin(self, epoch, logs={}):
    self.starttime=time()
  def on_epoch_end(self, epoch, logs={}):
    logs['time_elapsed'] = (time()-self.starttime)

# %%
class AdaptativeLossWeightsModifier2Vars(keras.callbacks.Callback):
  def __init__(self, alpha, beta, decay_rate=0.5):
    self.alpha = alpha
    self.beta = beta
    self.decay_rate = decay_rate
  
  def calculate_exponential(self, ratio, decay_rate, epoch):
    return np.exp(-ratio*decay_rate*epoch)

  def on_epoch_end(self, epoch, logs={}):
    if epoch < 1:
      pass
    
    else:
      loss_coarse = self.model.history.history['predictions_coarse_loss'][-1]
      loss_fine = self.model.history.history['predictions_fine_loss'][-1]
      ratio = (loss_coarse/loss_fine) 
      decaying = self.calculate_exponential(ratio, self.decay_rate, epoch)
        
      K.set_value(self.alpha, decaying)
      K.set_value(self.beta, 1 - decaying)
      print('Changing loss weights to: coarse = {}, fine = {}'.format(K.eval(self.alpha), K.eval(self.beta)))  
    
    logs['alpha'] = K.eval(self.alpha)
    logs['beta'] = K.eval(self.beta)

# %%
img_rows, img_cols = 28, 28
if K.image_data_format() == 'channels_first':
    input_shape = (1, img_rows, img_cols)
else:
    input_shape = (img_rows, img_cols, 1)

# %%
num_classes_coarse = 5
num_classes_fine = 10

img_input = Input(shape=input_shape, name='input')


x = Conv2D(32, (3, 3), activation='relu', name='block1_conv1')(img_input)
x = MaxPooling2D((2, 2), name='block1_pool')(x)

x = Conv2D(64, (3, 3), activation='relu', name='block1_conv2')(x)
x = MaxPooling2D((2, 2), name='block2_pool')(x)


x = Flatten(name='flatten')(x)
x = Dense(128, name='fc_1')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = Dropout(0.5)(x)

coarse_pred = Dense(num_classes_coarse, activation='softmax', name='predictions_coarse')(x)
fine_pred = Dense(num_classes_fine, activation='softmax', name='predictions_fine')(x)

# %%
model = Model(inputs=img_input, outputs=[coarse_pred, fine_pred], name='split_baseline_net')

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              (None, 28, 28, 1)    0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 26, 26, 32)   320         input[0][0]
# __________________________________________________________________________________________________
# block1_pool (MaxPooling2D)      (None, 13, 13, 32)   0           block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 11, 11, 64)   18496       block1_pool[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 5, 5, 64)     0           block1_conv2[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 1600)         0           block2_pool[0][0]
# __________________________________________________________________________________________________
# fc_1 (Dense)                    (None, 128)          204928      flatten[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 128)          512         fc_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 128)          0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 128)          0           activation_3[0][0]
# __________________________________________________________________________________________________
# predictions_coarse (Dense)      (None, 5)            645         dropout_3[0][0]
# __________________________________________________________________________________________________
# predictions_fine (Dense)        (None, 10)           1290        dropout_3[0][0]
# ==================================================================================================
# Total params: 226,191
# Trainable params: 225,935
# Non-trainable params: 256
# __________________________________________________________________________________________________

# %%
alpha = K.variable(value=0.95, dtype="float32", name="alpha") # A1 in paper
beta = K.variable(value=0.05, dtype="float32", name="beta") # A2 in paper

model.compile(loss='categorical_crossentropy', 
              optimizer='adam', 
              loss_weights=[alpha, beta],
              metrics=['accuracy'])

# %%
tb_cb = TensorBoard(log_dir='drive/TCC-ITAU/fashion-mnist/tensorboard/adaptative-split-baseline-net-simple', histogram_freq=0)
clr_cb = ReduceLROnPlateau(monitor='val_predictions_fine_loss', factor=0.5, patience=10, verbose=1)
time_cb = TimingCallback()
csv_cb = CSVLogger('drive/TCC-ITAU/fashion-mnist/training-data/split-baseline-net/adaptative-split-baseline-net-simple.csv', separator=',', append=False)
change_lw = AdaptativeLossWeightsModifier2Vars(alpha, beta, decay_rate=0.5)

cbks = [tb_cb, clr_cb, time_cb, change_lw, csv_cb]

# %%
epochs = 50
start_time = time()
training = model.fit(train_features, [y_train_c_cat, y_train_cat],
                     validation_data=(vali_features, [y_val_c_cat, y_val_cat]),
                     epochs=epochs,
                     batch_size=512, 
                     callbacks=cbks,
                     verbose=1)
training_time = time() - start_time
# Out:
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/50
# 48000/48000 [==============================] - 5s 98us/step - loss: 0.2602 - predictions_coarse_loss: 0.2081 - predictions_fine_loss: 1.2493 - predictions_coarse_acc: 0.9320 - predictions_fine_acc: 0.5735 - val_loss: 0.1257 - val_predictions_coarse_loss: 0.0987 - val_predictions_fine_loss: 0.6390 - val_predictions_coarse_acc: 0.9678 - val_predictions_fine_acc: 0.7785
# Epoch 2/50
# 48000/48000 [==============================] - 4s 81us/step - loss: 0.1246 - predictions_coarse_loss: 0.0982 - predictions_fine_loss: 0.6258 - predictions_coarse_acc: 0.9685 - predictions_fine_acc: 0.7746 - val_loss: 0.1031 - val_predictions_coarse_loss: 0.0820 - val_predictions_fine_loss: 0.5026 - val_predictions_coarse_acc: 0.9719 - val_predictions_fine_acc: 0.7995
# Changing loss weights to: coarse = 0.9200916886329651, fine = 0.07990828901529312
# Epoch 3/50
# 48000/48000 [==============================] - 4s 80us/step - loss: 0.1148 - predictions_coarse_loss: 0.0810 - predictions_fine_loss: 0.5035 - predictions_coarse_acc: 0.9730 - predictions_fine_acc: 0.8163 - val_loss: 0.0990 - val_predictions_coarse_loss: 0.0722 - val_predictions_fine_loss: 0.4085 - val_predictions_coarse_acc: 0.9755 - val_predictions_fine_acc: 0.8524
# Changing loss weights to: coarse = 0.8547783493995667, fine = 0.14522168040275574
# Epoch 4/50
# 48000/48000 [==============================] - 4s 80us/step - loss: 0.1176 - predictions_coarse_loss: 0.0676 - predictions_fine_loss: 0.4122 - predictions_coarse_acc: 0.9767 - predictions_fine_acc: 0.8503 - val_loss: 0.1091 - val_predictions_coarse_loss: 0.0649 - val_predictions_fine_loss: 0.3693 - val_predictions_coarse_acc: 0.9776 - val_predictions_fine_acc: 0.8579
# Changing loss weights to: coarse = 0.7855736613273621, fine = 0.21442635357379913
# Epoch 5/50
# 48000/48000 [==============================] - 4s 83us/step - loss: 0.1235 - predictions_coarse_loss: 0.0601 - predictions_fine_loss: 0.3556 - predictions_coarse_acc: 0.9798 - predictions_fine_acc: 0.8709 - val_loss: 0.1248 - val_predictions_coarse_loss: 0.0682 - val_predictions_fine_loss: 0.3320 - val_predictions_coarse_acc: 0.9742 - val_predictions_fine_acc: 0.8713
# Changing loss weights to: coarse = 0.7205458879470825, fine = 0.2794541120529175
# Epoch 6/50
# 48000/48000 [==============================] - 4s 81us/step - loss: 0.1276 - predictions_coarse_loss: 0.0544 - predictions_fine_loss: 0.3165 - predictions_coarse_acc: 0.9808 - predictions_fine_acc: 0.8830 - val_loss: 0.1223 - val_predictions_coarse_loss: 0.0592 - val_predictions_fine_loss: 0.2849 - val_predictions_coarse_acc: 0.9788 - val_predictions_fine_acc: 0.8964
# Changing loss weights to: coarse = 0.6553766131401062, fine = 0.3446233570575714
# Epoch 7/50
# 48000/48000 [==============================] - 4s 80us/step - loss: 0.1331 - predictions_coarse_loss: 0.0505 - predictions_fine_loss: 0.2901 - predictions_coarse_acc: 0.9828 - predictions_fine_acc: 0.8949 - val_loss: 0.1502 - val_predictions_coarse_loss: 0.0625 - val_predictions_fine_loss: 0.3170 - val_predictions_coarse_acc: 0.9774 - val_predictions_fine_acc: 0.8773
# Changing loss weights to: coarse = 0.5973042249679565, fine = 0.40269580483436584
# Epoch 8/50
# 48000/48000 [==============================] - 4s 80us/step - loss: 0.1357 - predictions_coarse_loss: 0.0467 - predictions_fine_loss: 0.2677 - predictions_coarse_acc: 0.9844 - predictions_fine_acc: 0.9015 - val_loss: 0.1529 - val_predictions_coarse_loss: 0.0647 - val_predictions_fine_loss: 0.2837 - val_predictions_coarse_acc: 0.9767 - val_predictions_fine_acc: 0.8933
# Changing loss weights to: coarse = 0.543657660484314, fine = 0.45634233951568604
# Epoch 9/50
# 48000/48000 [==============================] - 4s 79us/step - loss: 0.1372 - predictions_coarse_loss: 0.0431 - predictions_fine_loss: 0.2492 - predictions_coarse_acc: 0.9854 - predictions_fine_acc: 0.9085 - val_loss: 0.1490 - val_predictions_coarse_loss: 0.0538 - val_predictions_fine_loss: 0.2624 - val_predictions_coarse_acc: 0.9809 - val_predictions_fine_acc: 0.9018
# Changing loss weights to: coarse = 0.4979146718978882, fine = 0.5020853281021118
# Epoch 10/50
# 48000/48000 [==============================] - 4s 78us/step - loss: 0.1350 - predictions_coarse_loss: 0.0394 - predictions_fine_loss: 0.2299 - predictions_coarse_acc: 0.9865 - predictions_fine_acc: 0.9152 - val_loss: 0.1662 - val_predictions_coarse_loss: 0.0556 - val_predictions_fine_loss: 0.2758 - val_predictions_coarse_acc: 0.9794 - val_predictions_fine_acc: 0.8941
# Changing loss weights to: coarse = 0.45907294750213623, fine = 0.5409270524978638
# Epoch 11/50
# 48000/48000 [==============================] - 4s 82us/step - loss: 0.1351 - predictions_coarse_loss: 0.0370 - predictions_fine_loss: 0.2183 - predictions_coarse_acc: 0.9872 - predictions_fine_acc: 0.9193 - val_loss: 0.1631 - val_predictions_coarse_loss: 0.0578 - val_predictions_fine_loss: 0.2525 - val_predictions_coarse_acc: 0.9792 - val_predictions_fine_acc: 0.9056
# Changing loss weights to: coarse = 0.42424076795578003, fine = 0.57575923204422
# Epoch 12/50
# 48000/48000 [==============================] - 4s 79us/step - loss: 0.1322 - predictions_coarse_loss: 0.0345 - predictions_fine_loss: 0.2042 - predictions_coarse_acc: 0.9883 - predictions_fine_acc: 0.9239 - val_loss: 0.1832 - val_predictions_coarse_loss: 0.0632 - val_predictions_fine_loss: 0.2717 - val_predictions_coarse_acc: 0.9776 - val_predictions_fine_acc: 0.8983
# Changing loss weights to: coarse = 0.39379534125328064, fine = 0.606204628944397
# Epoch 13/50
# 48000/48000 [==============================] - 4s 80us/step - loss: 0.1294 - predictions_coarse_loss: 0.0332 - predictions_fine_loss: 0.1919 - predictions_coarse_acc: 0.9889 - predictions_fine_acc: 0.9285 - val_loss: 0.1891 - val_predictions_coarse_loss: 0.0572 - val_predictions_fine_loss: 0.2748 - val_predictions_coarse_acc: 0.9792 - val_predictions_fine_acc: 0.8994
# Changing loss weights to: coarse = 0.3633492887020111, fine = 0.6366506814956665
# Epoch 14/50
# 48000/48000 [==============================] - 4s 81us/step - loss: 0.1285 - predictions_coarse_loss: 0.0314 - predictions_fine_loss: 0.1839 - predictions_coarse_acc: 0.9897 - predictions_fine_acc: 0.9319 - val_loss: 0.1912 - val_predictions_coarse_loss: 0.0584 - val_predictions_fine_loss: 0.2670 - val_predictions_coarse_acc: 0.9802 - val_predictions_fine_acc: 0.9018
# Changing loss weights to: coarse = 0.32506242394447327, fine = 0.6749375462532043
# Epoch 15/50
# 48000/48000 [==============================] - 4s 79us/step - loss: 0.1248 - predictions_coarse_loss: 0.0292 - predictions_fine_loss: 0.1709 - predictions_coarse_acc: 0.9905 - predictions_fine_acc: 0.9366 - val_loss: 0.1964 - val_predictions_coarse_loss: 0.0608 - val_predictions_fine_loss: 0.2617 - val_predictions_coarse_acc: 0.9788 - val_predictions_fine_acc: 0.9025
# Changing loss weights to: coarse = 0.30306336283683777, fine = 0.6969366669654846
# Epoch 16/50
# 48000/48000 [==============================] - 4s 79us/step - loss: 0.1235 - predictions_coarse_loss: 0.0288 - predictions_fine_loss: 0.1646 - predictions_coarse_acc: 0.9903 - predictions_fine_acc: 0.9392 - val_loss: 0.2151 - val_predictions_coarse_loss: 0.0724 - val_predictions_fine_loss: 0.2771 - val_predictions_coarse_acc: 0.9777 - val_predictions_fine_acc: 0.9035
# Changing loss weights to: coarse = 0.2770322263240814, fine = 0.7229677438735962
# Epoch 17/50
# 48000/48000 [==============================] - 4s 79us/step - loss: 0.1167 - predictions_coarse_loss: 0.0270 - predictions_fine_loss: 0.1510 - predictions_coarse_acc: 0.9910 - predictions_fine_acc: 0.9438 - val_loss: 0.2027 - val_predictions_coarse_loss: 0.0603 - val_predictions_fine_loss: 0.2573 - val_predictions_coarse_acc: 0.9798 - val_predictions_fine_acc: 0.9139
# Changing loss weights to: coarse = 0.2466600239276886, fine = 0.7533400058746338
# Epoch 18/50
# 48000/48000 [==============================] - 4s 78us/step - loss: 0.1167 - predictions_coarse_loss: 0.0247 - predictions_fine_loss: 0.1468 - predictions_coarse_acc: 0.9918 - predictions_fine_acc: 0.9439 - val_loss: 0.2444 - val_predictions_coarse_loss: 0.0624 - val_predictions_fine_loss: 0.3040 - val_predictions_coarse_acc: 0.9796 - val_predictions_fine_acc: 0.8987
# Changing loss weights to: coarse = 0.2183402180671692, fine = 0.7816597819328308
# Epoch 19/50
# 48000/48000 [==============================] - 4s 79us/step - loss: 0.1134 - predictions_coarse_loss: 0.0249 - predictions_fine_loss: 0.1381 - predictions_coarse_acc: 0.9917 - predictions_fine_acc: 0.9483 - val_loss: 0.2382 - val_predictions_coarse_loss: 0.0596 - val_predictions_fine_loss: 0.2881 - val_predictions_coarse_acc: 0.9794 - val_predictions_fine_acc: 0.9052
# Changing loss weights to: coarse = 0.21979084610939026, fine = 0.7802091240882874
# Epoch 20/50
# 48000/48000 [==============================] - 4s 77us/step - loss: 0.1081 - predictions_coarse_loss: 0.0240 - predictions_fine_loss: 0.1318 - predictions_coarse_acc: 0.9919 - predictions_fine_acc: 0.9500 - val_loss: 0.2056 - val_predictions_coarse_loss: 0.0613 - val_predictions_fine_loss: 0.2463 - val_predictions_coarse_acc: 0.9799 - val_predictions_fine_acc: 0.9148
# Changing loss weights to: coarse = 0.1797742247581482, fine = 0.8202257752418518
# Epoch 21/50
# 48000/48000 [==============================] - 4s 77us/step - loss: 0.1070 - predictions_coarse_loss: 0.0235 - predictions_fine_loss: 0.1253 - predictions_coarse_acc: 0.9921 - predictions_fine_acc: 0.9534 - val_loss: 0.2334 - val_predictions_coarse_loss: 0.0609 - val_predictions_fine_loss: 0.2712 - val_predictions_coarse_acc: 0.9803 - val_predictions_fine_acc: 0.9099
# Changing loss weights to: coarse = 0.1614721566438675, fine = 0.8385278582572937
# Epoch 22/50
# 48000/48000 [==============================] - 4s 77us/step - loss: 0.1041 - predictions_coarse_loss: 0.0233 - predictions_fine_loss: 0.1197 - predictions_coarse_acc: 0.9925 - predictions_fine_acc: 0.9554 - val_loss: 0.2391 - val_predictions_coarse_loss: 0.0651 - val_predictions_fine_loss: 0.2726 - val_predictions_coarse_acc: 0.9796 - val_predictions_fine_acc: 0.9134
# Changing loss weights to: coarse = 0.13948333263397217, fine = 0.8605166673660278
# Epoch 23/50
# 48000/48000 [==============================] - 4s 77us/step - loss: 0.1011 - predictions_coarse_loss: 0.0206 - predictions_fine_loss: 0.1141 - predictions_coarse_acc: 0.9933 - predictions_fine_acc: 0.9568 - val_loss: 0.2552 - val_predictions_coarse_loss: 0.0612 - val_predictions_fine_loss: 0.2867 - val_predictions_coarse_acc: 0.9783 - val_predictions_fine_acc: 0.9061
# Changing loss weights to: coarse = 0.11764401942491531, fine = 0.8823559880256653
# Epoch 24/50
# 48000/48000 [==============================] - 4s 79us/step - loss: 0.0947 - predictions_coarse_loss: 0.0200 - predictions_fine_loss: 0.1047 - predictions_coarse_acc: 0.9936 - predictions_fine_acc: 0.9605 - val_loss: 0.2885 - val_predictions_coarse_loss: 0.0699 - val_predictions_fine_loss: 0.3176 - val_predictions_coarse_acc: 0.9781 - val_predictions_fine_acc: 0.9022
# Changing loss weights to: coarse = 0.1256568729877472, fine = 0.8743431568145752
# Epoch 25/50
# 48000/48000 [==============================] - 4s 80us/step - loss: 0.0916 - predictions_coarse_loss: 0.0210 - predictions_fine_loss: 0.1018 - predictions_coarse_acc: 0.9930 - predictions_fine_acc: 0.9617 - val_loss: 0.2635 - val_predictions_coarse_loss: 0.0684 - val_predictions_fine_loss: 0.2916 - val_predictions_coarse_acc: 0.9788 - val_predictions_fine_acc: 0.9144
# Changing loss weights to: coarse = 0.10162784159183502, fine = 0.8983721733093262
# Epoch 26/50
# 48000/48000 [==============================] - 4s 78us/step - loss: 0.0886 - predictions_coarse_loss: 0.0209 - predictions_fine_loss: 0.0963 - predictions_coarse_acc: 0.9933 - predictions_fine_acc: 0.9639 - val_loss: 0.2781 - val_predictions_coarse_loss: 0.0736 - val_predictions_fine_loss: 0.3012 - val_predictions_coarse_acc: 0.9771 - val_predictions_fine_acc: 0.9086
# Changing loss weights to: coarse = 0.07549476623535156, fine = 0.9245052337646484
# Epoch 27/50
# 48000/48000 [==============================] - 4s 79us/step - loss: 0.0841 - predictions_coarse_loss: 0.0197 - predictions_fine_loss: 0.0893 - predictions_coarse_acc: 0.9936 - predictions_fine_acc: 0.9667 - val_loss: 0.3184 - val_predictions_coarse_loss: 0.0805 - val_predictions_fine_loss: 0.3379 - val_predictions_coarse_acc: 0.9753 - val_predictions_fine_acc: 0.9061
# Changing loss weights to: coarse = 0.0592079721391201, fine = 0.9407920241355896
# Epoch 28/50
# 48000/48000 [==============================] - 4s 79us/step - loss: 0.0866 - predictions_coarse_loss: 0.0199 - predictions_fine_loss: 0.0908 - predictions_coarse_acc: 0.9934 - predictions_fine_acc: 0.9662 - val_loss: 0.3002 - val_predictions_coarse_loss: 0.0684 - val_predictions_fine_loss: 0.3148 - val_predictions_coarse_acc: 0.9782 - val_predictions_fine_acc: 0.9067
# Changing loss weights to: coarse = 0.050733331590890884, fine = 0.9492666721343994
# Epoch 29/50
# 48000/48000 [==============================] - 4s 77us/step - loss: 0.0818 - predictions_coarse_loss: 0.0195 - predictions_fine_loss: 0.0851 - predictions_coarse_acc: 0.9941 - predictions_fine_acc: 0.9678 - val_loss: 0.2902 - val_predictions_coarse_loss: 0.0713 - val_predictions_fine_loss: 0.3019 - val_predictions_coarse_acc: 0.9781 - val_predictions_fine_acc: 0.9128
# Changing loss weights to: coarse = 0.04611045494675636, fine = 0.9538895487785339
# Epoch 30/50
# 48000/48000 [==============================] - 4s 76us/step - loss: 0.0784 - predictions_coarse_loss: 0.0198 - predictions_fine_loss: 0.0813 - predictions_coarse_acc: 0.9934 - predictions_fine_acc: 0.9696 - val_loss: 0.2990 - val_predictions_coarse_loss: 0.0674 - val_predictions_fine_loss: 0.3102 - val_predictions_coarse_acc: 0.9784 - val_predictions_fine_acc: 0.9115
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Changing loss weights to: coarse = 0.036176275461912155, fine = 0.9638237357139587
# Epoch 31/50
# 48000/48000 [==============================] - 4s 77us/step - loss: 0.0638 - predictions_coarse_loss: 0.0166 - predictions_fine_loss: 0.0656 - predictions_coarse_acc: 0.9947 - predictions_fine_acc: 0.9760 - val_loss: 0.2892 - val_predictions_coarse_loss: 0.0703 - val_predictions_fine_loss: 0.2974 - val_predictions_coarse_acc: 0.9792 - val_predictions_fine_acc: 0.9167
# Changing loss weights to: coarse = 0.026058292016386986, fine = 0.9739416837692261
# Epoch 32/50
# 48000/48000 [==============================] - 4s 77us/step - loss: 0.0566 - predictions_coarse_loss: 0.0158 - predictions_fine_loss: 0.0577 - predictions_coarse_acc: 0.9951 - predictions_fine_acc: 0.9798 - val_loss: 0.2969 - val_predictions_coarse_loss: 0.0694 - val_predictions_fine_loss: 0.3030 - val_predictions_coarse_acc: 0.9796 - val_predictions_fine_acc: 0.9169
# Changing loss weights to: coarse = 0.0199307631701231, fine = 0.9800692200660706
# Epoch 33/50
# 48000/48000 [==============================] - 4s 81us/step - loss: 0.0516 - predictions_coarse_loss: 0.0146 - predictions_fine_loss: 0.0524 - predictions_coarse_acc: 0.9959 - predictions_fine_acc: 0.9817 - val_loss: 0.3121 - val_predictions_coarse_loss: 0.0706 - val_predictions_fine_loss: 0.3170 - val_predictions_coarse_acc: 0.9795 - val_predictions_fine_acc: 0.9161
# Changing loss weights to: coarse = 0.01246265135705471, fine = 0.9875373244285583
# Epoch 34/50
# 48000/48000 [==============================] - 4s 77us/step - loss: 0.0498 - predictions_coarse_loss: 0.0143 - predictions_fine_loss: 0.0503 - predictions_coarse_acc: 0.9958 - predictions_fine_acc: 0.9826 - val_loss: 0.3149 - val_predictions_coarse_loss: 0.0693 - val_predictions_fine_loss: 0.3180 - val_predictions_coarse_acc: 0.9798 - val_predictions_fine_acc: 0.9151
# Changing loss weights to: coarse = 0.010048137046396732, fine = 0.9899518489837646
# Epoch 35/50
# 48000/48000 [==============================] - 4s 77us/step - loss: 0.0489 - predictions_coarse_loss: 0.0153 - predictions_fine_loss: 0.0493 - predictions_coarse_acc: 0.9954 - predictions_fine_acc: 0.9832 - val_loss: 0.3233 - val_predictions_coarse_loss: 0.0680 - val_predictions_fine_loss: 0.3259 - val_predictions_coarse_acc: 0.9791 - val_predictions_fine_acc: 0.9157
# Changing loss weights to: coarse = 0.007880304008722305, fine = 0.9921196699142456
# Epoch 36/50
# 48000/48000 [==============================] - 4s 78us/step - loss: 0.0459 - predictions_coarse_loss: 0.0140 - predictions_fine_loss: 0.0462 - predictions_coarse_acc: 0.9961 - predictions_fine_acc: 0.9843 - val_loss: 0.3534 - val_predictions_coarse_loss: 0.0728 - val_predictions_fine_loss: 0.3556 - val_predictions_coarse_acc: 0.9796 - val_predictions_fine_acc: 0.9122
# Changing loss weights to: coarse = 0.004373201169073582, fine = 0.9956268072128296
# Epoch 37/50
# 48000/48000 [==============================] - 4s 77us/step - loss: 0.0435 - predictions_coarse_loss: 0.0139 - predictions_fine_loss: 0.0436 - predictions_coarse_acc: 0.9960 - predictions_fine_acc: 0.9850 - val_loss: 0.3233 - val_predictions_coarse_loss: 0.0700 - val_predictions_fine_loss: 0.3244 - val_predictions_coarse_acc: 0.9788 - val_predictions_fine_acc: 0.9163
# Changing loss weights to: coarse = 0.00419214554131031, fine = 0.9958078265190125
# Epoch 38/50
# 48000/48000 [==============================] - 4s 76us/step - loss: 0.0422 - predictions_coarse_loss: 0.0136 - predictions_fine_loss: 0.0424 - predictions_coarse_acc: 0.9961 - predictions_fine_acc: 0.9855 - val_loss: 0.3385 - val_predictions_coarse_loss: 0.0723 - val_predictions_fine_loss: 0.3396 - val_predictions_coarse_acc: 0.9784 - val_predictions_fine_acc: 0.9163
# Changing loss weights to: coarse = 0.0027675938326865435, fine = 0.9972323775291443
# Epoch 39/50
# 48000/48000 [==============================] - 4s 78us/step - loss: 0.0408 - predictions_coarse_loss: 0.0142 - predictions_fine_loss: 0.0409 - predictions_coarse_acc: 0.9956 - predictions_fine_acc: 0.9858 - val_loss: 0.3296 - val_predictions_coarse_loss: 0.0696 - val_predictions_fine_loss: 0.3303 - val_predictions_coarse_acc: 0.9799 - val_predictions_fine_acc: 0.9167
# Changing loss weights to: coarse = 0.002249197568744421, fine = 0.9977508187294006
# Epoch 40/50
# 48000/48000 [==============================] - 4s 78us/step - loss: 0.0394 - predictions_coarse_loss: 0.0140 - predictions_fine_loss: 0.0395 - predictions_coarse_acc: 0.9958 - predictions_fine_acc: 0.9864 - val_loss: 0.3377 - val_predictions_coarse_loss: 0.0758 - val_predictions_fine_loss: 0.3383 - val_predictions_coarse_acc: 0.9782 - val_predictions_fine_acc: 0.9165
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Changing loss weights to: coarse = 0.0011698337038978934, fine = 0.9988301396369934
# Epoch 41/50
# 48000/48000 [==============================] - 4s 78us/step - loss: 0.0349 - predictions_coarse_loss: 0.0127 - predictions_fine_loss: 0.0349 - predictions_coarse_acc: 0.9964 - predictions_fine_acc: 0.9882 - val_loss: 0.3414 - val_predictions_coarse_loss: 0.0718 - val_predictions_fine_loss: 0.3417 - val_predictions_coarse_acc: 0.9798 - val_predictions_fine_acc: 0.9165
# Changing loss weights to: coarse = 0.000852833385579288, fine = 0.9991471767425537
# Epoch 42/50
# 48000/48000 [==============================] - 4s 78us/step - loss: 0.0316 - predictions_coarse_loss: 0.0120 - predictions_fine_loss: 0.0316 - predictions_coarse_acc: 0.9966 - predictions_fine_acc: 0.9899 - val_loss: 0.3491 - val_predictions_coarse_loss: 0.0719 - val_predictions_fine_loss: 0.3493 - val_predictions_coarse_acc: 0.9796 - val_predictions_fine_acc: 0.9176
# Changing loss weights to: coarse = 0.0005766701069660485, fine = 0.9994233250617981
# Epoch 43/50
# 48000/48000 [==============================] - 4s 77us/step - loss: 0.0300 - predictions_coarse_loss: 0.0122 - predictions_fine_loss: 0.0300 - predictions_coarse_acc: 0.9967 - predictions_fine_acc: 0.9904 - val_loss: 0.3644 - val_predictions_coarse_loss: 0.0715 - val_predictions_fine_loss: 0.3645 - val_predictions_coarse_acc: 0.9794 - val_predictions_fine_acc: 0.9146
# Changing loss weights to: coarse = 0.00034638316719792783, fine = 0.9996536374092102
# Epoch 44/50
# 48000/48000 [==============================] - 4s 77us/step - loss: 0.0288 - predictions_coarse_loss: 0.0125 - predictions_fine_loss: 0.0288 - predictions_coarse_acc: 0.9968 - predictions_fine_acc: 0.9914 - val_loss: 0.3609 - val_predictions_coarse_loss: 0.0748 - val_predictions_fine_loss: 0.3610 - val_predictions_coarse_acc: 0.9793 - val_predictions_fine_acc: 0.9167
# Changing loss weights to: coarse = 0.00016200738900806755, fine = 0.9998379945755005
# Epoch 45/50
# 48000/48000 [==============================] - 4s 78us/step - loss: 0.0293 - predictions_coarse_loss: 0.0121 - predictions_fine_loss: 0.0293 - predictions_coarse_acc: 0.9965 - predictions_fine_acc: 0.9909 - val_loss: 0.3518 - val_predictions_coarse_loss: 0.0708 - val_predictions_fine_loss: 0.3519 - val_predictions_coarse_acc: 0.9802 - val_predictions_fine_acc: 0.9184
# Changing loss weights to: coarse = 7.469527918146923e-05, fine = 0.9999253153800964
# Epoch 46/50
# 48000/48000 [==============================] - 4s 78us/step - loss: 0.0285 - predictions_coarse_loss: 0.0129 - predictions_fine_loss: 0.0285 - predictions_coarse_acc: 0.9963 - predictions_fine_acc: 0.9910 - val_loss: 0.3502 - val_predictions_coarse_loss: 0.0735 - val_predictions_fine_loss: 0.3502 - val_predictions_coarse_acc: 0.9791 - val_predictions_fine_acc: 0.9151
# Changing loss weights to: coarse = 9.263352694688365e-05, fine = 0.999907374382019
# Epoch 47/50
# 48000/48000 [==============================] - 4s 78us/step - loss: 0.0272 - predictions_coarse_loss: 0.0118 - predictions_fine_loss: 0.0272 - predictions_coarse_acc: 0.9967 - predictions_fine_acc: 0.9912 - val_loss: 0.3560 - val_predictions_coarse_loss: 0.0744 - val_predictions_fine_loss: 0.3560 - val_predictions_coarse_acc: 0.9788 - val_predictions_fine_acc: 0.9175
# Changing loss weights to: coarse = 3.0026421882212162e-05, fine = 0.9999699592590332
# Epoch 48/50
# 48000/48000 [==============================] - 4s 77us/step - loss: 0.0277 - predictions_coarse_loss: 0.0124 - predictions_fine_loss: 0.0277 - predictions_coarse_acc: 0.9966 - predictions_fine_acc: 0.9915 - val_loss: 0.3702 - val_predictions_coarse_loss: 0.0750 - val_predictions_fine_loss: 0.3702 - val_predictions_coarse_acc: 0.9795 - val_predictions_fine_acc: 0.9170
# Changing loss weights to: coarse = 3.653302337625064e-05, fine = 0.9999634623527527
# Epoch 49/50
# 48000/48000 [==============================] - 4s 78us/step - loss: 0.0252 - predictions_coarse_loss: 0.0119 - predictions_fine_loss: 0.0252 - predictions_coarse_acc: 0.9970 - predictions_fine_acc: 0.9922 - val_loss: 0.3598 - val_predictions_coarse_loss: 0.0768 - val_predictions_fine_loss: 0.3598 - val_predictions_coarse_acc: 0.9786 - val_predictions_fine_acc: 0.9170
# Changing loss weights to: coarse = 2.055251388810575e-05, fine = 0.9999794363975525
# Epoch 50/50
# 48000/48000 [==============================] - 4s 76us/step - loss: 0.0253 - predictions_coarse_loss: 0.0126 - predictions_fine_loss: 0.0253 - predictions_coarse_acc: 0.9963 - predictions_fine_acc: 0.9919 - val_loss: 0.3646 - val_predictions_coarse_loss: 0.0717 - val_predictions_fine_loss: 0.3646 - val_predictions_coarse_acc: 0.9796 - val_predictions_fine_acc: 0.9178
#
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Changing loss weights to: coarse = 9.04227727005491e-06, fine = 0.9999909400939941

# %%
model.evaluate(test_features, [y_test_c_cat, y_test_cat])
# Out:
# 10000/10000 [==============================] - 1s 137us/step
# [0.38073392303846776, 0.08281451321828062, 0.3807366230931133, 0.9779, 0.9158]

# %%
model.save('drive/TCC-ITAU/fashion-mnist/models/adaptative-split-baseline-net-simple.h5')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-83a455621018> in <module>()
# ----> 1 model.save('drive/TCC-ITAU/fashion-mnist/models/adaptative-split-baseline-net-simple.h5')
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/network.py in save(self, filepath, overwrite, include_optimizer)
#    1088             raise NotImplementedError
#    1089         from ..models import save_model
# -> 1090         save_model(self, filepath, overwrite, include_optimizer)
#    1091
#    1092     def save_weights(self, filepath, overwrite=True):
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py in save_model(model, filepath, overwrite, include_optimizer)
#     380
#     381     try:
# --> 382         _serialize_model(model, f, include_optimizer)
#     383     finally:
#     384         if opened_new_file:
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py in _serialize_model(model, f, include_optimizer)
#     136                 'sample_weight_mode': model.sample_weight_mode,
#     137                 'loss_weights': model.loss_weights,
# --> 138             }, default=get_json_type).encode('utf8')
#     139             symbolic_weights = getattr(model.optimizer, 'weights')
#     140             if symbolic_weights:
#
# /usr/lib/python3.6/json/__init__.py in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     236         check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     237         separators=separators, default=default, sort_keys=sort_keys,
# --> 238         **kw).encode(obj)
#     239
#     240
#
# /usr/lib/python3.6/json/encoder.py in encode(self, o)
#     197         # exceptions aren't as detailed.  The list call should be roughly
#     198         # equivalent to the PySequence_Fast that ''.join() would do.
# --> 199         chunks = self.iterencode(o, _one_shot=True)
#     200         if not isinstance(chunks, (list, tuple)):
#     201             chunks = list(chunks)
#
# /usr/lib/python3.6/json/encoder.py in iterencode(self, o, _one_shot)
#     255                 self.key_separator, self.item_separator, self.sort_keys,
#     256                 self.skipkeys, _one_shot)
# --> 257         return _iterencode(o, 0)
#     258
#     259 def _make_iterencode(markers, _default, _encoder, _indent, _floatstr,
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py in get_json_type(obj)
#      72             return obj.__name__
#      73
# ---> 74         raise TypeError('Not JSON Serializable: %s' % (obj,))
#      75
#      76     from .. import __version__ as keras_version
#
# TypeError: Not JSON Serializable: <tf.Variable 'alpha_2:0' shape=() dtype=float32_ref>

# %%
training_time
# Out:
# 209.4751055240631
