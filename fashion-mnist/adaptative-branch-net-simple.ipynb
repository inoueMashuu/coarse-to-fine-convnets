# %% [markdown]
# # Adaptative Branch-net simple

# %%
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse

from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass

# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}
# Out:
# E: Package 'python-software-properties' has no installation candidate
# Selecting previously unselected package libfuse2:amd64.
# (Reading database ... 22280 files and directories currently installed.)
# Preparing to unpack .../libfuse2_2.9.7-1ubuntu1_amd64.deb ...
# Unpacking libfuse2:amd64 (2.9.7-1ubuntu1) ...
# Selecting previously unselected package fuse.
# Preparing to unpack .../fuse_2.9.7-1ubuntu1_amd64.deb ...
# Unpacking fuse (2.9.7-1ubuntu1) ...
# Selecting previously unselected package google-drive-ocamlfuse.
# Preparing to unpack .../google-drive-ocamlfuse_0.7.0-0ubuntu1~ubuntu18.04.1_amd64.deb ...
# Unpacking google-drive-ocamlfuse (0.7.0-0ubuntu1~ubuntu18.04.1) ...
# Setting up libfuse2:amd64 (2.9.7-1ubuntu1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...
# Setting up fuse (2.9.7-1ubuntu1) ...
# Setting up google-drive-ocamlfuse (0.7.0-0ubuntu1~ubuntu18.04.1) ...
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# ··········
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# Please enter the verification code: Access token retrieved correctly.

# %%
# !mkdir -p drive
# !google-drive-ocamlfuse drive

# %%
from time import time
import os
import gzip
import numpy as np
from keras.utils import np_utils

import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
def load_mnist(path, kind='train'):
    import os
    import gzip
    import numpy as np

    """Load MNIST data from `path`"""
    labels_path = os.path.join(path,
                               '%s-labels-idx1-ubyte.gz'
                               % kind)
    images_path = os.path.join(path,
                               '%s-images-idx3-ubyte.gz'
                               % kind)

    with gzip.open(labels_path, 'rb') as lbpath:
        labels = np.frombuffer(lbpath.read(), dtype=np.uint8,
                               offset=8)

    with gzip.open(images_path, 'rb') as imgpath:
        images = np.frombuffer(imgpath.read(), dtype=np.uint8,
                               offset=16).reshape(len(labels), 784)

    return images, labels

# %%
X_train, y_train = load_mnist('drive/TCC-ITAU/fashion-mnist/data/fashion', kind='train')
X_test, y_test = load_mnist('drive/TCC-ITAU/fashion-mnist/data/fashion', kind='t10k')

# %%
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=1974)

# %%
train_features = X_train.reshape(X_train.shape[0], 28, 28, 1)/255
vali_features = X_val.reshape(X_val.shape[0], 28, 28, 1)/255
test_features = X_test.reshape(X_test.shape[0], 28, 28, 1)/255

y_train_cat = np_utils.to_categorical(y_train)
y_val_cat = np_utils.to_categorical(y_val)
y_test_cat = np_utils.to_categorical(y_test)

# %% [markdown]
# ## Coarse and Fine classe
#
# | Label | Fine | Coarse |
# | --- | --- | --- |
# | 0 | T-shirt/top | TOP |
# | 1 | Trouser | BOTTOM |
# | 2 | Pullover | TOP |
# | 3 | Dress |BODY |
# | 4 | Coat | TOP |
# | 5 | Sandal | FEET |
# | 6 | Shirt | TOP |
# | 7 | Sneaker | FEET |
# | 8 | Bag | ACCESSORY |
# | 9 | Ankle boot | FEET |

# %%
dict_coarse = {0: 0,
              1: 1,
              2: 0,
              3: 2,
              4: 0,
              5: 3,
              6: 0,
              7: 3,
              8: 4,
              9: 3}

y_train_coarse = np.vectorize(dict_coarse.get)(y_train)
y_val_coarse = np.vectorize(dict_coarse.get)(y_val)
y_test_coarse = np.vectorize(dict_coarse.get)(y_test)

y_train_c_cat = np_utils.to_categorical(y_train_coarse)
y_val_c_cat = np_utils.to_categorical(y_val_coarse)
y_test_c_cat= np_utils.to_categorical(y_test_coarse)

# %%
import keras
from keras.models import Model
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D, Input
from keras import optimizers
from keras.callbacks import TensorBoard, ReduceLROnPlateau, CSVLogger
from keras.layers.normalization import BatchNormalization
from keras.utils.data_utils import get_file
from keras import backend as K

# %%
class TimingCallback(keras.callbacks.Callback):
    
  def on_epoch_begin(self, epoch, logs={}):
    self.starttime=time()
  def on_epoch_end(self, epoch, logs={}):
    logs['time_elapsed'] = (time()-self.starttime)

# %%
class AdaptativeLossWeightsModifier2Vars(keras.callbacks.Callback):
  def __init__(self, alpha, beta, decay_rate=0.5):
    self.alpha = alpha
    self.beta = beta
    self.decay_rate = decay_rate
  
  def calculate_exponential(self, ratio, decay_rate, epoch):
    return np.exp(-ratio*decay_rate*epoch)

  def on_epoch_end(self, epoch, logs={}):
    if epoch < 1:
      pass
    
    else:
      loss_coarse = self.model.history.history['predictions_coarse_loss'][-1]
      loss_fine = self.model.history.history['predictions_fine_loss'][-1]
      ratio = (loss_coarse/loss_fine) 
      decaying = self.calculate_exponential(ratio, self.decay_rate, epoch)
        
      K.set_value(self.alpha, decaying)
      K.set_value(self.beta, 1 - decaying)
      print('Changing loss weights to: coarse = {}, fine = {}'.format(K.eval(self.alpha), K.eval(self.beta)))  
    
    logs['alpha'] = K.eval(self.alpha)
    logs['beta'] = K.eval(self.beta)

# %%
img_rows, img_cols = 28, 28
if K.image_data_format() == 'channels_first':
    input_shape = (1, img_rows, img_cols)
else:
    input_shape = (img_rows, img_cols, 1)

# %%
num_classes_coarse = 5
num_classes_fine = 10

img_input = Input(shape=input_shape, name='input')


x = Conv2D(32, (3, 3), activation='relu', name='block1_conv1')(img_input)
x = MaxPooling2D((2, 2), name='block1_pool')(x)

#---- coarse branch ----
coarse = Flatten(name='c1_flatten')(x)
coarse = Dense(64, name='c1_fc_1')(coarse)
coarse = BatchNormalization()(coarse)
coarse = Activation('relu')(coarse)
coarse = Dropout(0.5)(coarse)
coarse_pred = Dense(num_classes_coarse, activation='softmax', name='predictions_coarse')(coarse)

x = Conv2D(64, (3, 3), activation='relu', name='block1_conv2')(x)
x = MaxPooling2D((2, 2), name='block2_pool')(x)

x = Flatten(name='flatten')(x)
x = Dense(128, name='fc_1')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = Dropout(0.5)(x)

fine_pred = Dense(num_classes_fine, activation='softmax', name='predictions_fine')(x)

# %%
model = Model(inputs=img_input, outputs=[coarse_pred, fine_pred], name='branch_net')

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              (None, 28, 28, 1)    0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 26, 26, 32)   320         input[0][0]
# __________________________________________________________________________________________________
# block1_pool (MaxPooling2D)      (None, 13, 13, 32)   0           block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 11, 11, 64)   18496       block1_pool[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 5, 5, 64)     0           block1_conv2[0][0]
# __________________________________________________________________________________________________
# c1_flatten (Flatten)            (None, 5408)         0           block1_pool[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 1600)         0           block2_pool[0][0]
# __________________________________________________________________________________________________
# c1_fc_1 (Dense)                 (None, 64)           346176      c1_flatten[0][0]
# __________________________________________________________________________________________________
# fc_1 (Dense)                    (None, 128)          204928      flatten[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 64)           256         c1_fc_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 128)          512         fc_1[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 64)           0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 128)          0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 64)           0           activation_9[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 128)          0           activation_10[0][0]
# __________________________________________________________________________________________________
# predictions_coarse (Dense)      (None, 5)            325         dropout_9[0][0]
# __________________________________________________________________________________________________
# predictions_fine (Dense)        (None, 10)           1290        dropout_10[0][0]
# ==================================================================================================
# Total params: 572,303
# Trainable params: 571,919
# Non-trainable params: 384
# __________________________________________________________________________________________________

# %%
alpha = K.variable(value=0.95, dtype="float32", name="alpha") # A1 in paper
beta = K.variable(value=0.05, dtype="float32", name="beta") # A2 in paper

model.compile(loss='categorical_crossentropy', 
              optimizer='adam', 
              loss_weights=[alpha, beta],
              metrics=['accuracy'])

# %%
tb_cb = TensorBoard(log_dir='drive/TCC-ITAU/fashion-mnist/tensorboard/adaptative-branch-net', histogram_freq=0)
clr_cb = ReduceLROnPlateau(monitor='val_predictions_fine_loss', factor=0.5, patience=10, verbose=1)
time_cb = TimingCallback()
csv_cb = CSVLogger('drive/TCC-ITAU/fashion-mnist/training-data/branch-net/adaptative-branch-net-simple.csv', separator=',', append=False)
change_lw = AdaptativeLossWeightsModifier2Vars(alpha, beta, decay_rate=0.3)


cbks = [tb_cb, clr_cb, time_cb, change_lw, csv_cb]

# %%
epochs = 50
start_time = time()
training = model.fit(train_features, [y_train_c_cat, y_train_cat],
                     validation_data=(vali_features, [y_val_c_cat, y_val_cat]),
                     epochs=epochs,
                     batch_size=512, 
                     callbacks=cbks,
                     verbose=1)
training_time = time() - start_time
# Out:
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/50
# 48000/48000 [==============================] - 5s 105us/step - loss: 0.2886 - predictions_coarse_loss: 0.2690 - predictions_fine_loss: 0.6599 - predictions_coarse_acc: 0.9231 - predictions_fine_acc: 0.7732 - val_loss: 0.1437 - val_predictions_coarse_loss: 0.1277 - val_predictions_fine_loss: 0.4466 - val_predictions_coarse_acc: 0.9679 - val_predictions_fine_acc: 0.8476
# Epoch 2/50
# 48000/48000 [==============================] - 4s 80us/step - loss: 0.1300 - predictions_coarse_loss: 0.1164 - predictions_fine_loss: 0.3880 - predictions_coarse_acc: 0.9667 - predictions_fine_acc: 0.8652 - val_loss: 0.1180 - val_predictions_coarse_loss: 0.1062 - val_predictions_fine_loss: 0.3418 - val_predictions_coarse_acc: 0.9709 - val_predictions_fine_acc: 0.8772
# Changing loss weights to: coarse = 0.8848890066146851, fine = 0.11511096358299255
# Epoch 3/50
# 48000/48000 [==============================] - 4s 79us/step - loss: 0.1210 - predictions_coarse_loss: 0.0936 - predictions_fine_loss: 0.3316 - predictions_coarse_acc: 0.9721 - predictions_fine_acc: 0.8825 - val_loss: 0.1089 - val_predictions_coarse_loss: 0.0779 - val_predictions_fine_loss: 0.3474 - val_predictions_coarse_acc: 0.9743 - val_predictions_fine_acc: 0.8782
# Changing loss weights to: coarse = 0.8352891802787781, fine = 0.16471083462238312
# Epoch 4/50
# 48000/48000 [==============================] - 4s 79us/step - loss: 0.1128 - predictions_coarse_loss: 0.0782 - predictions_fine_loss: 0.2885 - predictions_coarse_acc: 0.9755 - predictions_fine_acc: 0.8965 - val_loss: 0.1021 - val_predictions_coarse_loss: 0.0657 - val_predictions_fine_loss: 0.2867 - val_predictions_coarse_acc: 0.9777 - val_predictions_fine_acc: 0.8936
# Changing loss weights to: coarse = 0.7755998373031616, fine = 0.22440017759799957
# Epoch 5/50
# 48000/48000 [==============================] - 4s 79us/step - loss: 0.1115 - predictions_coarse_loss: 0.0685 - predictions_fine_loss: 0.2601 - predictions_coarse_acc: 0.9785 - predictions_fine_acc: 0.9068 - val_loss: 0.1152 - val_predictions_coarse_loss: 0.0666 - val_predictions_fine_loss: 0.2834 - val_predictions_coarse_acc: 0.9773 - val_predictions_fine_acc: 0.8963
# Changing loss weights to: coarse = 0.7224206328392029, fine = 0.2775793671607971
# Epoch 6/50
# 48000/48000 [==============================] - 4s 79us/step - loss: 0.1111 - predictions_coarse_loss: 0.0616 - predictions_fine_loss: 0.2399 - predictions_coarse_acc: 0.9800 - predictions_fine_acc: 0.9137 - val_loss: 0.1251 - val_predictions_coarse_loss: 0.0652 - val_predictions_fine_loss: 0.2809 - val_predictions_coarse_acc: 0.9770 - val_predictions_fine_acc: 0.8938
# Changing loss weights to: coarse = 0.673704206943512, fine = 0.32629579305648804
# Epoch 7/50
# 48000/48000 [==============================] - 4s 81us/step - loss: 0.1090 - predictions_coarse_loss: 0.0568 - predictions_fine_loss: 0.2170 - predictions_coarse_acc: 0.9816 - predictions_fine_acc: 0.9206 - val_loss: 0.1292 - val_predictions_coarse_loss: 0.0590 - val_predictions_fine_loss: 0.2743 - val_predictions_coarse_acc: 0.9802 - val_predictions_fine_acc: 0.9012
# Changing loss weights to: coarse = 0.6297729015350342, fine = 0.3702271282672882
# Epoch 8/50
# 48000/48000 [==============================] - 4s 81us/step - loss: 0.1060 - predictions_coarse_loss: 0.0519 - predictions_fine_loss: 0.1981 - predictions_coarse_acc: 0.9832 - predictions_fine_acc: 0.9267 - val_loss: 0.1479 - val_predictions_coarse_loss: 0.0567 - val_predictions_fine_loss: 0.3030 - val_predictions_coarse_acc: 0.9808 - val_predictions_fine_acc: 0.8912
# Changing loss weights to: coarse = 0.5772718787193298, fine = 0.42272812128067017
# Epoch 9/50
# 48000/48000 [==============================] - 4s 81us/step - loss: 0.1077 - predictions_coarse_loss: 0.0481 - predictions_fine_loss: 0.1891 - predictions_coarse_acc: 0.9841 - predictions_fine_acc: 0.9310 - val_loss: 0.1434 - val_predictions_coarse_loss: 0.0554 - val_predictions_fine_loss: 0.2636 - val_predictions_coarse_acc: 0.9814 - val_predictions_fine_acc: 0.9072
# Changing loss weights to: coarse = 0.5333805084228516, fine = 0.46661946177482605
# Epoch 10/50
# 48000/48000 [==============================] - 4s 80us/step - loss: 0.1043 - predictions_coarse_loss: 0.0451 - predictions_fine_loss: 0.1720 - predictions_coarse_acc: 0.9856 - predictions_fine_acc: 0.9364 - val_loss: 0.1591 - val_predictions_coarse_loss: 0.0602 - val_predictions_fine_loss: 0.2722 - val_predictions_coarse_acc: 0.9803 - val_predictions_fine_acc: 0.9055
# Changing loss weights to: coarse = 0.5033773183822632, fine = 0.49662265181541443
# Epoch 11/50
# 48000/48000 [==============================] - 4s 82us/step - loss: 0.1012 - predictions_coarse_loss: 0.0425 - predictions_fine_loss: 0.1607 - predictions_coarse_acc: 0.9857 - predictions_fine_acc: 0.9415 - val_loss: 0.1759 - val_predictions_coarse_loss: 0.0574 - val_predictions_fine_loss: 0.2960 - val_predictions_coarse_acc: 0.9811 - val_predictions_fine_acc: 0.8987
# Changing loss weights to: coarse = 0.45558446645736694, fine = 0.5444155335426331
# Epoch 12/50
# 48000/48000 [==============================] - 4s 83us/step - loss: 0.0993 - predictions_coarse_loss: 0.0386 - predictions_fine_loss: 0.1501 - predictions_coarse_acc: 0.9871 - predictions_fine_acc: 0.9451 - val_loss: 0.1970 - val_predictions_coarse_loss: 0.0560 - val_predictions_fine_loss: 0.3149 - val_predictions_coarse_acc: 0.9806 - val_predictions_fine_acc: 0.8977
# Changing loss weights to: coarse = 0.4176502227783203, fine = 0.5823497772216797
# Epoch 13/50
# 48000/48000 [==============================] - 4s 81us/step - loss: 0.0979 - predictions_coarse_loss: 0.0366 - predictions_fine_loss: 0.1418 - predictions_coarse_acc: 0.9878 - predictions_fine_acc: 0.9482 - val_loss: 0.1782 - val_predictions_coarse_loss: 0.0540 - val_predictions_fine_loss: 0.2673 - val_predictions_coarse_acc: 0.9815 - val_predictions_fine_acc: 0.9106
# Changing loss weights to: coarse = 0.396061509847641, fine = 0.6039385199546814
# Epoch 14/50
# 48000/48000 [==============================] - 4s 80us/step - loss: 0.0920 - predictions_coarse_loss: 0.0357 - predictions_fine_loss: 0.1289 - predictions_coarse_acc: 0.9881 - predictions_fine_acc: 0.9519 - val_loss: 0.1834 - val_predictions_coarse_loss: 0.0572 - val_predictions_fine_loss: 0.2661 - val_predictions_coarse_acc: 0.9807 - val_predictions_fine_acc: 0.9122
# Changing loss weights to: coarse = 0.3651912808418274, fine = 0.6348087191581726
# Epoch 15/50
# 48000/48000 [==============================] - 4s 80us/step - loss: 0.0923 - predictions_coarse_loss: 0.0342 - predictions_fine_loss: 0.1258 - predictions_coarse_acc: 0.9889 - predictions_fine_acc: 0.9539 - val_loss: 0.2095 - val_predictions_coarse_loss: 0.0590 - val_predictions_fine_loss: 0.2961 - val_predictions_coarse_acc: 0.9810 - val_predictions_fine_acc: 0.9027
# Changing loss weights to: coarse = 0.3127728998661041, fine = 0.6872271299362183
# Epoch 16/50
# 48000/48000 [==============================] - 4s 80us/step - loss: 0.0918 - predictions_coarse_loss: 0.0318 - predictions_fine_loss: 0.1192 - predictions_coarse_acc: 0.9893 - predictions_fine_acc: 0.9560 - val_loss: 0.2067 - val_predictions_coarse_loss: 0.0565 - val_predictions_fine_loss: 0.2751 - val_predictions_coarse_acc: 0.9810 - val_predictions_fine_acc: 0.9084
# Changing loss weights to: coarse = 0.2945845127105713, fine = 0.7054154872894287
# Epoch 17/50
# 48000/48000 [==============================] - 4s 81us/step - loss: 0.0842 - predictions_coarse_loss: 0.0299 - predictions_fine_loss: 0.1068 - predictions_coarse_acc: 0.9905 - predictions_fine_acc: 0.9604 - val_loss: 0.2458 - val_predictions_coarse_loss: 0.0589 - val_predictions_fine_loss: 0.3239 - val_predictions_coarse_acc: 0.9799 - val_predictions_fine_acc: 0.8951
# Changing loss weights to: coarse = 0.2782832086086273, fine = 0.7217168211936951
# Epoch 18/50
# 48000/48000 [==============================] - 4s 80us/step - loss: 0.0813 - predictions_coarse_loss: 0.0295 - predictions_fine_loss: 0.1013 - predictions_coarse_acc: 0.9905 - predictions_fine_acc: 0.9627 - val_loss: 0.2451 - val_predictions_coarse_loss: 0.0628 - val_predictions_fine_loss: 0.3153 - val_predictions_coarse_acc: 0.9802 - val_predictions_fine_acc: 0.9057
# Changing loss weights to: coarse = 0.23997759819030762, fine = 0.7600224018096924
# Epoch 19/50
# 48000/48000 [==============================] - 4s 79us/step - loss: 0.0774 - predictions_coarse_loss: 0.0271 - predictions_fine_loss: 0.0933 - predictions_coarse_acc: 0.9912 - predictions_fine_acc: 0.9654 - val_loss: 0.2708 - val_predictions_coarse_loss: 0.0649 - val_predictions_fine_loss: 0.3358 - val_predictions_coarse_acc: 0.9802 - val_predictions_fine_acc: 0.9056
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Changing loss weights to: coarse = 0.2076139599084854, fine = 0.7923860549926758
# Epoch 20/50
# 48000/48000 [==============================] - 4s 80us/step - loss: 0.0671 - predictions_coarse_loss: 0.0254 - predictions_fine_loss: 0.0780 - predictions_coarse_acc: 0.9916 - predictions_fine_acc: 0.9722 - val_loss: 0.2373 - val_predictions_coarse_loss: 0.0578 - val_predictions_fine_loss: 0.2843 - val_predictions_coarse_acc: 0.9813 - val_predictions_fine_acc: 0.9149
# Changing loss weights to: coarse = 0.19159817695617676, fine = 0.8084018230438232
# Epoch 21/50
# 48000/48000 [==============================] - 4s 79us/step - loss: 0.0590 - predictions_coarse_loss: 0.0235 - predictions_fine_loss: 0.0675 - predictions_coarse_acc: 0.9930 - predictions_fine_acc: 0.9763 - val_loss: 0.2644 - val_predictions_coarse_loss: 0.0588 - val_predictions_fine_loss: 0.3132 - val_predictions_coarse_acc: 0.9812 - val_predictions_fine_acc: 0.9085
# Changing loss weights to: coarse = 0.1412065178155899, fine = 0.8587934970855713
# Epoch 22/50
# 48000/48000 [==============================] - 4s 79us/step - loss: 0.0556 - predictions_coarse_loss: 0.0230 - predictions_fine_loss: 0.0610 - predictions_coarse_acc: 0.9928 - predictions_fine_acc: 0.9789 - val_loss: 0.2658 - val_predictions_coarse_loss: 0.0571 - val_predictions_fine_loss: 0.3001 - val_predictions_coarse_acc: 0.9812 - val_predictions_fine_acc: 0.9147
# Changing loss weights to: coarse = 0.1116667240858078, fine = 0.888333261013031
# Epoch 23/50
# 48000/48000 [==============================] - 4s 82us/step - loss: 0.0540 - predictions_coarse_loss: 0.0213 - predictions_fine_loss: 0.0581 - predictions_coarse_acc: 0.9935 - predictions_fine_acc: 0.9795 - val_loss: 0.2686 - val_predictions_coarse_loss: 0.0583 - val_predictions_fine_loss: 0.2951 - val_predictions_coarse_acc: 0.9812 - val_predictions_fine_acc: 0.9156
# Changing loss weights to: coarse = 0.08327018469572067, fine = 0.9167298078536987
# Epoch 24/50
# 48000/48000 [==============================] - 4s 81us/step - loss: 0.0536 - predictions_coarse_loss: 0.0210 - predictions_fine_loss: 0.0565 - predictions_coarse_acc: 0.9937 - predictions_fine_acc: 0.9803 - val_loss: 0.2798 - val_predictions_coarse_loss: 0.0602 - val_predictions_fine_loss: 0.2997 - val_predictions_coarse_acc: 0.9813 - val_predictions_fine_acc: 0.9152
# Changing loss weights to: coarse = 0.07978156954050064, fine = 0.9202184081077576
# Epoch 25/50
# 48000/48000 [==============================] - 4s 81us/step - loss: 0.0498 - predictions_coarse_loss: 0.0210 - predictions_fine_loss: 0.0523 - predictions_coarse_acc: 0.9934 - predictions_fine_acc: 0.9817 - val_loss: 0.2977 - val_predictions_coarse_loss: 0.0586 - val_predictions_fine_loss: 0.3184 - val_predictions_coarse_acc: 0.9818 - val_predictions_fine_acc: 0.9143
# Changing loss weights to: coarse = 0.0689447671175003, fine = 0.9310552477836609
# Epoch 26/50
# 48000/48000 [==============================] - 4s 78us/step - loss: 0.0490 - predictions_coarse_loss: 0.0205 - predictions_fine_loss: 0.0511 - predictions_coarse_acc: 0.9939 - predictions_fine_acc: 0.9825 - val_loss: 0.3014 - val_predictions_coarse_loss: 0.0580 - val_predictions_fine_loss: 0.3194 - val_predictions_coarse_acc: 0.9817 - val_predictions_fine_acc: 0.9110
# Changing loss weights to: coarse = 0.04957657307386398, fine = 0.9504234194755554
# Epoch 27/50
# 48000/48000 [==============================] - 4s 77us/step - loss: 0.0491 - predictions_coarse_loss: 0.0204 - predictions_fine_loss: 0.0506 - predictions_coarse_acc: 0.9936 - predictions_fine_acc: 0.9821 - val_loss: 0.3465 - val_predictions_coarse_loss: 0.0570 - val_predictions_fine_loss: 0.3616 - val_predictions_coarse_acc: 0.9819 - val_predictions_fine_acc: 0.9103
# Changing loss weights to: coarse = 0.0435277484357357, fine = 0.9564722776412964
# Epoch 28/50
# 48000/48000 [==============================] - 4s 78us/step - loss: 0.0462 - predictions_coarse_loss: 0.0203 - predictions_fine_loss: 0.0474 - predictions_coarse_acc: 0.9942 - predictions_fine_acc: 0.9830 - val_loss: 0.3250 - val_predictions_coarse_loss: 0.0578 - val_predictions_fine_loss: 0.3372 - val_predictions_coarse_acc: 0.9819 - val_predictions_fine_acc: 0.9102
# Changing loss weights to: coarse = 0.03795194253325462, fine = 0.9620480537414551
# Epoch 29/50
# 48000/48000 [==============================] - 4s 79us/step - loss: 0.0420 - predictions_coarse_loss: 0.0202 - predictions_fine_loss: 0.0428 - predictions_coarse_acc: 0.9940 - predictions_fine_acc: 0.9856 - val_loss: 0.3298 - val_predictions_coarse_loss: 0.0597 - val_predictions_fine_loss: 0.3405 - val_predictions_coarse_acc: 0.9812 - val_predictions_fine_acc: 0.9129
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Changing loss weights to: coarse = 0.02730684168636799, fine = 0.972693145275116
# Epoch 30/50
# 48000/48000 [==============================] - 4s 79us/step - loss: 0.0371 - predictions_coarse_loss: 0.0188 - predictions_fine_loss: 0.0376 - predictions_coarse_acc: 0.9946 - predictions_fine_acc: 0.9883 - val_loss: 0.3214 - val_predictions_coarse_loss: 0.0591 - val_predictions_fine_loss: 0.3287 - val_predictions_coarse_acc: 0.9814 - val_predictions_fine_acc: 0.9187
# Changing loss weights to: coarse = 0.01659766212105751, fine = 0.9834023118019104
# Epoch 31/50
# 48000/48000 [==============================] - 4s 80us/step - loss: 0.0341 - predictions_coarse_loss: 0.0192 - predictions_fine_loss: 0.0343 - predictions_coarse_acc: 0.9946 - predictions_fine_acc: 0.9888 - val_loss: 0.3347 - val_predictions_coarse_loss: 0.0590 - val_predictions_fine_loss: 0.3394 - val_predictions_coarse_acc: 0.9819 - val_predictions_fine_acc: 0.9158
# Changing loss weights to: coarse = 0.010993915610015392, fine = 0.9890061020851135
# Epoch 32/50
# 48000/48000 [==============================] - 4s 79us/step - loss: 0.0324 - predictions_coarse_loss: 0.0193 - predictions_fine_loss: 0.0325 - predictions_coarse_acc: 0.9942 - predictions_fine_acc: 0.9896 - val_loss: 0.3341 - val_predictions_coarse_loss: 0.0589 - val_predictions_fine_loss: 0.3372 - val_predictions_coarse_acc: 0.9819 - val_predictions_fine_acc: 0.9143
# Changing loss weights to: coarse = 0.005583872552961111, fine = 0.9944161176681519
# Epoch 33/50
# 48000/48000 [==============================] - 4s 81us/step - loss: 0.0325 - predictions_coarse_loss: 0.0189 - predictions_fine_loss: 0.0325 - predictions_coarse_acc: 0.9946 - predictions_fine_acc: 0.9893 - val_loss: 0.3425 - val_predictions_coarse_loss: 0.0590 - val_predictions_fine_loss: 0.3441 - val_predictions_coarse_acc: 0.9818 - val_predictions_fine_acc: 0.9149
# Changing loss weights to: coarse = 0.0033971078228205442, fine = 0.9966028928756714
# Epoch 34/50
# 48000/48000 [==============================] - 4s 81us/step - loss: 0.0320 - predictions_coarse_loss: 0.0184 - predictions_fine_loss: 0.0320 - predictions_coarse_acc: 0.9948 - predictions_fine_acc: 0.9899 - val_loss: 0.3430 - val_predictions_coarse_loss: 0.0586 - val_predictions_fine_loss: 0.3440 - val_predictions_coarse_acc: 0.9817 - val_predictions_fine_acc: 0.9170
# Changing loss weights to: coarse = 0.0031752134673297405, fine = 0.9968248009681702
# Epoch 35/50
# 48000/48000 [==============================] - 4s 81us/step - loss: 0.0297 - predictions_coarse_loss: 0.0187 - predictions_fine_loss: 0.0298 - predictions_coarse_acc: 0.9946 - predictions_fine_acc: 0.9908 - val_loss: 0.3353 - val_predictions_coarse_loss: 0.0588 - val_predictions_fine_loss: 0.3362 - val_predictions_coarse_acc: 0.9820 - val_predictions_fine_acc: 0.9148
# Changing loss weights to: coarse = 0.0028077242895960808, fine = 0.9971922636032104
# Epoch 36/50
# 48000/48000 [==============================] - 4s 81us/step - loss: 0.0291 - predictions_coarse_loss: 0.0190 - predictions_fine_loss: 0.0291 - predictions_coarse_acc: 0.9945 - predictions_fine_acc: 0.9911 - val_loss: 0.3416 - val_predictions_coarse_loss: 0.0580 - val_predictions_fine_loss: 0.3424 - val_predictions_coarse_acc: 0.9817 - val_predictions_fine_acc: 0.9152
# Changing loss weights to: coarse = 0.0013490354176610708, fine = 0.9986509680747986
# Epoch 37/50
# 48000/48000 [==============================] - 4s 83us/step - loss: 0.0281 - predictions_coarse_loss: 0.0189 - predictions_fine_loss: 0.0281 - predictions_coarse_acc: 0.9945 - predictions_fine_acc: 0.9905 - val_loss: 0.3448 - val_predictions_coarse_loss: 0.0590 - val_predictions_fine_loss: 0.3452 - val_predictions_coarse_acc: 0.9816 - val_predictions_fine_acc: 0.9153
# Changing loss weights to: coarse = 0.0008719816687516868, fine = 0.9991280436515808
# Epoch 38/50
# 48000/48000 [==============================] - 4s 81us/step - loss: 0.0261 - predictions_coarse_loss: 0.0189 - predictions_fine_loss: 0.0261 - predictions_coarse_acc: 0.9945 - predictions_fine_acc: 0.9918 - val_loss: 0.3526 - val_predictions_coarse_loss: 0.0589 - val_predictions_fine_loss: 0.3528 - val_predictions_coarse_acc: 0.9818 - val_predictions_fine_acc: 0.9159
# Changing loss weights to: coarse = 0.0005565591272898018, fine = 0.9994434118270874
# Epoch 39/50
# 48000/48000 [==============================] - 4s 80us/step - loss: 0.0266 - predictions_coarse_loss: 0.0193 - predictions_fine_loss: 0.0266 - predictions_coarse_acc: 0.9946 - predictions_fine_acc: 0.9918 - val_loss: 0.3603 - val_predictions_coarse_loss: 0.0584 - val_predictions_fine_loss: 0.3605 - val_predictions_coarse_acc: 0.9818 - val_predictions_fine_acc: 0.9152
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Changing loss weights to: coarse = 0.0002593568933662027, fine = 0.9997406601905823
# Epoch 40/50
# 48000/48000 [==============================] - 4s 80us/step - loss: 0.0243 - predictions_coarse_loss: 0.0191 - predictions_fine_loss: 0.0243 - predictions_coarse_acc: 0.9944 - predictions_fine_acc: 0.9927 - val_loss: 0.3615 - val_predictions_coarse_loss: 0.0589 - val_predictions_fine_loss: 0.3616 - val_predictions_coarse_acc: 0.9820 - val_predictions_fine_acc: 0.9165
# Changing loss weights to: coarse = 0.0002047465241048485, fine = 0.9997952580451965
# Epoch 41/50
# 48000/48000 [==============================] - 4s 79us/step - loss: 0.0238 - predictions_coarse_loss: 0.0191 - predictions_fine_loss: 0.0238 - predictions_coarse_acc: 0.9946 - predictions_fine_acc: 0.9931 - val_loss: 0.3569 - val_predictions_coarse_loss: 0.0588 - val_predictions_fine_loss: 0.3569 - val_predictions_coarse_acc: 0.9817 - val_predictions_fine_acc: 0.9177
# Changing loss weights to: coarse = 8.178378629963845e-05, fine = 0.9999182224273682
# Epoch 42/50
# 48000/48000 [==============================] - 4s 79us/step - loss: 0.0219 - predictions_coarse_loss: 0.0187 - predictions_fine_loss: 0.0219 - predictions_coarse_acc: 0.9945 - predictions_fine_acc: 0.9940 - val_loss: 0.3573 - val_predictions_coarse_loss: 0.0588 - val_predictions_fine_loss: 0.3573 - val_predictions_coarse_acc: 0.9817 - val_predictions_fine_acc: 0.9149
# Changing loss weights to: coarse = 5.187774877413176e-05, fine = 0.9999481439590454
# Epoch 43/50
# 48000/48000 [==============================] - 4s 82us/step - loss: 0.0216 - predictions_coarse_loss: 0.0180 - predictions_fine_loss: 0.0216 - predictions_coarse_acc: 0.9951 - predictions_fine_acc: 0.9934 - val_loss: 0.3589 - val_predictions_coarse_loss: 0.0583 - val_predictions_fine_loss: 0.3589 - val_predictions_coarse_acc: 0.9817 - val_predictions_fine_acc: 0.9152
# Changing loss weights to: coarse = 2.1644518710672855e-05, fine = 0.9999783635139465
# Epoch 44/50
# 48000/48000 [==============================] - 4s 80us/step - loss: 0.0206 - predictions_coarse_loss: 0.0187 - predictions_fine_loss: 0.0206 - predictions_coarse_acc: 0.9948 - predictions_fine_acc: 0.9944 - val_loss: 0.3629 - val_predictions_coarse_loss: 0.0586 - val_predictions_fine_loss: 0.3629 - val_predictions_coarse_acc: 0.9819 - val_predictions_fine_acc: 0.9179
# Changing loss weights to: coarse = 2.189647602790501e-05, fine = 0.9999781250953674
# Epoch 45/50
# 48000/48000 [==============================] - 4s 79us/step - loss: 0.0210 - predictions_coarse_loss: 0.0186 - predictions_fine_loss: 0.0210 - predictions_coarse_acc: 0.9946 - predictions_fine_acc: 0.9940 - val_loss: 0.3612 - val_predictions_coarse_loss: 0.0588 - val_predictions_fine_loss: 0.3612 - val_predictions_coarse_acc: 0.9817 - val_predictions_fine_acc: 0.9163
# Changing loss weights to: coarse = 6.305083388724597e-06, fine = 0.9999936819076538
# Epoch 46/50
# 48000/48000 [==============================] - 4s 80us/step - loss: 0.0212 - predictions_coarse_loss: 0.0193 - predictions_fine_loss: 0.0212 - predictions_coarse_acc: 0.9942 - predictions_fine_acc: 0.9936 - val_loss: 0.3646 - val_predictions_coarse_loss: 0.0588 - val_predictions_fine_loss: 0.3646 - val_predictions_coarse_acc: 0.9818 - val_predictions_fine_acc: 0.9167
# Changing loss weights to: coarse = 6.401012342394097e-06, fine = 0.999993622303009
# Epoch 47/50
# 48000/48000 [==============================] - 4s 81us/step - loss: 0.0205 - predictions_coarse_loss: 0.0183 - predictions_fine_loss: 0.0205 - predictions_coarse_acc: 0.9946 - predictions_fine_acc: 0.9941 - val_loss: 0.3686 - val_predictions_coarse_loss: 0.0585 - val_predictions_fine_loss: 0.3686 - val_predictions_coarse_acc: 0.9816 - val_predictions_fine_acc: 0.9155
# Changing loss weights to: coarse = 3.3887993140524486e-06, fine = 0.9999966025352478
# Epoch 48/50
# 48000/48000 [==============================] - 4s 80us/step - loss: 0.0203 - predictions_coarse_loss: 0.0187 - predictions_fine_loss: 0.0203 - predictions_coarse_acc: 0.9945 - predictions_fine_acc: 0.9942 - val_loss: 0.3697 - val_predictions_coarse_loss: 0.0586 - val_predictions_fine_loss: 0.3697 - val_predictions_coarse_acc: 0.9817 - val_predictions_fine_acc: 0.9170
# Changing loss weights to: coarse = 3.2097429993882542e-06, fine = 0.9999967813491821
# Epoch 49/50
# 48000/48000 [==============================] - 4s 79us/step - loss: 0.0203 - predictions_coarse_loss: 0.0187 - predictions_fine_loss: 0.0203 - predictions_coarse_acc: 0.9945 - predictions_fine_acc: 0.9945 - val_loss: 0.3748 - val_predictions_coarse_loss: 0.0589 - val_predictions_fine_loss: 0.3748 - val_predictions_coarse_acc: 0.9817 - val_predictions_fine_acc: 0.9173
#
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Changing loss weights to: coarse = 1.72554621258314e-06, fine = 0.9999982714653015
# Epoch 50/50
# 48000/48000 [==============================] - 4s 78us/step - loss: 0.0197 - predictions_coarse_loss: 0.0184 - predictions_fine_loss: 0.0197 - predictions_coarse_acc: 0.9948 - predictions_fine_acc: 0.9941 - val_loss: 0.3661 - val_predictions_coarse_loss: 0.0587 - val_predictions_fine_loss: 0.3661 - val_predictions_coarse_acc: 0.9819 - val_predictions_fine_acc: 0.9169
# Changing loss weights to: coarse = 1.2844799357480952e-06, fine = 0.9999986886978149

# %%
model.evaluate(test_features, [y_test_c_cat, y_test_cat])
# Out:
# 10000/10000 [==============================] - 2s 188us/step
# [0.3646362787865102, 0.07159908175964375, 0.36463666630387304, 0.9794, 0.9178]

# %%
model.save('drive/TCC-ITAU/fashion-mnist/models/adaptative-branch-net-simple.h5')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-fe679be47097> in <module>()
# ----> 1 model.save('drive/TCC-ITAU/fashion-mnist/models/adaptative-branch-net-simple.h5')
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/network.py in save(self, filepath, overwrite, include_optimizer)
#    1088             raise NotImplementedError
#    1089         from ..models import save_model
# -> 1090         save_model(self, filepath, overwrite, include_optimizer)
#    1091
#    1092     def save_weights(self, filepath, overwrite=True):
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py in save_model(model, filepath, overwrite, include_optimizer)
#     380
#     381     try:
# --> 382         _serialize_model(model, f, include_optimizer)
#     383     finally:
#     384         if opened_new_file:
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py in _serialize_model(model, f, include_optimizer)
#     136                 'sample_weight_mode': model.sample_weight_mode,
#     137                 'loss_weights': model.loss_weights,
# --> 138             }, default=get_json_type).encode('utf8')
#     139             symbolic_weights = getattr(model.optimizer, 'weights')
#     140             if symbolic_weights:
#
# /usr/lib/python3.6/json/__init__.py in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     236         check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     237         separators=separators, default=default, sort_keys=sort_keys,
# --> 238         **kw).encode(obj)
#     239
#     240
#
# /usr/lib/python3.6/json/encoder.py in encode(self, o)
#     197         # exceptions aren't as detailed.  The list call should be roughly
#     198         # equivalent to the PySequence_Fast that ''.join() would do.
# --> 199         chunks = self.iterencode(o, _one_shot=True)
#     200         if not isinstance(chunks, (list, tuple)):
#     201             chunks = list(chunks)
#
# /usr/lib/python3.6/json/encoder.py in iterencode(self, o, _one_shot)
#     255                 self.key_separator, self.item_separator, self.sort_keys,
#     256                 self.skipkeys, _one_shot)
# --> 257         return _iterencode(o, 0)
#     258
#     259 def _make_iterencode(markers, _default, _encoder, _indent, _floatstr,
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py in get_json_type(obj)
#      72             return obj.__name__
#      73
# ---> 74         raise TypeError('Not JSON Serializable: %s' % (obj,))
#      75
#      76     from .. import __version__ as keras_version
#
# TypeError: Not JSON Serializable: <tf.Variable 'alpha_4:0' shape=() dtype=float32_ref>

# %%
training_time
# Out:
# 205.4695601463318
