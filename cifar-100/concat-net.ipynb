# %% [markdown]
# ## Concat-net

# %%
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse

from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass

# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}

# %%
# !mkdir -p drive
# !google-drive-ocamlfuse drive

# %% [markdown]
# ## Loading the data

# %%
from time import time
import os
import gzip
import numpy as np
from keras.utils import np_utils
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

from keras.datasets import cifar100
# Out:
# Using TensorFlow backend.

# %%
(X_train, y_train), (X_test, y_test) = cifar100.load_data(label_mode='fine')
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, 
                                                  test_size=0.1, 
                                                  random_state=1974,
                                                  stratify = y_train)

# %%
train_features = X_train.reshape(X_train.shape[0], 32, 32, 3)/255
vali_features = X_val.reshape(X_val.shape[0], 32, 32, 3)/255
test_features = X_test.reshape(X_test.shape[0], 32, 32, 3)/255

y_train_cat = np_utils.to_categorical(y_train)
y_val_cat = np_utils.to_categorical(y_val)
y_test_cat = np_utils.to_categorical(y_test)

# %% [markdown]
# ## Defining coarse labels

# %%
dict_coarse2 = {0: 4,  1: 1,  2: 14,  3: 8,  4: 12,  5: 6,  6: 7,  7: 7,  8: 18,  9: 3,  10: 3,
                11: 14,  12: 9,  13: 18,  14: 7,  15: 11,  16: 3,  17: 9,  18: 7,  19: 11,  20: 6,
                21: 11,  22: 5,  23: 10,  24: 7,  25: 6,  26: 13,  27: 15,  28: 3,  29: 15,  30: 0,
                31: 11,  32: 1,  33: 10,  34: 12,  35: 14,  36: 16,  37: 9,  38: 11,  39: 5,  40: 5,
                41: 18,  42: 8,  43: 8,  44: 15,  45: 13,  46: 14,  47: 17,  48: 18,  49: 10,  50: 16,
                51: 4,  52: 17,  53: 4,  54: 2,  55: 12,  56: 17,  57: 4,  58: 18,  59: 17,  60: 10,
                61: 3,  62: 2,  63: 12,  64: 12,  65: 16,  66: 12,  67: 1,  68: 9,  69: 18,  70: 2,
                71: 10,  72: 12,  73: 1,  74: 16,  75: 12,  76: 9,  77: 13,  78: 15,  79: 13,  80: 16,
                81: 18,  82: 2,  83: 4,  84: 6,  85: 18,  86: 5,  87: 5,  88: 8,  89: 18,  90: 18,
                91: 1,  92: 2,  93: 15,  94: 6,  95: 0,  96: 17,  97: 8,  98: 14,  99: 13}


dict_coarse1 = {0: 0,
              1: 0,
              2: 1,
              3: 2,
              4: 1,
              5: 2,
              6: 2,
              7: 3,
              8: 4,
              9: 5,
              10: 5,
              11: 4,
              12: 4,
              13: 3,
              14: 6,
              15: 7,
              16: 4,
              17: 1,
              18: 8}

y_train_coarse2 = np.vectorize(dict_coarse2.get)(y_train)
y_val_coarse2 = np.vectorize(dict_coarse2.get)(y_val)
y_test_coarse2 = np.vectorize(dict_coarse2.get)(y_test)

y_train_coarse1 = np.vectorize(dict_coarse1.get)(y_train_coarse2)
y_val_coarse1 = np.vectorize(dict_coarse1.get)(y_val_coarse2)
y_test_coarse1 = np.vectorize(dict_coarse1.get)(y_test_coarse2)


y_train_c_cat1 = np_utils.to_categorical(y_train_coarse1)
y_val_c_cat1 = np_utils.to_categorical(y_val_coarse1)
y_test_c_cat1 = np_utils.to_categorical(y_test_coarse1)

y_train_c_cat2 = np_utils.to_categorical(y_train_coarse2)
y_val_c_cat2 = np_utils.to_categorical(y_val_coarse2)
y_test_c_cat2 = np_utils.to_categorical(y_test_coarse2)

# %% [markdown]
# ## Training the model

# %%
import keras
from keras.models import Model
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D, Input
from keras import optimizers
from keras.callbacks import TensorBoard, ReduceLROnPlateau, CSVLogger
from keras.layers.normalization import BatchNormalization
from keras import backend as K

# %%
class TimingCallback(keras.callbacks.Callback):
  """Callback that saves the time elapsed of each epoch to the log.
  """  
  def on_epoch_begin(self, epoch, logs={}):
    self.starttime=time()
  def on_epoch_end(self, epoch, logs={}):
    logs['time_elapsed'] = (time()-self.starttime)

# %%
class LossWeightsModifier3Vars(keras.callbacks.Callback):
  """Callback that modifies the loss weights on certain epochs.
    # Arguments
        alpha: coeficient for the coarser class.
        beta: coeficient for the second level coarse class.
        gamma: coeficient for the fine class.
  """  
  def __init__(self, alpha, beta, gamma):
    self.alpha = alpha
    self.beta = beta
    self.gamma = gamma
    
  def on_epoch_end(self, epoch, logs={}):

    if epoch == 4:
      K.set_value(self.alpha, 0.6)
      K.set_value(self.beta, 0.35)
      K.set_value(self.gamma, 0.05)
      print('Changing loss weights to: coarse1 = {}, coarse2 = {}, fine = {}'.format(K.eval(self.alpha), K.eval(self.beta), K.eval(self.gamma)))
    
    if epoch == 9:
      K.set_value(self.alpha, 0)
      K.set_value(self.beta, 0.8)
      K.set_value(self.gamma, 0.2)
      print('Changing loss weights to: coarse1 = {}, coarse2 = {}, fine = {}'.format(K.eval(self.alpha), K.eval(self.beta), K.eval(self.gamma)))
      
    if epoch == 14:
      K.set_value(self.alpha, 0)
      K.set_value(self.beta, 0.4)
      K.set_value(self.gamma, 0.6)  
      print('Changing loss weights to: coarse1 = {}, coarse2 = {}, fine = {}'.format(K.eval(self.alpha), K.eval(self.beta), K.eval(self.gamma)))
  
    if epoch == 21:
      K.set_value(self.alpha, 0)
      K.set_value(self.beta, 0)
      K.set_value(self.gamma, 1)  
      print('Changing loss weights to: coarse1 = {}, coarse2 = {}, fine = {}'.format(K.eval(self.alpha), K.eval(self.beta), K.eval(self.gamma)))
  
    logs['alpha'] = K.eval(self.alpha)
    logs['beta'] = K.eval(self.beta) 
    logs['gamma'] = K.eval(self.gamma)

# %%
img_rows, img_cols = 32, 32
input_shape = (img_rows, img_cols, 3)

num_classes_coarse1 = 9
num_classes_coarse2 = 19
num_classes_fine = 100

img_input = Input(shape=input_shape, name='input')



x = Conv2D(64, (3, 3), activation='relu', name='block1_conv1', padding='same')(img_input)
x = BatchNormalization()(x)
x = Conv2D(64, (3, 3), activation='relu', name='block1_conv2', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2), name='block1_pool')(x)

x = Conv2D(128, (3, 3), activation='relu', name='block1_conv3', padding='same')(x)
x = BatchNormalization()(x)
x = Conv2D(128, (3, 3), activation='relu', name='block1_conv4', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2), name='block2_pool')(x)


#---- coarse branch 1 ----
coarse1 = Flatten(name='c1_flatten')(x)
coarse1 = Dense(256, name='c1_fc_1')(coarse1)
coarse1 = BatchNormalization()(coarse1)
coarse1 = Activation('relu')(coarse1)
coarse1 = Dropout(0.5)(coarse1)

coarse1 = Dense(256, name='c1_fc_2')(coarse1)
coarse1 = BatchNormalization()(coarse1)
coarse1 = Activation('relu')(coarse1)
coarse1 = Dropout(0.5)(coarse1)

coarse_pred1 = Dense(num_classes_coarse1, activation='softmax', name='predictions_coarse1')(coarse1)


x = Conv2D(256, (3, 3), activation='relu', name='block1_conv5', padding='same')(x)
x = BatchNormalization()(x)
x = Conv2D(256, (3, 3), activation='relu', name='block1_conv6', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2), name='block3_pool')(x)


#---- coarse branch 2 ----
coarse2 = Flatten(name='c2_flatten')(x)
coarse2 = Dense(512, name='c2_fc_1')(coarse2)
coarse2 = BatchNormalization()(coarse2)
coarse2 = Activation('relu')(coarse2)
coarse2 = Dropout(0.5)(coarse2)

coarse2 = Dense(512, name='c2_fc_2')(coarse2)
coarse2 = BatchNormalization()(coarse2)
coarse2 = Activation('relu')(coarse2)
coarse2 = Dropout(0.5)(coarse2)

coarse2 = keras.layers.concatenate([coarse2, coarse1])
coarse_pred2 = Dense(num_classes_coarse2, activation='softmax', name='predictions_coarse2')(coarse2)


x = Conv2D(512, (3, 3), activation='relu', name='block1_conv7', padding='same')(x)
x = BatchNormalization()(x)
x = Conv2D(512, (3, 3), activation='relu', name='block1_conv8', padding='same')(x)
x = BatchNormalization()(x)


x = Flatten(name='flatten')(x)
x = Dense(1024, name='fc_1')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = Dropout(0.5)(x)

x = Dense(1024, name='fc_2')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = Dropout(0.5)(x)

x = keras.layers.concatenate([x, coarse2])
fine_pred = Dense(num_classes_fine, activation='softmax', name='predictions_fine')(x)

# %%
model = Model(inputs=img_input, outputs= [coarse_pred1, coarse_pred2, fine_pred], name='concat_net')

model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 32, 32, 64)   1792        input[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 32, 32, 64)   256         block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 32, 32, 64)   36928       batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 32, 32, 64)   256         block1_conv2[0][0]
# __________________________________________________________________________________________________
# block1_pool (MaxPooling2D)      (None, 16, 16, 64)   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# block1_conv3 (Conv2D)           (None, 16, 16, 128)  73856       block1_pool[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 16, 16, 128)  512         block1_conv3[0][0]
# __________________________________________________________________________________________________
# block1_conv4 (Conv2D)           (None, 16, 16, 128)  147584      batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 16, 16, 128)  512         block1_conv4[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 8, 8, 128)    0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# block1_conv5 (Conv2D)           (None, 8, 8, 256)    295168      block2_pool[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 8, 8, 256)    1024        block1_conv5[0][0]
# __________________________________________________________________________________________________
# block1_conv6 (Conv2D)           (None, 8, 8, 256)    590080      batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 8, 8, 256)    1024        block1_conv6[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 4, 4, 256)    0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# block1_conv7 (Conv2D)           (None, 4, 4, 512)    1180160     block3_pool[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 4, 4, 512)    2048        block1_conv7[0][0]
# __________________________________________________________________________________________________
# block1_conv8 (Conv2D)           (None, 4, 4, 512)    2359808     batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# c1_flatten (Flatten)            (None, 8192)         0           block2_pool[0][0]
# __________________________________________________________________________________________________
# c2_flatten (Flatten)            (None, 4096)         0           block3_pool[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 4, 4, 512)    2048        block1_conv8[0][0]
# __________________________________________________________________________________________________
# c1_fc_1 (Dense)                 (None, 256)          2097408     c1_flatten[0][0]
# __________________________________________________________________________________________________
# c2_fc_1 (Dense)                 (None, 512)          2097664     c2_flatten[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 8192)         0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 256)          1024        c1_fc_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 512)          2048        c2_fc_1[0][0]
# __________________________________________________________________________________________________
# fc_1 (Dense)                    (None, 1024)         8389632     flatten[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 256)          0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 512)          0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 1024)         4096        fc_1[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 256)          0           activation_7[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 512)          0           activation_9[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 1024)         0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# c1_fc_2 (Dense)                 (None, 256)          65792       dropout_7[0][0]
# __________________________________________________________________________________________________
# c2_fc_2 (Dense)                 (None, 512)          262656      dropout_9[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 1024)         0           activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 256)          1024        c1_fc_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 512)          2048        c2_fc_2[0][0]
# __________________________________________________________________________________________________
# fc_2 (Dense)                    (None, 1024)         1049600     dropout_11[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 256)          0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 512)          0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 1024)         4096        fc_2[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 256)          0           activation_8[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 512)          0           activation_10[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 1024)         0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 768)          0           dropout_10[0][0]
#                                                                  dropout_8[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 1024)         0           activation_12[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 1792)         0           dropout_12[0][0]
#                                                                  concatenate_3[0][0]
# __________________________________________________________________________________________________
# predictions_coarse1 (Dense)     (None, 9)            2313        dropout_8[0][0]
# __________________________________________________________________________________________________
# predictions_coarse2 (Dense)     (None, 19)           14611       concatenate_3[0][0]
# __________________________________________________________________________________________________
# predictions_fine (Dense)        (None, 100)          179300      concatenate_4[0][0]
# ==================================================================================================
# Total params: 18,866,368
# Trainable params: 18,855,360
# Non-trainable params: 11,008
# __________________________________________________________________________________________________

# %%
alpha = K.variable(value=0.9, dtype="float32", name="alpha") 
beta = K.variable(value=0.1, dtype="float32", name="beta") 
gamma = K.variable(value=0, dtype="float32", name="gamma") 

sgd = optimizers.SGD(lr=0.001, momentum=0.9, nesterov=True)

model.compile(loss='categorical_crossentropy', 
              optimizer=sgd,
              loss_weights=[alpha, beta, gamma],
              metrics=['accuracy'])

# %%
clr_cb = ReduceLROnPlateau(monitor='val_predictions_fine_loss', factor=0.5, patience=10, verbose=1, min_lr=3.125e-05)
time_cb = TimingCallback()
change_lw = LossWeightsModifier3Vars(alpha, beta, gamma)
csv_cb = CSVLogger('drive/TCC-ITAU/cifar-100/training-data/concat-net/concat-net.csv', separator=',', append=False)


cbks = [clr_cb, time_cb, change_lw, csv_cb]

# %%
epochs = 50
start_time = time()
training = model.fit(train_features, [y_train_c_cat1, y_train_c_cat2, y_train_cat],
                     validation_data=(vali_features, [y_val_c_cat1, y_val_c_cat2, y_val_cat]),
                     epochs=epochs,
                     batch_size=256, 
                     callbacks=cbks,
                     verbose=1)
training_time = time() - start_time
# Out:
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/50
# 45000/45000 [==============================] - 46s 1ms/step - loss: 2.2610 - predictions_coarse1_loss: 2.1258 - predictions_coarse2_loss: 3.4776 - predictions_fine_loss: 5.5458 - predictions_coarse1_acc: 0.3028 - predictions_coarse2_acc: 0.0756 - predictions_fine_acc: 0.0103 - val_loss: 1.7862 - val_predictions_coarse1_loss: 1.6808 - val_predictions_coarse2_loss: 2.7346 - val_predictions_fine_loss: 4.8383 - val_predictions_coarse1_acc: 0.4506 - val_predictions_coarse2_acc: 0.1642 - val_predictions_fine_acc: 0.0094
# Epoch 2/50
# 45000/45000 [==============================] - 36s 806us/step - loss: 1.9366 - predictions_coarse1_loss: 1.8072 - predictions_coarse2_loss: 3.1011 - predictions_fine_loss: 5.5288 - predictions_coarse1_acc: 0.3939 - predictions_coarse2_acc: 0.1242 - predictions_fine_acc: 0.0098 - val_loss: 1.6898 - val_predictions_coarse1_loss: 1.5906 - val_predictions_coarse2_loss: 2.5823 - val_predictions_fine_loss: 4.8394 - val_predictions_coarse1_acc: 0.4734 - val_predictions_coarse2_acc: 0.2222 - val_predictions_fine_acc: 0.0110
# Epoch 3/50
# 45000/45000 [==============================] - 36s 801us/step - loss: 1.8093 - predictions_coarse1_loss: 1.6868 - predictions_coarse2_loss: 2.9114 - predictions_fine_loss: 5.5254 - predictions_coarse1_acc: 0.4326 - predictions_coarse2_acc: 0.1620 - predictions_fine_acc: 0.0105 - val_loss: 1.6306 - val_predictions_coarse1_loss: 1.5404 - val_predictions_coarse2_loss: 2.4421 - val_predictions_fine_loss: 4.8281 - val_predictions_coarse1_acc: 0.4880 - val_predictions_coarse2_acc: 0.2650 - val_predictions_fine_acc: 0.0118
# Epoch 4/50
# 45000/45000 [==============================] - 36s 804us/step - loss: 1.7305 - predictions_coarse1_loss: 1.6111 - predictions_coarse2_loss: 2.8053 - predictions_fine_loss: 5.5306 - predictions_coarse1_acc: 0.4589 - predictions_coarse2_acc: 0.1870 - predictions_fine_acc: 0.0109 - val_loss: 1.5673 - val_predictions_coarse1_loss: 1.4761 - val_predictions_coarse2_loss: 2.3881 - val_predictions_fine_loss: 4.8635 - val_predictions_coarse1_acc: 0.5148 - val_predictions_coarse2_acc: 0.2738 - val_predictions_fine_acc: 0.0102
# Epoch 5/50
# 45000/45000 [==============================] - 36s 806us/step - loss: 1.6554 - predictions_coarse1_loss: 1.5388 - predictions_coarse2_loss: 2.7043 - predictions_fine_loss: 5.5277 - predictions_coarse1_acc: 0.4845 - predictions_coarse2_acc: 0.2073 - predictions_fine_acc: 0.0104 - val_loss: 1.5426 - val_predictions_coarse1_loss: 1.4556 - val_predictions_coarse2_loss: 2.3251 - val_predictions_fine_loss: 4.8501 - val_predictions_coarse1_acc: 0.5158 - val_predictions_coarse2_acc: 0.2932 - val_predictions_fine_acc: 0.0116
# Changing loss weights to: coarse1 = 0.6000000238418579, coarse2 = 0.3499999940395355, fine = 0.05000000074505806
# Epoch 6/50
# 45000/45000 [==============================] - 36s 803us/step - loss: 2.0676 - predictions_coarse1_loss: 1.4952 - predictions_coarse2_loss: 2.5734 - predictions_fine_loss: 5.3948 - predictions_coarse1_acc: 0.5003 - predictions_coarse2_acc: 0.2379 - predictions_fine_acc: 0.0111 - val_loss: 1.8734 - val_predictions_coarse1_loss: 1.4410 - val_predictions_coarse2_loss: 2.2201 - val_predictions_fine_loss: 4.6347 - val_predictions_coarse1_acc: 0.5200 - val_predictions_coarse2_acc: 0.3354 - val_predictions_fine_acc: 0.0226
# Epoch 7/50
# 45000/45000 [==============================] - 36s 804us/step - loss: 1.9756 - predictions_coarse1_loss: 1.4540 - predictions_coarse2_loss: 2.4157 - predictions_fine_loss: 5.1541 - predictions_coarse1_acc: 0.5131 - predictions_coarse2_acc: 0.2734 - predictions_fine_acc: 0.0169 - val_loss: 1.7557 - val_predictions_coarse1_loss: 1.3404 - val_predictions_coarse2_loss: 2.0827 - val_predictions_fine_loss: 4.4501 - val_predictions_coarse1_acc: 0.5614 - val_predictions_coarse2_acc: 0.3686 - val_predictions_fine_acc: 0.0440
# Epoch 8/50
# 45000/45000 [==============================] - 36s 804us/step - loss: 1.9016 - predictions_coarse1_loss: 1.4103 - predictions_coarse2_loss: 2.3046 - predictions_fine_loss: 4.9772 - predictions_coarse1_acc: 0.5283 - predictions_coarse2_acc: 0.3006 - predictions_fine_acc: 0.0242 - val_loss: 1.7776 - val_predictions_coarse1_loss: 1.3662 - val_predictions_coarse2_loss: 2.1143 - val_predictions_fine_loss: 4.3576 - val_predictions_coarse1_acc: 0.5404 - val_predictions_coarse2_acc: 0.3468 - val_predictions_fine_acc: 0.0556
# Epoch 9/50
# 45000/45000 [==============================] - 36s 805us/step - loss: 1.8373 - predictions_coarse1_loss: 1.3688 - predictions_coarse2_loss: 2.2133 - predictions_fine_loss: 4.8276 - predictions_coarse1_acc: 0.5433 - predictions_coarse2_acc: 0.3273 - predictions_fine_acc: 0.0322 - val_loss: 1.6604 - val_predictions_coarse1_loss: 1.2754 - val_predictions_coarse2_loss: 1.9525 - val_predictions_fine_loss: 4.2361 - val_predictions_coarse1_acc: 0.5830 - val_predictions_coarse2_acc: 0.3988 - val_predictions_fine_acc: 0.0794
# Epoch 10/50
# 45000/45000 [==============================] - 36s 805us/step - loss: 1.7797 - predictions_coarse1_loss: 1.3295 - predictions_coarse2_loss: 2.1313 - predictions_fine_loss: 4.7214 - predictions_coarse1_acc: 0.5577 - predictions_coarse2_acc: 0.3460 - predictions_fine_acc: 0.0360 - val_loss: 1.6428 - val_predictions_coarse1_loss: 1.2716 - val_predictions_coarse2_loss: 1.9193 - val_predictions_fine_loss: 4.1611 - val_predictions_coarse1_acc: 0.5724 - val_predictions_coarse2_acc: 0.3956 - val_predictions_fine_acc: 0.0942
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.800000011920929, fine = 0.20000000298023224
# Epoch 11/50
# 45000/45000 [==============================] - 36s 804us/step - loss: 2.5519 - predictions_coarse1_loss: 1.3256 - predictions_coarse2_loss: 2.0606 - predictions_fine_loss: 4.5172 - predictions_coarse1_acc: 0.5585 - predictions_coarse2_acc: 0.3623 - predictions_fine_acc: 0.0555 - val_loss: 2.2939 - val_predictions_coarse1_loss: 1.2939 - val_predictions_coarse2_loss: 1.8870 - val_predictions_fine_loss: 3.9215 - val_predictions_coarse1_acc: 0.5642 - val_predictions_coarse2_acc: 0.4106 - val_predictions_fine_acc: 0.1308
# Epoch 12/50
# 45000/45000 [==============================] - 36s 805us/step - loss: 2.4294 - predictions_coarse1_loss: 1.3246 - predictions_coarse2_loss: 1.9754 - predictions_fine_loss: 4.2456 - predictions_coarse1_acc: 0.5536 - predictions_coarse2_acc: 0.3838 - predictions_fine_acc: 0.0836 - val_loss: 2.2351 - val_predictions_coarse1_loss: 1.2623 - val_predictions_coarse2_loss: 1.8545 - val_predictions_fine_loss: 3.7575 - val_predictions_coarse1_acc: 0.5866 - val_predictions_coarse2_acc: 0.4170 - val_predictions_fine_acc: 0.1588
# Epoch 13/50
# 45000/45000 [==============================] - 36s 804us/step - loss: 2.3324 - predictions_coarse1_loss: 1.3271 - predictions_coarse2_loss: 1.8986 - predictions_fine_loss: 4.0677 - predictions_coarse1_acc: 0.5568 - predictions_coarse2_acc: 0.4101 - predictions_fine_acc: 0.1022 - val_loss: 2.0829 - val_predictions_coarse1_loss: 1.2177 - val_predictions_coarse2_loss: 1.7208 - val_predictions_fine_loss: 3.5310 - val_predictions_coarse1_acc: 0.6052 - val_predictions_coarse2_acc: 0.4594 - val_predictions_fine_acc: 0.1962
# Epoch 14/50
# 45000/45000 [==============================] - 36s 800us/step - loss: 2.2463 - predictions_coarse1_loss: 1.3209 - predictions_coarse2_loss: 1.8312 - predictions_fine_loss: 3.9065 - predictions_coarse1_acc: 0.5586 - predictions_coarse2_acc: 0.4248 - predictions_fine_acc: 0.1213 - val_loss: 2.0863 - val_predictions_coarse1_loss: 1.2295 - val_predictions_coarse2_loss: 1.7459 - val_predictions_fine_loss: 3.4479 - val_predictions_coarse1_acc: 0.5910 - val_predictions_coarse2_acc: 0.4500 - val_predictions_fine_acc: 0.2028
# Epoch 15/50
# 45000/45000 [==============================] - 36s 802us/step - loss: 2.1673 - predictions_coarse1_loss: 1.3136 - predictions_coarse2_loss: 1.7675 - predictions_fine_loss: 3.7666 - predictions_coarse1_acc: 0.5597 - predictions_coarse2_acc: 0.4438 - predictions_fine_acc: 0.1363 - val_loss: 2.1512 - val_predictions_coarse1_loss: 1.3245 - val_predictions_coarse2_loss: 1.8240 - val_predictions_fine_loss: 3.4603 - val_predictions_coarse1_acc: 0.5592 - val_predictions_coarse2_acc: 0.4330 - val_predictions_fine_acc: 0.2088
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.4000000059604645, fine = 0.6000000238418579
# Epoch 16/50
# 45000/45000 [==============================] - 36s 803us/step - loss: 2.8407 - predictions_coarse1_loss: 1.3064 - predictions_coarse2_loss: 1.7316 - predictions_fine_loss: 3.5801 - predictions_coarse1_acc: 0.5646 - predictions_coarse2_acc: 0.4553 - predictions_fine_acc: 0.1655 - val_loss: 2.6382 - val_predictions_coarse1_loss: 1.2450 - val_predictions_coarse2_loss: 1.7673 - val_predictions_fine_loss: 3.2187 - val_predictions_coarse1_acc: 0.5930 - val_predictions_coarse2_acc: 0.4516 - val_predictions_fine_acc: 0.2320
# Epoch 17/50
# 45000/45000 [==============================] - 36s 800us/step - loss: 2.6897 - predictions_coarse1_loss: 1.3081 - predictions_coarse2_loss: 1.7155 - predictions_fine_loss: 3.3392 - predictions_coarse1_acc: 0.5600 - predictions_coarse2_acc: 0.4577 - predictions_fine_acc: 0.2028 - val_loss: 2.4663 - val_predictions_coarse1_loss: 1.2314 - val_predictions_coarse2_loss: 1.6513 - val_predictions_fine_loss: 3.0096 - val_predictions_coarse1_acc: 0.6000 - val_predictions_coarse2_acc: 0.4808 - val_predictions_fine_acc: 0.2772
# Epoch 18/50
# 45000/45000 [==============================] - 36s 805us/step - loss: 2.5637 - predictions_coarse1_loss: 1.3108 - predictions_coarse2_loss: 1.6836 - predictions_fine_loss: 3.1505 - predictions_coarse1_acc: 0.5617 - predictions_coarse2_acc: 0.4707 - predictions_fine_acc: 0.2353 - val_loss: 2.3504 - val_predictions_coarse1_loss: 1.2234 - val_predictions_coarse2_loss: 1.6043 - val_predictions_fine_loss: 2.8477 - val_predictions_coarse1_acc: 0.6046 - val_predictions_coarse2_acc: 0.4938 - val_predictions_fine_acc: 0.3078
# Epoch 19/50
# 45000/45000 [==============================] - 36s 806us/step - loss: 2.4653 - predictions_coarse1_loss: 1.3103 - predictions_coarse2_loss: 1.6568 - predictions_fine_loss: 3.0044 - predictions_coarse1_acc: 0.5588 - predictions_coarse2_acc: 0.4741 - predictions_fine_acc: 0.2588 - val_loss: 2.2852 - val_predictions_coarse1_loss: 1.2028 - val_predictions_coarse2_loss: 1.5834 - val_predictions_fine_loss: 2.7530 - val_predictions_coarse1_acc: 0.6136 - val_predictions_coarse2_acc: 0.5000 - val_predictions_fine_acc: 0.3238
# Epoch 20/50
# 45000/45000 [==============================] - 36s 808us/step - loss: 2.3859 - predictions_coarse1_loss: 1.3088 - predictions_coarse2_loss: 1.6324 - predictions_fine_loss: 2.8883 - predictions_coarse1_acc: 0.5623 - predictions_coarse2_acc: 0.4804 - predictions_fine_acc: 0.2814 - val_loss: 2.2308 - val_predictions_coarse1_loss: 1.1944 - val_predictions_coarse2_loss: 1.5603 - val_predictions_fine_loss: 2.6779 - val_predictions_coarse1_acc: 0.6158 - val_predictions_coarse2_acc: 0.5108 - val_predictions_fine_acc: 0.3320
# Epoch 21/50
# 45000/45000 [==============================] - 36s 807us/step - loss: 2.3078 - predictions_coarse1_loss: 1.3056 - predictions_coarse2_loss: 1.6061 - predictions_fine_loss: 2.7755 - predictions_coarse1_acc: 0.5601 - predictions_coarse2_acc: 0.4876 - predictions_fine_acc: 0.3008 - val_loss: 2.2081 - val_predictions_coarse1_loss: 1.1779 - val_predictions_coarse2_loss: 1.5632 - val_predictions_fine_loss: 2.6380 - val_predictions_coarse1_acc: 0.6160 - val_predictions_coarse2_acc: 0.5058 - val_predictions_fine_acc: 0.3472
# Epoch 22/50
# 45000/45000 [==============================] - 36s 804us/step - loss: 2.2312 - predictions_coarse1_loss: 1.2985 - predictions_coarse2_loss: 1.5784 - predictions_fine_loss: 2.6664 - predictions_coarse1_acc: 0.5659 - predictions_coarse2_acc: 0.4965 - predictions_fine_acc: 0.3220 - val_loss: 2.1427 - val_predictions_coarse1_loss: 1.1890 - val_predictions_coarse2_loss: 1.5360 - val_predictions_fine_loss: 2.5471 - val_predictions_coarse1_acc: 0.6164 - val_predictions_coarse2_acc: 0.5168 - val_predictions_fine_acc: 0.3570
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.0, fine = 1.0
# Epoch 23/50
# 45000/45000 [==============================] - 36s 802us/step - loss: 2.6013 - predictions_coarse1_loss: 1.3086 - predictions_coarse2_loss: 1.5686 - predictions_fine_loss: 2.6013 - predictions_coarse1_acc: 0.5602 - predictions_coarse2_acc: 0.4977 - predictions_fine_acc: 0.3326 - val_loss: 2.5018 - val_predictions_coarse1_loss: 1.1929 - val_predictions_coarse2_loss: 1.5510 - val_predictions_fine_loss: 2.5018 - val_predictions_coarse1_acc: 0.6132 - val_predictions_coarse2_acc: 0.5082 - val_predictions_fine_acc: 0.3634
# Epoch 24/50
# 45000/45000 [==============================] - 36s 808us/step - loss: 2.4932 - predictions_coarse1_loss: 1.3188 - predictions_coarse2_loss: 1.5691 - predictions_fine_loss: 2.4932 - predictions_coarse1_acc: 0.5548 - predictions_coarse2_acc: 0.4966 - predictions_fine_acc: 0.3566 - val_loss: 2.5610 - val_predictions_coarse1_loss: 1.2834 - val_predictions_coarse2_loss: 1.6352 - val_predictions_fine_loss: 2.5610 - val_predictions_coarse1_acc: 0.5770 - val_predictions_coarse2_acc: 0.4924 - val_predictions_fine_acc: 0.3536
# Epoch 25/50
# 45000/45000 [==============================] - 36s 807us/step - loss: 2.3903 - predictions_coarse1_loss: 1.3234 - predictions_coarse2_loss: 1.5726 - predictions_fine_loss: 2.3903 - predictions_coarse1_acc: 0.5525 - predictions_coarse2_acc: 0.4973 - predictions_fine_acc: 0.3763 - val_loss: 2.4239 - val_predictions_coarse1_loss: 1.2345 - val_predictions_coarse2_loss: 1.5545 - val_predictions_fine_loss: 2.4239 - val_predictions_coarse1_acc: 0.5996 - val_predictions_coarse2_acc: 0.5118 - val_predictions_fine_acc: 0.3748
# Epoch 26/50
# 45000/45000 [==============================] - 36s 806us/step - loss: 2.2896 - predictions_coarse1_loss: 1.3263 - predictions_coarse2_loss: 1.5717 - predictions_fine_loss: 2.2896 - predictions_coarse1_acc: 0.5482 - predictions_coarse2_acc: 0.4972 - predictions_fine_acc: 0.4008 - val_loss: 2.3989 - val_predictions_coarse1_loss: 1.2376 - val_predictions_coarse2_loss: 1.5703 - val_predictions_fine_loss: 2.3989 - val_predictions_coarse1_acc: 0.5952 - val_predictions_coarse2_acc: 0.5146 - val_predictions_fine_acc: 0.3878
# Epoch 27/50
# 45000/45000 [==============================] - 36s 805us/step - loss: 2.1973 - predictions_coarse1_loss: 1.3254 - predictions_coarse2_loss: 1.5610 - predictions_fine_loss: 2.1973 - predictions_coarse1_acc: 0.5514 - predictions_coarse2_acc: 0.5004 - predictions_fine_acc: 0.4198 - val_loss: 2.3136 - val_predictions_coarse1_loss: 1.2157 - val_predictions_coarse2_loss: 1.5217 - val_predictions_fine_loss: 2.3136 - val_predictions_coarse1_acc: 0.6070 - val_predictions_coarse2_acc: 0.5176 - val_predictions_fine_acc: 0.3990
# Epoch 28/50
# 45000/45000 [==============================] - 36s 809us/step - loss: 2.1185 - predictions_coarse1_loss: 1.3347 - predictions_coarse2_loss: 1.5561 - predictions_fine_loss: 2.1185 - predictions_coarse1_acc: 0.5471 - predictions_coarse2_acc: 0.5007 - predictions_fine_acc: 0.4388 - val_loss: 2.2166 - val_predictions_coarse1_loss: 1.1963 - val_predictions_coarse2_loss: 1.4842 - val_predictions_fine_loss: 2.2166 - val_predictions_coarse1_acc: 0.6134 - val_predictions_coarse2_acc: 0.5350 - val_predictions_fine_acc: 0.4200
# Epoch 29/50
# 45000/45000 [==============================] - 36s 805us/step - loss: 2.0244 - predictions_coarse1_loss: 1.3331 - predictions_coarse2_loss: 1.5575 - predictions_fine_loss: 2.0244 - predictions_coarse1_acc: 0.5506 - predictions_coarse2_acc: 0.5006 - predictions_fine_acc: 0.4579 - val_loss: 2.2178 - val_predictions_coarse1_loss: 1.1992 - val_predictions_coarse2_loss: 1.4816 - val_predictions_fine_loss: 2.2178 - val_predictions_coarse1_acc: 0.6206 - val_predictions_coarse2_acc: 0.5314 - val_predictions_fine_acc: 0.4226
# Epoch 30/50
# 45000/45000 [==============================] - 36s 804us/step - loss: 1.9575 - predictions_coarse1_loss: 1.3369 - predictions_coarse2_loss: 1.5518 - predictions_fine_loss: 1.9575 - predictions_coarse1_acc: 0.5463 - predictions_coarse2_acc: 0.5001 - predictions_fine_acc: 0.4726 - val_loss: 2.1220 - val_predictions_coarse1_loss: 1.1991 - val_predictions_coarse2_loss: 1.4688 - val_predictions_fine_loss: 2.1220 - val_predictions_coarse1_acc: 0.6134 - val_predictions_coarse2_acc: 0.5344 - val_predictions_fine_acc: 0.4444
# Epoch 31/50
# 45000/45000 [==============================] - 36s 800us/step - loss: 1.8791 - predictions_coarse1_loss: 1.3403 - predictions_coarse2_loss: 1.5486 - predictions_fine_loss: 1.8791 - predictions_coarse1_acc: 0.5437 - predictions_coarse2_acc: 0.5005 - predictions_fine_acc: 0.4906 - val_loss: 2.1030 - val_predictions_coarse1_loss: 1.2140 - val_predictions_coarse2_loss: 1.4759 - val_predictions_fine_loss: 2.1030 - val_predictions_coarse1_acc: 0.6028 - val_predictions_coarse2_acc: 0.5320 - val_predictions_fine_acc: 0.4464
# Epoch 32/50
# 45000/45000 [==============================] - 36s 804us/step - loss: 1.7936 - predictions_coarse1_loss: 1.3365 - predictions_coarse2_loss: 1.5424 - predictions_fine_loss: 1.7936 - predictions_coarse1_acc: 0.5487 - predictions_coarse2_acc: 0.5053 - predictions_fine_acc: 0.5120 - val_loss: 2.1054 - val_predictions_coarse1_loss: 1.1932 - val_predictions_coarse2_loss: 1.4692 - val_predictions_fine_loss: 2.1054 - val_predictions_coarse1_acc: 0.6154 - val_predictions_coarse2_acc: 0.5354 - val_predictions_fine_acc: 0.4418
# Epoch 33/50
# 45000/45000 [==============================] - 36s 806us/step - loss: 1.7335 - predictions_coarse1_loss: 1.3321 - predictions_coarse2_loss: 1.5312 - predictions_fine_loss: 1.7335 - predictions_coarse1_acc: 0.5460 - predictions_coarse2_acc: 0.5069 - predictions_fine_acc: 0.5275 - val_loss: 2.0925 - val_predictions_coarse1_loss: 1.2249 - val_predictions_coarse2_loss: 1.4960 - val_predictions_fine_loss: 2.0925 - val_predictions_coarse1_acc: 0.5994 - val_predictions_coarse2_acc: 0.5242 - val_predictions_fine_acc: 0.4502
# Epoch 34/50
# 45000/45000 [==============================] - 36s 806us/step - loss: 1.6480 - predictions_coarse1_loss: 1.3390 - predictions_coarse2_loss: 1.5326 - predictions_fine_loss: 1.6480 - predictions_coarse1_acc: 0.5475 - predictions_coarse2_acc: 0.5055 - predictions_fine_acc: 0.5474 - val_loss: 2.0342 - val_predictions_coarse1_loss: 1.2011 - val_predictions_coarse2_loss: 1.4630 - val_predictions_fine_loss: 2.0342 - val_predictions_coarse1_acc: 0.6154 - val_predictions_coarse2_acc: 0.5438 - val_predictions_fine_acc: 0.4640
# Epoch 35/50
# 45000/45000 [==============================] - 36s 805us/step - loss: 1.5851 - predictions_coarse1_loss: 1.3305 - predictions_coarse2_loss: 1.5316 - predictions_fine_loss: 1.5851 - predictions_coarse1_acc: 0.5489 - predictions_coarse2_acc: 0.5089 - predictions_fine_acc: 0.5625 - val_loss: 2.0366 - val_predictions_coarse1_loss: 1.2136 - val_predictions_coarse2_loss: 1.4641 - val_predictions_fine_loss: 2.0366 - val_predictions_coarse1_acc: 0.6064 - val_predictions_coarse2_acc: 0.5400 - val_predictions_fine_acc: 0.4640
# Epoch 36/50
# 45000/45000 [==============================] - 36s 802us/step - loss: 1.5214 - predictions_coarse1_loss: 1.3396 - predictions_coarse2_loss: 1.5177 - predictions_fine_loss: 1.5214 - predictions_coarse1_acc: 0.5441 - predictions_coarse2_acc: 0.5106 - predictions_fine_acc: 0.5799 - val_loss: 1.9962 - val_predictions_coarse1_loss: 1.2042 - val_predictions_coarse2_loss: 1.4534 - val_predictions_fine_loss: 1.9962 - val_predictions_coarse1_acc: 0.6146 - val_predictions_coarse2_acc: 0.5466 - val_predictions_fine_acc: 0.4700
# Epoch 37/50
# 45000/45000 [==============================] - 36s 805us/step - loss: 1.4463 - predictions_coarse1_loss: 1.3361 - predictions_coarse2_loss: 1.5189 - predictions_fine_loss: 1.4463 - predictions_coarse1_acc: 0.5511 - predictions_coarse2_acc: 0.5124 - predictions_fine_acc: 0.5984 - val_loss: 2.0174 - val_predictions_coarse1_loss: 1.2071 - val_predictions_coarse2_loss: 1.4685 - val_predictions_fine_loss: 2.0174 - val_predictions_coarse1_acc: 0.6094 - val_predictions_coarse2_acc: 0.5378 - val_predictions_fine_acc: 0.4694
# Epoch 38/50
# 45000/45000 [==============================] - 36s 805us/step - loss: 1.3803 - predictions_coarse1_loss: 1.3351 - predictions_coarse2_loss: 1.5146 - predictions_fine_loss: 1.3803 - predictions_coarse1_acc: 0.5454 - predictions_coarse2_acc: 0.5120 - predictions_fine_acc: 0.6172 - val_loss: 1.9723 - val_predictions_coarse1_loss: 1.1994 - val_predictions_coarse2_loss: 1.4528 - val_predictions_fine_loss: 1.9723 - val_predictions_coarse1_acc: 0.6142 - val_predictions_coarse2_acc: 0.5410 - val_predictions_fine_acc: 0.4790
# Epoch 39/50
# 45000/45000 [==============================] - 36s 807us/step - loss: 1.3024 - predictions_coarse1_loss: 1.3375 - predictions_coarse2_loss: 1.5118 - predictions_fine_loss: 1.3024 - predictions_coarse1_acc: 0.5430 - predictions_coarse2_acc: 0.5114 - predictions_fine_acc: 0.6370 - val_loss: 1.9651 - val_predictions_coarse1_loss: 1.2014 - val_predictions_coarse2_loss: 1.4511 - val_predictions_fine_loss: 1.9651 - val_predictions_coarse1_acc: 0.6108 - val_predictions_coarse2_acc: 0.5428 - val_predictions_fine_acc: 0.4798
# Epoch 40/50
# 45000/45000 [==============================] - 36s 799us/step - loss: 1.2397 - predictions_coarse1_loss: 1.3299 - predictions_coarse2_loss: 1.5077 - predictions_fine_loss: 1.2397 - predictions_coarse1_acc: 0.5495 - predictions_coarse2_acc: 0.5150 - predictions_fine_acc: 0.6541 - val_loss: 2.0103 - val_predictions_coarse1_loss: 1.2148 - val_predictions_coarse2_loss: 1.4726 - val_predictions_fine_loss: 2.0103 - val_predictions_coarse1_acc: 0.6044 - val_predictions_coarse2_acc: 0.5386 - val_predictions_fine_acc: 0.4690
# Epoch 41/50
# 45000/45000 [==============================] - 36s 804us/step - loss: 1.1786 - predictions_coarse1_loss: 1.3357 - predictions_coarse2_loss: 1.4977 - predictions_fine_loss: 1.1786 - predictions_coarse1_acc: 0.5458 - predictions_coarse2_acc: 0.5167 - predictions_fine_acc: 0.6709 - val_loss: 1.9291 - val_predictions_coarse1_loss: 1.2063 - val_predictions_coarse2_loss: 1.4457 - val_predictions_fine_loss: 1.9291 - val_predictions_coarse1_acc: 0.6062 - val_predictions_coarse2_acc: 0.5506 - val_predictions_fine_acc: 0.4860
# Epoch 42/50
# 45000/45000 [==============================] - 36s 806us/step - loss: 1.1042 - predictions_coarse1_loss: 1.3367 - predictions_coarse2_loss: 1.5082 - predictions_fine_loss: 1.1042 - predictions_coarse1_acc: 0.5483 - predictions_coarse2_acc: 0.5147 - predictions_fine_acc: 0.6924 - val_loss: 1.9444 - val_predictions_coarse1_loss: 1.1863 - val_predictions_coarse2_loss: 1.4363 - val_predictions_fine_loss: 1.9444 - val_predictions_coarse1_acc: 0.6202 - val_predictions_coarse2_acc: 0.5504 - val_predictions_fine_acc: 0.4874
# Epoch 43/50
# 45000/45000 [==============================] - 36s 805us/step - loss: 1.0403 - predictions_coarse1_loss: 1.3331 - predictions_coarse2_loss: 1.4964 - predictions_fine_loss: 1.0403 - predictions_coarse1_acc: 0.5470 - predictions_coarse2_acc: 0.5157 - predictions_fine_acc: 0.7120 - val_loss: 1.9213 - val_predictions_coarse1_loss: 1.1915 - val_predictions_coarse2_loss: 1.4325 - val_predictions_fine_loss: 1.9213 - val_predictions_coarse1_acc: 0.6130 - val_predictions_coarse2_acc: 0.5476 - val_predictions_fine_acc: 0.4904
# Epoch 44/50
# 45000/45000 [==============================] - 36s 806us/step - loss: 0.9808 - predictions_coarse1_loss: 1.3425 - predictions_coarse2_loss: 1.4998 - predictions_fine_loss: 0.9808 - predictions_coarse1_acc: 0.5423 - predictions_coarse2_acc: 0.5127 - predictions_fine_acc: 0.7295 - val_loss: 1.9041 - val_predictions_coarse1_loss: 1.2003 - val_predictions_coarse2_loss: 1.4405 - val_predictions_fine_loss: 1.9041 - val_predictions_coarse1_acc: 0.6134 - val_predictions_coarse2_acc: 0.5494 - val_predictions_fine_acc: 0.4972
# Epoch 45/50
# 45000/45000 [==============================] - 36s 803us/step - loss: 0.9288 - predictions_coarse1_loss: 1.3344 - predictions_coarse2_loss: 1.5022 - predictions_fine_loss: 0.9288 - predictions_coarse1_acc: 0.5460 - predictions_coarse2_acc: 0.5131 - predictions_fine_acc: 0.7411 - val_loss: 1.9091 - val_predictions_coarse1_loss: 1.2002 - val_predictions_coarse2_loss: 1.4377 - val_predictions_fine_loss: 1.9091 - val_predictions_coarse1_acc: 0.6198 - val_predictions_coarse2_acc: 0.5524 - val_predictions_fine_acc: 0.4924
# Epoch 46/50
# 45000/45000 [==============================] - 36s 804us/step - loss: 0.8541 - predictions_coarse1_loss: 1.3324 - predictions_coarse2_loss: 1.4882 - predictions_fine_loss: 0.8541 - predictions_coarse1_acc: 0.5475 - predictions_coarse2_acc: 0.5163 - predictions_fine_acc: 0.7645 - val_loss: 1.8957 - val_predictions_coarse1_loss: 1.1925 - val_predictions_coarse2_loss: 1.4362 - val_predictions_fine_loss: 1.8957 - val_predictions_coarse1_acc: 0.6188 - val_predictions_coarse2_acc: 0.5464 - val_predictions_fine_acc: 0.4998
# Epoch 47/50
# 45000/45000 [==============================] - 36s 806us/step - loss: 0.7962 - predictions_coarse1_loss: 1.3366 - predictions_coarse2_loss: 1.4895 - predictions_fine_loss: 0.7962 - predictions_coarse1_acc: 0.5459 - predictions_coarse2_acc: 0.5168 - predictions_fine_acc: 0.7853 - val_loss: 1.8964 - val_predictions_coarse1_loss: 1.1968 - val_predictions_coarse2_loss: 1.4286 - val_predictions_fine_loss: 1.8964 - val_predictions_coarse1_acc: 0.6146 - val_predictions_coarse2_acc: 0.5512 - val_predictions_fine_acc: 0.5038
# Epoch 48/50
# 45000/45000 [==============================] - 36s 801us/step - loss: 0.7374 - predictions_coarse1_loss: 1.3322 - predictions_coarse2_loss: 1.4920 - predictions_fine_loss: 0.7374 - predictions_coarse1_acc: 0.5451 - predictions_coarse2_acc: 0.5179 - predictions_fine_acc: 0.8005 - val_loss: 1.8934 - val_predictions_coarse1_loss: 1.1954 - val_predictions_coarse2_loss: 1.4360 - val_predictions_fine_loss: 1.8934 - val_predictions_coarse1_acc: 0.6172 - val_predictions_coarse2_acc: 0.5468 - val_predictions_fine_acc: 0.5018
# Epoch 49/50
# 45000/45000 [==============================] - 36s 804us/step - loss: 0.6889 - predictions_coarse1_loss: 1.3337 - predictions_coarse2_loss: 1.4891 - predictions_fine_loss: 0.6889 - predictions_coarse1_acc: 0.5461 - predictions_coarse2_acc: 0.5163 - predictions_fine_acc: 0.8148 - val_loss: 1.9149 - val_predictions_coarse1_loss: 1.2003 - val_predictions_coarse2_loss: 1.4361 - val_predictions_fine_loss: 1.9149 - val_predictions_coarse1_acc: 0.6144 - val_predictions_coarse2_acc: 0.5458 - val_predictions_fine_acc: 0.4950
# Epoch 50/50
# 45000/45000 [==============================] - 36s 802us/step - loss: 0.6357 - predictions_coarse1_loss: 1.3341 - predictions_coarse2_loss: 1.4876 - predictions_fine_loss: 0.6357 - predictions_coarse1_acc: 0.5451 - predictions_coarse2_acc: 0.5194 - predictions_fine_acc: 0.8327 - val_loss: 1.9101 - val_predictions_coarse1_loss: 1.1944 - val_predictions_coarse2_loss: 1.4398 - val_predictions_fine_loss: 1.9101 - val_predictions_coarse1_acc: 0.6218 - val_predictions_coarse2_acc: 0.5468 - val_predictions_fine_acc: 0.4954

# %%
model.evaluate(test_features, [y_test_c_cat1,y_test_c_cat2, y_test_cat])
# Out:
# 10000/10000 [==============================] - 6s 603us/step
# [1.839475567817688,
#  1.1749474506378175,
#  1.4070644947052002,
#  1.839475567817688,
#  0.6251,
#  0.5599,
#  0.5205]

# %%
print('Total training time: {}'.format(training_time))
# Out:
# Total training time: 1855.852506160736

# %%
model.save('drive/TCC-ITAU/cifar-100/models/concat-net.h5')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-33ac653b877d> in <module>()
# ----> 1 model.save('drive/TCC-ITAU/cifar-100/models/concat-net.h5')
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/network.py in save(self, filepath, overwrite, include_optimizer)
#    1088             raise NotImplementedError
#    1089         from ..models import save_model
# -> 1090         save_model(self, filepath, overwrite, include_optimizer)
#    1091
#    1092     def save_weights(self, filepath, overwrite=True):
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py in save_model(model, filepath, overwrite, include_optimizer)
#     380
#     381     try:
# --> 382         _serialize_model(model, f, include_optimizer)
#     383     finally:
#     384         if opened_new_file:
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py in _serialize_model(model, f, include_optimizer)
#     136                 'sample_weight_mode': model.sample_weight_mode,
#     137                 'loss_weights': model.loss_weights,
# --> 138             }, default=get_json_type).encode('utf8')
#     139             symbolic_weights = getattr(model.optimizer, 'weights')
#     140             if symbolic_weights:
#
# /usr/lib/python3.6/json/__init__.py in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     236         check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     237         separators=separators, default=default, sort_keys=sort_keys,
# --> 238         **kw).encode(obj)
#     239
#     240
#
# /usr/lib/python3.6/json/encoder.py in encode(self, o)
#     197         # exceptions aren't as detailed.  The list call should be roughly
#     198         # equivalent to the PySequence_Fast that ''.join() would do.
# --> 199         chunks = self.iterencode(o, _one_shot=True)
#     200         if not isinstance(chunks, (list, tuple)):
#     201             chunks = list(chunks)
#
# /usr/lib/python3.6/json/encoder.py in iterencode(self, o, _one_shot)
#     255                 self.key_separator, self.item_separator, self.sort_keys,
#     256                 self.skipkeys, _one_shot)
# --> 257         return _iterencode(o, 0)
#     258
#     259 def _make_iterencode(markers, _default, _encoder, _indent, _floatstr,
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py in get_json_type(obj)
#      72             return obj.__name__
#      73
# ---> 74         raise TypeError('Not JSON Serializable: %s' % (obj,))
#      75
#      76     from .. import __version__ as keras_version
#
# TypeError: Not JSON Serializable: <tf.Variable 'alpha_1:0' shape=() dtype=float32_ref>
