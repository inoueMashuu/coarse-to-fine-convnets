# %% [markdown]
# ## Branch-net

# %%
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse

from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass

# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}

# %%
# !mkdir -p drive
# !google-drive-ocamlfuse drive

# %% [markdown]
# ## Loading the data

# %%
from time import time
import os
import gzip
import numpy as np
from keras.utils import np_utils
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

from keras.datasets import cifar100
# Out:
# Using TensorFlow backend.

# %%
(X_train, y_train), (X_test, y_test) = cifar100.load_data(label_mode='fine')
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, 
                                                  test_size=0.1, 
                                                  random_state=1974,
                                                  stratify = y_train)

# %%
train_features = X_train.reshape(X_train.shape[0], 32, 32, 3)/255
vali_features = X_val.reshape(X_val.shape[0], 32, 32, 3)/255
test_features = X_test.reshape(X_test.shape[0], 32, 32, 3)/255

y_train_cat = np_utils.to_categorical(y_train)
y_val_cat = np_utils.to_categorical(y_val)
y_test_cat = np_utils.to_categorical(y_test)

# %% [markdown]
# ## Defining coarse labels

# %%
dict_coarse2 = {0: 4,  1: 1,  2: 14,  3: 8,  4: 12,  5: 6,  6: 7,  7: 7,  8: 18,  9: 3,  10: 3,
                11: 14,  12: 9,  13: 18,  14: 7,  15: 11,  16: 3,  17: 9,  18: 7,  19: 11,  20: 6,
                21: 11,  22: 5,  23: 10,  24: 7,  25: 6,  26: 13,  27: 15,  28: 3,  29: 15,  30: 0,
                31: 11,  32: 1,  33: 10,  34: 12,  35: 14,  36: 16,  37: 9,  38: 11,  39: 5,  40: 5,
                41: 18,  42: 8,  43: 8,  44: 15,  45: 13,  46: 14,  47: 17,  48: 18,  49: 10,  50: 16,
                51: 4,  52: 17,  53: 4,  54: 2,  55: 12,  56: 17,  57: 4,  58: 18,  59: 17,  60: 10,
                61: 3,  62: 2,  63: 12,  64: 12,  65: 16,  66: 12,  67: 1,  68: 9,  69: 18,  70: 2,
                71: 10,  72: 12,  73: 1,  74: 16,  75: 12,  76: 9,  77: 13,  78: 15,  79: 13,  80: 16,
                81: 18,  82: 2,  83: 4,  84: 6,  85: 18,  86: 5,  87: 5,  88: 8,  89: 18,  90: 18,
                91: 1,  92: 2,  93: 15,  94: 6,  95: 0,  96: 17,  97: 8,  98: 14,  99: 13}


dict_coarse1 = {0: 0,
              1: 0,
              2: 1,
              3: 2,
              4: 1,
              5: 2,
              6: 2,
              7: 3,
              8: 4,
              9: 5,
              10: 5,
              11: 4,
              12: 4,
              13: 3,
              14: 6,
              15: 7,
              16: 4,
              17: 1,
              18: 8}

y_train_coarse2 = np.vectorize(dict_coarse2.get)(y_train)
y_val_coarse2 = np.vectorize(dict_coarse2.get)(y_val)
y_test_coarse2 = np.vectorize(dict_coarse2.get)(y_test)

y_train_coarse1 = np.vectorize(dict_coarse1.get)(y_train_coarse2)
y_val_coarse1 = np.vectorize(dict_coarse1.get)(y_val_coarse2)
y_test_coarse1 = np.vectorize(dict_coarse1.get)(y_test_coarse2)


y_train_c_cat1 = np_utils.to_categorical(y_train_coarse1)
y_val_c_cat1 = np_utils.to_categorical(y_val_coarse1)
y_test_c_cat1 = np_utils.to_categorical(y_test_coarse1)

y_train_c_cat2 = np_utils.to_categorical(y_train_coarse2)
y_val_c_cat2 = np_utils.to_categorical(y_val_coarse2)
y_test_c_cat2 = np_utils.to_categorical(y_test_coarse2)

# %% [markdown]
# ## Training the model

# %%
import keras
from keras.models import Model
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D, Input
from keras import optimizers
from keras.callbacks import TensorBoard, ReduceLROnPlateau, CSVLogger
from keras.layers.normalization import BatchNormalization
from keras import backend as K

# %%
class TimingCallback(keras.callbacks.Callback):
  """Callback that saves the time elapsed of each epoch to the log.
  """  
  def on_epoch_begin(self, epoch, logs={}):
    self.starttime=time()
  def on_epoch_end(self, epoch, logs={}):
    logs['time_elapsed'] = (time()-self.starttime)

# %%
class LossWeightsModifier3Vars(keras.callbacks.Callback):
  """Callback that modifies the loss weights on certain epochs.
    # Arguments
        alpha: coeficient for the coarser class.
        beta: coeficient for the second level coarse class.
        gamma: coeficient for the fine class.
  """  
  def __init__(self, alpha, beta, gamma):
    self.alpha = alpha
    self.beta = beta
    self.gamma = gamma
    
  def on_epoch_end(self, epoch, logs={}):

    if epoch == 4:
      K.set_value(self.alpha, 0.6)
      K.set_value(self.beta, 0.35)
      K.set_value(self.gamma, 0.05)
      print('Changing loss weights to: coarse1 = {}, coarse2 = {}, fine = {}'.format(K.eval(self.alpha), K.eval(self.beta), K.eval(self.gamma)))
    
    if epoch == 9:
      K.set_value(self.alpha, 0)
      K.set_value(self.beta, 0.8)
      K.set_value(self.gamma, 0.2)
      print('Changing loss weights to: coarse1 = {}, coarse2 = {}, fine = {}'.format(K.eval(self.alpha), K.eval(self.beta), K.eval(self.gamma)))
      
    if epoch == 14:
      K.set_value(self.alpha, 0)
      K.set_value(self.beta, 0.4)
      K.set_value(self.gamma, 0.6)  
      print('Changing loss weights to: coarse1 = {}, coarse2 = {}, fine = {}'.format(K.eval(self.alpha), K.eval(self.beta), K.eval(self.gamma)))
  
    if epoch == 21:
      K.set_value(self.alpha, 0)
      K.set_value(self.beta, 0)
      K.set_value(self.gamma, 1)  
      print('Changing loss weights to: coarse1 = {}, coarse2 = {}, fine = {}'.format(K.eval(self.alpha), K.eval(self.beta), K.eval(self.gamma)))
  
    logs['alpha'] = K.eval(self.alpha)
    logs['beta'] = K.eval(self.beta) 
    logs['gamma'] = K.eval(self.gamma)

# %%
img_rows, img_cols = 32, 32
input_shape = (img_rows, img_cols, 3)

num_classes_coarse1 = 9
num_classes_coarse2 = 19
num_classes_fine = 100

img_input = Input(shape=input_shape, name='input')



x = Conv2D(64, (3, 3), activation='relu', name='block1_conv1', padding='same')(img_input)
x = BatchNormalization()(x)
x = Conv2D(64, (3, 3), activation='relu', name='block1_conv2', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2), name='block1_pool')(x)

x = Conv2D(128, (3, 3), activation='relu', name='block1_conv3', padding='same')(x)
x = BatchNormalization()(x)
x = Conv2D(128, (3, 3), activation='relu', name='block1_conv4', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2), name='block2_pool')(x)


#---- coarse branch 1 ----
coarse1 = Flatten(name='c1_flatten')(x)
coarse1 = Dense(256, name='c1_fc_1')(coarse1)
coarse1 = BatchNormalization()(coarse1)
coarse1 = Activation('relu')(coarse1)
coarse1 = Dropout(0.5)(coarse1)

coarse1 = Dense(256, name='c1_fc_2')(coarse1)
coarse1 = BatchNormalization()(coarse1)
coarse1 = Activation('relu')(coarse1)
coarse1 = Dropout(0.5)(coarse1)

coarse_pred1 = Dense(num_classes_coarse1, activation='softmax', name='predictions_coarse1')(coarse1)


x = Conv2D(256, (3, 3), activation='relu', name='block1_conv5', padding='same')(x)
x = BatchNormalization()(x)
x = Conv2D(256, (3, 3), activation='relu', name='block1_conv6', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2), name='block3_pool')(x)


#---- coarse branch 2 ----
coarse2 = Flatten(name='c2_flatten')(x)
coarse2 = Dense(512, name='c2_fc_1')(coarse2)
coarse2 = BatchNormalization()(coarse2)
coarse2 = Activation('relu')(coarse2)
coarse2 = Dropout(0.5)(coarse2)

coarse2 = Dense(512, name='c2_fc_2')(coarse2)
coarse2 = BatchNormalization()(coarse2)
coarse2 = Activation('relu')(coarse2)
coarse2 = Dropout(0.5)(coarse2)

coarse_pred2 = Dense(num_classes_coarse2, activation='softmax', name='predictions_coarse2')(coarse2)


x = Conv2D(512, (3, 3), activation='relu', name='block1_conv7', padding='same')(x)
x = BatchNormalization()(x)
x = Conv2D(512, (3, 3), activation='relu', name='block1_conv8', padding='same')(x)
x = BatchNormalization()(x)


x = Flatten(name='flatten')(x)
x = Dense(1024, name='fc_1')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = Dropout(0.5)(x)

x = Dense(1024, name='fc_2')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = Dropout(0.5)(x)


fine_pred = Dense(num_classes_fine, activation='softmax', name='predictions_fine')(x)

# %%
model = Model(inputs=img_input, outputs= [coarse_pred1, coarse_pred2, fine_pred], name='branch_net')

model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 32, 32, 64)   1792        input[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 32, 32, 64)   256         block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 32, 32, 64)   36928       batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 32, 32, 64)   256         block1_conv2[0][0]
# __________________________________________________________________________________________________
# block1_pool (MaxPooling2D)      (None, 16, 16, 64)   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# block1_conv3 (Conv2D)           (None, 16, 16, 128)  73856       block1_pool[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 16, 16, 128)  512         block1_conv3[0][0]
# __________________________________________________________________________________________________
# block1_conv4 (Conv2D)           (None, 16, 16, 128)  147584      batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 16, 16, 128)  512         block1_conv4[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 8, 8, 128)    0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# block1_conv5 (Conv2D)           (None, 8, 8, 256)    295168      block2_pool[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 8, 8, 256)    1024        block1_conv5[0][0]
# __________________________________________________________________________________________________
# block1_conv6 (Conv2D)           (None, 8, 8, 256)    590080      batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 8, 8, 256)    1024        block1_conv6[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 4, 4, 256)    0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# block1_conv7 (Conv2D)           (None, 4, 4, 512)    1180160     block3_pool[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 4, 4, 512)    2048        block1_conv7[0][0]
# __________________________________________________________________________________________________
# block1_conv8 (Conv2D)           (None, 4, 4, 512)    2359808     batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 4, 4, 512)    2048        block1_conv8[0][0]
# __________________________________________________________________________________________________
# c1_flatten (Flatten)            (None, 8192)         0           block2_pool[0][0]
# __________________________________________________________________________________________________
# c2_flatten (Flatten)            (None, 4096)         0           block3_pool[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 8192)         0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# c1_fc_1 (Dense)                 (None, 256)          2097408     c1_flatten[0][0]
# __________________________________________________________________________________________________
# c2_fc_1 (Dense)                 (None, 512)          2097664     c2_flatten[0][0]
# __________________________________________________________________________________________________
# fc_1 (Dense)                    (None, 1024)         8389632     flatten[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 256)          1024        c1_fc_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 512)          2048        c2_fc_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 1024)         4096        fc_1[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 256)          0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 512)          0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 1024)         0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 256)          0           activation_7[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 512)          0           activation_9[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 1024)         0           activation_11[0][0]
# __________________________________________________________________________________________________
# c1_fc_2 (Dense)                 (None, 256)          65792       dropout_7[0][0]
# __________________________________________________________________________________________________
# c2_fc_2 (Dense)                 (None, 512)          262656      dropout_9[0][0]
# __________________________________________________________________________________________________
# fc_2 (Dense)                    (None, 1024)         1049600     dropout_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 256)          1024        c1_fc_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 512)          2048        c2_fc_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 1024)         4096        fc_2[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 256)          0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 512)          0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 1024)         0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 256)          0           activation_8[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 512)          0           activation_10[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 1024)         0           activation_12[0][0]
# __________________________________________________________________________________________________
# predictions_coarse1 (Dense)     (None, 9)            2313        dropout_8[0][0]
# __________________________________________________________________________________________________
# predictions_coarse2 (Dense)     (None, 19)           9747        dropout_10[0][0]
# __________________________________________________________________________________________________
# predictions_fine (Dense)        (None, 100)          102500      dropout_12[0][0]
# ==================================================================================================
# Total params: 18,784,704
# Trainable params: 18,773,696
# Non-trainable params: 11,008
# __________________________________________________________________________________________________

# %%
alpha = K.variable(value=0.9, dtype="float32", name="alpha") 
beta = K.variable(value=0.1, dtype="float32", name="beta") 
gamma = K.variable(value=0, dtype="float32", name="gamma") 

sgd = optimizers.SGD(lr=0.001, momentum=0.9, nesterov=True)

model.compile(loss='categorical_crossentropy', 
              optimizer=sgd,
              loss_weights=[alpha, beta, gamma],
              metrics=['accuracy'])

# %%
clr_cb = ReduceLROnPlateau(monitor='val_predictions_fine_loss', factor=0.5, patience=10, verbose=1, min_lr=3.125e-05)
time_cb = TimingCallback()
change_lw = LossWeightsModifier3Vars(alpha, beta, gamma)
csv_cb = CSVLogger('drive/TCC-ITAU/cifar-100/training-data/branch-net/branch-net.csv', separator=',', append=False)


cbks = [clr_cb, time_cb, change_lw, csv_cb]

# %%
epochs = 50
start_time = time()
training = model.fit(train_features, [y_train_c_cat1, y_train_c_cat2, y_train_cat],
                     validation_data=(vali_features, [y_val_c_cat1, y_val_c_cat2, y_val_cat]),
                     epochs=epochs,
                     batch_size=256, 
                     callbacks=cbks,
                     verbose=1)
training_time = time() - start_time
# Out:
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/50
# 45000/45000 [==============================] - 46s 1ms/step - loss: 2.2686 - predictions_coarse1_loss: 2.1316 - predictions_coarse2_loss: 3.5014 - predictions_fine_loss: 5.4688 - predictions_coarse1_acc: 0.3026 - predictions_coarse2_acc: 0.0735 - predictions_fine_acc: 0.0107 - val_loss: 1.8130 - val_predictions_coarse1_loss: 1.7105 - val_predictions_coarse2_loss: 2.7357 - val_predictions_fine_loss: 4.8752 - val_predictions_coarse1_acc: 0.4328 - val_predictions_coarse2_acc: 0.1638 - val_predictions_fine_acc: 0.0076
# Epoch 2/50
# 45000/45000 [==============================] - 36s 805us/step - loss: 1.9289 - predictions_coarse1_loss: 1.8004 - predictions_coarse2_loss: 3.0857 - predictions_fine_loss: 5.4723 - predictions_coarse1_acc: 0.3999 - predictions_coarse2_acc: 0.1265 - predictions_fine_acc: 0.0098 - val_loss: 1.6777 - val_predictions_coarse1_loss: 1.5779 - val_predictions_coarse2_loss: 2.5758 - val_predictions_fine_loss: 4.8212 - val_predictions_coarse1_acc: 0.4812 - val_predictions_coarse2_acc: 0.2258 - val_predictions_fine_acc: 0.0088
# Epoch 3/50
# 45000/45000 [==============================] - 36s 805us/step - loss: 1.8027 - predictions_coarse1_loss: 1.6800 - predictions_coarse2_loss: 2.9072 - predictions_fine_loss: 5.4668 - predictions_coarse1_acc: 0.4385 - predictions_coarse2_acc: 0.1600 - predictions_fine_acc: 0.0104 - val_loss: 1.6226 - val_predictions_coarse1_loss: 1.5274 - val_predictions_coarse2_loss: 2.4796 - val_predictions_fine_loss: 4.8097 - val_predictions_coarse1_acc: 0.4880 - val_predictions_coarse2_acc: 0.2492 - val_predictions_fine_acc: 0.0096
# Epoch 4/50
# 45000/45000 [==============================] - 36s 802us/step - loss: 1.7256 - predictions_coarse1_loss: 1.6055 - predictions_coarse2_loss: 2.8064 - predictions_fine_loss: 5.4677 - predictions_coarse1_acc: 0.4606 - predictions_coarse2_acc: 0.1840 - predictions_fine_acc: 0.0100 - val_loss: 1.5733 - val_predictions_coarse1_loss: 1.4788 - val_predictions_coarse2_loss: 2.4240 - val_predictions_fine_loss: 4.8078 - val_predictions_coarse1_acc: 0.4980 - val_predictions_coarse2_acc: 0.2640 - val_predictions_fine_acc: 0.0092
# Epoch 32/50
# 45000/45000 [==============================] - 36s 804us/step - loss: 1.7435 - predictions_coarse1_loss: 1.3552 - predictions_coarse2_loss: 1.5747 - predictions_fine_loss: 1.7435 - predictions_coarse1_acc: 0.5422 - predictions_coarse2_acc: 0.4962 - predictions_fine_acc: 0.5289 - val_loss: 2.1124 - val_predictions_coarse1_loss: 1.2187 - val_predictions_coarse2_loss: 1.4947 - val_predictions_fine_loss: 2.1124 - val_predictions_coarse1_acc: 0.5982 - val_predictions_coarse2_acc: 0.5252 - val_predictions_fine_acc: 0.4448
# Epoch 33/50
# 45000/45000 [==============================] - 36s 804us/step - loss: 1.6620 - predictions_coarse1_loss: 1.3547 - predictions_coarse2_loss: 1.5757 - predictions_fine_loss: 1.6620 - predictions_coarse1_acc: 0.5447 - predictions_coarse2_acc: 0.4957 - predictions_fine_acc: 0.5478 - val_loss: 2.0923 - val_predictions_coarse1_loss: 1.2218 - val_predictions_coarse2_loss: 1.5010 - val_predictions_fine_loss: 2.0923 - val_predictions_coarse1_acc: 0.5980 - val_predictions_coarse2_acc: 0.5304 - val_predictions_fine_acc: 0.4510
# Epoch 34/50
# 45000/45000 [==============================] - 36s 806us/step - loss: 1.5732 - predictions_coarse1_loss: 1.3646 - predictions_coarse2_loss: 1.5792 - predictions_fine_loss: 1.5732 - predictions_coarse1_acc: 0.5398 - predictions_coarse2_acc: 0.4947 - predictions_fine_acc: 0.5684 - val_loss: 2.0621 - val_predictions_coarse1_loss: 1.2076 - val_predictions_coarse2_loss: 1.4698 - val_predictions_fine_loss: 2.0621 - val_predictions_coarse1_acc: 0.6020 - val_predictions_coarse2_acc: 0.5358 - val_predictions_fine_acc: 0.4524
# Epoch 35/50
# 45000/45000 [==============================] - 36s 808us/step - loss: 1.4966 - predictions_coarse1_loss: 1.3588 - predictions_coarse2_loss: 1.5790 - predictions_fine_loss: 1.4966 - predictions_coarse1_acc: 0.5430 - predictions_coarse2_acc: 0.4944 - predictions_fine_acc: 0.5907 - val_loss: 2.0189 - val_predictions_coarse1_loss: 1.2157 - val_predictions_coarse2_loss: 1.4697 - val_predictions_fine_loss: 2.0189 - val_predictions_coarse1_acc: 0.5982 - val_predictions_coarse2_acc: 0.5392 - val_predictions_fine_acc: 0.4624
# Epoch 36/50
# 45000/45000 [==============================] - 36s 806us/step - loss: 1.4203 - predictions_coarse1_loss: 1.3617 - predictions_coarse2_loss: 1.5779 - predictions_fine_loss: 1.4203 - predictions_coarse1_acc: 0.5382 - predictions_coarse2_acc: 0.4929 - predictions_fine_acc: 0.6091 - val_loss: 2.0346 - val_predictions_coarse1_loss: 1.2163 - val_predictions_coarse2_loss: 1.4904 - val_predictions_fine_loss: 2.0346 - val_predictions_coarse1_acc: 0.6004 - val_predictions_coarse2_acc: 0.5278 - val_predictions_fine_acc: 0.4648
# Epoch 37/50
# Epoch 43/50
# 45000/45000 [==============================] - 36s 804us/step - loss: 0.8988 - predictions_coarse1_loss: 1.3728 - predictions_coarse2_loss: 1.5795 - predictions_fine_loss: 0.8988 - predictions_coarse1_acc: 0.5346 - predictions_coarse2_acc: 0.4933 - predictions_fine_acc: 0.7534 - val_loss: 1.9509 - val_predictions_coarse1_loss: 1.2218 - val_predictions_coarse2_loss: 1.4702 - val_predictions_fine_loss: 1.9509 - val_predictions_coarse1_acc: 0.5950 - val_predictions_coarse2_acc: 0.5386 - val_predictions_fine_acc: 0.4854
# Epoch 44/50
# 45000/45000 [==============================] - 36s 805us/step - loss: 0.8271 - predictions_coarse1_loss: 1.3662 - predictions_coarse2_loss: 1.5905 - predictions_fine_loss: 0.8271 - predictions_coarse1_acc: 0.5364 - predictions_coarse2_acc: 0.4900 - predictions_fine_acc: 0.7771 - val_loss: 1.9686 - val_predictions_coarse1_loss: 1.2108 - val_predictions_coarse2_loss: 1.4682 - val_predictions_fine_loss: 1.9686 - val_predictions_coarse1_acc: 0.5988 - val_predictions_coarse2_acc: 0.5376 - val_predictions_fine_acc: 0.4896
# Epoch 45/50
# 45000/45000 [==============================] - 36s 805us/step - loss: 0.7692 - predictions_coarse1_loss: 1.3690 - predictions_coarse2_loss: 1.5874 - predictions_fine_loss: 0.7692 - predictions_coarse1_acc: 0.5367 - predictions_coarse2_acc: 0.4880 - predictions_fine_acc: 0.7933 - val_loss: 1.9235 - val_predictions_coarse1_loss: 1.2052 - val_predictions_coarse2_loss: 1.4654 - val_predictions_fine_loss: 1.9235 - val_predictions_coarse1_acc: 0.6028 - val_predictions_coarse2_acc: 0.5444 - val_predictions_fine_acc: 0.4916
# Epoch 46/50
# 45000/45000 [==============================] - 36s 804us/step - loss: 0.7005 - predictions_coarse1_loss: 1.3691 - predictions_coarse2_loss: 1.5888 - predictions_fine_loss: 0.7005 - predictions_coarse1_acc: 0.5381 - predictions_coarse2_acc: 0.4920 - predictions_fine_acc: 0.8168 - val_loss: 1.9415 - val_predictions_coarse1_loss: 1.2170 - val_predictions_coarse2_loss: 1.4696 - val_predictions_fine_loss: 1.9415 - val_predictions_coarse1_acc: 0.5968 - val_predictions_coarse2_acc: 0.5456 - val_predictions_fine_acc: 0.4950
# Epoch 47/50
# 45000/45000 [==============================] - 36s 801us/step - loss: 0.6458 - predictions_coarse1_loss: 1.3704 - predictions_coarse2_loss: 1.5916 - predictions_fine_loss: 0.6458 - predictions_coarse1_acc: 0.5380 - predictions_coarse2_acc: 0.4911 - predictions_fine_acc: 0.8318 - val_loss: 1.9477 - val_predictions_coarse1_loss: 1.2097 - val_predictions_coarse2_loss: 1.4708 - val_predictions_fine_loss: 1.9477 - val_predictions_coarse1_acc: 0.6012 - val_predictions_coarse2_acc: 0.5414 - val_predictions_fine_acc: 0.4896
# Epoch 48/50
# 45000/45000 [==============================] - 36s 804us/step - loss: 0.5941 - predictions_coarse1_loss: 1.3656 - predictions_coarse2_loss: 1.5851 - predictions_fine_loss: 0.5941 - predictions_coarse1_acc: 0.5395 - predictions_coarse2_acc: 0.4912 - predictions_fine_acc: 0.8479 - val_loss: 1.9338 - val_predictions_coarse1_loss: 1.2069 - val_predictions_coarse2_loss: 1.4693 - val_predictions_fine_loss: 1.9338 - val_predictions_coarse1_acc: 0.6008 - val_predictions_coarse2_acc: 0.5450 - val_predictions_fine_acc: 0.4988
# Epoch 49/50
# 45000/45000 [==============================] - 36s 807us/step - loss: 0.5431 - predictions_coarse1_loss: 1.3649 - predictions_coarse2_loss: 1.5820 - predictions_fine_loss: 0.5431 - predictions_coarse1_acc: 0.5411 - predictions_coarse2_acc: 0.4912 - predictions_fine_acc: 0.8634 - val_loss: 1.9405 - val_predictions_coarse1_loss: 1.2102 - val_predictions_coarse2_loss: 1.4613 - val_predictions_fine_loss: 1.9405 - val_predictions_coarse1_acc: 0.6024 - val_predictions_coarse2_acc: 0.5412 - val_predictions_fine_acc: 0.4982
# Epoch 50/50
# 45000/45000 [==============================] - 36s 807us/step - loss: 0.4988 - predictions_coarse1_loss: 1.3696 - predictions_coarse2_loss: 1.5874 - predictions_fine_loss: 0.4988 - predictions_coarse1_acc: 0.5375 - predictions_coarse2_acc: 0.4895 - predictions_fine_acc: 0.8773 - val_loss: 1.9678 - val_predictions_coarse1_loss: 1.2113 - val_predictions_coarse2_loss: 1.4675 - val_predictions_fine_loss: 1.9678 - val_predictions_coarse1_acc: 0.6006 - val_predictions_coarse2_acc: 0.5394 - val_predictions_fine_acc: 0.4842

# %%
model.evaluate(test_features, [y_test_c_cat1,y_test_c_cat2, y_test_cat])
# Out:
# 10000/10000 [==============================] - 6s 588us/step
# [1.918118253326416,
#  1.1909347059249877,
#  1.4400707599639893,
#  1.918118253326416,
#  0.6092,
#  0.5486,
#  0.5031]

# %%
print('Total training time: {}'.format(training_time))
# Out:
# Total training time: 1854.3019461631775

# %%
model.save('drive/TCC-ITAU/cifar-100/models/branch-net.h5')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-4534c86fb40b> in <module>()
# ----> 1 model.save('drive/TCC-ITAU/cifar-100/models/branch-net.h5')
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/network.py in save(self, filepath, overwrite, include_optimizer)
#    1088             raise NotImplementedError
#    1089         from ..models import save_model
# -> 1090         save_model(self, filepath, overwrite, include_optimizer)
#    1091
#    1092     def save_weights(self, filepath, overwrite=True):
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py in save_model(model, filepath, overwrite, include_optimizer)
#     380
#     381     try:
# --> 382         _serialize_model(model, f, include_optimizer)
#     383     finally:
#     384         if opened_new_file:
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py in _serialize_model(model, f, include_optimizer)
#     136                 'sample_weight_mode': model.sample_weight_mode,
#     137                 'loss_weights': model.loss_weights,
# --> 138             }, default=get_json_type).encode('utf8')
#     139             symbolic_weights = getattr(model.optimizer, 'weights')
#     140             if symbolic_weights:
#
# /usr/lib/python3.6/json/__init__.py in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     236         check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     237         separators=separators, default=default, sort_keys=sort_keys,
# --> 238         **kw).encode(obj)
#     239
#     240
#
# /usr/lib/python3.6/json/encoder.py in encode(self, o)
#     197         # exceptions aren't as detailed.  The list call should be roughly
#     198         # equivalent to the PySequence_Fast that ''.join() would do.
# --> 199         chunks = self.iterencode(o, _one_shot=True)
#     200         if not isinstance(chunks, (list, tuple)):
#     201             chunks = list(chunks)
#
# /usr/lib/python3.6/json/encoder.py in iterencode(self, o, _one_shot)
#     255                 self.key_separator, self.item_separator, self.sort_keys,
#     256                 self.skipkeys, _one_shot)
# --> 257         return _iterencode(o, 0)
#     258
#     259 def _make_iterencode(markers, _default, _encoder, _indent, _floatstr,
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py in get_json_type(obj)
#      72             return obj.__name__
#      73
# ---> 74         raise TypeError('Not JSON Serializable: %s' % (obj,))
#      75
#      76     from .. import __version__ as keras_version
#
# TypeError: Not JSON Serializable: <tf.Variable 'alpha_1:0' shape=() dtype=float32_ref>
