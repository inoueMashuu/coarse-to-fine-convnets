# %% [markdown]
# ## Inverse Concat-net

# %%
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse

from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass

# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}

# %%
# !mkdir -p drive
# !google-drive-ocamlfuse drive

# %% [markdown]
# ## Loading the data

# %%
from time import time
import os
import gzip
import numpy as np
from keras.utils import np_utils
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

from keras.datasets import cifar100
# Out:
# Using TensorFlow backend.

# %%
(X_train, y_train), (X_test, y_test) = cifar100.load_data(label_mode='fine')
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, 
                                                  test_size=0.1, 
                                                  random_state=1974,
                                                  stratify = y_train)

# %%
train_features = X_train.reshape(X_train.shape[0], 32, 32, 3)/255
vali_features = X_val.reshape(X_val.shape[0], 32, 32, 3)/255
test_features = X_test.reshape(X_test.shape[0], 32, 32, 3)/255

y_train_cat = np_utils.to_categorical(y_train)
y_val_cat = np_utils.to_categorical(y_val)
y_test_cat = np_utils.to_categorical(y_test)

# %% [markdown]
# ## Defining coarse labels

# %%
dict_coarse2 = {0: 4,  1: 1,  2: 14,  3: 8,  4: 12,  5: 6,  6: 7,  7: 7,  8: 18,  9: 3,  10: 3,
                11: 14,  12: 9,  13: 18,  14: 7,  15: 11,  16: 3,  17: 9,  18: 7,  19: 11,  20: 6,
                21: 11,  22: 5,  23: 10,  24: 7,  25: 6,  26: 13,  27: 15,  28: 3,  29: 15,  30: 0,
                31: 11,  32: 1,  33: 10,  34: 12,  35: 14,  36: 16,  37: 9,  38: 11,  39: 5,  40: 5,
                41: 18,  42: 8,  43: 8,  44: 15,  45: 13,  46: 14,  47: 17,  48: 18,  49: 10,  50: 16,
                51: 4,  52: 17,  53: 4,  54: 2,  55: 12,  56: 17,  57: 4,  58: 18,  59: 17,  60: 10,
                61: 3,  62: 2,  63: 12,  64: 12,  65: 16,  66: 12,  67: 1,  68: 9,  69: 18,  70: 2,
                71: 10,  72: 12,  73: 1,  74: 16,  75: 12,  76: 9,  77: 13,  78: 15,  79: 13,  80: 16,
                81: 18,  82: 2,  83: 4,  84: 6,  85: 18,  86: 5,  87: 5,  88: 8,  89: 18,  90: 18,
                91: 1,  92: 2,  93: 15,  94: 6,  95: 0,  96: 17,  97: 8,  98: 14,  99: 13}


dict_coarse1 = {0: 0,
              1: 0,
              2: 1,
              3: 2,
              4: 1,
              5: 2,
              6: 2,
              7: 3,
              8: 4,
              9: 5,
              10: 5,
              11: 4,
              12: 4,
              13: 3,
              14: 6,
              15: 7,
              16: 4,
              17: 1,
              18: 8}

y_train_coarse2 = np.vectorize(dict_coarse2.get)(y_train)
y_val_coarse2 = np.vectorize(dict_coarse2.get)(y_val)
y_test_coarse2 = np.vectorize(dict_coarse2.get)(y_test)

y_train_coarse1 = np.vectorize(dict_coarse1.get)(y_train_coarse2)
y_val_coarse1 = np.vectorize(dict_coarse1.get)(y_val_coarse2)
y_test_coarse1 = np.vectorize(dict_coarse1.get)(y_test_coarse2)


y_train_c_cat1 = np_utils.to_categorical(y_train_coarse1)
y_val_c_cat1 = np_utils.to_categorical(y_val_coarse1)
y_test_c_cat1 = np_utils.to_categorical(y_test_coarse1)

y_train_c_cat2 = np_utils.to_categorical(y_train_coarse2)
y_val_c_cat2 = np_utils.to_categorical(y_val_coarse2)
y_test_c_cat2 = np_utils.to_categorical(y_test_coarse2)

# %% [markdown]
# ## Training the model

# %%
import keras
from keras.models import Model
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D, Input
from keras import optimizers
from keras.callbacks import TensorBoard, ReduceLROnPlateau, CSVLogger
from keras.layers.normalization import BatchNormalization
from keras import backend as K

# %%
class TimingCallback(keras.callbacks.Callback):
  """Callback that saves the time elapsed of each epoch to the log.
  """  
  def on_epoch_begin(self, epoch, logs={}):
    self.starttime=time()
  def on_epoch_end(self, epoch, logs={}):
    logs['time_elapsed'] = (time()-self.starttime)

# %%
class LossWeightsModifier3Vars(keras.callbacks.Callback):
  """Callback that modifies the loss weights on certain epochs.
    # Arguments
        alpha: coeficient for the coarser class.
        beta: coeficient for the second level coarse class.
        gamma: coeficient for the fine class.
  """  
  def __init__(self, alpha, beta, gamma):
    self.alpha = alpha
    self.beta = beta
    self.gamma = gamma
    
  def on_epoch_end(self, epoch, logs={}):

    if epoch == 4:
      K.set_value(self.alpha, 0.6)
      K.set_value(self.beta, 0.35)
      K.set_value(self.gamma, 0.05)
      print('Changing loss weights to: coarse1 = {}, coarse2 = {}, fine = {}'.format(K.eval(self.alpha), K.eval(self.beta), K.eval(self.gamma)))
    
    if epoch == 9:
      K.set_value(self.alpha, 0)
      K.set_value(self.beta, 0.8)
      K.set_value(self.gamma, 0.2)
      print('Changing loss weights to: coarse1 = {}, coarse2 = {}, fine = {}'.format(K.eval(self.alpha), K.eval(self.beta), K.eval(self.gamma)))
      
    if epoch == 14:
      K.set_value(self.alpha, 0)
      K.set_value(self.beta, 0.4)
      K.set_value(self.gamma, 0.6)  
      print('Changing loss weights to: coarse1 = {}, coarse2 = {}, fine = {}'.format(K.eval(self.alpha), K.eval(self.beta), K.eval(self.gamma)))
  
    if epoch == 21:
      K.set_value(self.alpha, 0)
      K.set_value(self.beta, 0)
      K.set_value(self.gamma, 1)  
      print('Changing loss weights to: coarse1 = {}, coarse2 = {}, fine = {}'.format(K.eval(self.alpha), K.eval(self.beta), K.eval(self.gamma)))
  
    logs['alpha'] = K.eval(self.alpha)
    logs['beta'] = K.eval(self.beta) 
    logs['gamma'] = K.eval(self.gamma)

# %%
img_rows, img_cols = 32, 32
input_shape = (img_rows, img_cols, 3)

num_classes_coarse1 = 9
num_classes_coarse2 = 19
num_classes_fine = 100

img_input = Input(shape=input_shape, name='input')



x = Conv2D(64, (3, 3), activation='relu', name='block1_conv1', padding='same')(img_input)
x = BatchNormalization()(x)
x = Conv2D(64, (3, 3), activation='relu', name='block1_conv2', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2), name='block1_pool')(x)

x = Conv2D(128, (3, 3), activation='relu', name='block1_conv3', padding='same')(x)
x = BatchNormalization()(x)
x = Conv2D(128, (3, 3), activation='relu', name='block1_conv4', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2), name='block2_pool')(x)


#---- coarse branch 1 ----
coarse1 = Flatten(name='c1_flatten')(x)
coarse1 = Dense(256, name='c1_fc_1')(coarse1)
coarse1 = BatchNormalization()(coarse1)
coarse1 = Activation('relu')(coarse1)
coarse1 = Dropout(0.5)(coarse1)

coarse1 = Dense(256, name='c1_fc_2')(coarse1)
coarse1 = BatchNormalization()(coarse1)
coarse1 = Activation('relu')(coarse1)
coarse1 = Dropout(0.5)(coarse1)


x = Conv2D(256, (3, 3), activation='relu', name='block1_conv5', padding='same')(x)
x = BatchNormalization()(x)
x = Conv2D(256, (3, 3), activation='relu', name='block1_conv6', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2), name='block3_pool')(x)


#---- coarse branch 2 ----
coarse2 = Flatten(name='c2_flatten')(x)
coarse2 = Dense(512, name='c2_fc_1')(coarse2)
coarse2 = BatchNormalization()(coarse2)
coarse2 = Activation('relu')(coarse2)
coarse2 = Dropout(0.5)(coarse2)

coarse2 = Dense(512, name='c2_fc_2')(coarse2)
coarse2 = BatchNormalization()(coarse2)
coarse2 = Activation('relu')(coarse2)
coarse2 = Dropout(0.5)(coarse2)


x = Conv2D(512, (3, 3), activation='relu', name='block1_conv7', padding='same')(x)
x = BatchNormalization()(x)
x = Conv2D(512, (3, 3), activation='relu', name='block1_conv8', padding='same')(x)
x = BatchNormalization()(x)


x = Flatten(name='flatten')(x)
x = Dense(1024, name='fc_1')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = Dropout(0.5)(x)

x = Dense(1024, name='fc_2')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = Dropout(0.5)(x)

fine_pred = Dense(num_classes_fine, activation='softmax', name='predictions_fine')(x)

coarse2 = keras.layers.concatenate([coarse2, x])
coarse_pred2 = Dense(num_classes_coarse2, activation='softmax', name='predictions_coarse2')(coarse2)

coarse1 = keras.layers.concatenate([coarse1, coarse2])
coarse_pred1 = Dense(num_classes_coarse1, activation='softmax', name='predictions_coarse1')(coarse1)

# %%
model = Model(inputs=img_input, outputs= [coarse_pred1, coarse_pred2, fine_pred], name='inverse_concat_net')

model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 32, 32, 64)   1792        input[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 64)   256         block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 32, 32, 64)   36928       batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 64)   256         block1_conv2[0][0]
# __________________________________________________________________________________________________
# block1_pool (MaxPooling2D)      (None, 16, 16, 64)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# block1_conv3 (Conv2D)           (None, 16, 16, 128)  73856       block1_pool[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 16, 16, 128)  512         block1_conv3[0][0]
# __________________________________________________________________________________________________
# block1_conv4 (Conv2D)           (None, 16, 16, 128)  147584      batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 16, 16, 128)  512         block1_conv4[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 8, 8, 128)    0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# block1_conv5 (Conv2D)           (None, 8, 8, 256)    295168      block2_pool[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 8, 8, 256)    1024        block1_conv5[0][0]
# __________________________________________________________________________________________________
# block1_conv6 (Conv2D)           (None, 8, 8, 256)    590080      batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 8, 8, 256)    1024        block1_conv6[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 4, 4, 256)    0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# block1_conv7 (Conv2D)           (None, 4, 4, 512)    1180160     block3_pool[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 4, 4, 512)    2048        block1_conv7[0][0]
# __________________________________________________________________________________________________
# block1_conv8 (Conv2D)           (None, 4, 4, 512)    2359808     batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 4, 4, 512)    2048        block1_conv8[0][0]
# __________________________________________________________________________________________________
# c2_flatten (Flatten)            (None, 4096)         0           block3_pool[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 8192)         0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# c1_flatten (Flatten)            (None, 8192)         0           block2_pool[0][0]
# __________________________________________________________________________________________________
# c2_fc_1 (Dense)                 (None, 512)          2097664     c2_flatten[0][0]
# __________________________________________________________________________________________________
# fc_1 (Dense)                    (None, 1024)         8389632     flatten[0][0]
# __________________________________________________________________________________________________
# c1_fc_1 (Dense)                 (None, 256)          2097408     c1_flatten[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 512)          2048        c2_fc_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 1024)         4096        fc_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 256)          1024        c1_fc_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 512)          0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 1024)         0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 256)          0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 512)          0           activation_3[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 1024)         0           activation_5[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 256)          0           activation_1[0][0]
# __________________________________________________________________________________________________
# c2_fc_2 (Dense)                 (None, 512)          262656      dropout_3[0][0]
# __________________________________________________________________________________________________
# fc_2 (Dense)                    (None, 1024)         1049600     dropout_5[0][0]
# __________________________________________________________________________________________________
# c1_fc_2 (Dense)                 (None, 256)          65792       dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 512)          2048        c2_fc_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 1024)         4096        fc_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 256)          1024        c1_fc_2[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 512)          0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 1024)         0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 256)          0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 512)          0           activation_4[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 1024)         0           activation_6[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 256)          0           activation_2[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 1536)         0           dropout_4[0][0]
#                                                                  dropout_6[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 1792)         0           dropout_2[0][0]
#                                                                  concatenate_1[0][0]
# __________________________________________________________________________________________________
# predictions_coarse1 (Dense)     (None, 9)            16137       concatenate_2[0][0]
# __________________________________________________________________________________________________
# predictions_coarse2 (Dense)     (None, 19)           29203       concatenate_1[0][0]
# __________________________________________________________________________________________________
# predictions_fine (Dense)        (None, 100)          102500      dropout_6[0][0]
# ==================================================================================================
# Total params: 18,817,984
# Trainable params: 18,806,976
# Non-trainable params: 11,008
# __________________________________________________________________________________________________

# %%
alpha = K.variable(value=0.9, dtype="float32", name="alpha") 
beta = K.variable(value=0.1, dtype="float32", name="beta") 
gamma = K.variable(value=0, dtype="float32", name="gamma") 

sgd = optimizers.SGD(lr=0.001, momentum=0.9, nesterov=True)

model.compile(loss='categorical_crossentropy', 
              optimizer=sgd,
              loss_weights=[alpha, beta, gamma],
              metrics=['accuracy'])

# %%
clr_cb = ReduceLROnPlateau(monitor='val_predictions_fine_loss', factor=0.5, patience=10, verbose=1, min_lr=3.125e-05)
time_cb = TimingCallback()
change_lw = LossWeightsModifier3Vars(alpha, beta, gamma)
csv_cb = CSVLogger('drive/TCC-ITAU/cifar-100/training-data/concat-net/inverse-concat-net.csv', separator=',', append=False)


cbks = [clr_cb, time_cb, change_lw, csv_cb]

# %%
epochs = 50
start_time = time()
training = model.fit(train_features, [y_train_c_cat1, y_train_c_cat2, y_train_cat],
                     validation_data=(vali_features, [y_val_c_cat1, y_val_c_cat2, y_val_cat]),
                     epochs=epochs,
                     batch_size=256, 
                     callbacks=cbks,
                     verbose=1)
training_time = time() - start_time
# Out:
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/50
# 45000/45000 [==============================] - 45s 1ms/step - loss: 2.2261 - predictions_coarse1_loss: 2.0959 - predictions_coarse2_loss: 3.3982 - predictions_fine_loss: 5.4538 - predictions_coarse1_acc: 0.3289 - predictions_coarse2_acc: 0.0854 - predictions_fine_acc: 0.0103 - val_loss: 1.7556 - val_predictions_coarse1_loss: 1.6510 - val_predictions_coarse2_loss: 2.6969 - val_predictions_fine_loss: 4.9402 - val_predictions_coarse1_acc: 0.4540 - val_predictions_coarse2_acc: 0.1828 - val_predictions_fine_acc: 0.0076
# Epoch 2/50
# 45000/45000 [==============================] - 37s 815us/step - loss: 1.8293 - predictions_coarse1_loss: 1.7040 - predictions_coarse2_loss: 2.9565 - predictions_fine_loss: 5.4073 - predictions_coarse1_acc: 0.4377 - predictions_coarse2_acc: 0.1525 - predictions_fine_acc: 0.0103 - val_loss: 1.6297 - val_predictions_coarse1_loss: 1.5321 - val_predictions_coarse2_loss: 2.5078 - val_predictions_fine_loss: 4.8969 - val_predictions_coarse1_acc: 0.4864 - val_predictions_coarse2_acc: 0.2470 - val_predictions_fine_acc: 0.0072
# Epoch 3/50
# 45000/45000 [==============================] - 37s 827us/step - loss: 1.6605 - predictions_coarse1_loss: 1.5396 - predictions_coarse2_loss: 2.7483 - predictions_fine_loss: 5.3908 - predictions_coarse1_acc: 0.4890 - predictions_coarse2_acc: 0.1989 - predictions_fine_acc: 0.0099 - val_loss: 1.5539 - val_predictions_coarse1_loss: 1.4630 - val_predictions_coarse2_loss: 2.3718 - val_predictions_fine_loss: 4.8536 - val_predictions_coarse1_acc: 0.5080 - val_predictions_coarse2_acc: 0.2878 - val_predictions_fine_acc: 0.0096
# Epoch 4/50
# Epoch 21/50
# 45000/45000 [==============================] - 37s 820us/step - loss: 1.9434 - predictions_coarse1_loss: 0.7907 - predictions_coarse2_loss: 1.1156 - predictions_fine_loss: 2.4953 - predictions_coarse1_acc: 0.7364 - predictions_coarse2_acc: 0.6328 - predictions_fine_acc: 0.3440 - val_loss: 2.0638 - val_predictions_coarse1_loss: 0.9472 - val_predictions_coarse2_loss: 1.4138 - val_predictions_fine_loss: 2.4971 - val_predictions_coarse1_acc: 0.6888 - val_predictions_coarse2_acc: 0.5660 - val_predictions_fine_acc: 0.3730
# Epoch 22/50
# 45000/45000 [==============================] - 37s 822us/step - loss: 1.8493 - predictions_coarse1_loss: 0.7682 - predictions_coarse2_loss: 1.0605 - predictions_fine_loss: 2.3752 - predictions_coarse1_acc: 0.7462 - predictions_coarse2_acc: 0.6445 - predictions_fine_acc: 0.3667 - val_loss: 2.0347 - val_predictions_coarse1_loss: 0.9714 - val_predictions_coarse2_loss: 1.4013 - val_predictions_fine_loss: 2.4570 - val_predictions_coarse1_acc: 0.6762 - val_predictions_coarse2_acc: 0.5720 - val_predictions_fine_acc: 0.3804
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.0, fine = 1.0
# Epoch 23/50
# 45000/45000 [==============================] - 37s 817us/step - loss: 2.2929 - predictions_coarse1_loss: 0.7759 - predictions_coarse2_loss: 1.0602 - predictions_fine_loss: 2.2929 - predictions_coarse1_acc: 0.7432 - predictions_coarse2_acc: 0.6485 - predictions_fine_acc: 0.3840 - val_loss: 2.3755 - val_predictions_coarse1_loss: 0.9429 - val_predictions_coarse2_loss: 1.4086 - val_predictions_fine_loss: 2.3755 - val_predictions_coarse1_acc: 0.6906 - val_predictions_coarse2_acc: 0.5712 - val_predictions_fine_acc: 0.3938
# Epoch 24/50
# 45000/45000 [==============================] - 37s 821us/step - loss: 2.1697 - predictions_coarse1_loss: 0.7742 - predictions_coarse2_loss: 1.0553 - predictions_fine_loss: 2.1697 - predictions_coarse1_acc: 0.7436 - predictions_coarse2_acc: 0.6480 - predictions_fine_acc: 0.4114 - val_loss: 2.3112 - val_predictions_coarse1_loss: 0.9470 - val_predictions_coarse2_loss: 1.3755 - val_predictions_fine_loss: 2.3112 - val_predictions_coarse1_acc: 0.6902 - val_predictions_coarse2_acc: 0.5716 - val_predictions_fine_acc: 0.4064
# Epoch 25/50
# 45000/45000 [==============================] - 37s 821us/step - loss: 2.0551 - predictions_coarse1_loss: 0.7661 - predictions_coarse2_loss: 1.0407 - predictions_fine_loss: 2.0551 - predictions_coarse1_acc: 0.7492 - predictions_coarse2_acc: 0.6545 - predictions_fine_acc: 0.4375 - val_loss: 2.3482 - val_predictions_coarse1_loss: 1.0060 - val_predictions_coarse2_loss: 1.4349 - val_predictions_fine_loss: 2.3482 - val_predictions_coarse1_acc: 0.6646 - val_predictions_coarse2_acc: 0.5630 - val_predictions_fine_acc: 0.3974
# Epoch 26/50
# 45000/45000 [==============================] - 36s 810us/step - loss: 0.3531 - predictions_coarse1_loss: 0.5826 - predictions_coarse2_loss: 0.6112 - predictions_fine_loss: 0.3531 - predictions_coarse1_acc: 0.8312 - predictions_coarse2_acc: 0.8157 - predictions_fine_acc: 0.9207 - val_loss: 2.1881 - val_predictions_coarse1_loss: 0.9852 - val_predictions_coarse2_loss: 1.3665 - val_predictions_fine_loss: 2.1881 - val_predictions_coarse1_acc: 0.6880 - val_predictions_coarse2_acc: 0.5804 - val_predictions_fine_acc: 0.4566
# Epoch 49/50
# 45000/45000 [==============================] - 36s 808us/step - loss: 0.3327 - predictions_coarse1_loss: 0.5796 - predictions_coarse2_loss: 0.6071 - predictions_fine_loss: 0.3327 - predictions_coarse1_acc: 0.8344 - predictions_coarse2_acc: 0.8190 - predictions_fine_acc: 0.9263 - val_loss: 2.1841 - val_predictions_coarse1_loss: 0.9682 - val_predictions_coarse2_loss: 1.3565 - val_predictions_fine_loss: 2.1841 - val_predictions_coarse1_acc: 0.6860 - val_predictions_coarse2_acc: 0.5842 - val_predictions_fine_acc: 0.4560
# Epoch 50/50
# 45000/45000 [==============================] - 36s 809us/step - loss: 0.3126 - predictions_coarse1_loss: 0.5799 - predictions_coarse2_loss: 0.6012 - predictions_fine_loss: 0.3126 - predictions_coarse1_acc: 0.8331 - predictions_coarse2_acc: 0.8201 - predictions_fine_acc: 0.9329 - val_loss: 2.1888 - val_predictions_coarse1_loss: 0.9710 - val_predictions_coarse2_loss: 1.3608 - val_predictions_fine_loss: 2.1888 - val_predictions_coarse1_acc: 0.6864 - val_predictions_coarse2_acc: 0.5818 - val_predictions_fine_acc: 0.4626

# %%
model.evaluate(test_features, [y_test_c_cat1,y_test_c_cat2, y_test_cat])
# Out:
# 10000/10000 [==============================] - 6s 592us/step
# [2.0839604093551634,
#  0.9413713696479797,
#  1.320653528213501,
#  2.0839604093551634,
#  0.6954,
#  0.5863,
#  0.4815]

# %%
print('Total training time: {}'.format(training_time))
# Out:
# Total training time: 1885.0631728172302

# %%
model.save('drive/TCC-ITAU/cifar-100/models/inverse-concat-net.h5')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-777d8179dc12> in <module>()
# ----> 1 model.save('drive/TCC-ITAU/cifar-100/models/inverse-concat-net.h5')
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/network.py in save(self, filepath, overwrite, include_optimizer)
#    1088             raise NotImplementedError
#    1089         from ..models import save_model
# -> 1090         save_model(self, filepath, overwrite, include_optimizer)
#    1091
#    1092     def save_weights(self, filepath, overwrite=True):
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py in save_model(model, filepath, overwrite, include_optimizer)
#     380
#     381     try:
# --> 382         _serialize_model(model, f, include_optimizer)
#     383     finally:
#     384         if opened_new_file:
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py in _serialize_model(model, f, include_optimizer)
#     136                 'sample_weight_mode': model.sample_weight_mode,
#     137                 'loss_weights': model.loss_weights,
# --> 138             }, default=get_json_type).encode('utf8')
#     139             symbolic_weights = getattr(model.optimizer, 'weights')
#     140             if symbolic_weights:
#
# /usr/lib/python3.6/json/__init__.py in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     236         check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     237         separators=separators, default=default, sort_keys=sort_keys,
# --> 238         **kw).encode(obj)
#     239
#     240
#
# /usr/lib/python3.6/json/encoder.py in encode(self, o)
#     197         # exceptions aren't as detailed.  The list call should be roughly
#     198         # equivalent to the PySequence_Fast that ''.join() would do.
# --> 199         chunks = self.iterencode(o, _one_shot=True)
#     200         if not isinstance(chunks, (list, tuple)):
#     201             chunks = list(chunks)
#
# /usr/lib/python3.6/json/encoder.py in iterencode(self, o, _one_shot)
#     255                 self.key_separator, self.item_separator, self.sort_keys,
#     256                 self.skipkeys, _one_shot)
# --> 257         return _iterencode(o, 0)
#     258
#     259 def _make_iterencode(markers, _default, _encoder, _indent, _floatstr,
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py in get_json_type(obj)
#      72             return obj.__name__
#      73
# ---> 74         raise TypeError('Not JSON Serializable: %s' % (obj,))
#      75
#      76     from .. import __version__ as keras_version
#
# TypeError: Not JSON Serializable: <tf.Variable 'alpha:0' shape=() dtype=float32_ref>
