# %% [markdown]
# ## Split-net

# %%
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse

from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass

# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}

# %%
# !mkdir -p drive
# !google-drive-ocamlfuse drive
# Out:
# fuse: mountpoint is not empty
# fuse: if you are sure this is safe, use the 'nonempty' mount option

# %% [markdown]
# ## Loading the data

# %%
from time import time
import os
import gzip
import numpy as np
from keras.utils import np_utils
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

from keras.datasets import cifar100
# Out:
# Using TensorFlow backend.

# %%
(X_train, y_train), (X_test, y_test) = cifar100.load_data(label_mode='fine')
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, 
                                                  test_size=0.1, 
                                                  random_state=1974,
                                                  stratify = y_train)

# %%
train_features = X_train.reshape(X_train.shape[0], 32, 32, 3)/255
vali_features = X_val.reshape(X_val.shape[0], 32, 32, 3)/255
test_features = X_test.reshape(X_test.shape[0], 32, 32, 3)/255

y_train_cat = np_utils.to_categorical(y_train)
y_val_cat = np_utils.to_categorical(y_val)
y_test_cat = np_utils.to_categorical(y_test)

# %% [markdown]
# ## Defining coarse labels

# %%
dict_coarse2 = {0: 4,  1: 1,  2: 14,  3: 8,  4: 12,  5: 6,  6: 7,  7: 7,  8: 18,  9: 3,  10: 3,
                11: 14,  12: 9,  13: 18,  14: 7,  15: 11,  16: 3,  17: 9,  18: 7,  19: 11,  20: 6,
                21: 11,  22: 5,  23: 10,  24: 7,  25: 6,  26: 13,  27: 15,  28: 3,  29: 15,  30: 0,
                31: 11,  32: 1,  33: 10,  34: 12,  35: 14,  36: 16,  37: 9,  38: 11,  39: 5,  40: 5,
                41: 18,  42: 8,  43: 8,  44: 15,  45: 13,  46: 14,  47: 17,  48: 18,  49: 10,  50: 16,
                51: 4,  52: 17,  53: 4,  54: 2,  55: 12,  56: 17,  57: 4,  58: 18,  59: 17,  60: 10,
                61: 3,  62: 2,  63: 12,  64: 12,  65: 16,  66: 12,  67: 1,  68: 9,  69: 18,  70: 2,
                71: 10,  72: 12,  73: 1,  74: 16,  75: 12,  76: 9,  77: 13,  78: 15,  79: 13,  80: 16,
                81: 18,  82: 2,  83: 4,  84: 6,  85: 18,  86: 5,  87: 5,  88: 8,  89: 18,  90: 18,
                91: 1,  92: 2,  93: 15,  94: 6,  95: 0,  96: 17,  97: 8,  98: 14,  99: 13}


dict_coarse1 = {0: 0,
              1: 0,
              2: 1,
              3: 2,
              4: 1,
              5: 2,
              6: 2,
              7: 3,
              8: 4,
              9: 5,
              10: 5,
              11: 4,
              12: 4,
              13: 3,
              14: 6,
              15: 7,
              16: 4,
              17: 1,
              18: 8}

y_train_coarse2 = np.vectorize(dict_coarse2.get)(y_train)
y_val_coarse2 = np.vectorize(dict_coarse2.get)(y_val)
y_test_coarse2 = np.vectorize(dict_coarse2.get)(y_test)

y_train_coarse1 = np.vectorize(dict_coarse1.get)(y_train_coarse2)
y_val_coarse1 = np.vectorize(dict_coarse1.get)(y_val_coarse2)
y_test_coarse1 = np.vectorize(dict_coarse1.get)(y_test_coarse2)


y_train_c_cat1 = np_utils.to_categorical(y_train_coarse1)
y_val_c_cat1 = np_utils.to_categorical(y_val_coarse1)
y_test_c_cat1 = np_utils.to_categorical(y_test_coarse1)

y_train_c_cat2 = np_utils.to_categorical(y_train_coarse2)
y_val_c_cat2 = np_utils.to_categorical(y_val_coarse2)
y_test_c_cat2 = np_utils.to_categorical(y_test_coarse2)

# %% [markdown]
# ## Training the model

# %%
import keras
from keras.models import Model
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D, Input
from keras import optimizers
from keras.callbacks import TensorBoard, ReduceLROnPlateau, CSVLogger
from keras.layers.normalization import BatchNormalization
from keras import backend as K

# %%
class TimingCallback(keras.callbacks.Callback):
  """Callback that saves the time elapsed of each epoch to the log.
  """  
  def on_epoch_begin(self, epoch, logs={}):
    self.starttime=time()
  def on_epoch_end(self, epoch, logs={}):
    logs['time_elapsed'] = (time()-self.starttime)

# %%
class LossWeightsModifier3Vars(keras.callbacks.Callback):
  """Callback that modifies the loss weights on certain epochs.
    # Arguments
        alpha: coeficient for the coarser class.
        beta: coeficient for the second level coarse class.
        gamma: coeficient for the fine class.
  """  
  def __init__(self, alpha, beta, gamma):
    self.alpha = alpha
    self.beta = beta
    self.gamma = gamma
    
  def on_epoch_end(self, epoch, logs={}):

    if epoch == 4:
      K.set_value(self.alpha, 0.6)
      K.set_value(self.beta, 0.35)
      K.set_value(self.gamma, 0.05)
      print('Changing loss weights to: coarse1 = {}, coarse2 = {}, fine = {}'.format(K.eval(self.alpha), K.eval(self.beta), K.eval(self.gamma)))
    
    if epoch == 9:
      K.set_value(self.alpha, 0)
      K.set_value(self.beta, 0.8)
      K.set_value(self.gamma, 0.2)
      print('Changing loss weights to: coarse1 = {}, coarse2 = {}, fine = {}'.format(K.eval(self.alpha), K.eval(self.beta), K.eval(self.gamma)))
      
    if epoch == 14:
      K.set_value(self.alpha, 0)
      K.set_value(self.beta, 0.4)
      K.set_value(self.gamma, 0.6)  
      print('Changing loss weights to: coarse1 = {}, coarse2 = {}, fine = {}'.format(K.eval(self.alpha), K.eval(self.beta), K.eval(self.gamma)))
  
    if epoch == 21:
      K.set_value(self.alpha, 0)
      K.set_value(self.beta, 0)
      K.set_value(self.gamma, 1)  
      print('Changing loss weights to: coarse1 = {}, coarse2 = {}, fine = {}'.format(K.eval(self.alpha), K.eval(self.beta), K.eval(self.gamma)))
  
    logs['alpha'] = K.eval(self.alpha)
    logs['beta'] = K.eval(self.beta) 
    logs['gamma'] = K.eval(self.gamma)

# %%
img_rows, img_cols = 32, 32
input_shape = (img_rows, img_cols, 3)

num_classes_coarse1 = 9
num_classes_coarse2 = 19
num_classes_fine = 100

img_input = Input(shape=input_shape, name='input')

x = Conv2D(64, (3, 3), activation='relu', name='block1_conv1', padding='same')(img_input)
x = BatchNormalization()(x)
x = Conv2D(64, (3, 3), activation='relu', name='block1_conv2', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2), name='block1_pool')(x)

x = Conv2D(128, (3, 3), activation='relu', name='block1_conv3', padding='same')(x)
x = BatchNormalization()(x)
x = Conv2D(128, (3, 3), activation='relu', name='block1_conv4', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2), name='block2_pool')(x)

x = Conv2D(256, (3, 3), activation='relu', name='block1_conv5', padding='same')(x)
x = BatchNormalization()(x)
x = Conv2D(256, (3, 3), activation='relu', name='block1_conv6', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2), name='block3_pool')(x)

x = Conv2D(512, (3, 3), activation='relu', name='block1_conv7', padding='same')(x)
x = BatchNormalization()(x)
x = Conv2D(512, (3, 3), activation='relu', name='block1_conv8', padding='same')(x)
x = BatchNormalization()(x)

x = Flatten(name='flatten')(x)
x = Dense(1024, name='fc_1')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = Dropout(0.5)(x)

x = Dense(1024, name='fc_2')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = Dropout(0.5)(x)


coarse_pred1 = Dense(num_classes_coarse1, activation='softmax', name='predictions_coarse1')(x)
coarse_pred2 = Dense(num_classes_coarse2, activation='softmax', name='predictions_coarse2')(x)
fine_pred = Dense(num_classes_fine, activation='softmax', name='predictions_fine')(x)

# %%
model = Model(inputs=img_input, outputs= [coarse_pred1, coarse_pred2, fine_pred], name='split_net')

model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 32, 32, 64)   1792        input[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 64)   256         block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 32, 32, 64)   36928       batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 64)   256         block1_conv2[0][0]
# __________________________________________________________________________________________________
# block1_pool (MaxPooling2D)      (None, 16, 16, 64)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# block1_conv3 (Conv2D)           (None, 16, 16, 128)  73856       block1_pool[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 16, 16, 128)  512         block1_conv3[0][0]
# __________________________________________________________________________________________________
# block1_conv4 (Conv2D)           (None, 16, 16, 128)  147584      batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 16, 16, 128)  512         block1_conv4[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 8, 8, 128)    0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# block1_conv5 (Conv2D)           (None, 8, 8, 256)    295168      block2_pool[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 8, 8, 256)    1024        block1_conv5[0][0]
# __________________________________________________________________________________________________
# block1_conv6 (Conv2D)           (None, 8, 8, 256)    590080      batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 8, 8, 256)    1024        block1_conv6[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 4, 4, 256)    0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# block1_conv7 (Conv2D)           (None, 4, 4, 512)    1180160     block3_pool[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 4, 4, 512)    2048        block1_conv7[0][0]
# __________________________________________________________________________________________________
# block1_conv8 (Conv2D)           (None, 4, 4, 512)    2359808     batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 4, 4, 512)    2048        block1_conv8[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 8192)         0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# fc_1 (Dense)                    (None, 1024)         8389632     flatten[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 1024)         4096        fc_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 1024)         0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 1024)         0           activation_1[0][0]
# __________________________________________________________________________________________________
# fc_2 (Dense)                    (None, 1024)         1049600     dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 1024)         4096        fc_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 1024)         0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 1024)         0           activation_2[0][0]
# __________________________________________________________________________________________________
# predictions_coarse1 (Dense)     (None, 9)            9225        dropout_2[0][0]
# __________________________________________________________________________________________________
# predictions_coarse2 (Dense)     (None, 19)           19475       dropout_2[0][0]
# __________________________________________________________________________________________________
# predictions_fine (Dense)        (None, 100)          102500      dropout_2[0][0]
# ==================================================================================================
# Total params: 14,271,680
# Trainable params: 14,263,744
# Non-trainable params: 7,936
# __________________________________________________________________________________________________

# %%
alpha = K.variable(value=0.9, dtype="float32", name="alpha") 
beta = K.variable(value=0.1, dtype="float32", name="beta") 
gamma = K.variable(value=0, dtype="float32", name="gamma") 

sgd = optimizers.SGD(lr=0.001, momentum=0.9, nesterov=True)

model.compile(loss='categorical_crossentropy', 
              optimizer=sgd,
              loss_weights=[alpha, beta, gamma],
              metrics=['accuracy'])

# %%
clr_cb = ReduceLROnPlateau(monitor='val_predictions_fine_loss', factor=0.5, patience=10, verbose=1, min_lr=3.125e-05)
time_cb = TimingCallback()
change_lw = LossWeightsModifier3Vars(alpha, beta, gamma)
csv_cb = CSVLogger('drive/TCC-ITAU/cifar-100/training-data/split-net.csv', separator=',', append=False)


cbks = [clr_cb, time_cb, change_lw, csv_cb]

# %%
epochs = 50
start_time = time()
training = model.fit(train_features, [y_train_c_cat1, y_train_c_cat2, y_train_cat],
                     validation_data=(vali_features, [y_val_c_cat1, y_val_c_cat2, y_val_cat]),
                     epochs=epochs,
                     batch_size=256, 
                     callbacks=cbks,
                     verbose=1)
training_time = time() - start_time
# Out:
# Train on 45000 samples, validate on 5000 samples
# Epoch 1
# Epoch 17/50
# 45000/45000 [==============================] - 34s 762us/step - loss: 2.4028 - predictions_coarse1_loss: 0.8239 - predictions_coarse2_loss: 1.2529 - predictions_fine_loss: 3.1694 - predictions_coarse1_acc: 0.7261 - predictions_coarse2_acc: 0.5904 - predictions_fine_acc: 0.2224 - val_loss: 2.3711 - val_predictions_coarse1_loss: 1.0467 - val_predictions_coarse2_loss: 1.5292 - val_predictions_fine_loss: 2.9323 - val_predictions_coarse1_acc: 0.6536 - val_predictions_coarse2_acc: 0.5320 - val_predictions_fine_acc: 0.2994
# Epoch 18/50
# 45000/45000 [==============================] - 34s 758us/step - loss: 2.2591 - predictions_coarse1_loss: 0.8050 - predictions_coarse2_loss: 1.2134 - predictions_fine_loss: 2.9563 - predictions_coarse1_acc: 0.7304 - predictions_coarse2_acc: 0.6028 - predictions_fine_acc: 0.2579 - val_loss: 2.2490 - val_predictions_coarse1_loss: 0.9888 - val_predictions_coarse2_loss: 1.4682 - val_predictions_fine_loss: 2.7695 - val_predictions_coarse1_acc: 0.6766 - val_predictions_coarse2_acc: 0.5520 - val_predictions_fine_acc: 0.3264
# Epoch 19/50
# 45000/45000 [==============================] - 34s 753us/step - loss: 2.1385 - predictions_coarse1_loss: 0.7856 - predictions_coarse2_loss: 1.1680 - predictions_fine_loss: 2.7855 - predictions_coarse1_acc: 0.7399 - predictions_coarse2_acc: 0.6161 - predictions_fine_acc: 0.2857 - val_loss: 2.2807 - val_predictions_coarse1_loss: 1.0664 - val_predictions_coarse2_loss: 1.5695 - val_predictions_fine_loss: 2.7548 - val_predictions_coarse1_acc: 0.6458 - val_predictions_coarse2_acc: 0.5296 - val_predictions_fine_acc: 0.3122
# Epoch 20/50
# 45000/45000 [==============================] - 34s 758us/step - loss: 2.0329 - predictions_coarse1_loss: 0.7590 - predictions_coarse2_loss: 1.1163 - predictions_fine_loss: 2.6441 - predictions_coarse1_acc: 0.7469 - predictions_coarse2_acc: 0.6333 - predictions_fine_acc: 0.3115 - val_loss: 2.1573 - val_predictions_coarse1_loss: 0.9988 - val_predictions_coarse2_loss: 1.4645 - val_predictions_fine_loss: 2.6192 - val_predictions_coarse1_acc: 0.6776 - val_predictions_coarse2_acc: 0.5584 - val_predictions_fine_acc: 0.3548
# Epoch 21/50
# 45000/45000 [==============================] - 34s 752us/step - loss: 1.9355 - predictions_coarse1_loss: 0.7359 - predictions_coarse2_loss: 1.0647 - predictions_fine_loss: 2.5160 - predictions_coarse1_acc: 0.7563 - predictions_coarse2_acc: 0.6437 - predictions_fine_acc: 0.3352 - val_loss: 2.1088 - val_predictions_coarse1_loss: 0.9815 - val_predictions_coarse2_loss: 1.4451 - val_predictions_fine_loss: 2.5514 - val_predictions_coarse1_acc: 0.6824 - val_predictions_coarse2_acc: 0.5654 - val_predictions_fine_acc: 0.3568
# Epoch 22/50
# 45000/45000 [==============================] - 34s 760us/step - loss: 1.8404 - predictions_coarse1_loss: 0.7118 - predictions_coarse2_loss: 1.0117 - predictions_fine_loss: 2.3928 - predictions_coarse1_acc: 0.7648 - predictions_coarse2_acc: 0.6650 - predictions_fine_acc: 0.3616 - val_loss: 2.0671 - val_predictions_coarse1_loss: 0.9656 - val_predictions_coarse2_loss: 1.4232 - val_predictions_fine_loss: 2.4964 - val_predictions_coarse1_acc: 0.6794 - val_predictions_coarse2_acc: 0.5700 - val_predictions_fine_acc: 0.3762
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.0, fine = 1.0
# Epoch 23/50
# 45000/45000 [==============================] - 34s 761us/step - loss: 2.3041 - predictions_coarse1_loss: 0.7247 - predictions_coarse2_loss: 1.0099 - predictions_fine_loss: 2.3041 - predictions_coarse1_acc: 0.7600 - predictions_coarse2_acc: 0.6615 - predictions_fine_acc: 0.3741 - val_loss: 2.4657 - val_predictions_coarse1_loss: 1.0036 - val_predictions_coarse2_loss: 1.4634 - val_predictions_fine_loss: 2.4657 - val_predictions_coarse1_acc: 0.6720 - val_predictions_coarse2_acc: 0.5608 - val_predictions_fine_acc: 0.3744
# Epoch 24/50
# 45000/45000 [==============================] - 34s 761us/step - loss: 2.1745 - predictions_coarse1_loss: 0.7327 - predictions_coarse2_loss: 1.0105 - predictions_fine_loss: 2.1745 - predictions_coarse1_acc: 0.7587 - predictions_coarse2_acc: 0.6638 - predictions_fine_acc: 0.4074 - val_loss: 2.4140 - val_predictions_coarse1_loss: 1.0101 - val_predictions_coarse2_loss: 1.4711 - val_predictions_fine_loss: 2.4140 - val_predictions_coarse1_acc: 0.6772 - val_predictions_coarse2_acc: 0.5630 - val_predictions_fine_acc: 0.3868
# Epoch 25/50
# 45000/45000 [==============================] - 34s 757us/step - loss: 2.0536 - predictions_coarse1_loss: 0.7227 - predictions_coarse2_loss: 1.0003 - predictions_fine_loss: 2.0536 - predictions_coarse1_acc: 0.7624 - predictions_coarse2_acc: 0.6666 - predictions_fine_acc: 0.4346 - val_loss: 2.4117 - val_predictions_coarse1_loss: 1.0030 - val_predictions_coarse2_loss: 1.4978 - val_predictions_fine_loss: 2.4117 - val_predictions_coarse1_acc: 0.6732 - val_predictions_coarse2_acc: 0.5512 - val_predictions_fine_acc: 0.3834
# Epoch 26/50
# 45000/45000 [==============================] - 34s 764us/step - loss: 1.9459 - predictions_coarse1_loss: 0.7162 - predictions_coarse2_loss: 0.9708 - predictions_fine_loss: 1.9459 - predictions_coarse1_acc: 0.7668 - predictions_coarse2_acc: 0.6747 - predictions_fine_acc: 0.4558 - val_loss: 2.3819 - val_predictions_coarse1_loss: 1.0317 - val_predictions_coarse2_loss: 1.4805 - val_predictions_fine_loss: 2.3819 - val_predictions_coarse1_acc: 0.6598 - val_predictions_coarse2_acc: 0.5426 - val_predictions_fine_acc: 0.3866
# Epoch 27/50
# 45000/45000 [==============================] - 34s 765us/step - loss: 1.8405 - predictions_coarse1_loss: 0.7070 - predictions_coarse2_loss: 0.9484 - predictions_fine_loss: 1.8405 - predictions_coarse1_acc: 0.7678 - predictions_coarse2_acc: 0.6849 - predictions_fine_acc: 0.4838 - val_loss: 2.2967 - val_predictions_coarse1_loss: 0.9871 - val_predictions_coarse2_loss: 1.4193 - val_predictions_fine_loss: 2.2967 - val_predictions_coarse1_acc: 0.6788 - val_predictions_coarse2_acc: 0.5692 - val_predictions_fine_acc: 0.4060
# Epoch 28/50
# 45000/45000 [==============================] - 34s 761us/step - loss: 1.7327 - predictions_coarse1_loss: 0.6915 - predictions_coarse2_loss: 0.9259 - predictions_fine_loss: 1.7327 - predictions_coarse1_acc: 0.7772 - predictions_coarse2_acc: 0.6912 - predictions_fine_acc: 0.5117 - val_loss: 2.2964 - val_predictions_coarse1_loss: 1.0301 - val_predictions_coarse2_loss: 1.4501 - val_predictions_fine_loss: 2.2964 - val_predictions_coarse1_acc: 0.6600 - val_predictions_coarse2_acc: 0.5644 - val_predictions_fine_acc: 0.4112
# Epoch 29/50
# 45000/45000 [==============================] - 34s 758us/step - loss: 1.6395 - predictions_coarse1_loss: 0.6743 - predictions_coarse2_loss: 0.8982 - predictions_fine_loss: 1.6395 - predictions_coarse1_acc: 0.7826 - predictions_coarse2_acc: 0.7006 - predictions_fine_acc: 0.5332 - val_loss: 2.2794 - val_predictions_coarse1_loss: 1.0180 - val_predictions_coarse2_loss: 1.4374 - val_predictions_fine_loss: 2.2794 - val_predictions_coarse1_acc: 0.6662 - val_predictions_coarse2_acc: 0.5678 - val_predictions_fine_acc: 0.4170
# Epoch 30/50
# 45000/45000 [==============================] - 34s 761us/step - loss: 1.5514 - predictions_coarse1_loss: 0.6652 - predictions_coarse2_loss: 0.8808 - predictions_fine_loss: 1.5514 - predictions_coarse1_acc: 0.7865 - predictions_coarse2_acc: 0.7058 - predictions_fine_acc: 0.5562 - val_loss: 2.2071 - val_predictions_coarse1_loss: 0.9809 - val_predictions_coarse2_loss: 1.3873 - val_predictions_fine_loss: 2.2071 - val_predictions_coarse1_acc: 0.6770 - val_predictions_coarse2_acc: 0.5740 - val_predictions_fine_acc: 0.4204
# Epoch 31/50
# 45000/45000 [==============================] - 34s 757us/step - loss: 1.4505 - predictions_coarse1_loss: 0.6456 - predictions_coarse2_loss: 0.8477 - predictions_fine_loss: 1.4505 - predictions_coarse1_acc: 0.7950 - predictions_coarse2_acc: 0.7159 - predictions_fine_acc: 0.5837 - val_loss: 2.2455 - val_predictions_coarse1_loss: 0.9899 - val_predictions_coarse2_loss: 1.4241 - val_predictions_fine_loss: 2.2455 - val_predictions_coarse1_acc: 0.6796 - val_predictions_coarse2_acc: 0.5666 - val_predictions_fine_acc: 0.4182
# Epoch 32/50
# 45000/45000 [==============================] - 34s 759us/step - loss: 1.3688 - predictions_coarse1_loss: 0.6380 - predictions_coarse2_loss: 0.8241 - predictions_fine_loss: 1.3688 - predictions_coarse1_acc: 0.7982 - predictions_coarse2_acc: 0.7253 - predictions_fine_acc: 0.6046 - val_loss: 2.2219 - val_predictions_coarse1_loss: 1.0032 - val_predictions_coarse2_loss: 1.4116 - val_predictions_fine_loss: 2.2219 - val_predictions_coarse1_acc: 0.6744 - val_predictions_coarse2_acc: 0.5684 - val_predictions_fine_acc: 0.4282
# Epoch 33/50
# 45000/45000 [==============================] - 34s 754us/step - loss: 1.2798 - predictions_coarse1_loss: 0.6258 - predictions_coarse2_loss: 0.8016 - predictions_fine_loss: 1.2798 - predictions_coarse1_acc: 0.8024 - predictions_coarse2_acc: 0.7344 - predictions_fine_acc: 0.6292 - val_loss: 2.2227 - val_predictions_coarse1_loss: 1.0302 - val_predictions_coarse2_loss: 1.4343 - val_predictions_fine_loss: 2.2227 - val_predictions_coarse1_acc: 0.6642 - val_predictions_coarse2_acc: 0.5712 - val_predictions_fine_acc: 0.4320
# Epoch 34/50
# 45000/45000 [==============================] - 34s 760us/step - loss: 1.1907 - predictions_coarse1_loss: 0.6129 - predictions_coarse2_loss: 0.7743 - predictions_fine_loss: 1.1907 - predictions_coarse1_acc: 0.8082 - predictions_coarse2_acc: 0.7414 - predictions_fine_acc: 0.6524 - val_loss: 2.2088 - val_predictions_coarse1_loss: 1.0034 - val_predictions_coarse2_loss: 1.4170 - val_predictions_fine_loss: 2.2088 - val_predictions_coarse1_acc: 0.6768 - val_predictions_coarse2_acc: 0.5700 - val_predictions_fine_acc: 0.4356
# Epoch 35/50
# 45000/45000 [==============================] - 34s 758us/step - loss: 1.1072 - predictions_coarse1_loss: 0.6053 - predictions_coarse2_loss: 0.7587 - predictions_fine_loss: 1.1072 - predictions_coarse1_acc: 0.8119 - predictions_coarse2_acc: 0.7498 - predictions_fine_acc: 0.6773 - val_loss: 2.1874 - val_predictions_coarse1_loss: 0.9988 - val_predictions_coarse2_loss: 1.4184 - val_predictions_fine_loss: 2.1874 - val_predictions_coarse1_acc: 0.6770 - val_predictions_coarse2_acc: 0.5648 - val_predictions_fine_acc: 0.4324
# Epoch 36/50
# 45000/45000 [==============================] - 34s 763us/step - loss: 1.0442 - predictions_coarse1_loss: 0.5966 - predictions_coarse2_loss: 0.7350 - predictions_fine_loss: 1.0442 - predictions_coarse1_acc: 0.8155 - predictions_coarse2_acc: 0.7579 - predictions_fine_acc: 0.6972 - val_loss: 2.2094 - val_predictions_coarse1_loss: 1.0227 - val_predictions_coarse2_loss: 1.4286 - val_predictions_fine_loss: 2.2094 - val_predictions_coarse1_acc: 0.6698 - val_predictions_coarse2_acc: 0.5668 - val_predictions_fine_acc: 0.4368
# Epoch 37/50
# 45000/45000 [==============================] - 34s 757us/step - loss: 0.9562 - predictions_coarse1_loss: 0.5959 - predictions_coarse2_loss: 0.7148 - predictions_fine_loss: 0.9562 - predictions_coarse1_acc: 0.8164 - predictions_coarse2_acc: 0.7673 - predictions_fine_acc: 0.7246 - val_loss: 2.1865 - val_predictions_coarse1_loss: 1.0356 - val_predictions_coarse2_loss: 1.4299 - val_predictions_fine_loss: 2.1865 - val_predictions_coarse1_acc: 0.6616 - val_predictions_coarse2_acc: 0.5638 - val_predictions_fine_acc: 0.4432
# Epoch 38/50
# 45000/45000 [==============================] - 34s 759us/step - loss: 0.8986 - predictions_coarse1_loss: 0.5854 - predictions_coarse2_loss: 0.7088 - predictions_fine_loss: 0.8986 - predictions_coarse1_acc: 0.8226 - predictions_coarse2_acc: 0.7690 - predictions_fine_acc: 0.7420 - val_loss: 2.2023 - val_predictions_coarse1_loss: 1.0337 - val_predictions_coarse2_loss: 1.4324 - val_predictions_fine_loss: 2.2023 - val_predictions_coarse1_acc: 0.6628 - val_predictions_coarse2_acc: 0.5600 - val_predictions_fine_acc: 0.4402
# Epoch 39/50
# 45000/45000 [==============================] - 34s 755us/step - loss: 0.8284 - predictions_coarse1_loss: 0.5833 - predictions_coarse2_loss: 0.6868 - predictions_fine_loss: 0.8284 - predictions_coarse1_acc: 0.8213 - predictions_coarse2_acc: 0.7785 - predictions_fine_acc: 0.7641 - val_loss: 2.2779 - val_predictions_coarse1_loss: 1.0478 - val_predictions_coarse2_loss: 1.4667 - val_predictions_fine_loss: 2.2779 - val_predictions_coarse1_acc: 0.6698 - val_predictions_coarse2_acc: 0.5634 - val_predictions_fine_acc: 0.4422
# Epoch 40/50
# 45000/45000 [==============================] - 34s 760us/step - loss: 0.7622 - predictions_coarse1_loss: 0.5734 - predictions_coarse2_loss: 0.6699 - predictions_fine_loss: 0.7622 - predictions_coarse1_acc: 0.8268 - predictions_coarse2_acc: 0.7847 - predictions_fine_acc: 0.7874 - val_loss: 2.2226 - val_predictions_coarse1_loss: 1.0383 - val_predictions_coarse2_loss: 1.4519 - val_predictions_fine_loss: 2.2226 - val_predictions_coarse1_acc: 0.6628 - val_predictions_coarse2_acc: 0.5580 - val_predictions_fine_acc: 0.4358
# Epoch 41/50
# 45000/45000 [==============================] - 34s 755us/step - loss: 0.7110 - predictions_coarse1_loss: 0.5708 - predictions_coarse2_loss: 0.6552 - predictions_fine_loss: 0.7110 - predictions_coarse1_acc: 0.8276 - predictions_coarse2_acc: 0.7916 - predictions_fine_acc: 0.8020 - val_loss: 2.2327 - val_predictions_coarse1_loss: 1.0517 - val_predictions_coarse2_loss: 1.4572 - val_predictions_fine_loss: 2.2327 - val_predictions_coarse1_acc: 0.6632 - val_predictions_coarse2_acc: 0.5608 - val_predictions_fine_acc: 0.4380
# Epoch 42/50
# 45000/45000 [==============================] - 34s 765us/step - loss: 0.6530 - predictions_coarse1_loss: 0.5656 - predictions_coarse2_loss: 0.6439 - predictions_fine_loss: 0.6530 - predictions_coarse1_acc: 0.8286 - predictions_coarse2_acc: 0.7965 - predictions_fine_acc: 0.8197 - val_loss: 2.2284 - val_predictions_coarse1_loss: 1.0526 - val_predictions_coarse2_loss: 1.4525 - val_predictions_fine_loss: 2.2284 - val_predictions_coarse1_acc: 0.6562 - val_predictions_coarse2_acc: 0.5610 - val_predictions_fine_acc: 0.4428
# Epoch 43/50
# 45000/45000 [==============================] - 34s 765us/step - loss: 0.5967 - predictions_coarse1_loss: 0.5710 - predictions_coarse2_loss: 0.6370 - predictions_fine_loss: 0.5967 - predictions_coarse1_acc: 0.8265 - predictions_coarse2_acc: 0.7983 - predictions_fine_acc: 0.8424 - val_loss: 2.2533 - val_predictions_coarse1_loss: 1.0604 - val_predictions_coarse2_loss: 1.4674 - val_predictions_fine_loss: 2.2533 - val_predictions_coarse1_acc: 0.6548 - val_predictions_coarse2_acc: 0.5550 - val_predictions_fine_acc: 0.4440
# Epoch 44/50
# 45000/45000 [==============================] - 34s 755us/step - loss: 0.5410 - predictions_coarse1_loss: 0.5653 - predictions_coarse2_loss: 0.6249 - predictions_fine_loss: 0.5410 - predictions_coarse1_acc: 0.8293 - predictions_coarse2_acc: 0.8047 - predictions_fine_acc: 0.8591 - val_loss: 2.2598 - val_predictions_coarse1_loss: 1.0737 - val_predictions_coarse2_loss: 1.4623 - val_predictions_fine_loss: 2.2598 - val_predictions_coarse1_acc: 0.6550 - val_predictions_coarse2_acc: 0.5638 - val_predictions_fine_acc: 0.4388
# Epoch 45/50
# 45000/45000 [==============================] - 34s 754us/step - loss: 0.4995 - predictions_coarse1_loss: 0.5630 - predictions_coarse2_loss: 0.6045 - predictions_fine_loss: 0.4995 - predictions_coarse1_acc: 0.8313 - predictions_coarse2_acc: 0.8121 - predictions_fine_acc: 0.8739 - val_loss: 2.2753 - val_predictions_coarse1_loss: 1.0575 - val_predictions_coarse2_loss: 1.4651 - val_predictions_fine_loss: 2.2753 - val_predictions_coarse1_acc: 0.6556 - val_predictions_coarse2_acc: 0.5582 - val_predictions_fine_acc: 0.4392
# Epoch 46/50
# 45000/45000 [==============================] - 34s 764us/step - loss: 0.4592 - predictions_coarse1_loss: 0.5580 - predictions_coarse2_loss: 0.5995 - predictions_fine_loss: 0.4592 - predictions_coarse1_acc: 0.8335 - predictions_coarse2_acc: 0.8166 - predictions_fine_acc: 0.8852 - val_loss: 2.2615 - val_predictions_coarse1_loss: 1.0697 - val_predictions_coarse2_loss: 1.4666 - val_predictions_fine_loss: 2.2615 - val_predictions_coarse1_acc: 0.6514 - val_predictions_coarse2_acc: 0.5560 - val_predictions_fine_acc: 0.4504
# Epoch 47/50
# 45000/45000 [==============================] - 34s 761us/step - loss: 0.4201 - predictions_coarse1_loss: 0.5577 - predictions_coarse2_loss: 0.5903 - predictions_fine_loss: 0.4201 - predictions_coarse1_acc: 0.8336 - predictions_coarse2_acc: 0.8192 - predictions_fine_acc: 0.8963 - val_loss: 2.3132 - val_predictions_coarse1_loss: 1.0889 - val_predictions_coarse2_loss: 1.4982 - val_predictions_fine_loss: 2.3132 - val_predictions_coarse1_acc: 0.6462 - val_predictions_coarse2_acc: 0.5478 - val_predictions_fine_acc: 0.4388
#
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 48/50
# 45000/45000 [==============================] - 34s 760us/step - loss: 0.3535 - predictions_coarse1_loss: 0.5434 - predictions_coarse2_loss: 0.5575 - predictions_fine_loss: 0.3535 - predictions_coarse1_acc: 0.8417 - predictions_coarse2_acc: 0.8323 - predictions_fine_acc: 0.9207 - val_loss: 2.2624 - val_predictions_coarse1_loss: 1.0697 - val_predictions_coarse2_loss: 1.4640 - val_predictions_fine_loss: 2.2624 - val_predictions_coarse1_acc: 0.6550 - val_predictions_coarse2_acc: 0.5580 - val_predictions_fine_acc: 0.4496
# Epoch 49/50
# 45000/45000 [==============================] - 34s 758us/step - loss: 0.3208 - predictions_coarse1_loss: 0.5380 - predictions_coarse2_loss: 0.5446 - predictions_fine_loss: 0.3208 - predictions_coarse1_acc: 0.8436 - predictions_coarse2_acc: 0.8380 - predictions_fine_acc: 0.9297 - val_loss: 2.2560 - val_predictions_coarse1_loss: 1.0784 - val_predictions_coarse2_loss: 1.4711 - val_predictions_fine_loss: 2.2560 - val_predictions_coarse1_acc: 0.6474 - val_predictions_coarse2_acc: 0.5526 - val_predictions_fine_acc: 0.4454
# Epoch 50/50
# 45000/45000 [==============================] - 34s 759us/step - loss: 0.3022 - predictions_coarse1_loss: 0.5355 - predictions_coarse2_loss: 0.5387 - predictions_fine_loss: 0.3022 - predictions_coarse1_acc: 0.8439 - predictions_coarse2_acc: 0.8428 - predictions_fine_acc: 0.9365 - val_loss: 2.2735 - val_predictions_coarse1_loss: 1.0654 - val_predictions_coarse2_loss: 1.4674 - val_predictions_fine_loss: 2.2735 - val_predictions_coarse1_acc: 0.6516 - val_predictions_coarse2_acc: 0.5570 - val_predictions_fine_acc: 0.4418

# %%
model.evaluate(test_features, [y_test_c_cat1,y_test_c_cat2, y_test_cat])
# Out:
# 10000/10000 [==============================] - 5s 539us/step
# [2.1723835582733155,
#  1.0474919864654542,
#  1.4395026556015014,
#  2.1723835582733155,
#  0.6617,
#  0.5671,
#  0.4653]

# %%
print('Total training time: {}'.format(training_time))
# Out:
# Total training time: 1754.4178442955017

# %%
model.save('drive/TCC-ITAU/cifar-100/models/split-net.h5')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-af9abb2928fe> in <module>()
# ----> 1 model.save('drive/TCC-ITAU/cifar-100/models/split-net.h5')
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/network.py in save(self, filepath, overwrite, include_optimizer)
#    1088             raise NotImplementedError
#    1089         from ..models import save_model
# -> 1090         save_model(self, filepath, overwrite, include_optimizer)
#    1091
#    1092     def save_weights(self, filepath, overwrite=True):
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py in save_model(model, filepath, overwrite, include_optimizer)
#     380
#     381     try:
# --> 382         _serialize_model(model, f, include_optimizer)
#     383     finally:
#     384         if opened_new_file:
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py in _serialize_model(model, f, include_optimizer)
#     136                 'sample_weight_mode': model.sample_weight_mode,
#     137                 'loss_weights': model.loss_weights,
# --> 138             }, default=get_json_type).encode('utf8')
#     139             symbolic_weights = getattr(model.optimizer, 'weights')
#     140             if symbolic_weights:
#
# /usr/lib/python3.6/json/__init__.py in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     236         check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     237         separators=separators, default=default, sort_keys=sort_keys,
# --> 238         **kw).encode(obj)
#     239
#     240
#
# /usr/lib/python3.6/json/encoder.py in encode(self, o)
#     197         # exceptions aren't as detailed.  The list call should be roughly
#     198         # equivalent to the PySequence_Fast that ''.join() would do.
# --> 199         chunks = self.iterencode(o, _one_shot=True)
#     200         if not isinstance(chunks, (list, tuple)):
#     201             chunks = list(chunks)
#
# /usr/lib/python3.6/json/encoder.py in iterencode(self, o, _one_shot)
#     255                 self.key_separator, self.item_separator, self.sort_keys,
#     256                 self.skipkeys, _one_shot)
# --> 257         return _iterencode(o, 0)
#     258
#     259 def _make_iterencode(markers, _default, _encoder, _indent, _floatstr,
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py in get_json_type(obj)
#      72             return obj.__name__
#      73
# ---> 74         raise TypeError('Not JSON Serializable: %s' % (obj,))
#      75
#      76     from .. import __version__ as keras_version
#
# TypeError: Not JSON Serializable: <tf.Variable 'alpha:0' shape=() dtype=float32_ref>
