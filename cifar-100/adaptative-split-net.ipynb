# %% [markdown]
# ## Adaptative Split-net

# %%
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse

from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass

# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}

# %%
# !mkdir -p drive
# !google-drive-ocamlfuse drive

# %% [markdown]
# ## Loading the data

# %%
from time import time
import os
import gzip
import numpy as np
from keras.utils import np_utils
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

from keras.datasets import cifar100
# Out:
# Using TensorFlow backend.

# %%
(X_train, y_train), (X_test, y_test) = cifar100.load_data(label_mode='fine')
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, 
                                                  test_size=0.1, 
                                                  random_state=1974,
                                                  stratify = y_train)

# %%
train_features = X_train.reshape(X_train.shape[0], 32, 32, 3)/255
vali_features = X_val.reshape(X_val.shape[0], 32, 32, 3)/255
test_features = X_test.reshape(X_test.shape[0], 32, 32, 3)/255

y_train_cat = np_utils.to_categorical(y_train)
y_val_cat = np_utils.to_categorical(y_val)
y_test_cat = np_utils.to_categorical(y_test)

# %% [markdown]
# ## Defining coarse labels

# %%
dict_coarse2 = {0: 4,  1: 1,  2: 14,  3: 8,  4: 12,  5: 6,  6: 7,  7: 7,  8: 18,  9: 3,  10: 3,
                11: 14,  12: 9,  13: 18,  14: 7,  15: 11,  16: 3,  17: 9,  18: 7,  19: 11,  20: 6,
                21: 11,  22: 5,  23: 10,  24: 7,  25: 6,  26: 13,  27: 15,  28: 3,  29: 15,  30: 0,
                31: 11,  32: 1,  33: 10,  34: 12,  35: 14,  36: 16,  37: 9,  38: 11,  39: 5,  40: 5,
                41: 18,  42: 8,  43: 8,  44: 15,  45: 13,  46: 14,  47: 17,  48: 18,  49: 10,  50: 16,
                51: 4,  52: 17,  53: 4,  54: 2,  55: 12,  56: 17,  57: 4,  58: 18,  59: 17,  60: 10,
                61: 3,  62: 2,  63: 12,  64: 12,  65: 16,  66: 12,  67: 1,  68: 9,  69: 18,  70: 2,
                71: 10,  72: 12,  73: 1,  74: 16,  75: 12,  76: 9,  77: 13,  78: 15,  79: 13,  80: 16,
                81: 18,  82: 2,  83: 4,  84: 6,  85: 18,  86: 5,  87: 5,  88: 8,  89: 18,  90: 18,
                91: 1,  92: 2,  93: 15,  94: 6,  95: 0,  96: 17,  97: 8,  98: 14,  99: 13}


dict_coarse1 = {0: 0,
              1: 0,
              2: 1,
              3: 2,
              4: 1,
              5: 2,
              6: 2,
              7: 3,
              8: 4,
              9: 5,
              10: 5,
              11: 4,
              12: 4,
              13: 3,
              14: 6,
              15: 7,
              16: 4,
              17: 1,
              18: 8}

y_train_coarse2 = np.vectorize(dict_coarse2.get)(y_train)
y_val_coarse2 = np.vectorize(dict_coarse2.get)(y_val)
y_test_coarse2 = np.vectorize(dict_coarse2.get)(y_test)

y_train_coarse1 = np.vectorize(dict_coarse1.get)(y_train_coarse2)
y_val_coarse1 = np.vectorize(dict_coarse1.get)(y_val_coarse2)
y_test_coarse1 = np.vectorize(dict_coarse1.get)(y_test_coarse2)


y_train_c_cat1 = np_utils.to_categorical(y_train_coarse1)
y_val_c_cat1 = np_utils.to_categorical(y_val_coarse1)
y_test_c_cat1 = np_utils.to_categorical(y_test_coarse1)

y_train_c_cat2 = np_utils.to_categorical(y_train_coarse2)
y_val_c_cat2 = np_utils.to_categorical(y_val_coarse2)
y_test_c_cat2 = np_utils.to_categorical(y_test_coarse2)

# %% [markdown]
# ## Training the model

# %%
import keras
from keras.models import Model
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D, Input
from keras import optimizers
from keras.callbacks import TensorBoard, ReduceLROnPlateau, CSVLogger
from keras.layers.normalization import BatchNormalization
from keras import backend as K

# %%
class TimingCallback(keras.callbacks.Callback):
  """Callback that saves the time elapsed of each epoch to the log.
  """  
  def on_epoch_begin(self, epoch, logs={}):
    self.starttime=time()
  def on_epoch_end(self, epoch, logs={}):
    logs['time_elapsed'] = (time()-self.starttime)

# %%
class AdaptativeLossWeightsModifier3Vars(keras.callbacks.Callback):
  def __init__(self, alpha, beta, gamma, decay_rate=0.5):
    self.alpha = alpha
    self.beta = beta
    self.gamma = gamma
    self.decay_rate = decay_rate
    self.offset_epoch = 0
    self.par_reduce = [0, 1]
  
  def calculate_exponential(self, ratio, decay_rate, epoch):
    return np.exp(-ratio*decay_rate*epoch)

  def on_epoch_end(self, epoch, logs={}):
    list_vars = [K.eval(self.alpha), K.eval(self.beta), K.eval(self.gamma)]
    if epoch < 1:
      pass
    
    else:
      loss_coarse1 = self.model.history.history['predictions_coarse1_loss'][-1]
      loss_coarse2 = self.model.history.history['predictions_coarse2_loss'][-1]
      loss_fine = self.model.history.history['predictions_fine_loss'][-1]
      
      losses_classes = [loss_coarse1, loss_coarse2, loss_fine]
      ratio = losses_classes[self.par_reduce[0]] / losses_classes[self.par_reduce[1]] *(epoch + 1 - self.offset_epoch) 
      
      decaying = self.calculate_exponential(ratio, self.decay_rate/(max(self.par_reduce)**2), epoch)
      increasing = 1 - decaying
    
    
      if (1 - increasing) < 0.1 and (self.par_reduce[1] < len(list_vars) - 1):
        list_vars[self.par_reduce[0]] = 0
        list_vars[self.par_reduce[1]] = 1
        self.par_reduce = [i + 1 for i in self.par_reduce]
        self.offset_epoch = self.offset_epoch + epoch

      else:
       list_vars[self.par_reduce[0]] = decaying
       list_vars[self.par_reduce[1]] = increasing

        
      K.set_value(self.alpha, list_vars[0])
      K.set_value(self.beta, list_vars[1])
      K.set_value(self.gamma, list_vars[2])
        
      print('Changing loss weights to: coarse1 = {}, coarse2 = {}, fine = {}'.format(K.eval(self.alpha), K.eval(self.beta), K.eval(self.gamma)))
    
    logs['alpha'] = K.eval(self.alpha)
    logs['beta'] = K.eval(self.beta) 
    logs['gamma'] = K.eval(self.gamma)

# %%
img_rows, img_cols = 32, 32
input_shape = (img_rows, img_cols, 3)

num_classes_coarse1 = 9
num_classes_coarse2 = 19
num_classes_fine = 100

img_input = Input(shape=input_shape, name='input')

x = Conv2D(64, (3, 3), activation='relu', name='block1_conv1', padding='same')(img_input)
x = BatchNormalization()(x)
x = Conv2D(64, (3, 3), activation='relu', name='block1_conv2', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2), name='block1_pool')(x)

x = Conv2D(128, (3, 3), activation='relu', name='block1_conv3', padding='same')(x)
x = BatchNormalization()(x)
x = Conv2D(128, (3, 3), activation='relu', name='block1_conv4', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2), name='block2_pool')(x)

x = Conv2D(256, (3, 3), activation='relu', name='block1_conv5', padding='same')(x)
x = BatchNormalization()(x)
x = Conv2D(256, (3, 3), activation='relu', name='block1_conv6', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2), name='block3_pool')(x)

x = Conv2D(512, (3, 3), activation='relu', name='block1_conv7', padding='same')(x)
x = BatchNormalization()(x)
x = Conv2D(512, (3, 3), activation='relu', name='block1_conv8', padding='same')(x)
x = BatchNormalization()(x)

x = Flatten(name='flatten')(x)
x = Dense(1024, name='fc_1')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = Dropout(0.5)(x)

x = Dense(1024, name='fc_2')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = Dropout(0.5)(x)


coarse_pred1 = Dense(num_classes_coarse1, activation='softmax', name='predictions_coarse1')(x)
coarse_pred2 = Dense(num_classes_coarse2, activation='softmax', name='predictions_coarse2')(x)
fine_pred = Dense(num_classes_fine, activation='softmax', name='predictions_fine')(x)

# %%
model = Model(inputs=img_input, outputs= [coarse_pred1, coarse_pred2, fine_pred], name='adaptative_split_net')

model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 32, 32, 64)   1792        input[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 32, 32, 64)   256         block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 32, 32, 64)   36928       batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 32, 32, 64)   256         block1_conv2[0][0]
# __________________________________________________________________________________________________
# block1_pool (MaxPooling2D)      (None, 16, 16, 64)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# block1_conv3 (Conv2D)           (None, 16, 16, 128)  73856       block1_pool[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 16, 16, 128)  512         block1_conv3[0][0]
# __________________________________________________________________________________________________
# block1_conv4 (Conv2D)           (None, 16, 16, 128)  147584      batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 16, 16, 128)  512         block1_conv4[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 8, 8, 128)    0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# block1_conv5 (Conv2D)           (None, 8, 8, 256)    295168      block2_pool[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 8, 8, 256)    1024        block1_conv5[0][0]
# __________________________________________________________________________________________________
# block1_conv6 (Conv2D)           (None, 8, 8, 256)    590080      batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 8, 8, 256)    1024        block1_conv6[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 4, 4, 256)    0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# block1_conv7 (Conv2D)           (None, 4, 4, 512)    1180160     block3_pool[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 4, 4, 512)    2048        block1_conv7[0][0]
# __________________________________________________________________________________________________
# block1_conv8 (Conv2D)           (None, 4, 4, 512)    2359808     batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 4, 4, 512)    2048        block1_conv8[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 8192)         0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# fc_1 (Dense)                    (None, 1024)         8389632     flatten[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 1024)         4096        fc_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 1024)         0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 1024)         0           activation_3[0][0]
# __________________________________________________________________________________________________
# fc_2 (Dense)                    (None, 1024)         1049600     dropout_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 1024)         4096        fc_2[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 1024)         0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 1024)         0           activation_4[0][0]
# __________________________________________________________________________________________________
# predictions_coarse1 (Dense)     (None, 9)            9225        dropout_4[0][0]
# __________________________________________________________________________________________________
# predictions_coarse2 (Dense)     (None, 19)           19475       dropout_4[0][0]
# __________________________________________________________________________________________________
# predictions_fine (Dense)        (None, 100)          102500      dropout_4[0][0]
# ==================================================================================================
# Total params: 14,271,680
# Trainable params: 14,263,744
# Non-trainable params: 7,936
# __________________________________________________________________________________________________

# %%
alpha = K.variable(value=0.9, dtype="float32", name="alpha") 
beta = K.variable(value=0.1, dtype="float32", name="beta") 
gamma = K.variable(value=0, dtype="float32", name="gamma") 

sgd = optimizers.SGD(lr=0.001, momentum=0.9, nesterov=True)

model.compile(loss='categorical_crossentropy', 
              optimizer=sgd,
              loss_weights=[alpha, beta, gamma],
              metrics=['accuracy'])

# %%
clr_cb = ReduceLROnPlateau(monitor='val_predictions_fine_loss', factor=0.5, patience=10, verbose=1, min_lr=3.125e-05)
time_cb = TimingCallback()
change_lw = AdaptativeLossWeightsModifier3Vars(alpha, beta, gamma, decay_rate=0.1)
csv_cb = CSVLogger('drive/TCC-ITAU/cifar-100/training-data/adaptative-split-net.csv', separator=',', append=False)


cbks = [clr_cb, time_cb, change_lw, csv_cb]

# %%
epochs = 50
start_time = time()
training = model.fit(train_features, [y_train_c_cat1, y_train_c_cat2, y_train_cat],
                     validation_data=(vali_features, [y_val_c_cat1, y_val_c_cat2, y_val_cat]),
                     epochs=epochs,
                     batch_size=256, 
                     callbacks=cbks,
                     verbose=1)
training_time = time() - start_time
# Out:
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/50
# 45000/45000 [==============================] - 36s 808us/step - loss: 2.1956 - predictions_coarse1_loss: 2.0615 - predictions_coarse2_loss: 3.4026 - predictions_fine_loss: 5.4557 - predictions_coarse1_acc: 0.3358 - predictions_coarse2_acc: 0.0838 - predictions_fine_acc: 0.0103 - val_loss: 1.9272 - val_predictions_coarse1_loss: 1.8353 - val_predictions_coarse2_loss: 2.7543 - val_predictions_fine_loss: 5.0204 - val_predictions_coarse1_acc: 0.4022 - val_predictions_coarse2_acc: 0.1726 - val_predictions_fine_acc: 0.0100
# Epoch 2/50
# 45000/45000 [==============================] - 33s 744us/step - loss: 1.7976 - predictions_coarse1_loss: 1.6712 - predictions_coarse2_loss: 2.9348 - predictions_fine_loss: 5.4004 - predictions_coarse1_acc: 0.4470 - predictions_coarse2_acc: 0.1492 - predictions_fine_acc: 0.0096 - val_loss: 1.6597 - val_predictions_coarse1_loss: 1.5687 - val_predictions_coarse2_loss: 2.4792 - val_predictions_fine_loss: 4.8535 - val_predictions_coarse1_acc: 0.4744 - val_predictions_coarse2_acc: 0.2492 - val_predictions_fine_acc: 0.0104
# Changing loss weights to: coarse1 = 0.8858795762062073, coarse2 = 0.11412043869495392, fine = 0.0
# Epoch 3/50
# 45000/45000 [==============================] - 34s 745us/step - loss: 1.6328 - predictions_coarse1_loss: 1.4953 - predictions_coarse2_loss: 2.7009 - predictions_fine_loss: 5.3723 - predictions_coarse1_acc: 0.5046 - predictions_coarse2_acc: 0.2011 - predictions_fine_acc: 0.0098 - val_loss: 1.6429 - val_predictions_coarse1_loss: 1.5495 - val_predictions_coarse2_loss: 2.3684 - val_predictions_fine_loss: 4.8096 - val_predictions_coarse1_acc: 0.4690 - val_predictions_coarse2_acc: 0.2676 - val_predictions_fine_acc: 0.0102
# Changing loss weights to: coarse1 = 0.7105818390846252, coarse2 = 0.28941819071769714, fine = 0.0
# Epoch 4/50
# 45000/45000 [==============================] - 33s 744us/step - loss: 1.6851 - predictions_coarse1_loss: 1.3735 - predictions_coarse2_loss: 2.4501 - predictions_fine_loss: 5.3511 - predictions_coarse1_acc: 0.5418 - predictions_coarse2_acc: 0.2629 - predictions_fine_acc: 0.0092 - val_loss: 1.5420 - val_predictions_coarse1_loss: 1.3106 - val_predictions_coarse2_loss: 2.1101 - val_predictions_fine_loss: 4.8181 - val_predictions_coarse1_acc: 0.5658 - val_predictions_coarse2_acc: 0.3534 - val_predictions_fine_acc: 0.0082
# Changing loss weights to: coarse1 = 0.5146117210388184, coarse2 = 0.48538830876350403, fine = 0.0
# Epoch 5/50
# 45000/45000 [==============================] - 34s 746us/step - loss: 1.7294 - predictions_coarse1_loss: 1.2809 - predictions_coarse2_loss: 2.2049 - predictions_fine_loss: 5.3344 - predictions_coarse1_acc: 0.5760 - predictions_coarse2_acc: 0.3271 - predictions_fine_acc: 0.0088 - val_loss: 1.6566 - val_predictions_coarse1_loss: 1.3142 - val_predictions_coarse2_loss: 2.0195 - val_predictions_fine_loss: 4.8258 - val_predictions_coarse1_acc: 0.5560 - val_predictions_coarse2_acc: 0.3874 - val_predictions_fine_acc: 0.0076
# Changing loss weights to: coarse1 = 0.3258923292160034, coarse2 = 0.6741076707839966, fine = 0.0
# Epoch 6/50
# 45000/45000 [==============================] - 34s 748us/step - loss: 1.7579 - predictions_coarse1_loss: 1.2180 - predictions_coarse2_loss: 2.0188 - predictions_fine_loss: 5.3278 - predictions_coarse1_acc: 0.5939 - predictions_coarse2_acc: 0.3762 - predictions_fine_acc: 0.0098 - val_loss: 1.8806 - val_predictions_coarse1_loss: 1.4527 - val_predictions_coarse2_loss: 2.0875 - val_predictions_fine_loss: 4.8574 - val_predictions_coarse1_acc: 0.5132 - val_predictions_coarse2_acc: 0.3696 - val_predictions_fine_acc: 0.0118
# Changing loss weights to: coarse1 = 0.17503783106803894, coarse2 = 0.8249621987342834, fine = 0.0
# Epoch 7/50
# 45000/45000 [==============================] - 34s 746us/step - loss: 1.7550 - predictions_coarse1_loss: 1.1847 - predictions_coarse2_loss: 1.8761 - predictions_fine_loss: 5.3356 - predictions_coarse1_acc: 0.6064 - predictions_coarse2_acc: 0.4160 - predictions_fine_acc: 0.0094 - val_loss: 1.7596 - val_predictions_coarse1_loss: 1.2565 - val_predictions_coarse2_loss: 1.8664 - val_predictions_fine_loss: 4.8166 - val_predictions_coarse1_acc: 0.5822 - val_predictions_coarse2_acc: 0.4190 - val_predictions_fine_acc: 0.0084
# Changing loss weights to: coarse1 = 0.0, coarse2 = 1.0, fine = 0.0
# Epoch 8/50
# 45000/45000 [==============================] - 34s 745us/step - loss: 1.7561 - predictions_coarse1_loss: 1.1502 - predictions_coarse2_loss: 1.7561 - predictions_fine_loss: 5.3295 - predictions_coarse1_acc: 0.6185 - predictions_coarse2_acc: 0.4467 - predictions_fine_acc: 0.0092 - val_loss: 1.9431 - val_predictions_coarse1_loss: 1.4184 - val_predictions_coarse2_loss: 1.9431 - val_predictions_fine_loss: 4.8300 - val_predictions_coarse1_acc: 0.5230 - val_predictions_coarse2_acc: 0.4190 - val_predictions_fine_acc: 0.0116
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.8842074275016785, fine = 0.11579255014657974
# Epoch 9/50
# 45000/45000 [==============================] - 34s 746us/step - loss: 2.0553 - predictions_coarse1_loss: 1.1289 - predictions_coarse2_loss: 1.6521 - predictions_fine_loss: 5.1340 - predictions_coarse1_acc: 0.6196 - predictions_coarse2_acc: 0.4762 - predictions_fine_acc: 0.0143 - val_loss: 1.9685 - val_predictions_coarse1_loss: 1.1416 - val_predictions_coarse2_loss: 1.6357 - val_predictions_fine_loss: 4.5104 - val_predictions_coarse1_acc: 0.6258 - val_predictions_coarse2_acc: 0.4950 - val_predictions_fine_acc: 0.0370
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.8206146955490112, fine = 0.17938531935214996
# Epoch 10/50
# 45000/45000 [==============================] - 34s 747us/step - loss: 2.1308 - predictions_coarse1_loss: 1.1034 - predictions_coarse2_loss: 1.5588 - predictions_fine_loss: 4.7477 - predictions_coarse1_acc: 0.6325 - predictions_coarse2_acc: 0.5056 - predictions_fine_acc: 0.0310 - val_loss: 2.1035 - val_predictions_coarse1_loss: 1.1426 - val_predictions_coarse2_loss: 1.6455 - val_predictions_fine_loss: 4.1987 - val_predictions_coarse1_acc: 0.6268 - val_predictions_coarse2_acc: 0.4848 - val_predictions_fine_acc: 0.0930
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.7485451102256775, fine = 0.2514548599720001
# Epoch 11/50
# 45000/45000 [==============================] - 34s 745us/step - loss: 2.2204 - predictions_coarse1_loss: 1.0843 - predictions_coarse2_loss: 1.4949 - predictions_fine_loss: 4.3801 - predictions_coarse1_acc: 0.6418 - predictions_coarse2_acc: 0.5243 - predictions_fine_acc: 0.0624 - val_loss: 2.1217 - val_predictions_coarse1_loss: 1.0923 - val_predictions_coarse2_loss: 1.5366 - val_predictions_fine_loss: 3.8632 - val_predictions_coarse1_acc: 0.6468 - val_predictions_coarse2_acc: 0.5188 - val_predictions_fine_acc: 0.1624
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.6633850336074829, fine = 0.3366149663925171
# Epoch 12/50
# 45000/45000 [==============================] - 34s 746us/step - loss: 2.3033 - predictions_coarse1_loss: 1.0703 - predictions_coarse2_loss: 1.4291 - predictions_fine_loss: 4.0263 - predictions_coarse1_acc: 0.6426 - predictions_coarse2_acc: 0.5411 - predictions_fine_acc: 0.1034 - val_loss: 2.2604 - val_predictions_coarse1_loss: 1.1184 - val_predictions_coarse2_loss: 1.5826 - val_predictions_fine_loss: 3.5961 - val_predictions_coarse1_acc: 0.6376 - val_predictions_coarse2_acc: 0.5078 - val_predictions_fine_acc: 0.2056
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.5694339871406555, fine = 0.4305660128593445
# Epoch 13/50
# 45000/45000 [==============================] - 34s 745us/step - loss: 2.3888 - predictions_coarse1_loss: 1.0554 - predictions_coarse2_loss: 1.3856 - predictions_fine_loss: 3.7155 - predictions_coarse1_acc: 0.6477 - predictions_coarse2_acc: 0.5530 - predictions_fine_acc: 0.1463 - val_loss: 2.2827 - val_predictions_coarse1_loss: 1.1005 - val_predictions_coarse2_loss: 1.5153 - val_predictions_fine_loss: 3.2977 - val_predictions_coarse1_acc: 0.6434 - val_predictions_coarse2_acc: 0.5348 - val_predictions_fine_acc: 0.2546
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.47456276416778564, fine = 0.5254372358322144
# Epoch 14/50
# 45000/45000 [==============================] - 34s 746us/step - loss: 2.4432 - predictions_coarse1_loss: 1.0451 - predictions_coarse2_loss: 1.3499 - predictions_fine_loss: 3.4305 - predictions_coarse1_acc: 0.6530 - predictions_coarse2_acc: 0.5681 - predictions_fine_acc: 0.1868 - val_loss: 2.3599 - val_predictions_coarse1_loss: 1.1128 - val_predictions_coarse2_loss: 1.5566 - val_predictions_fine_loss: 3.0855 - val_predictions_coarse1_acc: 0.6392 - val_predictions_coarse2_acc: 0.5272 - val_predictions_fine_acc: 0.2764
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.379226416349411, fine = 0.6207736134529114
# Epoch 15/50
# 45000/45000 [==============================] - 34s 746us/step - loss: 2.4660 - predictions_coarse1_loss: 1.0442 - predictions_coarse2_loss: 1.3169 - predictions_fine_loss: 3.1679 - predictions_coarse1_acc: 0.6487 - predictions_coarse2_acc: 0.5714 - predictions_fine_acc: 0.2235 - val_loss: 2.3472 - val_predictions_coarse1_loss: 1.0547 - val_predictions_coarse2_loss: 1.4790 - val_predictions_fine_loss: 2.8776 - val_predictions_coarse1_acc: 0.6538 - val_predictions_coarse2_acc: 0.5432 - val_predictions_fine_acc: 0.3088
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.2895134687423706, fine = 0.7104865312576294
# Epoch 16/50
# 45000/45000 [==============================] - 34s 746us/step - loss: 2.4813 - predictions_coarse1_loss: 1.0471 - predictions_coarse2_loss: 1.3046 - predictions_fine_loss: 2.9608 - predictions_coarse1_acc: 0.6478 - predictions_coarse2_acc: 0.5793 - predictions_fine_acc: 0.2598 - val_loss: 2.3903 - val_predictions_coarse1_loss: 1.0839 - val_predictions_coarse2_loss: 1.5020 - val_predictions_fine_loss: 2.7522 - val_predictions_coarse1_acc: 0.6482 - val_predictions_coarse2_acc: 0.5324 - val_predictions_fine_acc: 0.3302
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.21038056910037994, fine = 0.7896194458007812
# Epoch 17/50
# 45000/45000 [==============================] - 34s 747us/step - loss: 2.4588 - predictions_coarse1_loss: 1.0430 - predictions_coarse2_loss: 1.2715 - predictions_fine_loss: 2.7751 - predictions_coarse1_acc: 0.6476 - predictions_coarse2_acc: 0.5876 - predictions_fine_acc: 0.2913 - val_loss: 2.3913 - val_predictions_coarse1_loss: 1.0831 - val_predictions_coarse2_loss: 1.4641 - val_predictions_fine_loss: 2.6384 - val_predictions_coarse1_acc: 0.6506 - val_predictions_coarse2_acc: 0.5446 - val_predictions_fine_acc: 0.3462
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.14388981461524963, fine = 0.856110155582428
# Epoch 18/50
# 45000/45000 [==============================] - 34s 746us/step - loss: 2.4205 - predictions_coarse1_loss: 1.0491 - predictions_coarse2_loss: 1.2605 - predictions_fine_loss: 2.6155 - predictions_coarse1_acc: 0.6451 - predictions_coarse2_acc: 0.5882 - predictions_fine_acc: 0.3254 - val_loss: 2.3832 - val_predictions_coarse1_loss: 1.0503 - val_predictions_coarse2_loss: 1.4453 - val_predictions_fine_loss: 2.5409 - val_predictions_coarse1_acc: 0.6624 - val_predictions_coarse2_acc: 0.5520 - val_predictions_fine_acc: 0.3596
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.09663708508014679, fine = 0.9033629298210144
# Epoch 19/50
# 45000/45000 [==============================] - 34s 747us/step - loss: 2.3612 - predictions_coarse1_loss: 1.0426 - predictions_coarse2_loss: 1.2469 - predictions_fine_loss: 2.4804 - predictions_coarse1_acc: 0.6488 - predictions_coarse2_acc: 0.5938 - predictions_fine_acc: 0.3488 - val_loss: 2.3958 - val_predictions_coarse1_loss: 1.0959 - val_predictions_coarse2_loss: 1.4580 - val_predictions_fine_loss: 2.4961 - val_predictions_coarse1_acc: 0.6456 - val_predictions_coarse2_acc: 0.5412 - val_predictions_fine_acc: 0.3750
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.05964796245098114, fine = 0.9403520226478577
# Epoch 20/50
# 45000/45000 [==============================] - 34s 746us/step - loss: 2.2761 - predictions_coarse1_loss: 1.0395 - predictions_coarse2_loss: 1.2245 - predictions_fine_loss: 2.3428 - predictions_coarse1_acc: 0.6486 - predictions_coarse2_acc: 0.6007 - predictions_fine_acc: 0.3785 - val_loss: 2.3580 - val_predictions_coarse1_loss: 1.0617 - val_predictions_coarse2_loss: 1.4253 - val_predictions_fine_loss: 2.4172 - val_predictions_coarse1_acc: 0.6542 - val_predictions_coarse2_acc: 0.5518 - val_predictions_fine_acc: 0.3826
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.03533373400568962, fine = 0.9646662473678589
# Epoch 21/50
# 45000/45000 [==============================] - 34s 745us/step - loss: 2.1953 - predictions_coarse1_loss: 1.0304 - predictions_coarse2_loss: 1.1952 - predictions_fine_loss: 2.2319 - predictions_coarse1_acc: 0.6534 - predictions_coarse2_acc: 0.6097 - predictions_fine_acc: 0.4036 - val_loss: 2.3425 - val_predictions_coarse1_loss: 1.0692 - val_predictions_coarse2_loss: 1.4164 - val_predictions_fine_loss: 2.3765 - val_predictions_coarse1_acc: 0.6564 - val_predictions_coarse2_acc: 0.5580 - val_predictions_fine_acc: 0.3916
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.01983736641705036, fine = 0.9801626205444336
# Epoch 22/50
# 45000/45000 [==============================] - 33s 744us/step - loss: 2.1025 - predictions_coarse1_loss: 1.0265 - predictions_coarse2_loss: 1.1740 - predictions_fine_loss: 2.1212 - predictions_coarse1_acc: 0.6562 - predictions_coarse2_acc: 0.6185 - predictions_fine_acc: 0.4240 - val_loss: 2.3633 - val_predictions_coarse1_loss: 1.1051 - val_predictions_coarse2_loss: 1.4623 - val_predictions_fine_loss: 2.3815 - val_predictions_coarse1_acc: 0.6394 - val_predictions_coarse2_acc: 0.5418 - val_predictions_fine_acc: 0.3812
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.011128166690468788, fine = 0.9888718128204346
# Epoch 23/50
# 45000/45000 [==============================] - 34s 746us/step - loss: 2.0043 - predictions_coarse1_loss: 1.0195 - predictions_coarse2_loss: 1.1577 - predictions_fine_loss: 2.0138 - predictions_coarse1_acc: 0.6570 - predictions_coarse2_acc: 0.6210 - predictions_fine_acc: 0.4500 - val_loss: 2.3642 - val_predictions_coarse1_loss: 1.1849 - val_predictions_coarse2_loss: 1.5047 - val_predictions_fine_loss: 2.3738 - val_predictions_coarse1_acc: 0.6006 - val_predictions_coarse2_acc: 0.5360 - val_predictions_fine_acc: 0.3888
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.0056582423858344555, fine = 0.9943417310714722
# Epoch 24/50
# 45000/45000 [==============================] - 34s 747us/step - loss: 1.9089 - predictions_coarse1_loss: 1.0150 - predictions_coarse2_loss: 1.1297 - predictions_fine_loss: 1.9134 - predictions_coarse1_acc: 0.6606 - predictions_coarse2_acc: 0.6299 - predictions_fine_acc: 0.4739 - val_loss: 2.2365 - val_predictions_coarse1_loss: 1.0568 - val_predictions_coarse2_loss: 1.3886 - val_predictions_fine_loss: 2.2413 - val_predictions_coarse1_acc: 0.6688 - val_predictions_coarse2_acc: 0.5686 - val_predictions_fine_acc: 0.4216
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.002606389345601201, fine = 0.9973936080932617
# Epoch 25/50
# 45000/45000 [==============================] - 34s 748us/step - loss: 1.8127 - predictions_coarse1_loss: 1.0037 - predictions_coarse2_loss: 1.1101 - predictions_fine_loss: 1.8145 - predictions_coarse1_acc: 0.6633 - predictions_coarse2_acc: 0.6361 - predictions_fine_acc: 0.4987 - val_loss: 2.1697 - val_predictions_coarse1_loss: 1.0440 - val_predictions_coarse2_loss: 1.3511 - val_predictions_fine_loss: 2.1718 - val_predictions_coarse1_acc: 0.6666 - val_predictions_coarse2_acc: 0.5728 - val_predictions_fine_acc: 0.4376
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.0011934572830796242, fine = 0.9988065361976624
# Epoch 26/50
# 45000/45000 [==============================] - 34s 748us/step - loss: 1.7175 - predictions_coarse1_loss: 1.0014 - predictions_coarse2_loss: 1.0888 - predictions_fine_loss: 1.7182 - predictions_coarse1_acc: 0.6652 - predictions_coarse2_acc: 0.6426 - predictions_fine_acc: 0.5207 - val_loss: 2.1809 - val_predictions_coarse1_loss: 1.0611 - val_predictions_coarse2_loss: 1.3800 - val_predictions_fine_loss: 2.1818 - val_predictions_coarse1_acc: 0.6626 - val_predictions_coarse2_acc: 0.5664 - val_predictions_fine_acc: 0.4296
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.00047733099199831486, fine = 0.9995226860046387
# Epoch 27/50
# 45000/45000 [==============================] - 34s 747us/step - loss: 1.6289 - predictions_coarse1_loss: 0.9818 - predictions_coarse2_loss: 1.0711 - predictions_fine_loss: 1.6292 - predictions_coarse1_acc: 0.6725 - predictions_coarse2_acc: 0.6464 - predictions_fine_acc: 0.5442 - val_loss: 2.1721 - val_predictions_coarse1_loss: 1.0777 - val_predictions_coarse2_loss: 1.3838 - val_predictions_fine_loss: 2.1724 - val_predictions_coarse1_acc: 0.6552 - val_predictions_coarse2_acc: 0.5654 - val_predictions_fine_acc: 0.4378
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.00017516373191028833, fine = 0.9998248219490051
# Epoch 28/50
# 45000/45000 [==============================] - 34s 746us/step - loss: 1.5324 - predictions_coarse1_loss: 0.9813 - predictions_coarse2_loss: 1.0392 - predictions_fine_loss: 1.5325 - predictions_coarse1_acc: 0.6711 - predictions_coarse2_acc: 0.6604 - predictions_fine_acc: 0.5697 - val_loss: 2.1580 - val_predictions_coarse1_loss: 1.0796 - val_predictions_coarse2_loss: 1.3851 - val_predictions_fine_loss: 2.1581 - val_predictions_coarse1_acc: 0.6520 - val_predictions_coarse2_acc: 0.5660 - val_predictions_fine_acc: 0.4328
# Changing loss weights to: coarse1 = 0.0, coarse2 = 5.751931530539878e-05, fine = 0.9999424815177917
# Epoch 29/50
# 45000/45000 [==============================] - 34s 746us/step - loss: 1.4470 - predictions_coarse1_loss: 0.9667 - predictions_coarse2_loss: 1.0184 - predictions_fine_loss: 1.4470 - predictions_coarse1_acc: 0.6799 - predictions_coarse2_acc: 0.6695 - predictions_fine_acc: 0.5880 - val_loss: 2.1130 - val_predictions_coarse1_loss: 1.0687 - val_predictions_coarse2_loss: 1.3629 - val_predictions_fine_loss: 2.1130 - val_predictions_coarse1_acc: 0.6646 - val_predictions_coarse2_acc: 0.5756 - val_predictions_fine_acc: 0.4542
# Changing loss weights to: coarse1 = 0.0, coarse2 = 1.8137090592063032e-05, fine = 0.9999818801879883
# Epoch 30/50
# 45000/45000 [==============================] - 34s 747us/step - loss: 1.3615 - predictions_coarse1_loss: 0.9645 - predictions_coarse2_loss: 0.9910 - predictions_fine_loss: 1.3615 - predictions_coarse1_acc: 0.6790 - predictions_coarse2_acc: 0.6751 - predictions_fine_acc: 0.6143 - val_loss: 2.1066 - val_predictions_coarse1_loss: 1.0959 - val_predictions_coarse2_loss: 1.3778 - val_predictions_fine_loss: 2.1066 - val_predictions_coarse1_acc: 0.6556 - val_predictions_coarse2_acc: 0.5638 - val_predictions_fine_acc: 0.4514
# Changing loss weights to: coarse1 = 0.0, coarse2 = 4.802414423465962e-06, fine = 0.9999951720237732
# Epoch 31/50
# 45000/45000 [==============================] - 34s 749us/step - loss: 1.2723 - predictions_coarse1_loss: 0.9522 - predictions_coarse2_loss: 0.9707 - predictions_fine_loss: 1.2723 - predictions_coarse1_acc: 0.6834 - predictions_coarse2_acc: 0.6810 - predictions_fine_acc: 0.6389 - val_loss: 2.1258 - val_predictions_coarse1_loss: 1.0946 - val_predictions_coarse2_loss: 1.3916 - val_predictions_fine_loss: 2.1258 - val_predictions_coarse1_acc: 0.6514 - val_predictions_coarse2_acc: 0.5672 - val_predictions_fine_acc: 0.4438
# Changing loss weights to: coarse1 = 0.0, coarse2 = 1.1829006325569935e-06, fine = 0.9999988079071045
# Epoch 32/50
# 45000/45000 [==============================] - 34s 750us/step - loss: 1.1924 - predictions_coarse1_loss: 0.9444 - predictions_coarse2_loss: 0.9488 - predictions_fine_loss: 1.1924 - predictions_coarse1_acc: 0.6858 - predictions_coarse2_acc: 0.6908 - predictions_fine_acc: 0.6615 - val_loss: 2.1159 - val_predictions_coarse1_loss: 1.0919 - val_predictions_coarse2_loss: 1.3977 - val_predictions_fine_loss: 2.1159 - val_predictions_coarse1_acc: 0.6504 - val_predictions_coarse2_acc: 0.5628 - val_predictions_fine_acc: 0.4530
# Changing loss weights to: coarse1 = 0.0, coarse2 = 2.105711160993451e-07, fine = 0.9999997615814209
# Epoch 33/50
# 45000/45000 [==============================] - 34s 749us/step - loss: 1.1088 - predictions_coarse1_loss: 0.9331 - predictions_coarse2_loss: 0.9306 - predictions_fine_loss: 1.1088 - predictions_coarse1_acc: 0.6908 - predictions_coarse2_acc: 0.6968 - predictions_fine_acc: 0.6862 - val_loss: 2.0987 - val_predictions_coarse1_loss: 1.1115 - val_predictions_coarse2_loss: 1.3953 - val_predictions_fine_loss: 2.0987 - val_predictions_coarse1_acc: 0.6516 - val_predictions_coarse2_acc: 0.5646 - val_predictions_fine_acc: 0.4526
# Changing loss weights to: coarse1 = 0.0, coarse2 = 3.437848050680259e-08, fine = 0.9999999403953552
# Epoch 34/50
# 45000/45000 [==============================] - 34s 751us/step - loss: 1.0370 - predictions_coarse1_loss: 0.9230 - predictions_coarse2_loss: 0.9105 - predictions_fine_loss: 1.0370 - predictions_coarse1_acc: 0.6930 - predictions_coarse2_acc: 0.7077 - predictions_fine_acc: 0.7064 - val_loss: 2.1180 - val_predictions_coarse1_loss: 1.1279 - val_predictions_coarse2_loss: 1.4179 - val_predictions_fine_loss: 2.1180 - val_predictions_coarse1_acc: 0.6408 - val_predictions_coarse2_acc: 0.5590 - val_predictions_fine_acc: 0.4504
# Changing loss weights to: coarse1 = 0.0, coarse2 = 3.8039087435493e-09, fine = 1.0
# Epoch 35/50
# 45000/45000 [==============================] - 34s 750us/step - loss: 0.9601 - predictions_coarse1_loss: 0.9202 - predictions_coarse2_loss: 0.8898 - predictions_fine_loss: 0.9601 - predictions_coarse1_acc: 0.6941 - predictions_coarse2_acc: 0.7140 - predictions_fine_acc: 0.7292 - val_loss: 2.1294 - val_predictions_coarse1_loss: 1.1109 - val_predictions_coarse2_loss: 1.4034 - val_predictions_fine_loss: 2.1294 - val_predictions_coarse1_acc: 0.6542 - val_predictions_coarse2_acc: 0.5686 - val_predictions_fine_acc: 0.4544
# Changing loss weights to: coarse1 = 0.0, coarse2 = 3.9871439483363247e-10, fine = 1.0
# Epoch 36/50
# 45000/45000 [==============================] - 34s 750us/step - loss: 0.8936 - predictions_coarse1_loss: 0.9180 - predictions_coarse2_loss: 0.8787 - predictions_fine_loss: 0.8936 - predictions_coarse1_acc: 0.6944 - predictions_coarse2_acc: 0.7183 - predictions_fine_acc: 0.7478 - val_loss: 2.1141 - val_predictions_coarse1_loss: 1.1142 - val_predictions_coarse2_loss: 1.4082 - val_predictions_fine_loss: 2.1141 - val_predictions_coarse1_acc: 0.6452 - val_predictions_coarse2_acc: 0.5638 - val_predictions_fine_acc: 0.4546
# Changing loss weights to: coarse1 = 0.0, coarse2 = 2.720956793211826e-11, fine = 1.0
# Epoch 37/50
# 45000/45000 [==============================] - 34s 749us/step - loss: 0.8182 - predictions_coarse1_loss: 0.9173 - predictions_coarse2_loss: 0.8576 - predictions_fine_loss: 0.8182 - predictions_coarse1_acc: 0.6965 - predictions_coarse2_acc: 0.7286 - predictions_fine_acc: 0.7726 - val_loss: 2.1044 - val_predictions_coarse1_loss: 1.1209 - val_predictions_coarse2_loss: 1.4037 - val_predictions_fine_loss: 2.1044 - val_predictions_coarse1_acc: 0.6412 - val_predictions_coarse2_acc: 0.5612 - val_predictions_fine_acc: 0.4616
# Changing loss weights to: coarse1 = 0.0, coarse2 = 1.2153974658299371e-12, fine = 1.0
# Epoch 38/50
# 45000/45000 [==============================] - 34s 749us/step - loss: 0.7517 - predictions_coarse1_loss: 0.9145 - predictions_coarse2_loss: 0.8358 - predictions_fine_loss: 0.7517 - predictions_coarse1_acc: 0.6988 - predictions_coarse2_acc: 0.7353 - predictions_fine_acc: 0.7909 - val_loss: 2.1368 - val_predictions_coarse1_loss: 1.1291 - val_predictions_coarse2_loss: 1.4228 - val_predictions_fine_loss: 2.1368 - val_predictions_coarse1_acc: 0.6414 - val_predictions_coarse2_acc: 0.5556 - val_predictions_fine_acc: 0.4584
# Changing loss weights to: coarse1 = 0.0, coarse2 = 3.352835248478757e-14, fine = 1.0
# Epoch 39/50
# 45000/45000 [==============================] - 34s 748us/step - loss: 0.6955 - predictions_coarse1_loss: 0.9106 - predictions_coarse2_loss: 0.8240 - predictions_fine_loss: 0.6955 - predictions_coarse1_acc: 0.6992 - predictions_coarse2_acc: 0.7411 - predictions_fine_acc: 0.8119 - val_loss: 2.1098 - val_predictions_coarse1_loss: 1.1632 - val_predictions_coarse2_loss: 1.4122 - val_predictions_fine_loss: 2.1098 - val_predictions_coarse1_acc: 0.6296 - val_predictions_coarse2_acc: 0.5668 - val_predictions_fine_acc: 0.4586
# Changing loss weights to: coarse1 = 0.0, coarse2 = 7.257990802774829e-16, fine = 1.0
# Epoch 40/50
# 45000/45000 [==============================] - 34s 750us/step - loss: 0.6367 - predictions_coarse1_loss: 0.9093 - predictions_coarse2_loss: 0.8098 - predictions_fine_loss: 0.6367 - predictions_coarse1_acc: 0.6994 - predictions_coarse2_acc: 0.7466 - predictions_fine_acc: 0.8268 - val_loss: 2.1184 - val_predictions_coarse1_loss: 1.1566 - val_predictions_coarse2_loss: 1.4326 - val_predictions_fine_loss: 2.1184 - val_predictions_coarse1_acc: 0.6348 - val_predictions_coarse2_acc: 0.5590 - val_predictions_fine_acc: 0.4636
# Changing loss weights to: coarse1 = 0.0, coarse2 = 8.77199810603803e-18, fine = 1.0
# Epoch 41/50
# 45000/45000 [==============================] - 34s 750us/step - loss: 0.5771 - predictions_coarse1_loss: 0.9084 - predictions_coarse2_loss: 0.7969 - predictions_fine_loss: 0.5771 - predictions_coarse1_acc: 0.7000 - predictions_coarse2_acc: 0.7513 - predictions_fine_acc: 0.8484 - val_loss: 2.1207 - val_predictions_coarse1_loss: 1.1481 - val_predictions_coarse2_loss: 1.4146 - val_predictions_fine_loss: 2.1207 - val_predictions_coarse1_acc: 0.6346 - val_predictions_coarse2_acc: 0.5654 - val_predictions_fine_acc: 0.4604
# Changing loss weights to: coarse1 = 0.0, coarse2 = 4.635364087030033e-20, fine = 1.0
# Epoch 42/50
# 45000/45000 [==============================] - 34s 748us/step - loss: 0.5386 - predictions_coarse1_loss: 0.9008 - predictions_coarse2_loss: 0.7890 - predictions_fine_loss: 0.5386 - predictions_coarse1_acc: 0.7026 - predictions_coarse2_acc: 0.7567 - predictions_fine_acc: 0.8608 - val_loss: 2.1363 - val_predictions_coarse1_loss: 1.1391 - val_predictions_coarse2_loss: 1.4296 - val_predictions_fine_loss: 2.1363 - val_predictions_coarse1_acc: 0.6368 - val_predictions_coarse2_acc: 0.5638 - val_predictions_fine_acc: 0.4612
# Changing loss weights to: coarse1 = 0.0, coarse2 = 7.424557522637151e-23, fine = 1.0
# Epoch 43/50
# 45000/45000 [==============================] - 34s 750us/step - loss: 0.4908 - predictions_coarse1_loss: 0.8999 - predictions_coarse2_loss: 0.7754 - predictions_fine_loss: 0.4908 - predictions_coarse1_acc: 0.7026 - predictions_coarse2_acc: 0.7617 - predictions_fine_acc: 0.8771 - val_loss: 2.1836 - val_predictions_coarse1_loss: 1.1617 - val_predictions_coarse2_loss: 1.4518 - val_predictions_fine_loss: 2.1836 - val_predictions_coarse1_acc: 0.6306 - val_predictions_coarse2_acc: 0.5576 - val_predictions_fine_acc: 0.4574
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Changing loss weights to: coarse1 = 0.0, coarse2 = 1.9286264928284109e-25, fine = 1.0
# Epoch 44/50
# 45000/45000 [==============================] - 34s 751us/step - loss: 0.4112 - predictions_coarse1_loss: 0.8878 - predictions_coarse2_loss: 0.7438 - predictions_fine_loss: 0.4112 - predictions_coarse1_acc: 0.7075 - predictions_coarse2_acc: 0.7739 - predictions_fine_acc: 0.9036 - val_loss: 2.1154 - val_predictions_coarse1_loss: 1.1707 - val_predictions_coarse2_loss: 1.4322 - val_predictions_fine_loss: 2.1154 - val_predictions_coarse1_acc: 0.6320 - val_predictions_coarse2_acc: 0.5602 - val_predictions_fine_acc: 0.4676
# Changing loss weights to: coarse1 = 0.0, coarse2 = 9.343185698301807e-29, fine = 1.0
# Epoch 45/50
# 45000/45000 [==============================] - 34s 751us/step - loss: 0.3707 - predictions_coarse1_loss: 0.8791 - predictions_coarse2_loss: 0.7290 - predictions_fine_loss: 0.3707 - predictions_coarse1_acc: 0.7123 - predictions_coarse2_acc: 0.7805 - predictions_fine_acc: 0.9182 - val_loss: 2.1473 - val_predictions_coarse1_loss: 1.1634 - val_predictions_coarse2_loss: 1.4311 - val_predictions_fine_loss: 2.1473 - val_predictions_coarse1_acc: 0.6328 - val_predictions_coarse2_acc: 0.5644 - val_predictions_fine_acc: 0.4650
# Changing loss weights to: coarse1 = 0.0, coarse2 = 1.9880692849188386e-34, fine = 1.0
# Epoch 46/50
# 45000/45000 [==============================] - 34s 751us/step - loss: 0.3456 - predictions_coarse1_loss: 0.8818 - predictions_coarse2_loss: 0.7166 - predictions_fine_loss: 0.3456 - predictions_coarse1_acc: 0.7112 - predictions_coarse2_acc: 0.7870 - predictions_fine_acc: 0.9265 - val_loss: 2.1428 - val_predictions_coarse1_loss: 1.1704 - val_predictions_coarse2_loss: 1.4380 - val_predictions_fine_loss: 2.1428 - val_predictions_coarse1_acc: 0.6240 - val_predictions_coarse2_acc: 0.5632 - val_predictions_fine_acc: 0.4674
# Changing loss weights to: coarse1 = 0.0, coarse2 = 3.656302985577921e-39, fine = 1.0
# Epoch 47/50
# 45000/45000 [==============================] - 34s 749us/step - loss: 0.3319 - predictions_coarse1_loss: 0.8813 - predictions_coarse2_loss: 0.7175 - predictions_fine_loss: 0.3319 - predictions_coarse1_acc: 0.7119 - predictions_coarse2_acc: 0.7878 - predictions_fine_acc: 0.9300 - val_loss: 2.1384 - val_predictions_coarse1_loss: 1.1769 - val_predictions_coarse2_loss: 1.4403 - val_predictions_fine_loss: 2.1384 - val_predictions_coarse1_acc: 0.6276 - val_predictions_coarse2_acc: 0.5606 - val_predictions_fine_acc: 0.4678
# Changing loss weights to: coarse1 = 0.0, coarse2 = 3.517259145455291e-43, fine = 1.0
# Epoch 48/50
# 45000/45000 [==============================] - 34s 748us/step - loss: 0.3182 - predictions_coarse1_loss: 0.8750 - predictions_coarse2_loss: 0.7108 - predictions_fine_loss: 0.3182 - predictions_coarse1_acc: 0.7130 - predictions_coarse2_acc: 0.7898 - predictions_fine_acc: 0.9316 - val_loss: 2.1509 - val_predictions_coarse1_loss: 1.1696 - val_predictions_coarse2_loss: 1.4358 - val_predictions_fine_loss: 2.1509 - val_predictions_coarse1_acc: 0.6352 - val_predictions_coarse2_acc: 0.5650 - val_predictions_fine_acc: 0.4676
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.0, fine = 1.0
# Epoch 49/50
# 45000/45000 [==============================] - 34s 749us/step - loss: 0.3007 - predictions_coarse1_loss: 0.8725 - predictions_coarse2_loss: 0.7105 - predictions_fine_loss: 0.3007 - predictions_coarse1_acc: 0.7150 - predictions_coarse2_acc: 0.7904 - predictions_fine_acc: 0.9391 - val_loss: 2.1505 - val_predictions_coarse1_loss: 1.1599 - val_predictions_coarse2_loss: 1.4278 - val_predictions_fine_loss: 2.1505 - val_predictions_coarse1_acc: 0.6304 - val_predictions_coarse2_acc: 0.5632 - val_predictions_fine_acc: 0.4696
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.0, fine = 1.0
# Epoch 50/50
# 45000/45000 [==============================] - 34s 749us/step - loss: 0.2825 - predictions_coarse1_loss: 0.8811 - predictions_coarse2_loss: 0.7081 - predictions_fine_loss: 0.2825 - predictions_coarse1_acc: 0.7116 - predictions_coarse2_acc: 0.7889 - predictions_fine_acc: 0.9442 - val_loss: 2.1683 - val_predictions_coarse1_loss: 1.1785 - val_predictions_coarse2_loss: 1.4432 - val_predictions_fine_loss: 2.1683 - val_predictions_coarse1_acc: 0.6236 - val_predictions_coarse2_acc: 0.5666 - val_predictions_fine_acc: 0.4616
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.0, fine = 1.0

# %%
model.evaluate(test_features, [y_test_c_cat1,y_test_c_cat2, y_test_cat])
# Out:
# 10000/10000 [==============================] - 5s 534us/step
# [2.0852878395080565,
#  1.1455978946685792,
#  1.402786441230774,
#  2.0852878395080565,
#  0.6393,
#  0.5749,
#  0.4821]

# %%
print('Total training time: {}'.format(training_time))
# Out:
# Total training time: 1716.6737546920776

# %%
model.save('drive/TCC-ITAU/cifar-100/models/adaptative-split-net.h5')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-bf8fa1ea8537> in <module>()
# ----> 1 model.save('drive/TCC-ITAU/cifar-100/models/adaptative-split-net.h5')
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/network.py in save(self, filepath, overwrite, include_optimizer)
#    1088             raise NotImplementedError
#    1089         from ..models import save_model
# -> 1090         save_model(self, filepath, overwrite, include_optimizer)
#    1091
#    1092     def save_weights(self, filepath, overwrite=True):
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py in save_model(model, filepath, overwrite, include_optimizer)
#     380
#     381     try:
# --> 382         _serialize_model(model, f, include_optimizer)
#     383     finally:
#     384         if opened_new_file:
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py in _serialize_model(model, f, include_optimizer)
#     136                 'sample_weight_mode': model.sample_weight_mode,
#     137                 'loss_weights': model.loss_weights,
# --> 138             }, default=get_json_type).encode('utf8')
#     139             symbolic_weights = getattr(model.optimizer, 'weights')
#     140             if symbolic_weights:
#
# /usr/lib/python3.6/json/__init__.py in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     236         check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     237         separators=separators, default=default, sort_keys=sort_keys,
# --> 238         **kw).encode(obj)
#     239
#     240
#
# /usr/lib/python3.6/json/encoder.py in encode(self, o)
#     197         # exceptions aren't as detailed.  The list call should be roughly
#     198         # equivalent to the PySequence_Fast that ''.join() would do.
# --> 199         chunks = self.iterencode(o, _one_shot=True)
#     200         if not isinstance(chunks, (list, tuple)):
#     201             chunks = list(chunks)
#
# /usr/lib/python3.6/json/encoder.py in iterencode(self, o, _one_shot)
#     255                 self.key_separator, self.item_separator, self.sort_keys,
#     256                 self.skipkeys, _one_shot)
# --> 257         return _iterencode(o, 0)
#     258
#     259 def _make_iterencode(markers, _default, _encoder, _indent, _floatstr,
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py in get_json_type(obj)
#      72             return obj.__name__
#      73
# ---> 74         raise TypeError('Not JSON Serializable: %s' % (obj,))
#      75
#      76     from .. import __version__ as keras_version
#
# TypeError: Not JSON Serializable: <tf.Variable 'alpha_1:0' shape=() dtype=float32_ref>
