# %% [markdown]
# ## Guide-net

# %%
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse

from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass

# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}

# %%
# !mkdir -p drive
# !google-drive-ocamlfuse drive
# Out:
# fuse: mountpoint is not empty
# fuse: if you are sure this is safe, use the 'nonempty' mount option

# %% [markdown]
# ## Loading the data

# %%
from time import time
import os
import gzip
import numpy as np
from keras.utils import np_utils
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

from keras.datasets import cifar100
# Out:
# Using TensorFlow backend.

# %%
(X_train, y_train), (X_test, y_test) = cifar100.load_data(label_mode='fine')
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, 
                                                  test_size=0.1, 
                                                  random_state=1974,
                                                  stratify = y_train)

# %%
train_features = X_train.reshape(X_train.shape[0], 32, 32, 3)/255
vali_features = X_val.reshape(X_val.shape[0], 32, 32, 3)/255
test_features = X_test.reshape(X_test.shape[0], 32, 32, 3)/255

y_train_cat = np_utils.to_categorical(y_train)
y_val_cat = np_utils.to_categorical(y_val)
y_test_cat = np_utils.to_categorical(y_test)

# %% [markdown]
# ## Defining coarse labels

# %%
dict_coarse2 = {0: 4,  1: 1,  2: 14,  3: 8,  4: 12,  5: 6,  6: 7,  7: 7,  8: 18,  9: 3,  10: 3,
                11: 14,  12: 9,  13: 18,  14: 7,  15: 11,  16: 3,  17: 9,  18: 7,  19: 11,  20: 6,
                21: 11,  22: 5,  23: 10,  24: 7,  25: 6,  26: 13,  27: 15,  28: 3,  29: 15,  30: 0,
                31: 11,  32: 1,  33: 10,  34: 12,  35: 14,  36: 16,  37: 9,  38: 11,  39: 5,  40: 5,
                41: 18,  42: 8,  43: 8,  44: 15,  45: 13,  46: 14,  47: 17,  48: 18,  49: 10,  50: 16,
                51: 4,  52: 17,  53: 4,  54: 2,  55: 12,  56: 17,  57: 4,  58: 18,  59: 17,  60: 10,
                61: 3,  62: 2,  63: 12,  64: 12,  65: 16,  66: 12,  67: 1,  68: 9,  69: 18,  70: 2,
                71: 10,  72: 12,  73: 1,  74: 16,  75: 12,  76: 9,  77: 13,  78: 15,  79: 13,  80: 16,
                81: 18,  82: 2,  83: 4,  84: 6,  85: 18,  86: 5,  87: 5,  88: 8,  89: 18,  90: 18,
                91: 1,  92: 2,  93: 15,  94: 6,  95: 0,  96: 17,  97: 8,  98: 14,  99: 13}


dict_coarse1 = {0: 0,
              1: 0,
              2: 1,
              3: 2,
              4: 1,
              5: 2,
              6: 2,
              7: 3,
              8: 4,
              9: 5,
              10: 5,
              11: 4,
              12: 4,
              13: 3,
              14: 6,
              15: 7,
              16: 4,
              17: 1,
              18: 8}

y_train_coarse2 = np.vectorize(dict_coarse2.get)(y_train)
y_val_coarse2 = np.vectorize(dict_coarse2.get)(y_val)
y_test_coarse2 = np.vectorize(dict_coarse2.get)(y_test)

y_train_coarse1 = np.vectorize(dict_coarse1.get)(y_train_coarse2)
y_val_coarse1 = np.vectorize(dict_coarse1.get)(y_val_coarse2)
y_test_coarse1 = np.vectorize(dict_coarse1.get)(y_test_coarse2)


y_train_c_cat1 = np_utils.to_categorical(y_train_coarse1)
y_val_c_cat1 = np_utils.to_categorical(y_val_coarse1)
y_test_c_cat1 = np_utils.to_categorical(y_test_coarse1)

y_train_c_cat2 = np_utils.to_categorical(y_train_coarse2)
y_val_c_cat2 = np_utils.to_categorical(y_val_coarse2)
y_test_c_cat2 = np_utils.to_categorical(y_test_coarse2)

# %% [markdown]
# ## Training the model

# %%
import keras
from keras.models import Model
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D, Input
from keras import optimizers
from keras.callbacks import TensorBoard, ReduceLROnPlateau, CSVLogger
from keras.layers.normalization import BatchNormalization
from keras import backend as K

# %%
class TimingCallback(keras.callbacks.Callback):
  """Callback that saves the time elapsed of each epoch to the log.
  """  
  def on_epoch_begin(self, epoch, logs={}):
    self.starttime=time()
  def on_epoch_end(self, epoch, logs={}):
    logs['time_elapsed'] = (time()-self.starttime)

# %%
class LossWeightsModifier3Vars(keras.callbacks.Callback):
  """Callback that modifies the loss weights on certain epochs.
    # Arguments
        alpha: coeficient for the coarser class.
        beta: coeficient for the second level coarse class.
        gamma: coeficient for the fine class.
  """  
  def __init__(self, alpha, beta, gamma):
    self.alpha = alpha
    self.beta = beta
    self.gamma = gamma
    
  def on_epoch_end(self, epoch, logs={}):

    if epoch == 4:
      K.set_value(self.alpha, 0.6)
      K.set_value(self.beta, 0.35)
      K.set_value(self.gamma, 0.05)
      print('Changing loss weights to: coarse1 = {}, coarse2 = {}, fine = {}'.format(K.eval(self.alpha), K.eval(self.beta), K.eval(self.gamma)))
    
    if epoch == 9:
      K.set_value(self.alpha, 0)
      K.set_value(self.beta, 0.8)
      K.set_value(self.gamma, 0.2)
      print('Changing loss weights to: coarse1 = {}, coarse2 = {}, fine = {}'.format(K.eval(self.alpha), K.eval(self.beta), K.eval(self.gamma)))
      
    if epoch == 14:
      K.set_value(self.alpha, 0)
      K.set_value(self.beta, 0.4)
      K.set_value(self.gamma, 0.6)  
      print('Changing loss weights to: coarse1 = {}, coarse2 = {}, fine = {}'.format(K.eval(self.alpha), K.eval(self.beta), K.eval(self.gamma)))
  
    if epoch == 21:
      K.set_value(self.alpha, 0)
      K.set_value(self.beta, 0)
      K.set_value(self.gamma, 1)  
      print('Changing loss weights to: coarse1 = {}, coarse2 = {}, fine = {}'.format(K.eval(self.alpha), K.eval(self.beta), K.eval(self.gamma)))
  
    logs['alpha'] = K.eval(self.alpha)
    logs['beta'] = K.eval(self.beta) 
    logs['gamma'] = K.eval(self.gamma)

# %%
img_rows, img_cols = 32, 32
input_shape = (img_rows, img_cols, 3)

num_classes_coarse1 = 9
num_classes_coarse2 = 19
num_classes_fine = 100

img_input = Input(shape=input_shape, name='input')

# coarse 1 network
coarse1 = Conv2D(64, (3, 3), activation='relu', name='c1_block1_conv1', padding='same')(img_input)
coarse1 = BatchNormalization()(coarse1)
coarse1 = Conv2D(64, (3, 3), activation='relu', name='c1_block1_conv2', padding='same')(coarse1)
coarse1 = BatchNormalization()(coarse1)
coarse1 = MaxPooling2D((2, 2), name='c1_block1_pool')(coarse1)

coarse1 = Conv2D(128, (3, 3), activation='relu', name='c1_block1_conv3', padding='same')(coarse1)
coarse1 = BatchNormalization()(coarse1)
coarse1 = Conv2D(128, (3, 3), activation='relu', name='c1_block1_conv4', padding='same')(coarse1)
coarse1 = BatchNormalization()(coarse1)
coarse1 = MaxPooling2D((2, 2), name='c1_block2_pool')(coarse1)

coarse1 = Conv2D(256, (3, 3), activation='relu', name='c1_block1_conv5', padding='same')(coarse1)
coarse1 = BatchNormalization()(coarse1)
coarse1 = Conv2D(256, (3, 3), activation='relu', name='c1_block1_conv6', padding='same')(coarse1)
coarse1 = BatchNormalization()(coarse1)
coarse1 = MaxPooling2D((2, 2), name='c1_block3_pool')(coarse1)

coarse1 = Conv2D(512, (3, 3), activation='relu', name='c1_block1_conv7', padding='same')(coarse1)
coarse1 = BatchNormalization()(coarse1)
coarse1 = Conv2D(512, (3, 3), activation='relu', name='c1_block1_conv8', padding='same')(coarse1)
coarse1 = BatchNormalization()(coarse1)

coarse1 = Flatten(name='c1_flatten')(coarse1)
coarse1 = Dense(1024, name='c1_fc_1')(coarse1)
coarse1 = BatchNormalization()(coarse1)
coarse1 = Activation('relu')(coarse1)
coarse1 = Dropout(0.5)(coarse1)

coarse1 = Dense(1024, name='c1_fc_2')(coarse1)
coarse1 = BatchNormalization()(coarse1)
coarse1 = Activation('relu')(coarse1)
coarse1 = Dropout(0.5)(coarse1)



# coarse 2 network
coarse2 = Conv2D(64, (3, 3), activation='relu', name='c2_block1_conv1', padding='same')(img_input)
coarse2 = BatchNormalization()(coarse2)
coarse2 = Conv2D(64, (3, 3), activation='relu', name='c2_block1_conv2', padding='same')(coarse2)
coarse2 = BatchNormalization()(coarse2)
coarse2 = MaxPooling2D((2, 2), name='c2_block1_pool')(coarse2)

coarse2 = Conv2D(128, (3, 3), activation='relu', name='c2_block1_conv3', padding='same')(coarse2)
coarse2 = BatchNormalization()(coarse2)
coarse2 = Conv2D(128, (3, 3), activation='relu', name='c2_block1_conv4', padding='same')(coarse2)
coarse2 = BatchNormalization()(coarse2)
coarse2 = MaxPooling2D((2, 2), name='c2_block2_pool')(coarse2)

coarse2 = Conv2D(256, (3, 3), activation='relu', name='c2_block1_conv5', padding='same')(coarse2)
coarse2 = BatchNormalization()(coarse2)
coarse2 = Conv2D(256, (3, 3), activation='relu', name='c2_block1_conv6', padding='same')(coarse2)
coarse2 = BatchNormalization()(coarse2)
coarse2 = MaxPooling2D((2, 2), name='c2_block3_pool')(coarse2)

coarse2 = Conv2D(512, (3, 3), activation='relu', name='c2_block1_conv7', padding='same')(coarse2)
coarse2 = BatchNormalization()(coarse2)
coarse2 = Conv2D(512, (3, 3), activation='relu', name='c2_block1_conv8', padding='same')(coarse2)
coarse2 = BatchNormalization()(coarse2)

coarse2 = Flatten(name='c2_flatten')(coarse2)
coarse2 = Dense(1024, name='c2_fc_1')(coarse2)
coarse2 = BatchNormalization()(coarse2)
coarse2 = Activation('relu')(coarse2)
coarse2 = Dropout(0.5)(coarse2)

coarse2 = Dense(1024, name='c2_fc_2')(coarse2)
coarse2 = BatchNormalization()(coarse2)
coarse2 = Activation('relu')(coarse2)
coarse2 = Dropout(0.5)(coarse2)

coarse2 = keras.layers.concatenate([coarse2, coarse1])


# fine network
fine = Conv2D(64, (3, 3), activation='relu', name='block1_conv1', padding='same')(img_input)
fine = BatchNormalization()(fine)
fine = Conv2D(64, (3, 3), activation='relu', name='block1_conv2', padding='same')(fine)
fine = BatchNormalization()(fine)
fine = MaxPooling2D((2, 2), name='block1_pool')(fine)

fine = Conv2D(128, (3, 3), activation='relu', name='block1_conv3', padding='same')(fine)
fine = BatchNormalization()(fine)
fine = Conv2D(128, (3, 3), activation='relu', name='block1_conv4', padding='same')(fine)
fine = BatchNormalization()(fine)
fine = MaxPooling2D((2, 2), name='block2_pool')(fine)

fine = Conv2D(256, (3, 3), activation='relu', name='block1_conv5', padding='same')(fine)
fine = BatchNormalization()(fine)
fine = Conv2D(256, (3, 3), activation='relu', name='block1_conv6', padding='same')(fine)
fine = BatchNormalization()(fine)
fine = MaxPooling2D((2, 2), name='block3_pool')(fine)

fine = Conv2D(512, (3, 3), activation='relu', name='block1_conv7', padding='same')(fine)
fine = BatchNormalization()(fine)
fine = Conv2D(512, (3, 3), activation='relu', name='block1_conv8', padding='same')(fine)
fine = BatchNormalization()(fine)

fine = Flatten(name='flatten')(fine)
fine = Dense(1024, name='fc_1')(fine)
fine = BatchNormalization()(fine)
fine = Activation('relu')(fine)
fine = Dropout(0.5)(fine)

fine = Dense(1024, name='fc_2')(fine)
fine = BatchNormalization()(fine)
fine = Activation('relu')(fine)
fine = Dropout(0.5)(fine)

fine = keras.layers.concatenate([fine, coarse2])

coarse_pred1 = Dense(num_classes_coarse1, activation='softmax', name='predictions_coarse1')(coarse1)
coarse_pred2 = Dense(num_classes_coarse2, activation='softmax', name='predictions_coarse2')(coarse2)
fine_pred = Dense(num_classes_fine, activation='softmax', name='predictions_fine')(fine)

# %%
model = Model(inputs=img_input, outputs= [coarse_pred1, coarse_pred2, fine_pred], name='guide_net')

model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# c1_block1_conv1 (Conv2D)        (None, 32, 32, 64)   1792        input[0][0]
# __________________________________________________________________________________________________
# c2_block1_conv1 (Conv2D)        (None, 32, 32, 64)   1792        input[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 32, 32, 64)   256         c1_block1_conv1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 32, 32, 64)   256         c2_block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 32, 32, 64)   1792        input[0][0]
# __________________________________________________________________________________________________
# c1_block1_conv2 (Conv2D)        (None, 32, 32, 64)   36928       batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# c2_block1_conv2 (Conv2D)        (None, 32, 32, 64)   36928       batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 32, 32, 64)   256         block1_conv1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 32, 32, 64)   256         c1_block1_conv2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 32, 32, 64)   256         c2_block1_conv2[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 32, 32, 64)   36928       batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# c1_block1_pool (MaxPooling2D)   (None, 16, 16, 64)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# c2_block1_pool (MaxPooling2D)   (None, 16, 16, 64)   0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 32, 32, 64)   256         block1_conv2[0][0]
# __________________________________________________________________________________________________
# c1_block1_conv3 (Conv2D)        (None, 16, 16, 128)  73856       c1_block1_pool[0][0]
# __________________________________________________________________________________________________
# c2_block1_conv3 (Conv2D)        (None, 16, 16, 128)  73856       c2_block1_pool[0][0]
# __________________________________________________________________________________________________
# block1_pool (MaxPooling2D)      (None, 16, 16, 64)   0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 16, 16, 128)  512         c1_block1_conv3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 16, 16, 128)  512         c2_block1_conv3[0][0]
# __________________________________________________________________________________________________
# block1_conv3 (Conv2D)           (None, 16, 16, 128)  73856       block1_pool[0][0]
# __________________________________________________________________________________________________
# c1_block1_conv4 (Conv2D)        (None, 16, 16, 128)  147584      batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# c2_block1_conv4 (Conv2D)        (None, 16, 16, 128)  147584      batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 16, 16, 128)  512         block1_conv3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 16, 16, 128)  512         c1_block1_conv4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 16, 16, 128)  512         c2_block1_conv4[0][0]
# __________________________________________________________________________________________________
# block1_conv4 (Conv2D)           (None, 16, 16, 128)  147584      batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# c1_block2_pool (MaxPooling2D)   (None, 8, 8, 128)    0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# c2_block2_pool (MaxPooling2D)   (None, 8, 8, 128)    0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 16, 16, 128)  512         block1_conv4[0][0]
# __________________________________________________________________________________________________
# c1_block1_conv5 (Conv2D)        (None, 8, 8, 256)    295168      c1_block2_pool[0][0]
# __________________________________________________________________________________________________
# c2_block1_conv5 (Conv2D)        (None, 8, 8, 256)    295168      c2_block2_pool[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 8, 8, 128)    0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 8, 8, 256)    1024        c1_block1_conv5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 8, 8, 256)    1024        c2_block1_conv5[0][0]
# __________________________________________________________________________________________________
# block1_conv5 (Conv2D)           (None, 8, 8, 256)    295168      block2_pool[0][0]
# __________________________________________________________________________________________________
# c1_block1_conv6 (Conv2D)        (None, 8, 8, 256)    590080      batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# c2_block1_conv6 (Conv2D)        (None, 8, 8, 256)    590080      batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 8, 8, 256)    1024        block1_conv5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 8, 8, 256)    1024        c1_block1_conv6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 8, 8, 256)    1024        c2_block1_conv6[0][0]
# __________________________________________________________________________________________________
# block1_conv6 (Conv2D)           (None, 8, 8, 256)    590080      batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# c1_block3_pool (MaxPooling2D)   (None, 4, 4, 256)    0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# c2_block3_pool (MaxPooling2D)   (None, 4, 4, 256)    0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 8, 8, 256)    1024        block1_conv6[0][0]
# __________________________________________________________________________________________________
# c1_block1_conv7 (Conv2D)        (None, 4, 4, 512)    1180160     c1_block3_pool[0][0]
# __________________________________________________________________________________________________
# c2_block1_conv7 (Conv2D)        (None, 4, 4, 512)    1180160     c2_block3_pool[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 4, 4, 256)    0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 4, 4, 512)    2048        c1_block1_conv7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 4, 4, 512)    2048        c2_block1_conv7[0][0]
# __________________________________________________________________________________________________
# block1_conv7 (Conv2D)           (None, 4, 4, 512)    1180160     block3_pool[0][0]
# __________________________________________________________________________________________________
# c1_block1_conv8 (Conv2D)        (None, 4, 4, 512)    2359808     batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# c2_block1_conv8 (Conv2D)        (None, 4, 4, 512)    2359808     batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 4, 4, 512)    2048        block1_conv7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 4, 4, 512)    2048        c1_block1_conv8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 4, 4, 512)    2048        c2_block1_conv8[0][0]
# __________________________________________________________________________________________________
# block1_conv8 (Conv2D)           (None, 4, 4, 512)    2359808     batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# c1_flatten (Flatten)            (None, 8192)         0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# c2_flatten (Flatten)            (None, 8192)         0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 4, 4, 512)    2048        block1_conv8[0][0]
# __________________________________________________________________________________________________
# c1_fc_1 (Dense)                 (None, 1024)         8389632     c1_flatten[0][0]
# __________________________________________________________________________________________________
# c2_fc_1 (Dense)                 (None, 1024)         8389632     c2_flatten[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 8192)         0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 1024)         4096        c1_fc_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 1024)         4096        c2_fc_1[0][0]
# __________________________________________________________________________________________________
# fc_1 (Dense)                    (None, 1024)         8389632     flatten[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 1024)         0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 1024)         0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 1024)         4096        fc_1[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 1024)         0           activation_7[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 1024)         0           activation_9[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 1024)         0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# c1_fc_2 (Dense)                 (None, 1024)         1049600     dropout_7[0][0]
# __________________________________________________________________________________________________
# c2_fc_2 (Dense)                 (None, 1024)         1049600     dropout_9[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 1024)         0           activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 1024)         4096        c1_fc_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 1024)         4096        c2_fc_2[0][0]
# __________________________________________________________________________________________________
# fc_2 (Dense)                    (None, 1024)         1049600     dropout_11[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 1024)         0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 1024)         0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 1024)         4096        fc_2[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 1024)         0           activation_8[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 1024)         0           activation_10[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 1024)         0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 2048)         0           dropout_10[0][0]
#                                                                  dropout_8[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 1024)         0           activation_12[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 3072)         0           dropout_12[0][0]
#                                                                  concatenate_3[0][0]
# __________________________________________________________________________________________________
# predictions_coarse1 (Dense)     (None, 9)            9225        dropout_8[0][0]
# __________________________________________________________________________________________________
# predictions_coarse2 (Dense)     (None, 19)           38931       concatenate_3[0][0]
# __________________________________________________________________________________________________
# predictions_fine (Dense)        (None, 100)          307300      concatenate_4[0][0]
# ==================================================================================================
# Total params: 42,776,896
# Trainable params: 42,753,088
# Non-trainable params: 23,808
# __________________________________________________________________________________________________

# %%
alpha = K.variable(value=0.9, dtype="float32", name="alpha") 
beta = K.variable(value=0.1, dtype="float32", name="beta") 
gamma = K.variable(value=0, dtype="float32", name="gamma") 

sgd = optimizers.SGD(lr=0.001, momentum=0.9, nesterov=True)

model.compile(loss='categorical_crossentropy', 
              optimizer=sgd,
              loss_weights=[alpha, beta, gamma],
              metrics=['accuracy'])

# %%
clr_cb = ReduceLROnPlateau(monitor='val_predictions_fine_loss', factor=0.5, patience=10, verbose=1, min_lr=3.125e-05)
time_cb = TimingCallback()
change_lw = LossWeightsModifier3Vars(alpha, beta, gamma)
csv_cb = CSVLogger('drive/TCC-ITAU/cifar-100/training-data/guide-net/guide-net.csv', separator=',', append=False)


cbks = [clr_cb, time_cb, change_lw, csv_cb]

# %%
epochs = 50
start_time = time()
training = model.fit(train_features, [y_train_c_cat1, y_train_c_cat2, y_train_cat],
                     validation_data=(vali_features, [y_val_c_cat1, y_val_c_cat2, y_val_cat]),
                     epochs=epochs,
                     batch_size=256, 
                     callbacks=cbks,
                     verbose=1)
training_time = time() - start_time
# Out:
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/50
# 45000/45000 [==============================] - 106s 2ms/step - loss: 2.2164 - predictions_coarse1_loss: 2.0899 - predictions_coarse2_loss: 3.3553 - predictions_fine_loss: 5.5138 - predictions_coarse1_acc: 0.3263 - predictions_coarse2_acc: 0.0912 - predictions_fine_acc: 0.0107 - val_loss: 1.8479 - val_predictions_coarse1_loss: 1.7549 - val_predictions_coarse2_loss: 2.6848 - val_predictions_fine_loss: 4.8486 - val_predictions_coarse1_acc: 0.4350 - val_predictions_coarse2_acc: 0.1954 - val_predictions_fine_acc: 0.0120
# Epoch 2/50
# 45000/45000 [==============================] - 95s 2ms/step - loss: 1.8139 - predictions_coarse1_loss: 1.6884 - predictions_coarse2_loss: 2.9431 - predictions_fine_loss: 5.4993 - predictions_coarse1_acc: 0.4417 - predictions_coarse2_acc: 0.1582 - predictions_fine_acc: 0.0100 - val_loss: 1.5861 - val_predictions_coarse1_loss: 1.4862 - val_predictions_coarse2_loss: 2.4854 - val_predictions_fine_loss: 4.8095 - val_predictions_coarse1_acc: 0.4962 - val_predictions_coarse2_acc: 0.2504 - val_predictions_fine_acc: 0.0112
# Epoch 3/50
# 45000/45000 [==============================] - 95s 2ms/step - loss: 1.6423 - predictions_coarse1_loss: 1.5210 - predictions_coarse2_loss: 2.7336 - predictions_fine_loss: 5.4778 - predictions_coarse1_acc: 0.4922 - predictions_coarse2_acc: 0.2023 - predictions_fine_acc: 0.0101 - val_loss: 1.5160 - val_predictions_coarse1_loss: 1.4263 - val_predictions_coarse2_loss: 2.3235 - val_predictions_fine_loss: 4.7884 - val_predictions_coarse1_acc: 0.5228 - val_predictions_coarse2_acc: 0.2928 - val_predictions_fine_acc: 0.0110
# Epoch 4/50
# 45000/45000 [==============================] - 95s 2ms/step - loss: 1.5197 - predictions_coarse1_loss: 1.3992 - predictions_coarse2_loss: 2.6045 - predictions_fine_loss: 5.4706 - predictions_coarse1_acc: 0.5331 - predictions_coarse2_acc: 0.2322 - predictions_fine_acc: 0.0096 - val_loss: 1.4477 - val_predictions_coarse1_loss: 1.3556 - val_predictions_coarse2_loss: 2.2768 - val_predictions_fine_loss: 4.7934 - val_predictions_coarse1_acc: 0.5412 - val_predictions_coarse2_acc: 0.3078 - val_predictions_fine_acc: 0.0094
# Epoch 5/50
# 45000/45000 [==============================] - 95s 2ms/step - loss: 1.4264 - predictions_coarse1_loss: 1.3075 - predictions_coarse2_loss: 2.4966 - predictions_fine_loss: 5.4616 - predictions_coarse1_acc: 0.5651 - predictions_coarse2_acc: 0.2586 - predictions_fine_acc: 0.0103 - val_loss: 1.4448 - val_predictions_coarse1_loss: 1.3620 - val_predictions_coarse2_loss: 2.1901 - val_predictions_fine_loss: 4.7885 - val_predictions_coarse1_acc: 0.5412 - val_predictions_coarse2_acc: 0.3426 - val_predictions_fine_acc: 0.0138
# Changing loss weights to: coarse1 = 0.6000000238418579, coarse2 = 0.3499999940395355, fine = 0.05000000074505806
# Epoch 6/50
# 45000/45000 [==============================] - 95s 2ms/step - loss: 1.8100 - predictions_coarse1_loss: 1.2116 - predictions_coarse2_loss: 2.3351 - predictions_fine_loss: 5.3143 - predictions_coarse1_acc: 0.5981 - predictions_coarse2_acc: 0.3006 - predictions_fine_acc: 0.0134 - val_loss: 1.6631 - val_predictions_coarse1_loss: 1.2156 - val_predictions_coarse2_loss: 2.0141 - val_predictions_fine_loss: 4.5767 - val_predictions_coarse1_acc: 0.5960 - val_predictions_coarse2_acc: 0.3824 - val_predictions_fine_acc: 0.0316
# Epoch 7/50
# 45000/45000 [==============================] - 95s 2ms/step - loss: 1.6978 - predictions_coarse1_loss: 1.1549 - predictions_coarse2_loss: 2.1459 - predictions_fine_loss: 5.0762 - predictions_coarse1_acc: 0.6159 - predictions_coarse2_acc: 0.3470 - predictions_fine_acc: 0.0207 - val_loss: 1.6631 - val_predictions_coarse1_loss: 1.2679 - val_predictions_coarse2_loss: 1.9466 - val_predictions_fine_loss: 4.4213 - val_predictions_coarse1_acc: 0.5742 - val_predictions_coarse2_acc: 0.4026 - val_predictions_fine_acc: 0.0546
# Epoch 8/50
# 45000/45000 [==============================] - 95s 2ms/step - loss: 1.6036 - predictions_coarse1_loss: 1.0944 - predictions_coarse2_loss: 2.0049 - predictions_fine_loss: 4.9047 - predictions_coarse1_acc: 0.6333 - predictions_coarse2_acc: 0.3828 - predictions_fine_acc: 0.0274 - val_loss: 1.5826 - val_predictions_coarse1_loss: 1.1946 - val_predictions_coarse2_loss: 1.8586 - val_predictions_fine_loss: 4.3062 - val_predictions_coarse1_acc: 0.6052 - val_predictions_coarse2_acc: 0.4214 - val_predictions_fine_acc: 0.0690
# Epoch 9/50
# 45000/45000 [==============================] - 95s 2ms/step - loss: 1.5187 - predictions_coarse1_loss: 1.0288 - predictions_coarse2_loss: 1.8958 - predictions_fine_loss: 4.7578 - predictions_coarse1_acc: 0.6558 - predictions_coarse2_acc: 0.4111 - predictions_fine_acc: 0.0370 - val_loss: 1.5262 - val_predictions_coarse1_loss: 1.1536 - val_predictions_coarse2_loss: 1.7861 - val_predictions_fine_loss: 4.1778 - val_predictions_coarse1_acc: 0.6234 - val_predictions_coarse2_acc: 0.4526 - val_predictions_fine_acc: 0.0960
# Epoch 10/50
# 45000/45000 [==============================] - 95s 2ms/step - loss: 1.4454 - predictions_coarse1_loss: 0.9800 - predictions_coarse2_loss: 1.7864 - predictions_fine_loss: 4.6442 - predictions_coarse1_acc: 0.6739 - predictions_coarse2_acc: 0.4390 - predictions_fine_acc: 0.0463 - val_loss: 1.5014 - val_predictions_coarse1_loss: 1.1469 - val_predictions_coarse2_loss: 1.7374 - val_predictions_fine_loss: 4.1034 - val_predictions_coarse1_acc: 0.6242 - val_predictions_coarse2_acc: 0.4600 - val_predictions_fine_acc: 0.1068
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.800000011920929, fine = 0.20000000298023224
# Epoch 11/50
# 45000/45000 [==============================] - 95s 2ms/step - loss: 2.2496 - predictions_coarse1_loss: 0.9435 - predictions_coarse2_loss: 1.6960 - predictions_fine_loss: 4.4637 - predictions_coarse1_acc: 0.6840 - predictions_coarse2_acc: 0.4641 - predictions_fine_acc: 0.0642 - val_loss: 2.1487 - val_predictions_coarse1_loss: 1.1650 - val_predictions_coarse2_loss: 1.7143 - val_predictions_fine_loss: 3.8865 - val_predictions_coarse1_acc: 0.6278 - val_predictions_coarse2_acc: 0.4706 - val_predictions_fine_acc: 0.1412
# Epoch 12/50
# 45000/45000 [==============================] - 95s 2ms/step - loss: 2.1109 - predictions_coarse1_loss: 0.9367 - predictions_coarse2_loss: 1.5953 - predictions_fine_loss: 4.1733 - predictions_coarse1_acc: 0.6855 - predictions_coarse2_acc: 0.4929 - predictions_fine_acc: 0.0929 - val_loss: 2.1176 - val_predictions_coarse1_loss: 1.1981 - val_predictions_coarse2_loss: 1.7261 - val_predictions_fine_loss: 3.6834 - val_predictions_coarse1_acc: 0.6162 - val_predictions_coarse2_acc: 0.4660 - val_predictions_fine_acc: 0.1742
# Epoch 13/50
# 45000/45000 [==============================] - 95s 2ms/step - loss: 1.9850 - predictions_coarse1_loss: 0.9088 - predictions_coarse2_loss: 1.4941 - predictions_fine_loss: 3.9490 - predictions_coarse1_acc: 0.6954 - predictions_coarse2_acc: 0.5207 - predictions_fine_acc: 0.1207 - val_loss: 1.9853 - val_predictions_coarse1_loss: 1.1323 - val_predictions_coarse2_loss: 1.6034 - val_predictions_fine_loss: 3.5128 - val_predictions_coarse1_acc: 0.6200 - val_predictions_coarse2_acc: 0.4910 - val_predictions_fine_acc: 0.2036
# Epoch 14/50
# 45000/45000 [==============================] - 95s 2ms/step - loss: 1.8779 - predictions_coarse1_loss: 0.8800 - predictions_coarse2_loss: 1.4026 - predictions_fine_loss: 3.7790 - predictions_coarse1_acc: 0.7056 - predictions_coarse2_acc: 0.5483 - predictions_fine_acc: 0.1433 - val_loss: 1.9887 - val_predictions_coarse1_loss: 1.1778 - val_predictions_coarse2_loss: 1.6334 - val_predictions_fine_loss: 3.4099 - val_predictions_coarse1_acc: 0.6082 - val_predictions_coarse2_acc: 0.5042 - val_predictions_fine_acc: 0.2218
# Epoch 15/50
# 45000/45000 [==============================] - 95s 2ms/step - loss: 1.7870 - predictions_coarse1_loss: 0.8549 - predictions_coarse2_loss: 1.3297 - predictions_fine_loss: 3.6162 - predictions_coarse1_acc: 0.7123 - predictions_coarse2_acc: 0.5693 - predictions_fine_acc: 0.1650 - val_loss: 1.9006 - val_predictions_coarse1_loss: 1.0988 - val_predictions_coarse2_loss: 1.5565 - val_predictions_fine_loss: 3.2769 - val_predictions_coarse1_acc: 0.6430 - val_predictions_coarse2_acc: 0.5218 - val_predictions_fine_acc: 0.2362
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.4000000059604645, fine = 0.6000000238418579
# Epoch 16/50
# 45000/45000 [==============================] - 95s 2ms/step - loss: 2.5479 - predictions_coarse1_loss: 0.8202 - predictions_coarse2_loss: 1.2612 - predictions_fine_loss: 3.4058 - predictions_coarse1_acc: 0.7253 - predictions_coarse2_acc: 0.5893 - predictions_fine_acc: 0.1931 - val_loss: 2.4533 - val_predictions_coarse1_loss: 1.0615 - val_predictions_coarse2_loss: 1.5220 - val_predictions_fine_loss: 3.0742 - val_predictions_coarse1_acc: 0.6534 - val_predictions_coarse2_acc: 0.5328 - val_predictions_fine_acc: 0.2694
# Epoch 17/50
# 45000/45000 [==============================] - 95s 2ms/step - loss: 2.3488 - predictions_coarse1_loss: 0.8034 - predictions_coarse2_loss: 1.2238 - predictions_fine_loss: 3.0987 - predictions_coarse1_acc: 0.7304 - predictions_coarse2_acc: 0.5974 - predictions_fine_acc: 0.2388 - val_loss: 2.3546 - val_predictions_coarse1_loss: 1.0709 - val_predictions_coarse2_loss: 1.5189 - val_predictions_fine_loss: 2.9117 - val_predictions_coarse1_acc: 0.6544 - val_predictions_coarse2_acc: 0.5296 - val_predictions_fine_acc: 0.2844
# Epoch 18/50
# 45000/45000 [==============================] - 95s 2ms/step - loss: 2.2141 - predictions_coarse1_loss: 0.7884 - predictions_coarse2_loss: 1.1805 - predictions_fine_loss: 2.9031 - predictions_coarse1_acc: 0.7373 - predictions_coarse2_acc: 0.6098 - predictions_fine_acc: 0.2720 - val_loss: 2.2509 - val_predictions_coarse1_loss: 1.0580 - val_predictions_coarse2_loss: 1.4995 - val_predictions_fine_loss: 2.7517 - val_predictions_coarse1_acc: 0.6634 - val_predictions_coarse2_acc: 0.5420 - val_predictions_fine_acc: 0.3188
# Epoch 19/50
# 45000/45000 [==============================] - 95s 2ms/step - loss: 2.0913 - predictions_coarse1_loss: 0.7711 - predictions_coarse2_loss: 1.1377 - predictions_fine_loss: 2.7270 - predictions_coarse1_acc: 0.7422 - predictions_coarse2_acc: 0.6230 - predictions_fine_acc: 0.3016 - val_loss: 2.2128 - val_predictions_coarse1_loss: 1.0922 - val_predictions_coarse2_loss: 1.5127 - val_predictions_fine_loss: 2.6795 - val_predictions_coarse1_acc: 0.6438 - val_predictions_coarse2_acc: 0.5408 - val_predictions_fine_acc: 0.3304
# Epoch 20/50
# 45000/45000 [==============================] - 95s 2ms/step - loss: 1.9842 - predictions_coarse1_loss: 0.7381 - predictions_coarse2_loss: 1.0870 - predictions_fine_loss: 2.5824 - predictions_coarse1_acc: 0.7521 - predictions_coarse2_acc: 0.6384 - predictions_fine_acc: 0.3268 - val_loss: 2.2420 - val_predictions_coarse1_loss: 1.1537 - val_predictions_coarse2_loss: 1.6146 - val_predictions_fine_loss: 2.6603 - val_predictions_coarse1_acc: 0.6400 - val_predictions_coarse2_acc: 0.5284 - val_predictions_fine_acc: 0.3334
# Epoch 21/50
# 45000/45000 [==============================] - 95s 2ms/step - loss: 1.8791 - predictions_coarse1_loss: 0.7106 - predictions_coarse2_loss: 1.0260 - predictions_fine_loss: 2.4478 - predictions_coarse1_acc: 0.7610 - predictions_coarse2_acc: 0.6564 - predictions_fine_acc: 0.3548 - val_loss: 2.0852 - val_predictions_coarse1_loss: 1.0501 - val_predictions_coarse2_loss: 1.4389 - val_predictions_fine_loss: 2.5160 - val_predictions_coarse1_acc: 0.6626 - val_predictions_coarse2_acc: 0.5578 - val_predictions_fine_acc: 0.3620
# Epoch 22/50
# 45000/45000 [==============================] - 95s 2ms/step - loss: 1.7765 - predictions_coarse1_loss: 0.6797 - predictions_coarse2_loss: 0.9733 - predictions_fine_loss: 2.3120 - predictions_coarse1_acc: 0.7717 - predictions_coarse2_acc: 0.6736 - predictions_fine_acc: 0.3799 - val_loss: 2.0653 - val_predictions_coarse1_loss: 1.0852 - val_predictions_coarse2_loss: 1.4630 - val_predictions_fine_loss: 2.4668 - val_predictions_coarse1_acc: 0.6538 - val_predictions_coarse2_acc: 0.5632 - val_predictions_fine_acc: 0.3646
# Changing loss weights to: coarse1 = 0.0, coarse2 = 0.0, fine = 1.0
# Epoch 23/50
# 45000/45000 [==============================] - 95s 2ms/step - loss: 2.2231 - predictions_coarse1_loss: 0.6833 - predictions_coarse2_loss: 0.9597 - predictions_fine_loss: 2.2231 - predictions_coarse1_acc: 0.7693 - predictions_coarse2_acc: 0.6717 - predictions_fine_acc: 0.3910 - val_loss: 2.4724 - val_predictions_coarse1_loss: 1.1030 - val_predictions_coarse2_loss: 1.5248 - val_predictions_fine_loss: 2.4724 - val_predictions_coarse1_acc: 0.6400 - val_predictions_coarse2_acc: 0.5474 - val_predictions_fine_acc: 0.3644
# Epoch 24/50
# 45000/45000 [==============================] - 95s 2ms/step - loss: 2.0892 - predictions_coarse1_loss: 0.6813 - predictions_coarse2_loss: 0.9586 - predictions_fine_loss: 2.0892 - predictions_coarse1_acc: 0.7722 - predictions_coarse2_acc: 0.6731 - predictions_fine_acc: 0.4261 - val_loss: 2.3759 - val_predictions_coarse1_loss: 1.0740 - val_predictions_coarse2_loss: 1.4710 - val_predictions_fine_loss: 2.3759 - val_predictions_coarse1_acc: 0.6618 - val_predictions_coarse2_acc: 0.5606 - val_predictions_fine_acc: 0.3874
# Epoch 25/50
# 45000/45000 [==============================] - 95s 2ms/step - loss: 1.9714 - predictions_coarse1_loss: 0.6700 - predictions_coarse2_loss: 0.9461 - predictions_fine_loss: 1.9714 - predictions_coarse1_acc: 0.7741 - predictions_coarse2_acc: 0.6808 - predictions_fine_acc: 0.4491 - val_loss: 2.3552 - val_predictions_coarse1_loss: 1.1414 - val_predictions_coarse2_loss: 1.5001 - val_predictions_fine_loss: 2.3552 - val_predictions_coarse1_acc: 0.6278 - val_predictions_coarse2_acc: 0.5536 - val_predictions_fine_acc: 0.3876
# Epoch 26/50
# 45000/45000 [==============================] - 95s 2ms/step - loss: 1.8482 - predictions_coarse1_loss: 0.6472 - predictions_coarse2_loss: 0.9256 - predictions_fine_loss: 1.8482 - predictions_coarse1_acc: 0.7836 - predictions_coarse2_acc: 0.6827 - predictions_fine_acc: 0.4808 - val_loss: 2.3357 - val_predictions_coarse1_loss: 1.1288 - val_predictions_coarse2_loss: 1.5018 - val_predictions_fine_loss: 2.3357 - val_predictions_coarse1_acc: 0.6560 - val_predictions_coarse2_acc: 0.5634 - val_predictions_fine_acc: 0.4030
# Epoch 27/50
# 45000/45000 [==============================] - 95s 2ms/step - loss: 1.7375 - predictions_coarse1_loss: 0.6216 - predictions_coarse2_loss: 0.9003 - predictions_fine_loss: 1.7375 - predictions_coarse1_acc: 0.7916 - predictions_coarse2_acc: 0.6903 - predictions_fine_acc: 0.5077 - val_loss: 2.3543 - val_predictions_coarse1_loss: 1.1546 - val_predictions_coarse2_loss: 1.5625 - val_predictions_fine_loss: 2.3543 - val_predictions_coarse1_acc: 0.6394 - val_predictions_coarse2_acc: 0.5404 - val_predictions_fine_acc: 0.4006
# Epoch 28/50
# 45000/45000 [==============================] - 95s 2ms/step - loss: 1.6351 - predictions_coarse1_loss: 0.6045 - predictions_coarse2_loss: 0.8804 - predictions_fine_loss: 1.6351 - predictions_coarse1_acc: 0.7998 - predictions_coarse2_acc: 0.6982 - predictions_fine_acc: 0.5318 - val_loss: 2.2796 - val_predictions_coarse1_loss: 1.1103 - val_predictions_coarse2_loss: 1.4746 - val_predictions_fine_loss: 2.2796 - val_predictions_coarse1_acc: 0.6524 - val_predictions_coarse2_acc: 0.5594 - val_predictions_fine_acc: 0.4148
# Epoch 29/50
# 45000/45000 [==============================] - 95s 2ms/step - loss: 1.5260 - predictions_coarse1_loss: 0.5798 - predictions_coarse2_loss: 0.8468 - predictions_fine_loss: 1.5260 - predictions_coarse1_acc: 0.8068 - predictions_coarse2_acc: 0.7084 - predictions_fine_acc: 0.5576 - val_loss: 2.2364 - val_predictions_coarse1_loss: 1.1152 - val_predictions_coarse2_loss: 1.4568 - val_predictions_fine_loss: 2.2364 - val_predictions_coarse1_acc: 0.6530 - val_predictions_coarse2_acc: 0.5618 - val_predictions_fine_acc: 0.4230
# Epoch 30/50
# 45000/45000 [==============================] - 95s 2ms/step - loss: 1.4208 - predictions_coarse1_loss: 0.5596 - predictions_coarse2_loss: 0.8257 - predictions_fine_loss: 1.4208 - predictions_coarse1_acc: 0.8153 - predictions_coarse2_acc: 0.7137 - predictions_fine_acc: 0.5885 - val_loss: 2.2268 - val_predictions_coarse1_loss: 1.1421 - val_predictions_coarse2_loss: 1.4767 - val_predictions_fine_loss: 2.2268 - val_predictions_coarse1_acc: 0.6374 - val_predictions_coarse2_acc: 0.5556 - val_predictions_fine_acc: 0.4216
# Epoch 31/50
# 45000/45000 [==============================] - 95s 2ms/step - loss: 1.3332 - predictions_coarse1_loss: 0.5468 - predictions_coarse2_loss: 0.8012 - predictions_fine_loss: 1.3332 - predictions_coarse1_acc: 0.8203 - predictions_coarse2_acc: 0.7203 - predictions_fine_acc: 0.6095 - val_loss: 2.2125 - val_predictions_coarse1_loss: 1.1149 - val_predictions_coarse2_loss: 1.4592 - val_predictions_fine_loss: 2.2125 - val_predictions_coarse1_acc: 0.6474 - val_predictions_coarse2_acc: 0.5644 - val_predictions_fine_acc: 0.4286
# Epoch 32/50
# 45000/45000 [==============================] - 95s 2ms/step - loss: 1.2403 - predictions_coarse1_loss: 0.5237 - predictions_coarse2_loss: 0.7777 - predictions_fine_loss: 1.2403 - predictions_coarse1_acc: 0.8262 - predictions_coarse2_acc: 0.7305 - predictions_fine_acc: 0.6350 - val_loss: 2.1928 - val_predictions_coarse1_loss: 1.0746 - val_predictions_coarse2_loss: 1.4510 - val_predictions_fine_loss: 2.1928 - val_predictions_coarse1_acc: 0.6632 - val_predictions_coarse2_acc: 0.5694 - val_predictions_fine_acc: 0.4350
# Epoch 33/50
# 45000/45000 [==============================] - 95s 2ms/step - loss: 1.1573 - predictions_coarse1_loss: 0.5077 - predictions_coarse2_loss: 0.7546 - predictions_fine_loss: 1.1573 - predictions_coarse1_acc: 0.8344 - predictions_coarse2_acc: 0.7379 - predictions_fine_acc: 0.6572 - val_loss: 2.2176 - val_predictions_coarse1_loss: 1.1075 - val_predictions_coarse2_loss: 1.4814 - val_predictions_fine_loss: 2.2176 - val_predictions_coarse1_acc: 0.6528 - val_predictions_coarse2_acc: 0.5578 - val_predictions_fine_acc: 0.4334
# Epoch 34/50
# 45000/45000 [==============================] - 95s 2ms/step - loss: 1.0735 - predictions_coarse1_loss: 0.4898 - predictions_coarse2_loss: 0.7323 - predictions_fine_loss: 1.0735 - predictions_coarse1_acc: 0.8405 - predictions_coarse2_acc: 0.7466 - predictions_fine_acc: 0.6842 - val_loss: 2.1953 - val_predictions_coarse1_loss: 1.1245 - val_predictions_coarse2_loss: 1.4663 - val_predictions_fine_loss: 2.1953 - val_predictions_coarse1_acc: 0.6468 - val_predictions_coarse2_acc: 0.5666 - val_predictions_fine_acc: 0.4420
# Epoch 35/50
# 45000/45000 [==============================] - 95s 2ms/step - loss: 0.9940 - predictions_coarse1_loss: 0.4840 - predictions_coarse2_loss: 0.7156 - predictions_fine_loss: 0.9940 - predictions_coarse1_acc: 0.8426 - predictions_coarse2_acc: 0.7523 - predictions_fine_acc: 0.7065 - val_loss: 2.1911 - val_predictions_coarse1_loss: 1.1294 - val_predictions_coarse2_loss: 1.4880 - val_predictions_fine_loss: 2.1911 - val_predictions_coarse1_acc: 0.6420 - val_predictions_coarse2_acc: 0.5576 - val_predictions_fine_acc: 0.4394
# Epoch 36/50
# 45000/45000 [==============================] - 95s 2ms/step - loss: 0.9220 - predictions_coarse1_loss: 0.4724 - predictions_coarse2_loss: 0.6965 - predictions_fine_loss: 0.9220 - predictions_coarse1_acc: 0.8475 - predictions_coarse2_acc: 0.7592 - predictions_fine_acc: 0.7310 - val_loss: 2.1888 - val_predictions_coarse1_loss: 1.1208 - val_predictions_coarse2_loss: 1.4655 - val_predictions_fine_loss: 2.1888 - val_predictions_coarse1_acc: 0.6500 - val_predictions_coarse2_acc: 0.5618 - val_predictions_fine_acc: 0.4456
# Epoch 37/50
# 45000/45000 [==============================] - 95s 2ms/step - loss: 0.8483 - predictions_coarse1_loss: 0.4555 - predictions_coarse2_loss: 0.6767 - predictions_fine_loss: 0.8483 - predictions_coarse1_acc: 0.8534 - predictions_coarse2_acc: 0.7662 - predictions_fine_acc: 0.7553 - val_loss: 2.1947 - val_predictions_coarse1_loss: 1.0926 - val_predictions_coarse2_loss: 1.4569 - val_predictions_fine_loss: 2.1947 - val_predictions_coarse1_acc: 0.6596 - val_predictions_coarse2_acc: 0.5684 - val_predictions_fine_acc: 0.4486
# Epoch 38/50
# 45000/45000 [==============================] - 95s 2ms/step - loss: 0.7777 - predictions_coarse1_loss: 0.4507 - predictions_coarse2_loss: 0.6595 - predictions_fine_loss: 0.7777 - predictions_coarse1_acc: 0.8550 - predictions_coarse2_acc: 0.7740 - predictions_fine_acc: 0.7770 - val_loss: 2.2141 - val_predictions_coarse1_loss: 1.1187 - val_predictions_coarse2_loss: 1.4798 - val_predictions_fine_loss: 2.2141 - val_predictions_coarse1_acc: 0.6502 - val_predictions_coarse2_acc: 0.5600 - val_predictions_fine_acc: 0.4442
# Epoch 39/50
# 45000/45000 [==============================] - 95s 2ms/step - loss: 0.7147 - predictions_coarse1_loss: 0.4421 - predictions_coarse2_loss: 0.6481 - predictions_fine_loss: 0.7147 - predictions_coarse1_acc: 0.8585 - predictions_coarse2_acc: 0.7782 - predictions_fine_acc: 0.7966 - val_loss: 2.2066 - val_predictions_coarse1_loss: 1.1377 - val_predictions_coarse2_loss: 1.4877 - val_predictions_fine_loss: 2.2066 - val_predictions_coarse1_acc: 0.6452 - val_predictions_coarse2_acc: 0.5576 - val_predictions_fine_acc: 0.4498
# Epoch 40/50
# 45000/45000 [==============================] - 95s 2ms/step - loss: 0.6584 - predictions_coarse1_loss: 0.4403 - predictions_coarse2_loss: 0.6345 - predictions_fine_loss: 0.6584 - predictions_coarse1_acc: 0.8593 - predictions_coarse2_acc: 0.7844 - predictions_fine_acc: 0.8155 - val_loss: 2.2145 - val_predictions_coarse1_loss: 1.1789 - val_predictions_coarse2_loss: 1.5083 - val_predictions_fine_loss: 2.2145 - val_predictions_coarse1_acc: 0.6288 - val_predictions_coarse2_acc: 0.5544 - val_predictions_fine_acc: 0.4418
# Epoch 41/50
# 45000/45000 [==============================] - 95s 2ms/step - loss: 0.6051 - predictions_coarse1_loss: 0.4281 - predictions_coarse2_loss: 0.6241 - predictions_fine_loss: 0.6051 - predictions_coarse1_acc: 0.8640 - predictions_coarse2_acc: 0.7883 - predictions_fine_acc: 0.8331 - val_loss: 2.2286 - val_predictions_coarse1_loss: 1.1751 - val_predictions_coarse2_loss: 1.5223 - val_predictions_fine_loss: 2.2286 - val_predictions_coarse1_acc: 0.6306 - val_predictions_coarse2_acc: 0.5430 - val_predictions_fine_acc: 0.4460
# Epoch 42/50
# 45000/45000 [==============================] - 95s 2ms/step - loss: 0.5523 - predictions_coarse1_loss: 0.4293 - predictions_coarse2_loss: 0.6127 - predictions_fine_loss: 0.5523 - predictions_coarse1_acc: 0.8646 - predictions_coarse2_acc: 0.7939 - predictions_fine_acc: 0.8527 - val_loss: 2.2403 - val_predictions_coarse1_loss: 1.1778 - val_predictions_coarse2_loss: 1.5104 - val_predictions_fine_loss: 2.2403 - val_predictions_coarse1_acc: 0.6306 - val_predictions_coarse2_acc: 0.5464 - val_predictions_fine_acc: 0.4506
# Epoch 43/50
# 45000/45000 [==============================] - 95s 2ms/step - loss: 0.5072 - predictions_coarse1_loss: 0.4257 - predictions_coarse2_loss: 0.6049 - predictions_fine_loss: 0.5072 - predictions_coarse1_acc: 0.8653 - predictions_coarse2_acc: 0.7979 - predictions_fine_acc: 0.8684 - val_loss: 2.2235 - val_predictions_coarse1_loss: 1.1658 - val_predictions_coarse2_loss: 1.5075 - val_predictions_fine_loss: 2.2235 - val_predictions_coarse1_acc: 0.6354 - val_predictions_coarse2_acc: 0.5548 - val_predictions_fine_acc: 0.4490
# Epoch 44/50
# 45000/45000 [==============================] - 95s 2ms/step - loss: 0.4643 - predictions_coarse1_loss: 0.4221 - predictions_coarse2_loss: 0.5917 - predictions_fine_loss: 0.4643 - predictions_coarse1_acc: 0.8664 - predictions_coarse2_acc: 0.8028 - predictions_fine_acc: 0.8838 - val_loss: 2.2278 - val_predictions_coarse1_loss: 1.1629 - val_predictions_coarse2_loss: 1.5158 - val_predictions_fine_loss: 2.2278 - val_predictions_coarse1_acc: 0.6346 - val_predictions_coarse2_acc: 0.5504 - val_predictions_fine_acc: 0.4464
# Epoch 45/50
# 45000/45000 [==============================] - 95s 2ms/step - loss: 0.4322 - predictions_coarse1_loss: 0.4238 - predictions_coarse2_loss: 0.5893 - predictions_fine_loss: 0.4322 - predictions_coarse1_acc: 0.8664 - predictions_coarse2_acc: 0.8026 - predictions_fine_acc: 0.8917 - val_loss: 2.2744 - val_predictions_coarse1_loss: 1.1576 - val_predictions_coarse2_loss: 1.5223 - val_predictions_fine_loss: 2.2744 - val_predictions_coarse1_acc: 0.6428 - val_predictions_coarse2_acc: 0.5454 - val_predictions_fine_acc: 0.4436
# Epoch 46/50
# 45000/45000 [==============================] - 95s 2ms/step - loss: 0.3893 - predictions_coarse1_loss: 0.4170 - predictions_coarse2_loss: 0.5781 - predictions_fine_loss: 0.3893 - predictions_coarse1_acc: 0.8696 - predictions_coarse2_acc: 0.8060 - predictions_fine_acc: 0.9052 - val_loss: 2.3153 - val_predictions_coarse1_loss: 1.1732 - val_predictions_coarse2_loss: 1.5373 - val_predictions_fine_loss: 2.3153 - val_predictions_coarse1_acc: 0.6338 - val_predictions_coarse2_acc: 0.5506 - val_predictions_fine_acc: 0.4502
#
# Epoch 00046: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 47/50
# 45000/45000 [==============================] - 95s 2ms/step - loss: 0.3317 - predictions_coarse1_loss: 0.4007 - predictions_coarse2_loss: 0.5513 - predictions_fine_loss: 0.3317 - predictions_coarse1_acc: 0.8760 - predictions_coarse2_acc: 0.8186 - predictions_fine_acc: 0.9257 - val_loss: 2.2274 - val_predictions_coarse1_loss: 1.1522 - val_predictions_coarse2_loss: 1.4923 - val_predictions_fine_loss: 2.2274 - val_predictions_coarse1_acc: 0.6410 - val_predictions_coarse2_acc: 0.5574 - val_predictions_fine_acc: 0.4586
# Epoch 48/50
# 45000/45000 [==============================] - 95s 2ms/step - loss: 0.3038 - predictions_coarse1_loss: 0.3933 - predictions_coarse2_loss: 0.5337 - predictions_fine_loss: 0.3038 - predictions_coarse1_acc: 0.8785 - predictions_coarse2_acc: 0.8257 - predictions_fine_acc: 0.9341 - val_loss: 2.2270 - val_predictions_coarse1_loss: 1.1666 - val_predictions_coarse2_loss: 1.5007 - val_predictions_fine_loss: 2.2270 - val_predictions_coarse1_acc: 0.6324 - val_predictions_coarse2_acc: 0.5516 - val_predictions_fine_acc: 0.4566
# Epoch 49/50
# 45000/45000 [==============================] - 95s 2ms/step - loss: 0.2845 - predictions_coarse1_loss: 0.3971 - predictions_coarse2_loss: 0.5384 - predictions_fine_loss: 0.2845 - predictions_coarse1_acc: 0.8758 - predictions_coarse2_acc: 0.8243 - predictions_fine_acc: 0.9411 - val_loss: 2.2435 - val_predictions_coarse1_loss: 1.1588 - val_predictions_coarse2_loss: 1.5047 - val_predictions_fine_loss: 2.2435 - val_predictions_coarse1_acc: 0.6402 - val_predictions_coarse2_acc: 0.5536 - val_predictions_fine_acc: 0.4572
# Epoch 50/50
# 45000/45000 [==============================] - 95s 2ms/step - loss: 0.2677 - predictions_coarse1_loss: 0.3886 - predictions_coarse2_loss: 0.5292 - predictions_fine_loss: 0.2677 - predictions_coarse1_acc: 0.8818 - predictions_coarse2_acc: 0.8273 - predictions_fine_acc: 0.9460 - val_loss: 2.2428 - val_predictions_coarse1_loss: 1.1920 - val_predictions_coarse2_loss: 1.5161 - val_predictions_fine_loss: 2.2428 - val_predictions_coarse1_acc: 0.6322 - val_predictions_coarse2_acc: 0.5508 - val_predictions_fine_acc: 0.4584

# %%
model.evaluate(test_features, [y_test_c_cat1,y_test_c_cat2, y_test_cat])
# Out:
# 10000/10000 [==============================] - 13s 1ms/step
# [2.217876749420166,
#  1.207866297340393,
#  1.5306305707931518,
#  2.217876749420166,
#  0.6231,
#  0.5533,
#  0.4647]

# %%
print('Total training time: {}'.format(training_time))
# Out:
# Total training time: 4835.388230085373

# %%
model.save('drive/TCC-ITAU/cifar-100/models/guide-net.h5')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-3f59c2048e41> in <module>()
# ----> 1 model.save('drive/TCC-ITAU/cifar-100/models/guide-net.h5')
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/network.py in save(self, filepath, overwrite, include_optimizer)
#    1088             raise NotImplementedError
#    1089         from ..models import save_model
# -> 1090         save_model(self, filepath, overwrite, include_optimizer)
#    1091
#    1092     def save_weights(self, filepath, overwrite=True):
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py in save_model(model, filepath, overwrite, include_optimizer)
#     380
#     381     try:
# --> 382         _serialize_model(model, f, include_optimizer)
#     383     finally:
#     384         if opened_new_file:
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py in _serialize_model(model, f, include_optimizer)
#     136                 'sample_weight_mode': model.sample_weight_mode,
#     137                 'loss_weights': model.loss_weights,
# --> 138             }, default=get_json_type).encode('utf8')
#     139             symbolic_weights = getattr(model.optimizer, 'weights')
#     140             if symbolic_weights:
#
# /usr/lib/python3.6/json/__init__.py in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     236         check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     237         separators=separators, default=default, sort_keys=sort_keys,
# --> 238         **kw).encode(obj)
#     239
#     240
#
# /usr/lib/python3.6/json/encoder.py in encode(self, o)
#     197         # exceptions aren't as detailed.  The list call should be roughly
#     198         # equivalent to the PySequence_Fast that ''.join() would do.
# --> 199         chunks = self.iterencode(o, _one_shot=True)
#     200         if not isinstance(chunks, (list, tuple)):
#     201             chunks = list(chunks)
#
# /usr/lib/python3.6/json/encoder.py in iterencode(self, o, _one_shot)
#     255                 self.key_separator, self.item_separator, self.sort_keys,
#     256                 self.skipkeys, _one_shot)
# --> 257         return _iterencode(o, 0)
#     258
#     259 def _make_iterencode(markers, _default, _encoder, _indent, _floatstr,
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py in get_json_type(obj)
#      72             return obj.__name__
#      73
# ---> 74         raise TypeError('Not JSON Serializable: %s' % (obj,))
#      75
#      76     from .. import __version__ as keras_version
#
# TypeError: Not JSON Serializable: <tf.Variable 'alpha_1:0' shape=() dtype=float32_ref>
